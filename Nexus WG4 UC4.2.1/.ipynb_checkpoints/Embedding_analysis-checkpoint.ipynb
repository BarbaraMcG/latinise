# %% [markdown]
# # Semantic change in LatinISE (terms related to revolution)
#
#
# Barbara McGillivray, Paola Marongiu

# %% [markdown]
# This notebook contains the code used for the word embedding analysis of the terms related to revolution for the use case 4.2.1 of the working group 4 of the COST Action “Nexus Linguarum” (CA 18209).

# %% [markdown]
# ## Initialisation

# %% [markdown]
# I install version 4.0 of gensim, which is needed to train the word2vec models.

# %%
# !pip install gensim==4.0
# !pip install plotly
# Out:
# Requirement already satisfied: gensim==4.0 in /Users/barbaramcgillivray/opt/anaconda3/lib/python3.8/site-packages (4.0.0)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/barbaramcgillivray/opt/anaconda3/lib/python3.8/site-packages (from gensim==4.0) (5.2.1)
# Requirement already satisfied: numpy>=1.11.3 in /Users/barbaramcgillivray/opt/anaconda3/lib/python3.8/site-packages (from gensim==4.0) (1.20.1)
# Requirement already satisfied: scipy>=0.18.1 in /Users/barbaramcgillivray/opt/anaconda3/lib/python3.8/site-packages (from gensim==4.0) (1.6.2)
#
# [notice] A new release of pip available: 22.1.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: plotly in /Users/barbaramcgillivray/opt/anaconda3/lib/python3.8/site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/barbaramcgillivray/opt/anaconda3/lib/python3.8/site-packages (from plotly) (8.0.1)
#
# [notice] A new release of pip available: 22.1.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# Import libraries

# %%
import os 
#from bs4 import BeautifulSoup
import csv
import numpy as np
import pandas as pd
#from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer
#from nltk.corpus import stopwords
#import nltk
#nltk.download('punkt')
#nltk.download('stopwords')
from gensim.models import FastText
import gensim
from scipy import spatial
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import time
from sklearn.decomposition import PCA
import spacy
import plotly.express as px
import re
from statistics import mean
#from langdetect import detect
# to make our plot outputs appear and be stored within the notebook:
# %matplotlib inline

# %% [markdown]
# # Parameters

# %% [markdown]
# I set the parameters of the analysis.

# %%
lemmas_or_tokens = "lemmas" # this can be "lemmas" or "tokens"

# %% [markdown]
# ## Reading the files

# %% [markdown]
# I define the name of the folders:

# %%
#dir_in = os.path.join("/home", "paola_user", "Scaricati", "LatinISE")
dir_in = os.path.join("/Users", "barbaramcgillivray", "Library", "CloudStorage", "OneDrive-King'sCollegeLondon", "Research", "2022", "Nexus Linguarum WG4 UC4.2", "LatinISE")
dir_out = os.path.join(dir_in, "semantic_change_output_nexus")

# %% [markdown]
# I define the list of all files:

# %%
files = os.listdir(os.path.join(dir_in, "preprocessed_"+lemmas_or_tokens))

# %% [markdown]
# How many files are in the folder?

# %%
len(files)
# Out:
# 1268

# %% [markdown]
# We only want IntraText files: (why? because some texts are repeated. add medical texts not in IntraText)

# %%
files = [f for f in files[:] if "IT" in f]
len(files)
# Out:
# 670

# %% [markdown]
# I read the metadata file:

# %%
metadata_df = pd.read_csv(os.path.join(dir_in, 'latinise_metadata.csv'), sep = ",")
metadata_df = metadata_df[metadata_df['id'].str.startswith("IT")] #we want all the files from IT (one medical text is not among IntraText)
#metadata_df = metadata_df[metadata_df['date'] < 1000] #stop at x year
metadata_df
# Out:
#                 id                          title  \
# 18      IT-LAT0001                        Vulgata
# 19      IT-LAT0537                   Ars amatoria
# 20      IT-LAT0011            S. Benedicti Regula
# 21      IT-LAT0012   In psalmis Davidis expositio
# 22      IT-LAT0014                Adoro te devote
# ...            ...                            ...
# 683   IT-LAT0534_1  De origine et situ Germanorum
# 684   IT-LAT0534_2        De vita Iulii Agricolae
# 685   IT-LAT0534_3         Dialogus de oratoribus
# 686   IT-LAT0534_4                      Historiae
# 1265    IT-LAT0202                  Institutiones
#
#                                                 creator    date    type  \
# 18                                           Hieronymus   382.0  poetry
# 19                                Ovidius Naso, Publius    -9.0  poetry
# 20                                 Benedictus Nursianus   524.0   prose
# 21                              Thomas Aquinas: Sanctus  1254.0   prose
# 22                              Thomas Aquinas: Sanctus  1254.0  poetry
# ...                                                 ...     ...     ...
# 683                  Tacitus, Publius (Gaius) Cornelius   116.0   prose
# 684                  Tacitus, Publius (Gaius) Cornelius   116.0   prose
# 685                  Tacitus, Publius (Gaius) Cornelius   116.0   prose
# 686                  Tacitus, Publius (Gaius) Cornelius   116.0   prose
# 1265  Iustinianus, Caesar Flavius (Imperator Iustini...   533.0   prose
#
#                            file
# 18      lat_0382_IT-LAT0001.txt
# 19      lat_-009_IT-LAT0537.txt
# 20      lat_0524_IT-LAT0011.txt
# 21      lat_1254_IT-LAT0012.txt
# 22      lat_1254_IT-LAT0014.txt
# ...                         ...
# 683   lat_0116_IT-LAT0534_1.txt
# 684   lat_0116_IT-LAT0534_2.txt
# 685   lat_0116_IT-LAT0534_3.txt
# 686   lat_0116_IT-LAT0534_4.txt
# 1265    lat_0533_IT-LAT0202.txt
#
# [670 rows x 6 columns]

# %%
metadata_df.shape
# Out:
# (670, 6)

# %%
metadata_df.columns
# Out:
# Index(['id', 'title', 'creator', 'date', 'type', 'file'], dtype='object')

# %%
metadata_df['date'].describe
# Out:
# <bound method NDFrame.describe of 18       382.0
# 19        -9.0
# 20       524.0
# 21      1254.0
# 22      1254.0
#          ...
# 683      116.0
# 684      116.0
# 685      116.0
# 686      116.0
# 1265     533.0
# Name: date, Length: 670, dtype: float64>

# %%
metadata_df.dtypes
# Out:
# id          object
# title       object
# creator     object
# date       float64
# type        object
# file        object
# dtype: object

# %% [markdown]
# Convert date to integer

# %%
metadata_df['date'] = metadata_df['date'].astype(int)
metadata_df.dtypes
# Out:
# id         object
# title      object
# creator    object
# date        int64
# type       object
# file       object
# dtype: object

# %%
metadata_df.head
# Out:
# <bound method NDFrame.head of                 id                          title  \
# 18      IT-LAT0001                        Vulgata
# 19      IT-LAT0537                   Ars amatoria
# 20      IT-LAT0011            S. Benedicti Regula
# 21      IT-LAT0012   In psalmis Davidis expositio
# 22      IT-LAT0014                Adoro te devote
# ...            ...                            ...
# 683   IT-LAT0534_1  De origine et situ Germanorum
# 684   IT-LAT0534_2        De vita Iulii Agricolae
# 685   IT-LAT0534_3         Dialogus de oratoribus
# 686   IT-LAT0534_4                      Historiae
# 1265    IT-LAT0202                  Institutiones
#
#                                                 creator  date    type  \
# 18                                           Hieronymus   382  poetry
# 19                                Ovidius Naso, Publius    -9  poetry
# 20                                 Benedictus Nursianus   524   prose
# 21                              Thomas Aquinas: Sanctus  1254   prose
# 22                              Thomas Aquinas: Sanctus  1254  poetry
# ...                                                 ...   ...     ...
# 683                  Tacitus, Publius (Gaius) Cornelius   116   prose
# 684                  Tacitus, Publius (Gaius) Cornelius   116   prose
# 685                  Tacitus, Publius (Gaius) Cornelius   116   prose
# 686                  Tacitus, Publius (Gaius) Cornelius   116   prose
# 1265  Iustinianus, Caesar Flavius (Imperator Iustini...   533   prose
#
#                            file
# 18      lat_0382_IT-LAT0001.txt
# 19      lat_-009_IT-LAT0537.txt
# 20      lat_0524_IT-LAT0011.txt
# 21      lat_1254_IT-LAT0012.txt
# 22      lat_1254_IT-LAT0014.txt
# ...                         ...
# 683   lat_0116_IT-LAT0534_1.txt
# 684   lat_0116_IT-LAT0534_2.txt
# 685   lat_0116_IT-LAT0534_3.txt
# 686   lat_0116_IT-LAT0534_4.txt
# 1265    lat_0533_IT-LAT0202.txt
#
# [670 rows x 6 columns]>

# %% [markdown]
# Number of works per year:

# %%
metadata_df0 = metadata_df.groupby(['date']).count()
metadata_df0 = metadata_df0['id']
metadata_df0
# Out:
# date
# -450     1
# -229     1
# -199     3
# -185     1
# -149     2
#         ..
#  2001    4
#  2002    2
#  2003    1
#  2004    1
#  2005    1
# Name: id, Length: 263, dtype: int64

# %%
ax = metadata_df0.plot(kind='bar', figsize=(20,16), color="indigo", fontsize=10);
#ax.set_alpha(0.5)
ax.set_title("Number of works per year", fontsize=22)
plt.show()

# %% [markdown]
# ## Training embeddings for the whole corpus

# %% [markdown]
# Function for printing the vocabulary of a model

# %%
def print_vocab(model, top_n = None):
  if model == '':
    print("Empty model!")
  else:
    count = 0
    if top_n is not None:
      for index, word in enumerate(model.wv.index_to_key):
        count+= 1
        if count < top_n:
          print(f"word #{index}/{len(model.wv.index_to_key)} is {word}")
    else:
      for index, word in enumerate(model.wv.index_to_key):
        print(f"word #{index}/{len(model.wv.index_to_key)} is {word}")

# %% [markdown]
# Function that converts dates into the standard format:

# %%
def convert_dates(sign, date0):

    if sign == "0":
        if date0 == 0:
            final_date = "+0000"
        elif date0 < 100:
            final_date = "+" + "00" + str(date0)
            #print("1-final_date", final_date)
        elif date0 < 1000:
            final_date = "+" + "0" + str(date0)
            #print("2-final_date", final_date)
        else:
            final_date = "+" + str(date0)
            #print("3-final_date", final_date)
    else:
        if date0 == 0:
            final_date = "+0000"
        elif date0 < 100:
            final_date = str(sign) + "00" + str(date0)
            #print("1-final_date", final_date)
        elif date0 < 1000:
            final_date = str(sign) + "0" + str(date0)
            #print("2-final_date", final_date)
        else:
            final_date = str(sign) + str(date0)
            #print("3-final_date", final_date)

    if final_date.startswith("+"):
        final_date = final_date.replace("+", "")
    return final_date

# %% [markdown]
# #### Stopwords exclusion and further filtering

# %% [markdown]
# I exclude punctuation marks:

# %%
punctuation = ['.', ',', '...', ';', ':', '?']

# %% [markdown]
# I create a list of lists, containing the tokens of each sentence in the whole corpus:

# %%
corpus = list()
files_corpus = metadata_df
for index, df_line in files_corpus.iterrows():
    #print("line:",df_line['id'], df_line['time_interval'])
    sign = "+"
    #print(df_line['date'])
    if df_line['date'] < 0:
        sign = "-"
    #print("date:", convert_dates(sign, abs(df_line['date'])))
    file_name = 'lat_'+str(convert_dates(sign, abs(df_line['date'])))+"_"+str(df_line['id'])+'.txt'
    print(file_name)
    file = open(os.path.join(dir_in, "preprocessed_"+lemmas_or_tokens, file_name), 'r')
    sentences_this_file = list()
    while True:
        line = file.readline().strip()
        if line != "":
            #sentences_this_file.append(line.split(" "))
            #sentences_this_file.append([token for token in line.split(" ") if token not in punctuation])
            corpus.append([token for token in line.split(" ") if token not in punctuation])
        # if line is empty end of file is reached
        if not line:
            break
    file.close()
corpus.append(sentences_this_file)
# Out:
# lat_0382_IT-LAT0001.txt
# lat_-009_IT-LAT0537.txt
# lat_0524_IT-LAT0011.txt
# lat_1254_IT-LAT0012.txt
# lat_1254_IT-LAT0014.txt
# lat_0399_IT-LAT0015.txt
# lat_0391_IT-LAT0016.txt
# lat_1224_IT-LAT0017.txt
# lat_1150_IT-LAT0018.txt
# lat_2000_IT-LAT0021.txt
# lat_1517_IT-LAT0022.txt
# lat_1547_IT-LAT0023.txt
# lat_1530_IT-LAT0024.txt
# lat_1260_IT-LAT0025.txt
# lat_1250_IT-LAT0026.txt
# lat_1998_IT-LAT0027.txt
# lat_-0049_IT-LAT0029.txt
# lat_2001_IT-LAT0030.txt
# lat_1992_IT-LAT0031.txt
# lat_0158_IT-LAT0043.txt
# lat_0049_IT-LAT0045.txt
# lat_-0045_IT-LAT0047.txt
# lat_0050_IT-LAT0051.txt
# lat_0121_IT-LAT0054.txt
# lat_-0049_IT-LAT0056.txt
# lat_0199_IT-LAT0058.txt
# lat_0387_IT-LAT0061.txt
# lat_0197_IT-LAT0062.txt
# lat_0050_IT-LAT0563.txt
# lat_0062_IT-LAT0071.txt
# lat_0049_IT-LAT0072.txt
# lat_0063_IT-LAT0073.txt
# lat_0000_IT-LAT0075.txt
# lat_0062_IT-LAT0078.txt
# lat_0058_IT-LAT0079.txt
# lat_0385_IT-LAT0574.txt
# lat_0040_IT-LAT0083.txt
# lat_0385_IT-LAT0574_1.txt
# lat_0385_IT-LAT0574_2.txt
# lat_-0080_IT-LAT0093.txt
# lat_-0079_IT-LAT0094.txt
# lat_-0061_IT-LAT0095.txt
# lat_-0051_IT-LAT0096.txt
# lat_-0043_IT-LAT0097.txt
# lat_-0043_IT-LAT0098.txt
# lat_0385_IT-LAT0574_3.txt
# lat_-0043_IT-LAT0101.txt
# lat_0000_IT-LAT0102.txt
# lat_0385_IT-LAT0574_4.txt
# lat_-0049_IT-LAT0108.txt
# lat_0065_IT-LAT0109.txt
# lat_0100_IT-LAT0111.txt
# lat_0043_IT-LAT0112.txt
# lat_0050_IT-LAT0114.txt
# lat_0350_IT-LAT0115.txt
# lat_0041_IT-LAT0116.txt
# lat_0385_IT-LAT0574_5.txt
# lat_0250_IT-LAT0118.txt
# lat_-002_IT-LAT0119.txt
# lat_0113_IT-LAT0120.txt
# lat_0362_IT-LAT0121.txt
# lat_-0075_IT-LAT0122.txt
# lat_-0065_IT-LAT0124.txt
# lat_-0062_IT-LAT0125.txt
# lat_-0062_IT-LAT0126.txt
# lat_0000_IT-LAT0127.txt
# lat_-0058_IT-LAT0128.txt
# lat_0382_IT-LAT0001_1.txt
# lat_0385_IT-LAT0574_6.txt
# lat_0385_IT-LAT0574_7.txt
# lat_-0055_IT-LAT0133.txt
# lat_-0055_IT-LAT0134.txt
# lat_-0055_IT-LAT0135.txt
# lat_-0053_IT-LAT0136.txt
# lat_-0054_IT-LAT0137.txt
# lat_-0045_IT-LAT0138.txt
# lat_-0045_IT-LAT0139.txt
# lat_-0044_IT-LAT0140.txt
# lat_0385_IT-LAT0574_8.txt
# lat_-001_IT-LAT0142.txt
# lat_0029_IT-LAT0148.txt
# lat_0385_IT-LAT0574_9.txt
# lat_0050_IT-LAT0588.txt
# lat_0050_IT-LAT0588_1.txt
# lat_0800_IT-LAT0911.txt
# lat_-0043_IT-LAT0155.txt
# lat_0800_IT-LAT0911_1.txt
# lat_0800_IT-LAT0911_2.txt
# lat_0800_IT-LAT0911_3.txt
# lat_0800_IT-LAT0911_4.txt
# lat_0800_IT-LAT0911_5.txt
# lat_0800_IT-LAT0911_6.txt
# lat_-0045_IT-LAT0922.txt
# lat_-0045_IT-LAT0922_1.txt
# lat_-0045_IT-LAT0922_2.txt
# lat_-0045_IT-LAT0922_3.txt
# lat_0000_IT-LAT0181.txt
# lat_-0045_IT-LAT0922_4.txt
# lat_-0045_IT-LAT0922_5.txt
# lat_0390_IT-LAT0189.txt
# lat_0550_IT-LAT0196.txt
# lat_-0045_IT-LAT0922_6.txt
# lat_0250_IT-LAT0201.txt
# lat_-0045_IT-LAT0922_7.txt
# lat_0300_IT-LAT0203.txt
# lat_0250_IT-LAT0204.txt
# lat_-0045_IT-LAT0922_8.txt
# lat_-0045_IT-LAT0922_9.txt
# lat_-0045_IT-LAT0217.txt
# lat_-0059_IT-LAT0218.txt
# lat_-0045_IT-LAT0922_10.txt
# lat_-0055_IT-LAT0220.txt
# lat_-0084_IT-LAT0221.txt
# lat_-0045_IT-LAT0922_11.txt
# lat_0054_IT-LAT0228.txt
# lat_-0045_IT-LAT0922_12.txt
# lat_0062_IT-LAT0230.txt
# lat_-0045_IT-LAT0922_13.txt
# lat_0350_IT-LAT0233.txt
# lat_-0199_IT-LAT0236.txt
# lat_0065_IT-LAT0237.txt
# lat_0350_IT-LAT0238.txt
# lat_0050_IT-LAT0239.txt
# lat_-0089_IT-LAT0240.txt
# lat_-0049_IT-LAT0241.txt
# lat_-0049_IT-LAT0242.txt
# lat_0562_IT-LAT0243.txt
# lat_1428_IT-LAT0245.txt
# lat_0197_IT-LAT0246.txt
# lat_0198_IT-LAT0248.txt
# lat_0540_IT-LAT0250.txt
# lat_0535_IT-LAT0251.txt
# lat_0535_IT-LAT0252.txt
# lat_-0047_IT-LAT0254.txt
# lat_-0044_IT-LAT0255.txt
# lat_0198_IT-LAT0256.txt
# lat_-0051_IT-LAT0257.txt
# lat_0350_IT-LAT0261.txt
# lat_0350_IT-LAT0262.txt
# lat_0350_IT-LAT0263.txt
# lat_0300_IT-LAT0264.txt
# lat_0050_IT-LAT0265.txt
# lat_0050_IT-LAT0266.txt
# lat_0150_IT-LAT0267.txt
# lat_0318_IT-LAT0268.txt
# lat_0400_IT-LAT0270.txt
# lat_-0049_IT-LAT0272.txt
# lat_1350_IT-LAT0277.txt
# lat_0013_IT-LAT0278.txt
# lat_1254_IT-LAT0279.txt
# lat_-0049_IT-LAT0284.txt
# lat_-0450_IT-LAT0285.txt
# lat_0350_IT-LAT0286.txt
# lat_-0045_IT-LAT0922_14.txt
# lat_-0045_IT-LAT0922_15.txt
# lat_0550_IT-LAT0990.txt
# lat_1312_IT-LAT0291.txt
# lat_1278_IT-LAT0292.txt
# lat_0387_IT-LAT0315.txt
# lat_0394_IT-LAT0316.txt
# lat_0387_IT-LAT0317.txt
# lat_0387_IT-LAT0318.txt
# lat_0387_IT-LAT0319.txt
# lat_-0044_IT-LAT0320.txt
# lat_0050_IT-LAT0325.txt
# lat_0400_IT-LAT0329.txt
# lat_0091_IT-LAT0332.txt
# lat_0450_IT-LAT0333.txt
# lat_0450_IT-LAT0334.txt
# lat_0450_IT-LAT0336.txt
# lat_0420_IT-LAT0337.txt
# lat_0792_IT-LAT0338.txt
# lat_0100_IT-LAT0339.txt
# lat_0100_IT-LAT0340.txt
# lat_0100_IT-LAT0341.txt
# lat_0100_IT-LAT0342.txt
# lat_0100_IT-LAT0345.txt
# lat_0100_IT-LAT0346.txt
# lat_0100_IT-LAT0347.txt
# lat_0100_IT-LAT0348.txt
# lat_0100_IT-LAT0349.txt
# lat_0205_IT-LAT0350.txt
# lat_0300_IT-LAT0351.txt
# lat_0350_IT-LAT0353.txt
# lat_0050_IT-LAT0355.txt
# lat_0759_IT-LAT0357.txt
# lat_0759_IT-LAT0358.txt
# lat_0150_IT-LAT0360.txt
# lat_0350_IT-LAT0361.txt
# lat_0350_IT-LAT0362.txt
# lat_0350_IT-LAT0363.txt
# lat_0350_IT-LAT0364.txt
# lat_0350_IT-LAT0365.txt
# lat_0350_IT-LAT0366.txt
# lat_0350_IT-LAT0367.txt
# lat_-0091_IT-LAT0370.txt
# lat_1450_IT-LAT0371.txt
# lat_-0149_IT-LAT0372.txt
# lat_0398_IT-LAT0373.txt
# lat_-0049_IT-LAT0377.txt
# lat_001_IT-LAT0378.txt
# lat_-0199_IT-LAT0380.txt
# lat_1998_IT-LAT0381.txt
# lat_0030_IT-LAT0382.txt
# lat_0438_IT-LAT0383.txt
# lat_-0079_IT-LAT0384.txt
# lat_0818_IT-LAT0386.txt
# lat_-0049_IT-LAT0393.txt
# lat_0550_IT-LAT0990_1.txt
# lat_0393_IT-LAT0397.txt
# lat_0550_IT-LAT0990_2.txt
# lat_0550_IT-LAT0990_3.txt
# lat_0550_IT-LAT0990_4.txt
# lat_0399_IT-LAT0403.txt
# lat_-0199_IT-LAT0405.txt
# lat_0150_IT-LAT0406.txt
# lat_0150_IT-LAT0407.txt
# lat_0550_IT-LAT0990_5.txt
# lat_0403_IT-LAT0410.txt
# lat_0250_IT-LAT0413.txt
# lat_0450_IT-LAT0414.txt
# lat_0550_IT-LAT0990_6.txt
# lat_0704_IT-LAT0419.txt
# lat_0704_IT-LAT0420.txt
# lat_0704_IT-LAT0421.txt
# lat_0704_IT-LAT0422.txt
# lat_0721_IT-LAT0423.txt
# lat_0050_IT-LAT0425.txt
# lat_1110_IT-LAT0428.txt
# lat_0550_IT-LAT0429.txt
# lat_0550_IT-LAT0431.txt
# lat_0550_IT-LAT0433.txt
# lat_0550_IT-LAT0435.txt
# lat_2001_IT-LAT0437.txt
# lat_1435_IT-LAT0438.txt
# lat_1319_IT-LAT0441.txt
# lat_1293_IT-LAT0442.txt
# lat_1320_IT-LAT0443.txt
# lat_1310_IT-LAT0444.txt
# lat_1304_IT-LAT0445.txt
# lat_2002_IT-LAT0446.txt
# lat_2001_IT-LAT0447.txt
# lat_0197_IT-LAT0448.txt
# lat_1994_IT-LAT0449.txt
# lat_1438_IT-LAT0450.txt
# lat_1438_IT-LAT0451.txt
# lat_0550_IT-LAT0990_7.txt
# lat_1438_IT-LAT0453.txt
# lat_0550_IT-LAT0990_8.txt
# lat_1998_IT-LAT0456.txt
# lat_0950_IT-LAT0458.txt
# lat_0850_IT-LAT0459.txt
# lat_0800_IT-LAT0461.txt
# lat_1141_IT-LAT0463.txt
# lat_1550_IT-LAT0465.txt
# lat_1242_IT-LAT0466.txt
# lat_0200_IT-LAT0471.txt
# lat_0909_IT-LAT0472.txt
# lat_1098_IT-LAT0477.txt
# lat_1096_IT-LAT0478.txt
# lat_1150_IT-LAT0479.txt
# lat_1766_IT-LAT0480.txt
# lat_1050_IT-LAT0481.txt
# lat_0562_IT-LAT0482.txt
# lat_1492_IT-LAT0483.txt
# lat_0775_IT-LAT0486.txt
# lat_1526_IT-LAT0488.txt
# lat_1550_IT-LAT0489.txt
# lat_0382_IT-LAT0001_2.txt
# lat_0838_IT-LAT0494.txt
# lat_1410_IT-LAT0495.txt
# lat_1200_IT-LAT0496.txt
# lat_1098_IT-LAT0497.txt
# lat_1185_IT-LAT0498.txt
# lat_1300_IT-LAT0499.txt
# lat_0833_IT-LAT0500.txt
# lat_1200_IT-LAT0502.txt
# lat_1200_IT-LAT0503.txt
# lat_0382_IT-LAT0001_3.txt
# lat_0382_IT-LAT0001_4.txt
# lat_1125_IT-LAT0506.txt
# lat_1200_IT-LAT0507.txt
# lat_1200_IT-LAT0508.txt
# lat_1200_IT-LAT0509.txt
# lat_1200_IT-LAT0510.txt
# lat_1200_IT-LAT0511.txt
# lat_1200_IT-LAT0512.txt
# lat_1200_IT-LAT0513.txt
# lat_1200_IT-LAT0514.txt
# lat_1200_IT-LAT0515.txt
# lat_1200_IT-LAT0516.txt
# lat_1200_IT-LAT0517.txt
# lat_1200_IT-LAT0518.txt
# lat_1200_IT-LAT0519.txt
# lat_1200_IT-LAT0520.txt
# lat_1200_IT-LAT0521.txt
# lat_1200_IT-LAT0522.txt
# lat_1200_IT-LAT0523.txt
# lat_1118_IT-LAT0524.txt
# lat_1200_IT-LAT0525.txt
# lat_1200_IT-LAT0526.txt
# lat_1200_IT-LAT0527.txt
# lat_1200_IT-LAT0528.txt
# lat_0116_IT-LAT0534.txt
# lat_-0051_IT-LAT0535.txt
# lat_2002_IT-LAT0536.txt
# lat_0382_IT-LAT0001_5.txt
# lat_0382_IT-LAT0001_6.txt
# lat_1545_IT-LAT0546.txt
# lat_1524_IT-LAT0547.txt
# lat_1215_IT-LAT0548.txt
# lat_0382_IT-LAT0001_7.txt
# lat_0382_IT-LAT0001_8.txt
# lat_0382_IT-LAT0001_9.txt
# lat_0382_IT-LAT0001_10.txt
# lat_0382_IT-LAT0001_11.txt
# lat_0382_IT-LAT0001_12.txt
# lat_1546_IT-LAT0558.txt
# lat_1519_IT-LAT0559.txt
# lat_1516_IT-LAT0560.txt
# lat_1506_IT-LAT0561.txt
# lat_0050_IT-LAT0563_1.txt
# lat_0382_IT-LAT0001_13.txt
# lat_0382_IT-LAT0001_14.txt
# lat_0382_IT-LAT0001_15.txt
# lat_1820_IT-LAT0567.txt
# lat_1360_IT-LAT0568.txt
# lat_1530_IT-LAT0569.txt
# lat_1517_IT-LAT0570.txt
# lat_1998_IT-LAT0571.txt
# lat_1998_IT-LAT0572.txt
# lat_1815_IT-LAT0573.txt
# lat_1478_IT-LAT0575.txt
# lat_1486_IT-LAT0576.txt
# lat_1445_IT-LAT0577.txt
# lat_1750_IT-LAT0579.txt
# lat_1050_IT-LAT0580.txt
# lat_1868_IT-LAT0581.txt
# lat_1868_IT-LAT0582.txt
# lat_1869_IT-LAT0583.txt
# lat_1065_IT-LAT0584.txt
# lat_0382_IT-LAT0001_16.txt
# lat_1494_IT-LAT0586.txt
# lat_1550_IT-LAT0587.txt
# lat_0050_IT-LAT0588_2.txt
# lat_1632_IT-LAT0590.txt
# lat_1668_IT-LAT0591.txt
# lat_0382_IT-LAT0001_17.txt
# lat_0382_IT-LAT0001_18.txt
# lat_0382_IT-LAT0001_19.txt
# lat_1707_IT-LAT0595.txt
# lat_0382_IT-LAT0001_20.txt
# lat_1050_IT-LAT0597.txt
# lat_0382_IT-LAT0001_21.txt
# lat_0382_IT-LAT0001_22.txt
# lat_0382_IT-LAT0001_23.txt
# lat_1150_IT-LAT0604.txt
# lat_1050_IT-LAT0605.txt
# lat_0210_IT-LAT0606.txt
# lat_0250_IT-LAT0607.txt
# lat_0450_IT-LAT0608.txt
# lat_0350_IT-LAT0609.txt
# lat_0426_IT-LAT0610.txt
# lat_0450_IT-LAT0611.txt
# lat_0350_IT-LAT0612.txt
# lat_1150_IT-LAT0616.txt
# lat_0950_IT-LAT0617.txt
# lat_1250_IT-LAT0618.txt
# lat_1088_IT-LAT0619.txt
# lat_1492_IT-LAT0620.txt
# lat_0250_IT-LAT0621.txt
# lat_1150_IT-LAT0622.txt
# lat_1150_IT-LAT0623.txt
# lat_1667_IT-LAT0624.txt
# lat_1695_IT-LAT0625.txt
# lat_1695_IT-LAT0626.txt
# lat_1695_IT-LAT0627.txt
# lat_1695_IT-LAT0628.txt
# lat_1695_IT-LAT0629.txt
# lat_1695_IT-LAT0630.txt
# lat_1695_IT-LAT0631.txt
# lat_0050_IT-LAT0632.txt
# lat_1243_IT-LAT0633.txt
# lat_1650_IT-LAT0634.txt
# lat_1245_IT-LAT0635.txt
# lat_1650_IT-LAT0636.txt
# lat_1550_IT-LAT0637.txt
# lat_1483_IT-LAT0638.txt
# lat_1627_IT-LAT0639.txt
# lat_1550_IT-LAT0640.txt
# lat_1988_IT-LAT0641.txt
# lat_1999_IT-LAT0642.txt
# lat_1450_IT-LAT0643.txt
# lat_1450_IT-LAT0644.txt
# lat_1650_IT-LAT0645.txt
# lat_1494_IT-LAT0646.txt
# lat_1350_IT-LAT0649.txt
# lat_1350_IT-LAT0650.txt
# lat_1650_IT-LAT0652.txt
# lat_1593_IT-LAT0653.txt
# lat_1593_IT-LAT0654.txt
# lat_0382_IT-LAT0001_24.txt
# lat_0382_IT-LAT0001_25.txt
# lat_0382_IT-LAT0001_26.txt
# lat_0382_IT-LAT0001_27.txt
# lat_0382_IT-LAT0001_28.txt
# lat_1150_IT-LAT0663.txt
# lat_1112_IT-LAT0664.txt
# lat_0250_IT-LAT0665.txt
# lat_1504_IT-LAT0666.txt
# lat_1511_IT-LAT0667.txt
# lat_1979_IT-LAT0669.txt
# lat_1500_IT-LAT0674.txt
# lat_1595_IT-LAT0676.txt
# lat_1872_IT-LAT0686.txt
# lat_1073_IT-LAT0687.txt
# lat_1289_IT-LAT0689.txt
# lat_1323_IT-LAT0690.txt
# lat_1324_IT-LAT0691.txt
# lat_1482_IT-LAT0692.txt
# lat_1858_IT-LAT0695.txt
# lat_1226_IT-LAT0700.txt
# lat_1795_IT-LAT0701.txt
# lat_1810_IT-LAT0703.txt
# lat_1600_IT-LAT0705.txt
# lat_1767_IT-LAT0708.txt
# lat_1254_IT-LAT0718.txt
# lat_0350_IT-LAT0719.txt
# lat_0113_IT-LAT0720.txt
# lat_1150_IT-LAT0722.txt
# lat_1200_IT-LAT0723.txt
# lat_1000_IT-LAT0724.txt
# lat_0950_IT-LAT0725.txt
# lat_0390_IT-LAT0726.txt
# lat_0210_IT-LAT0733.txt
# lat_0213_IT-LAT0736.txt
# lat_0198_IT-LAT0737.txt
# lat_0550_IT-LAT0739.txt
# lat_1200_IT-LAT0743.txt
# lat_0205_IT-LAT0744.txt
# lat_0210_IT-LAT0746.txt
# lat_0213_IT-LAT0747.txt
# lat_0198_IT-LAT0749.txt
# lat_0198_IT-LAT0750.txt
# lat_1998_IT-LAT0753.txt
# lat_1999_IT-LAT0754.txt
# lat_0213_IT-LAT0755.txt
# lat_1100_IT-LAT0756.txt
# lat_1990_IT-LAT0758.txt
# lat_1978_IT-LAT0759.txt
# lat_1975_IT-LAT0760.txt
# lat_1975_IT-LAT0761.txt
# lat_2003_IT-LAT0762.txt
# lat_1978_IT-LAT0763.txt
# lat_0419_IT-LAT0768.txt
# lat_1781_IT-LAT0771.txt
# lat_1957_IT-LAT0772.txt
# lat_0850_IT-LAT0773.txt
# lat_1150_IT-LAT0774.txt
# lat_0350_IT-LAT0775.txt
# lat_0350_IT-LAT0776.txt
# lat_1165_IT-LAT0780.txt
# lat_1142_IT-LAT0781.txt
# lat_0871_IT-LAT0782.txt
# lat_0550_IT-LAT0783.txt
# lat_0100_IT-LAT0784.txt
# lat_0650_IT-LAT0785.txt
# lat_0950_IT-LAT0786.txt
# lat_1998_IT-LAT0787.txt
# lat_0213_IT-LAT0788.txt
# lat_1760_IT-LAT0789.txt
# lat_1779_IT-LAT0790.txt
# lat_0550_IT-LAT0791.txt
# lat_0850_IT-LAT0792.txt
# lat_0389_IT-LAT0793.txt
# lat_0382_IT-LAT0001_29.txt
# lat_0382_IT-LAT0001_30.txt
# lat_0382_IT-LAT0001_31.txt
# lat_0382_IT-LAT0001_32.txt
# lat_0382_IT-LAT0001_33.txt
# lat_0382_IT-LAT0001_34.txt
# lat_0382_IT-LAT0001_35.txt
# lat_1997_IT-LAT0806.txt
# lat_0382_IT-LAT0001_36.txt
# lat_0382_IT-LAT0001_37.txt
# lat_0382_IT-LAT0001_38.txt
# lat_0382_IT-LAT0001_39.txt
# lat_1917_IT-LAT0813.txt
# lat_1316_IT-LAT0814.txt
# lat_1148_IT-LAT0815.txt
# lat_1570_IT-LAT0820.txt
# lat_1350_IT-LAT0821.txt
# lat_1223_IT-LAT0823.txt
# lat_1968_IT-LAT0824.txt
# lat_1203_IT-LAT0825.txt
# lat_1204_IT-LAT0826.txt
# lat_1223_IT-LAT0827.txt
# lat_1588_IT-LAT0828.txt
# lat_1909_IT-LAT0829.txt
# lat_1250_IT-LAT0830.txt
# lat_1250_IT-LAT0831.txt
# lat_1242_IT-LAT0832.txt
# lat_1250_IT-LAT0834.txt
# lat_2001_IT-LAT0835.txt
# lat_1980_IT-LAT0836.txt
# lat_1250_IT-LAT0837.txt
# lat_1228_IT-LAT0838.txt
# lat_2004_IT-LAT0839.txt
# lat_2005_IT-LAT0840.txt
# lat_1150_IT-LAT0841.txt
# lat_1165_IT-LAT0842.txt
# lat_0400_IT-LAT0843.txt
# lat_1250_IT-LAT0844.txt
# lat_1150_IT-LAT0845.txt
# lat_0250_IT-LAT0846.txt
# lat_0391_IT-LAT0847.txt
# lat_0650_IT-LAT0848.txt
# lat_-0049_IT-LAT0849.txt
# lat_0350_IT-LAT0850.txt
# lat_0382_IT-LAT0001_40.txt
# lat_1650_IT-LAT0863.txt
# lat_1550_IT-LAT0864.txt
# lat_0250_IT-LAT0865.txt
# lat_0531_IT-LAT0867.txt
# lat_0050_IT-LAT0868.txt
# lat_1196_IT-LAT0869.txt
# lat_1150_IT-LAT0870.txt
# lat_1150_IT-LAT0871.txt
# lat_0300_IT-LAT0873.txt
# lat_1550_IT-LAT0874.txt
# lat_0550_IT-LAT0875.txt
# lat_1200_IT-LAT0876.txt
# lat_1150_IT-LAT0877.txt
# lat_0400_IT-LAT0878.txt
# lat_1486_IT-LAT0879.txt
# lat_0400_IT-LAT0880.txt
# lat_1792_IT-LAT0882.txt
# lat_0030_IT-LAT0883.txt
# lat_1235_IT-LAT0885.txt
# lat_0330_IT-LAT0886.txt
# lat_0841_IT-LAT0888.txt
# lat_0907_IT-LAT0891.txt
# lat_1610_IT-LAT0892.txt
# lat_0260_IT-LAT0893.txt
# lat_0260_IT-LAT0895.txt
# lat_0260_IT-LAT0896.txt
# lat_1699_IT-LAT0897.txt
# lat_1741_IT-LAT0899.txt
# lat_1078_IT-LAT0900.txt
# lat_1157_IT-LAT0901.txt
# lat_1254_IT-LAT0902.txt
# lat_1136_IT-LAT0903.txt
# lat_0450_IT-LAT0904.txt
# lat_1218_IT-LAT0905.txt
# lat_0550_IT-LAT0906.txt
# lat_0770_IT-LAT0907.txt
# lat_0598_IT-LAT0908.txt
# lat_0598_IT-LAT0909.txt
# lat_1112_IT-LAT0910.txt
# lat_0800_IT-LAT0911_7.txt
# lat_1073_IT-LAT0912.txt
# lat_0250_IT-LAT0913.txt
# lat_0250_IT-LAT0914.txt
# lat_0150_IT-LAT0916.txt
# lat_0502_IT-LAT0917.txt
# lat_1247_IT-LAT0918.txt
# lat_0350_IT-LAT0919.txt
# lat_0850_IT-LAT0920.txt
# lat_0731_IT-LAT0921.txt
# lat_-0045_IT-LAT0922_16.txt
# lat_1501_IT-LAT0923.txt
# lat_1501_IT-LAT0924.txt
# lat_1501_IT-LAT0925.txt
# lat_1603_IT-LAT0926.txt
# lat_1475_IT-LAT0927.txt
# lat_1501_IT-LAT0928.txt
# lat_1568_IT-LAT0929.txt
# lat_1434_IT-LAT0930.txt
# lat_1434_IT-LAT0931.txt
# lat_1434_IT-LAT0932.txt
# lat_1528_IT-LAT0933.txt
# lat_0067_IT-LAT0934.txt
# lat_1708_IT-LAT0935.txt
# lat_0833_IT-LAT0936.txt
# lat_1337_IT-LAT0937.txt
# lat_1339_IT-LAT0938.txt
# lat_1355_IT-LAT0939.txt
# lat_-0185_IT-LAT0952.txt
# lat_1397_IT-LAT0954.txt
# lat_-0044_IT-LAT0955.txt
# lat_-0044_IT-LAT0956.txt
# lat_0598_IT-LAT0957.txt
# lat_1250_IT-LAT0958.txt
# lat_0250_IT-LAT0959.txt
# lat_1110_IT-LAT0963.txt
# lat_1110_IT-LAT0964.txt
# lat_1110_IT-LAT0965.txt
# lat_1110_IT-LAT0966.txt
# lat_1110_IT-LAT0967.txt
# lat_1110_IT-LAT0968.txt
# lat_1110_IT-LAT0969.txt
# lat_1110_IT-LAT0970.txt
# lat_1110_IT-LAT0971.txt
# lat_1110_IT-LAT0972.txt
# lat_1110_IT-LAT0973.txt
# lat_1110_IT-LAT0974.txt
# lat_1067_IT-LAT0975.txt
# lat_1110_IT-LAT0976.txt
# lat_1110_IT-LAT0977.txt
# lat_0350_IT-LAT0978.txt
# lat_0950_IT-LAT0980.txt
# lat_1897_IT-LAT0982.txt
# lat_1902_IT-LAT0983.txt
# lat_1891_IT-LAT0984.txt
# lat_1892_IT-LAT0985.txt
# lat_1892_IT-LAT0986.txt
# lat_0550_IT-LAT0987.txt
# lat_-0149_IT-LAT0988.txt
# lat_0550_IT-LAT0990_9.txt
# lat_1550_IT-LAT0991.txt
# lat_-0107_IT-LAT0992.txt
# lat_1621_IT-LAT0993.txt
# lat_1614_IT-LAT0994.txt
# lat_1685_IT-LAT0995.txt
# lat_-0037_IT-LAT0996.txt
# lat_-0037_IT-LAT0997.txt
# lat_1501_IT-LAT1000.txt
# lat_0450_IT-LAT1001.txt
# lat_1483_IT-LAT1002.txt
# lat_1550_IT-LAT1003.txt
# lat_0395_IT-LAT1004.txt
# lat_-0229_IT-LAT1006.txt
# lat_1555_IT-LAT1007.txt
# lat_1684_IT-LAT1008.txt
# lat_1684_IT-LAT1009.txt
# lat_0382_IT-LAT0001_41.txt
# lat_0382_IT-LAT0001_42.txt
# lat_0382_IT-LAT0001_43.txt
# lat_0382_IT-LAT0001_44.txt
# lat_0382_IT-LAT0001_45.txt
# lat_0382_IT-LAT0001_46.txt
# lat_0382_IT-LAT0001_47.txt
# lat_0382_IT-LAT0001_48.txt
# lat_0382_IT-LAT0001_49.txt
# lat_0382_IT-LAT0001_50.txt
# lat_0382_IT-LAT0001_51.txt
# lat_0382_IT-LAT0001_52.txt
# lat_0382_IT-LAT0001_53.txt
# lat_0382_IT-LAT0001_54.txt
# lat_0382_IT-LAT0001_55.txt
# lat_0382_IT-LAT0001_56.txt
# lat_0382_IT-LAT0001_57.txt
# lat_0382_IT-LAT0001_58.txt
# lat_0382_IT-LAT0001_59.txt
# lat_0382_IT-LAT0001_60.txt
# lat_0382_IT-LAT0001_61.txt
# lat_0382_IT-LAT0001_62.txt
# lat_0382_IT-LAT0001_63.txt
# lat_0382_IT-LAT0001_64.txt
# lat_0382_IT-LAT0001_65.txt
# lat_0382_IT-LAT0001_66.txt
# lat_0382_IT-LAT0001_67.txt
# lat_0382_IT-LAT0001_68.txt
# lat_0382_IT-LAT0001_69.txt
# lat_0382_IT-LAT1039.txt
# lat_0116_IT-LAT0534_1.txt
# lat_0116_IT-LAT0534_2.txt
# lat_0116_IT-LAT0534_3.txt
# lat_0116_IT-LAT0534_4.txt
# lat_0533_IT-LAT0202.txt

# %%
metadata_df
# Out:
#                 id                          title  \
# 18      IT-LAT0001                        Vulgata
# 19      IT-LAT0537                   Ars amatoria
# 20      IT-LAT0011            S. Benedicti Regula
# 21      IT-LAT0012   In psalmis Davidis expositio
# 22      IT-LAT0014                Adoro te devote
# ...            ...                            ...
# 683   IT-LAT0534_1  De origine et situ Germanorum
# 684   IT-LAT0534_2        De vita Iulii Agricolae
# 685   IT-LAT0534_3         Dialogus de oratoribus
# 686   IT-LAT0534_4                      Historiae
# 1265    IT-LAT0202                  Institutiones
#
#                                                 creator  date    type  \
# 18                                           Hieronymus   382  poetry
# 19                                Ovidius Naso, Publius    -9  poetry
# 20                                 Benedictus Nursianus   524   prose
# 21                              Thomas Aquinas: Sanctus  1254   prose
# 22                              Thomas Aquinas: Sanctus  1254  poetry
# ...                                                 ...   ...     ...
# 683                  Tacitus, Publius (Gaius) Cornelius   116   prose
# 684                  Tacitus, Publius (Gaius) Cornelius   116   prose
# 685                  Tacitus, Publius (Gaius) Cornelius   116   prose
# 686                  Tacitus, Publius (Gaius) Cornelius   116   prose
# 1265  Iustinianus, Caesar Flavius (Imperator Iustini...   533   prose
#
#                            file
# 18      lat_0382_IT-LAT0001.txt
# 19      lat_-009_IT-LAT0537.txt
# 20      lat_0524_IT-LAT0011.txt
# 21      lat_1254_IT-LAT0012.txt
# 22      lat_1254_IT-LAT0014.txt
# ...                         ...
# 683   lat_0116_IT-LAT0534_1.txt
# 684   lat_0116_IT-LAT0534_2.txt
# 685   lat_0116_IT-LAT0534_3.txt
# 686   lat_0116_IT-LAT0534_4.txt
# 1265    lat_0533_IT-LAT0202.txt
#
# [670 rows x 6 columns]

# %%
corpus
# Out:
# [['in', 'principium', 'creo', 'deus', 'caelum', 'et', 'terra'],
#  ['terra',
#   'autem',
#   'sum',
#   'inanis',
#   'et',
#   'vacuus',
#   'et',
#   'tenebrae',
#   'super',
#   'facies',
#   'abyssus',
#   'et',
#   'spiritus',
#   'deus',
#   'fero',
#   'super',
#   'aqua'],
#  ['dico', 'deus', 'fio', 'lux', 'et', 'facio', 'sum', 'lux'],
#  ['et',
#   'video',
#   'deus',
#   'lux',
#   'quod',
#   'sum',
#   'bonus',
#   'et',
#   'divisor',
#   'lux',
#   'atque',
#   'tenebrae'],
#  ['appello',
#   'lux',
#   'dies',
#   'et',
#   'tenebrae',
#   'nox',
#   'factumque',
#   'sum',
#   'vesper',
#   'et',
#   'mane',
#   'dies',
#   'unus'],
#  ['dico#2',
#   'quoque',
#   'deus',
#   'fio',
#   'firmamentum',
#   'in',
#   'medius',
#   'aqua',
#   'et',
#   'divido',
#   'aqua',
#   'ab',
#   'aqua'],
#  ['et',
#   'facio',
#   'deus',
#   'firmamentum',
#   'divisitque',
#   'aqua',
#   'quis#2',
#   'sum',
#   'sub',
#   'firmamentum',
#   'ab',
#   'hic',
#   'quis#2',
#   'sum',
#   'super',
#   'firmamentum',
#   'et',
#   'facio',
#   'sum',
#   'ita'],
#  ['voco',
#   'deus',
#   'firmamentum',
#   'caelum',
#   'et',
#   'facio',
#   'sum',
#   'vesper',
#   'et',
#   'mane',
#   'dies',
#   'secundus'],
#  ['dico#2',
#   'verus',
#   'deus',
#   'congrego',
#   'aqua',
#   'quis#2',
#   'sub',
#   'caelum',
#   'sum',
#   'in',
#   'locus',
#   'unus',
#   'et',
#   'appareo',
#   'aridus',
#   'factumque',
#   'sum',
#   'ita'],
#  ['et',
#   'voco',
#   'deus',
#   'aridus',
#   'terra',
#   'congregationesque',
#   'aqua',
#   'appello',
#   'mare',
#   'et',
#   'video',
#   'deus',
#   'quod',
#   'sum',
#   'bonus'],
#  ['et',
#   'ajo',
#   'germino',
#   'terra',
#   'herba',
#   'vireo',
#   'et',
#   'facio',
#   'semen',
#   'et',
#   'lignum',
#   'pomiferum',
#   'facio',
#   'fructus',
#   'iuxta',
#   'genus',
#   'suus',
#   'quis#2',
#   'semen',
#   'in',
#   'sui',
#   'ipse',
#   'sum',
#   'super',
#   'terra',
#   'et',
#   'facio',
#   'sum',
#   'ita'],
#  ['et',
#   'profero',
#   'terra',
#   'herba',
#   'vireo',
#   'et',
#   'adfero',
#   'semen',
#   'iuxta',
#   'genus',
#   'suus',
#   'lignumque',
#   'facio',
#   'fructus',
#   'et',
#   'habeo',
#   'unusquisque',
#   'sementis',
#   'secundum',
#   'species',
#   'suus',
#   'et',
#   'video',
#   'deus',
#   'quod',
#   'sum',
#   'bonus'],
#  ['factumque', 'sum', 'vesper', 'et', 'mane', 'dies', 'tertius'],
#  ['dico#2',
#   'autem',
#   'deus',
#   'fio',
#   'luminarium',
#   'in',
#   'firmamentum',
#   'caelum',
#   'ut',
#   'divido',
#   'dies',
#   'atque',
#   'nox',
#   'et',
#   'sum',
#   'in',
#   'signum',
#   'et',
#   'tempus',
#   'et',
#   'dies',
#   'et',
#   'annus'],
#  ['ut',
#   'luceo',
#   'in',
#   'firmamentum',
#   'caelum',
#   'et',
#   'inlumino',
#   'terra',
#   'et',
#   'facio',
#   'sum',
#   'ita'],
#  ['fecitque',
#   'deus',
#   'duo',
#   'magnus',
#   'luminarium',
#   'lumino',
#   'magnus',
#   'ut',
#   'praeesset',
#   'dies',
#   'et',
#   'lumino',
#   'parvus',
#   'ut',
#   'praeesset',
#   'nocti',
#   'et',
#   'stella'],
#  ['et',
#   'pono',
#   'is',
#   'in',
#   'firmamentum',
#   'caelum',
#   'ut',
#   'luceo',
#   'super',
#   'terra'],
#  ['et',
#   'praesum',
#   'dies',
#   'atque',
#   'nocti',
#   'et',
#   'divido',
#   'lux',
#   'atque',
#   'tenebrae',
#   'et',
#   'video',
#   'deus',
#   'quod',
#   'sum',
#   'bonus'],
#  ['et', 'facio', 'sum', 'vesper', 'et', 'mane', 'dies', 'quartus'],
#  ['dico#2',
#   'etiam',
#   'deus',
#   'produco',
#   'aqua',
#   'reptilis',
#   'anima',
#   'vivo',
#   'et',
#   'volatilis',
#   'super',
#   'terra',
#   'sub',
#   'firmamentum',
#   'caelum'],
#  ['creavitque',
#   'deus',
#   'cetus',
#   'grandis',
#   'et',
#   'omnis',
#   'anima',
#   'vivo',
#   'atque',
#   'motabilis',
#   'quam#4',
#   'produco',
#   'aqua',
#   'in',
#   'species',
#   'suus',
#   'et',
#   'omnis',
#   'volatilis',
#   'secundum',
#   'genus',
#   'suus',
#   'et',
#   'video',
#   'deus',
#   'quod',
#   'sum',
#   'bonus'],
#  ['benedico',
#   'is',
#   'dico#2',
#   'crescite',
#   'et',
#   'multiplico',
#   'et',
#   'replete',
#   'aqua',
#   'mas',
#   'avesque',
#   'multiplico',
#   'super',
#   'terra'],
#  ['et', 'facio', 'sum', 'vesper', 'et', 'mane', 'dies', 'quintus'],
#  ['dico#2',
#   'quoque',
#   'deus',
#   'produco',
#   'terra',
#   'anima',
#   'vivo',
#   'in',
#   'genus',
#   'suus',
#   'iumentum',
#   'et',
#   'reptilis',
#   'et',
#   'bestia',
#   'terra',
#   'secundum',
#   'species',
#   'suus',
#   'factumque',
#   'sum',
#   'ita'],
#  ['et',
#   'facio',
#   'deus',
#   'bestia',
#   'terra',
#   'iuxta',
#   'species',
#   'suus',
#   'et',
#   'iumentum',
#   'et',
#   'omnis',
#   'reptilis',
#   'terra',
#   'in',
#   'genus',
#   'suus',
#   'et',
#   'video',
#   'deus',
#   'quod',
#   'sum',
#   'bonus'],
#  ['et',
#   'ajo',
#   'facio',
#   'homo',
#   'ad',
#   'imago',
#   'et',
#   'similitudo',
#   'noster',
#   'et',
#   'praesum',
#   'piscis',
#   'mas',
#   'et',
#   'volatilis',
#   'caelum',
#   'et',
#   'bestia',
#   'universaeque',
#   'terra',
#   'omnique',
#   'reptilis',
#   'quod',
#   'moveo',
#   'in',
#   'terra'],
#  ['et',
#   'creo',
#   'deus',
#   'homo',
#   'ad',
#   'imago',
#   'suus',
#   'ad',
#   'imago',
#   'deus',
#   'creo',
#   'ille',
#   'masculus',
#   'et',
#   'femina',
#   'creo',
#   'is'],
#  ['benedico',
#   'ille',
#   'deus',
#   'et',
#   'ajo',
#   'crescite',
#   'et',
#   'multiplico',
#   'et',
#   'replete',
#   'terra',
#   'et',
#   'subicite',
#   'is',
#   'et',
#   'dominamini',
#   'piscis',
#   'mas',
#   'et',
#   'volatilis',
#   'caelum',
#   'et',
#   'universus',
#   'animo',
#   'quis#2',
#   'moveo',
#   'super',
#   'terra'],
#  ['dico',
#   'deus',
#   'ecce',
#   'do',
#   'vos',
#   'omnis',
#   'herba',
#   'adfero',
#   'semen',
#   'super',
#   'terra',
#   'et',
#   'universus',
#   'lignum',
#   'quis#2',
#   'habeo',
#   'in',
#   'sui',
#   'ipse',
#   'sementis',
#   'genus',
#   'suus',
#   'ut',
#   'sum',
#   'vos',
#   'in',
#   'esca'],
#  ['et',
#   'cunctus',
#   'animo',
#   'terra',
#   'omnique',
#   'volucri',
#   'caelum',
#   'et',
#   'universus',
#   'quis#2',
#   'moveo',
#   'in',
#   'terra',
#   'et',
#   'in',
#   'quis#2',
#   'sum',
#   'anima',
#   'vivo',
#   'ut',
#   'habeo',
#   'ad',
#   'vesco',
#   'et',
#   'facio',
#   'sum',
#   'ita'],
#  ['video',
#   'deus',
#   'cunctus',
#   'quis#2',
#   'facio',
#   'et',
#   'sum',
#   'valde',
#   'bonus',
#   'et',
#   'facio',
#   'sum',
#   'vesper',
#   'et',
#   'mane',
#   'dies',
#   'sextus'],
#  ['igitur',
#   'perfectus',
#   'sum',
#   'caelum',
#   'et',
#   'terra',
#   'et',
#   'omnis',
#   'ornatus',
#   'is'],
#  ['conplevitque',
#   'deus',
#   'dies',
#   'septimus',
#   'opus',
#   'suus',
#   'quod',
#   'facio',
#   'et',
#   'requiesco',
#   'dies',
#   'septimus',
#   'ab',
#   'universus',
#   'opus',
#   'quod',
#   'patrarat'],
#  ['et',
#   'benedico',
#   'dies',
#   'septimus',
#   'et',
#   'sanctifico',
#   'ille',
#   'quia',
#   'in',
#   'ipse',
#   'cesso',
#   'ab',
#   'omnis',
#   'opus',
#   'suus',
#   'quod',
#   'creo',
#   'deus',
#   'ut',
#   'facio'],
#  ['iste',
#   'generatio',
#   'caelum',
#   'et',
#   'terra',
#   'quando',
#   'creo',
#   'sum',
#   'in',
#   'dies',
#   'quo',
#   'facio',
#   'dominus',
#   'deus',
#   'caelum',
#   'et',
#   'terra'],
#  ['et',
#   'omnis',
#   'virgultum',
#   'ager',
#   'antequam',
#   'orior',
#   'in',
#   'terra',
#   'omnemque',
#   'herba',
#   'regio',
#   'priusquam',
#   'germino',
#   'non',
#   'enim',
#   'pluerat',
#   'dominus',
#   'deus',
#   'super',
#   'terra',
#   'et',
#   'homo',
#   'non',
#   'sum',
#   'quis#2',
#   'opero',
#   'terra'],
#  ['sed',
#   'fons',
#   'ascendo',
#   'ex',
#   'terra',
#   'inrigo',
#   'universus',
#   'superficiem',
#   'terra'],
#  ['formo',
#   'igitur',
#   'dominus',
#   'deus',
#   'homo',
#   'de',
#   'limus',
#   'terra',
#   'et',
#   'inspiravit',
#   'in',
#   'facies',
#   'is',
#   'spiraculum',
#   'vita',
#   'et',
#   'facio',
#   'sum',
#   'homo',
#   'in',
#   'anima',
#   'vivo'],
#  ['planto',
#   'autem',
#   'dominus',
#   'deus',
#   'paradisus',
#   'voluptas',
#   'ab',
#   'principium',
#   'in',
#   'quo',
#   'pono',
#   'homo',
#   'quis#2',
#   'formo'],
#  ['produxitque',
#   'dominus',
#   'deus',
#   'de',
#   'humo',
#   'omnis',
#   'lignum',
#   'pulcher',
#   'video',
#   'et',
#   'ad',
#   'vesco',
#   'suavis',
#   'lignum',
#   'etiam',
#   'vita',
#   'in',
#   'medius',
#   'paradisus',
#   'lignumque',
#   'scientia',
#   'bonus',
#   'et',
#   'malus'],
#  ['et',
#   'fluvius',
#   'egredior',
#   'de',
#   'locus',
#   'voluptas',
#   'ad',
#   'inrigo',
#   'paradisus',
#   'quis#2',
#   'inde',
#   'divido',
#   'in',
#   'quattuor',
#   'capitum'],
#  ['nomen',
#   'unus',
#   'Phison',
#   'ipse',
#   'sum',
#   'quis#2',
#   'circumeo',
#   'omnis',
#   'terra',
#   'Evilat',
#   'ubi',
#   'nascor',
#   'aurum'],
#  ['et',
#   'aurum',
#   'terra',
#   'ille',
#   'bonus',
#   'sum',
#   'ibique',
#   'invenio',
#   'bdellium',
#   'et',
#   'lapis',
#   'onychinus'],
#  ['et',
#   'nomen',
#   'fluvius',
#   'secundus',
#   'Geon',
#   'ipse',
#   'sum',
#   'quis#2',
#   'circumeo',
#   'omnis',
#   'terra',
#   'Aethiopia'],
#  ['nomen',
#   'verus',
#   'flumen',
#   'tertius',
#   'tigris',
#   'ipse',
#   'vado',
#   'contra',
#   'Assyrius',
#   'fluvius',
#   'autem',
#   'quartus',
#   'ipse',
#   'sum',
#   'Eufrates'],
#  ['fero',
#   'ergo',
#   'dominus',
#   'deus',
#   'homo',
#   'et',
#   'pono',
#   'is',
#   'in',
#   'paradisus',
#   'voluptas',
#   'ut',
#   'opero',
#   'et',
#   'custodio',
#   'ille'],
#  ['praecipio', 'is', 'dico#2', 'ex', 'omnis', 'lignum', 'paradisus', 'comedo'],
#  ['de',
#   'lignum',
#   'autem',
#   'scientia',
#   'bonus',
#   'et',
#   'malus',
#   'ne#2',
#   'comedas',
#   'in',
#   'quicumque',
#   'enim',
#   'dies',
#   'comederis',
#   'ex',
#   'is',
#   'mors',
#   'morior'],
#  ['dico#2',
#   'quoque',
#   'dominus',
#   'deus',
#   'non',
#   'sum',
#   'bonus',
#   'sum',
#   'homo',
#   'solus',
#   'facio',
#   'is',
#   'adjutor',
#   'similis',
#   'suus'],
#  ['formo',
#   'igitur',
#   'dominus',
#   'deus',
#   'de',
#   'humo',
#   'cunctus',
#   'animo',
#   'terra',
#   'et',
#   'universus',
#   'volatilis',
#   'caelum',
#   'adduco',
#   'is',
#   'ad',
#   'Adam',
#   'ut',
#   'video',
#   'quis#2',
#   'voco',
#   'is',
#   'omnis',
#   'enim',
#   'quod',
#   'voco',
#   'Adam',
#   'anima',
#   'vivo',
#   'ipse',
#   'sum',
#   'nomen',
#   'is'],
#  ['appello',
#   'Adam',
#   'nomen',
#   'suus',
#   'cunctus',
#   'animo',
#   'et',
#   'universus',
#   'volatile',
#   'caelum',
#   'et',
#   'omnis',
#   'bestia',
#   'terra',
#   'Adam',
#   'verus',
#   'non',
#   'invenio',
#   'adjuto',
#   'similis',
#   'is'],
#  ['inmitto',
#   'ergo',
#   'dominus',
#   'deus',
#   'sopor',
#   'in',
#   'Adam',
#   'cumque',
#   'obdormisset',
#   'fero',
#   'unus',
#   'de',
#   'costa',
#   'is',
#   'et',
#   'repleo',
#   'caro',
#   'pro',
#   'is'],
#  ['et',
#   'aedifico',
#   'dominus',
#   'deus',
#   'costa',
#   'quam#4',
#   'offertor',
#   'de',
#   'Adam',
#   'in',
#   'mulier',
#   'et',
#   'adduco',
#   'is',
#   'ad',
#   'Adam'],
#  ['dico',
#   'Adam',
#   'hic',
#   'nunc',
#   'os#2',
#   'ex',
#   'os#2',
#   'meus',
#   'et',
#   'caro',
#   'de',
#   'caro',
#   'meus',
#   'hic',
#   'voco',
#   'virago',
#   'quoniam',
#   'de',
#   'vir',
#   'sumo',
#   'sum'],
#  ['quam#4',
#   'ob',
#   'res',
#   'relinquo',
#   'homo',
#   'pater',
#   'suus',
#   'et',
#   'mater',
#   'et',
#   'adhaereo',
#   'uxor',
#   'suus',
#   'et',
#   'sum',
#   'duo',
#   'in',
#   'caro',
#   'unus'],
#  ['sum',
#   'autem',
#   'uterque',
#   'nudus',
#   'Adam',
#   'scilicet',
#   'et',
#   'uxor',
#   'is',
#   'et',
#   'non',
#   'erubesco'],
#  ['sed',
#   'et',
#   'serpens',
#   'sum',
#   'callidus',
#   'cunctus',
#   'animo',
#   'terra',
#   'quis#2',
#   'facio',
#   'dominus',
#   'deus',
#   'quis#2',
#   'dico#2',
#   'ad',
#   'mulier',
#   'cur',
#   'praecipio',
#   'vos',
#   'deus',
#   'ut',
#   'non',
#   'comederetis',
#   'de',
#   'omnis',
#   'lignum',
#   'paradisus'],
#  ['quis#2',
#   'respondeo',
#   'mulier',
#   'de',
#   'fructus',
#   'lignum',
#   'quis#2',
#   'sum',
#   'in',
#   'paradisus',
#   'vesco'],
#  ['de',
#   'fructus',
#   'verus',
#   'lignum',
#   'quod',
#   'sum',
#   'in',
#   'medius',
#   'paradisus',
#   'praecipio',
#   'nos',
#   'deus',
#   'ne#2',
#   'comederemus',
#   'et',
#   'ne#2',
#   'tango',
#   'ille',
#   'ne#2',
#   'forte',
#   'morior'],
#  ['dico#2', 'autem', 'serpens', 'ad', 'mulier', 'nequaquam', 'mors', 'morior'],
#  ['scio',
#   'enim',
#   'deus',
#   'quod',
#   'in',
#   'quicumque',
#   'dies',
#   'comederitis',
#   'ex',
#   'is',
#   'aperio',
#   'oculus',
#   'vos',
#   'et',
#   'sum',
#   'sicut',
#   'deus',
#   'scio',
#   'bonus',
#   'et',
#   'malus#3'],
#  ['video',
#   'igitur',
#   'mulier',
#   'quod',
#   'bonus',
#   'sum',
#   'lignum',
#   'ad',
#   'vesco',
#   'et',
#   'pulcher',
#   'oculus',
#   'aspectuque',
#   'delectabilis',
#   'et',
#   'fero',
#   'de',
#   'fructus',
#   'ille',
#   'et',
#   'comedo',
#   'do',
#   'vir',
#   'suus',
#   'quis#2',
#   'comedo'],
#  ['et',
#   'aperio',
#   'sum',
#   'oculus',
#   'ambo',
#   'cumque',
#   'cognosco',
#   'sum',
#   'se',
#   'nudus',
#   'consuo',
#   'folium',
#   'ficus',
#   'et',
#   'facio',
#   'se',
#   'perizomata'],
#  ['et',
#   'cum',
#   'audio',
#   'vox',
#   'dominus',
#   'deus',
#   'deambulo',
#   'in',
#   'paradisus',
#   'ad',
#   'aura',
#   'post',
#   'meridies',
#   'abscondo',
#   'se',
#   'Adam',
#   'et',
#   'uxor',
#   'is',
#   'ab',
#   'facies',
#   'dominus',
#   'deus',
#   'in',
#   'medius',
#   'lignum',
#   'paradisus'],
#  ['voco', 'dominus', 'deus', 'Adam', 'et', 'dico#2', 'is', 'ubi', 'sum'],
#  ['quis#2',
#   'ajo',
#   'vox',
#   'tuus',
#   'audio',
#   'in',
#   'paradisus',
#   'et',
#   'timeo',
#   'is',
#   'quod',
#   'nudus',
#   'sum',
#   'et',
#   'abscondo',
#   'ego'],
#  ['quis#2',
#   'dico#2',
#   'quis#2',
#   'enim',
#   'indico#2',
#   'tu',
#   'quod',
#   'nudus',
#   'sum',
#   'nisi',
#   'quod',
#   'ex',
#   'lignum',
#   'de',
#   'quo',
#   'tu',
#   'praecipio',
#   'ne#2',
#   'comederes',
#   'comedisti'],
#  ['dico',
#   'Adam',
#   'mulier',
#   'quam#4',
#   'do',
#   'socia',
#   'ego',
#   'do',
#   'ego',
#   'de',
#   'lignum',
#   'et',
#   'comedo'],
#  ['et',
#   'dico#2',
#   'dominus',
#   'deus',
#   'ad',
#   'mulier',
#   'quare',
#   'hic',
#   'facio',
#   'quis#2',
#   'respondeo',
#   'serpens',
#   'decipio',
#   'ego',
#   'et',
#   'comedo'],
#  ['et',
#   'ajo',
#   'dominus',
#   'deus',
#   'ad',
#   'serpens',
#   'quia',
#   'facio',
#   'hic',
#   'maledico',
#   'sum',
#   'inter',
#   'omnis',
#   'animo',
#   'et',
#   'bestia',
#   'terra',
#   'super',
#   'pectus',
#   'tuus',
#   'gradieris',
#   'et',
#   'terra',
#   'comedes',
#   'cunctus',
#   'dies',
#   'vita',
#   'tuus'],
#  ['inimicitia',
#   'pono',
#   'inter',
#   'tu',
#   'et',
#   'mulier',
#   'et',
#   'semen',
#   'tuus',
#   'et',
#   'semen',
#   'ille',
#   'ipse',
#   'contero',
#   'caput',
#   'tuus',
#   'et',
#   'tuuus',
#   'insidiaberis',
#   'calcaneus',
#   'is'],
#  ['mulier',
#   'quoque',
#   'dico#2',
#   'multiplico',
#   'aerumna',
#   'tuus',
#   'et',
#   'conceptus',
#   'tuus',
#   'in',
#   'dolor',
#   'pario',
#   'filius',
#   'et',
#   'sub',
#   'vir',
#   'potestas',
#   'sum',
#   'et',
#   'ipse',
#   'deminor',
#   'tuus'],
#  ['ad',
#   'Adam',
#   'verus',
#   'dico#2',
#   'quia',
#   'audio',
#   'vox',
#   'uxor',
#   'tuus',
#   'et',
#   'comedisti',
#   'de',
#   'lignum',
#   'ex',
#   'quo',
#   'praecipio',
#   'tu',
#   'ne#2',
#   'comederes',
#   'maledico',
#   'terra',
#   'in',
#   'opus',
#   'tuus',
#   'in',
#   'labor',
#   'comedes',
#   'is',
#   'cunctus',
#   'dies',
#   'vita',
#   'tuus'],
#  ['spina',
#   'et',
#   'tribulus',
#   'germino',
#   'tu',
#   'et',
#   'comedes',
#   'herba',
#   'terra'],
#  ['in',
#   'sudor',
#   'vultus',
#   'tuus',
#   'vesco',
#   'panus',
#   'donec',
#   'revertaris',
#   'in',
#   'terra',
#   'de',
#   'qui',
#   'sumptus',
#   'sum',
#   'quia',
#   'pulvis',
#   'sum',
#   'et',
#   'in',
#   'pulvis',
#   'revorto'],
#  ['et',
#   'voco',
#   'Adam',
#   'nomen',
#   'uxor',
#   'suus',
#   'Hava',
#   'is',
#   'quod',
#   'mater',
#   'sum',
#   'cunctus',
#   'vivo'],
#  ['facio',
#   'quoque',
#   'dominus',
#   'deus',
#   'Adam',
#   'et',
#   'uxor',
#   'is',
#   'tunica',
#   'pellicius',
#   'et',
#   'induo',
#   'is'],
#  ['et',
#   'ajo',
#   'ecce',
#   'Adam',
#   'facio',
#   'sum',
#   'quasi',
#   'unus',
#   'ex',
#   'nos',
#   'scio',
#   'bonus',
#   'et',
#   'malus#3',
#   'nunc',
#   'ergo',
#   'ne#2',
#   'forte',
#   'mitto',
#   'manus',
#   'suus',
#   'et',
#   'sumo',
#   'etiam',
#   'de',
#   'lignum',
#   'vita',
#   'et',
#   'comedat',
#   'et',
#   'vivo',
#   'in',
#   'aeternus'],
#  ['emitto',
#   'is',
#   'dominus',
#   'deus',
#   'de',
#   'paradisus',
#   'voluptas',
#   'ut',
#   'opero',
#   'terra',
#   'de',
#   'qui',
#   'sumptus',
#   'sum'],
#  ['eiecitque',
#   'Adam',
#   'et',
#   'conloco',
#   'ante',
#   'paradisus',
#   'voluptas',
#   'cherubin',
#   'et',
#   'flammeum',
#   'gladius',
#   'atque',
#   'versatilis',
#   'ad',
#   'custodio',
#   'via',
#   'lignum',
#   'vita'],
#  ['Adam',
#   'verus',
#   'cognosco',
#   'Havam',
#   'uxor',
#   'suus',
#   'quis#2',
#   'concipio',
#   'et',
#   'pario#2',
#   'Cain',
#   'dico#2',
#   'possedi',
#   'homo',
#   'per',
#   'dominus'],
#  ['rursusque',
#   'pario#2',
#   'frater',
#   'is',
#   'Abel',
#   'sum',
#   'autem',
#   'Abel',
#   'pastor',
#   'ovis',
#   'et',
#   'Cain',
#   'agricola'],
#  ['facio',
#   'sum',
#   'autem',
#   'post',
#   'multus',
#   'dies',
#   'ut',
#   'offerret',
#   'Cain',
#   'de',
#   'fructus',
#   'terra',
#   'munus',
#   'dominus'],
#  ['Abel',
#   'quoque',
#   'offertor',
#   'de',
#   'primogenitus',
#   'grex',
#   'suus',
#   'et',
#   'de',
#   'adipibus',
#   'is',
#   'et',
#   'respicio',
#   'dominus',
#   'ad',
#   'Abel',
#   'et',
#   'ad',
#   'munus',
#   'is'],
#  ['ad',
#   'Cain',
#   'verus',
#   'et',
#   'ad',
#   'munus',
#   'ille',
#   'non',
#   'respicio',
#   'iratusque',
#   'sum',
#   'Cain',
#   'vehementer',
#   'et',
#   'concedo',
#   'vultus',
#   'is'],
#  ['dico',
#   'dominus',
#   'ad',
#   'is',
#   'quare',
#   'maestus',
#   'sum',
#   'et',
#   'cur',
#   'concedo',
#   'facies',
#   'tuus'],
#  ['nonne',
#   'si',
#   'bene',
#   'ago',
#   'recipio',
#   'sin',
#   'autem',
#   'male',
#   'statim',
#   'in',
#   'foris',
#   'peccatum',
#   'adsum',
#   'sed',
#   'sub',
#   'tu',
#   'sum',
#   'appetitus',
#   'is',
#   'et',
#   'tuuus',
#   'dominaberis',
#   'ille'],
#  ['dico',
#   'Cain',
#   'ad',
#   'Abel',
#   'frater',
#   'suus',
#   'egrediamur',
#   'foras',
#   'cumque',
#   'sum',
#   'in',
#   'ager',
#   'consurgo',
#   'Cain',
#   'adversus#2',
#   'Abel',
#   'frater',
#   'suus',
#   'et',
#   'interfacio',
#   'is'],
#  ['et',
#   'ajo',
#   'dominus',
#   'ad',
#   'Cain',
#   'ubi',
#   'sum',
#   'Abel',
#   'frater',
#   'tuus',
#   'quis#2',
#   'respondeo',
#   'nescio',
#   'num',
#   'custos',
#   'frater',
#   'meus',
#   'sum'],
#  ['dico',
#   'ad',
#   'is',
#   'quis#2',
#   'facio',
#   'vox',
#   'sanguis',
#   'frater',
#   'tuus',
#   'clamo',
#   'ad',
#   'ego',
#   'de',
#   'terra'],
#  ['nunc',
#   'igitur',
#   'maledico',
#   'sum',
#   'super',
#   'terra',
#   'quis#2',
#   'aperio',
#   'os#2',
#   'suus',
#   'et',
#   'suscipio',
#   'sanguis',
#   'frater',
#   'tuus',
#   'de',
#   'manus',
#   'tuus'],
#  ['cum',
#   'operor',
#   'sum',
#   'is',
#   'non',
#   'do',
#   'tu',
#   'fructus',
#   'suus',
#   'vagus',
#   'et',
#   'profugus',
#   'sum',
#   'super',
#   'terra'],
#  ['dico',
#   'Cain',
#   'ad',
#   'dominus',
#   'magnus',
#   'sum',
#   'iniquitas',
#   'meus',
#   'quam#4',
#   'ut',
#   'venio',
#   'mereo'],
#  ['ecce',
#   'eicio',
#   'ego',
#   'hodie',
#   'ab',
#   'facies',
#   'terra',
#   'et',
#   'ab',
#   'facies',
#   'tuus',
#   'abscondo',
#   'et',
#   'sum',
#   'vagus',
#   'et',
#   'profugus',
#   'in',
#   'terra',
#   'omnis',
#   'igitur',
#   'quis#2',
#   'invenio',
#   'ego',
#   'occido#1',
#   'ego'],
#  ['dico',
#   'is',
#   'dominus',
#   'nequaquam',
#   'ita',
#   'fio',
#   'sed',
#   'omnis',
#   'quis#2',
#   'occido#1',
#   'Cain',
#   'septuplum',
#   'punietur',
#   'posuitque',
#   'dominus',
#   'Cain',
#   'signum',
#   'ut',
#   'non',
#   'is',
#   'interficio',
#   'omnis',
#   'quis#2',
#   'invenio',
#   'is'],
#  ['egressusque',
#   'Cain',
#   'ab',
#   'facies',
#   'dominus',
#   'habito',
#   'in',
#   'terra',
#   'profugus',
#   'ad',
#   'orientalis',
#   'plaga',
#   'Eden'],
#  ['cognosco',
#   'autem',
#   'Cain',
#   'uxor',
#   'suus',
#   'quis#2',
#   'concipio',
#   'et',
#   'pario#2',
#   'Enoch',
#   'et',
#   'aedifico',
#   'civitas',
#   'voco',
#   'nomen',
#   'is',
#   'ex',
#   'nomen',
#   'filius',
#   'suus',
#   'Enoch'],
#  ['porro',
#   'Enoch',
#   'gigno',
#   'Irad',
#   'et',
#   'Irad',
#   'gigno',
#   'Maviahel',
#   'et',
#   'Maviahel',
#   'gigno',
#   'Matusahel',
#   'et',
#   'Matusahel',
#   'gigno',
#   'Lamech'],
#  ['quis#2',
#   'accipio',
#   'uxor',
#   'duo',
#   'nomen',
#   'unus',
#   'Ada',
#   'et',
#   'nomen',
#   'alter',
#   'sella'],
#  ['genuitque',
#   'Ada',
#   'Iabel',
#   'quis#2',
#   'sum',
#   'pater',
#   'habito',
#   'in',
#   'tentorium',
#   'atque',
#   'pastor'],
#  ['et',
#   'nomen',
#   'frater',
#   'is',
#   'Iubal',
#   'ipse',
#   'sum',
#   'pater',
#   'cano',
#   'cithara',
#   'et',
#   'organum'],
#  ['sella',
#   'quoque',
#   'gigno',
#   'Thubalcain',
#   'quis#2',
#   'sum',
#   'malleator',
#   'et',
#   'faber',
#   'in',
#   'cunctus',
#   'opus',
#   'aer',
#   'et',
#   'fero',
#   'soror',
#   'verus',
#   'Thubalcain',
#   'Noemma'],
#  ['dico',
#   'Lamech',
#   'uxoribus',
#   'suus',
#   'adae',
#   'et',
#   'sella',
#   'audio',
#   'vox',
#   'meus',
#   'uxor',
#   'Lamech',
#   'ausculto',
#   'sermo',
#   'meus',
#   'quoniam',
#   'occido#2',
#   'vir',
#   'in',
#   'vulnus',
#   'meus',
#   'et',
#   'adulescentulus',
#   'in',
#   'livorem',
#   'meus'],
#  ['septuplum',
#   'ultio',
#   'do',
#   'de',
#   'Cain',
#   'de',
#   'Lamech',
#   'verus',
#   'septuagiens',
#   'septiens'],
#  ['cognosco',
#   'quoque',
#   'adhuc',
#   'Adam',
#   'uxor',
#   'suus',
#   'et',
#   'pario#2',
#   'filius',
#   'voco',
#   'nomen',
#   'is',
#   'Seth',
#   'dico#2',
#   'pono',
#   'ego',
#   'deus',
#   'semen',
#   'alius',
#   'pro',
#   'Abel',
#   'quis#2',
#   'occido#1',
#   'Cain'],
#  ['sed',
#   'et',
#   'Seth',
#   'nascor',
#   'sum',
#   'filius',
#   'quis#2',
#   'voco',
#   'Enos',
#   'iste',
#   'coepio',
#   'invoco',
#   'nomen',
#   'dominus'],
#  ['hic',
#   'sum',
#   'liber#4',
#   'generatio',
#   'Adam',
#   'in',
#   'dies',
#   'qui',
#   'creo',
#   'deus',
#   'homo',
#   'ad',
#   'similitudo',
#   'deus',
#   'facio',
#   'ille'],
#  ['masculus',
#   'et',
#   'femina',
#   'creo',
#   'is',
#   'et',
#   'benedico',
#   'ille',
#   'et',
#   'voco',
#   'nomen',
#   'is',
#   'Adam',
#   'in',
#   'dies',
#   'qui',
#   'creo',
#   'sum'],
#  ['vivo',
#   'autem',
#   'Adam',
#   'centum',
#   'triginta',
#   'annus',
#   'et',
#   'gigno',
#   'ad',
#   'similitudo',
#   'et',
#   'imago',
#   'suus',
#   'voco',
#   'nomen',
#   'is',
#   'Seth'],
#  ['et',
#   'facio',
#   'sum',
#   'dies',
#   'Adam',
#   'postquam',
#   'gigno',
#   'Seth',
#   'octingenti',
#   'annus',
#   'genuitque',
#   'filius',
#   'et',
#   'filia'],
#  ['et',
#   'facio',
#   'sum',
#   'omnis',
#   'tempus',
#   'quod',
#   'vivo',
#   'Adam',
#   'annus',
#   'nongenti',
#   'triginta',
#   'et',
#   'morior',
#   'sum'],
#  ['vivo',
#   'quoque',
#   'Seth',
#   'centum',
#   'quinque',
#   'annus',
#   'et',
#   'gigno',
#   'Enos'],
#  ['vivo',
#   'Seth',
#   'postquam',
#   'gigno',
#   'Enos',
#   'octingenti',
#   'septem',
#   'annus',
#   'genuitque',
#   'filius',
#   'et',
#   'filia'],
#  ['et',
#   'facio',
#   'sum',
#   'omnis',
#   'dies',
#   'Seth',
#   'nongentorum',
#   'duodecim',
#   'annus',
#   'et',
#   'morior',
#   'sum'],
#  ['vivo', 'verus', 'Enos', 'nonaginta', 'annus', 'et', 'gigno', 'Cainan'],
#  ['post',
#   'quis#2',
#   'orior',
#   'vivo',
#   'octingenti',
#   'quindecim',
#   'annus',
#   'et',
#   'gigno',
#   'filius',
#   'et',
#   'filia'],
#  ['factique',
#   'sum',
#   'omnis',
#   'dies',
#   'Enos',
#   'nongentorum',
#   'quinque',
#   'annus',
#   'et',
#   'morior',
#   'sum'],
#  ['vivo',
#   'quoque',
#   'Cainan',
#   'septuaginta',
#   'annus',
#   'et',
#   'gigno',
#   'Malalehel'],
#  ['et',
#   'vivo',
#   'Cainan',
#   'postquam',
#   'gigno',
#   'Malalehel',
#   'octingenti',
#   'quadraginta',
#   'annus',
#   'genuitque',
#   'filius',
#   'et',
#   'filia'],
#  ['et',
#   'facio',
#   'sum',
#   'omnis',
#   'dies',
#   'Cainan',
#   'nongenti',
#   'decem',
#   'annus',
#   'et',
#   'morior',
#   'sum'],
#  ['vivo',
#   'autem',
#   'Malalehel',
#   'sexaginta',
#   'quinque',
#   'annus',
#   'et',
#   'gigno',
#   'Iared'],
#  ['et',
#   'vivo',
#   'Malalehel',
#   'postquam',
#   'gigno',
#   'Iared',
#   'octingenti',
#   'triginta',
#   'annus',
#   'et',
#   'gigno',
#   'filius',
#   'et',
#   'filia'],
#  ['et',
#   'facio',
#   'sum',
#   'omnis',
#   'dies',
#   'Malalehel',
#   'octingenti',
#   'nonaginta',
#   'quinque',
#   'annus',
#   'et',
#   'morior',
#   'sum'],
#  ['vivo',
#   'Iared',
#   'centum',
#   'sexaginta',
#   'duo',
#   'annus',
#   'et',
#   'gigno',
#   'Enoch'],
#  ['et',
#   'vivo',
#   'Iared',
#   'postquam',
#   'gigno',
#   'Enoch',
#   'octingenti',
#   'annus',
#   'et',
#   'gigno',
#   'filius',
#   'et',
#   'filia'],
#  ['et',
#   'facio',
#   'sum',
#   'omnis',
#   'dies',
#   'Iared',
#   'nongenti',
#   'sexaginta',
#   'duo',
#   'annus',
#   'et',
#   'morior',
#   'sum'],
#  ['porro',
#   'Enoch',
#   'vivo',
#   'sexaginta',
#   'quinque',
#   'annus',
#   'et',
#   'gigno',
#   'Mathusalam'],
#  ['et',
#   'ambulo',
#   'Enoch',
#   'cum',
#   'deus',
#   'postquam',
#   'gigno',
#   'Mathusalam',
#   'trecenti',
#   'annus',
#   'et',
#   'gigno',
#   'filius',
#   'et',
#   'filia'],
#  ['et',
#   'facio',
#   'sum',
#   'omnis',
#   'dies',
#   'Enoch',
#   'trecenti',
#   'sexaginta',
#   'quinque',
#   'annus'],
#  ['ambulavitque',
#   'cum',
#   'deus',
#   'et',
#   'non',
#   'appareo',
#   'quia',
#   'fero',
#   'is',
#   'deus'],
#  ['vivo',
#   'quoque',
#   'Mathusalam',
#   'centum',
#   'octoginta',
#   'septem',
#   'annus',
#   'et',
#   'gigno',
#   'Lamech'],
#  ['et',
#   'vivo',
#   'Mathusalam',
#   'postquam',
#   'gigno',
#   'Lamech',
#   'septingentos',
#   'octoginta',
#   'duo',
#   'annus',
#   'et',
#   'gigno',
#   'filius',
#   'et',
#   'filia'],
#  ['et',
#   'facio',
#   'sum',
#   'omnis',
#   'dies',
#   'Mathusala',
#   'nongenti',
#   'sexaginta',
#   'novem',
#   'annus',
#   'et',
#   'morior',
#   'sum'],
#  ['vivo',
#   'autem',
#   'Lamech',
#   'centum',
#   'octoginta',
#   'duo',
#   'annus',
#   'et',
#   'gigno',
#   'filius'],
#  ['voco',
#   'nomen',
#   'is',
#   'Noe',
#   'dico#2',
#   'iste',
#   'consolo',
#   'nos',
#   'ab',
#   'opus',
#   'et',
#   'labor',
#   'manus',
#   'noster',
#   'in',
#   'terra',
#   'quis#2',
#   'maledixit',
#   'dominus'],
#  ['vivo',
#   'Lamech',
#   'postquam',
#   'gigno',
#   'Noe',
#   'quingenti',
#   'nonaginta',
#   'quinque',
#   'annus',
#   'et',
#   'gigno',
#   'filius',
#   'et',
#   'filia'],
#  ['et',
#   'facio',
#   'sum',
#   'omnis',
#   'dies',
#   'Lamech',
#   'septingenti',
#   'septuaginta',
#   'septem',
#   'annus',
#   'et',
#   'morior',
#   'sum'],
#  ['Noe',
#   'verus',
#   'cum',
#   'quingentorum',
#   'sum',
#   'annus',
#   'gigno',
#   'Sem',
#   'et',
#   'Ham',
#   'et',
#   'Iafeth'],
#  ['cumque',
#   'coepio',
#   'homo',
#   'multiplico',
#   'super',
#   'terra',
#   'et',
#   'filia',
#   'procreassent'],
#  ['video',
#   'filius',
#   'deus',
#   'filia',
#   'is',
#   'quod',
#   'sum',
#   'Pulchra',
#   'accipio',
#   'uxor',
#   'se',
#   'ex',
#   'omnis',
#   'quis#2',
#   'eligo'],
#  ['dico',
#   'deus',
#   'non',
#   'permaneo',
#   'spiritus',
#   'meus',
#   'in',
#   'homo',
#   'in',
#   'aeternus',
#   'quia',
#   'caro',
#   'sum',
#   'eruntque',
#   'dies',
#   'ille',
#   'centum',
#   'viginti',
#   'annus'],
#  ['gigantes',
#   'autem',
#   'sum',
#   'super',
#   'terra',
#   'in',
#   'dies',
#   'ille',
#   'postquam',
#   'enim',
#   'ingredior',
#   'sum',
#   'filius',
#   'deus',
#   'ad',
#   'filia',
#   'homo',
#   'illaeque',
#   'gigno',
#   'iste',
#   'sum',
#   'potens',
#   'ab',
#   'saeculum',
#   'vir',
#   'famosus'],
#  ['video',
#   'autem',
#   'deus',
#   'quod',
#   'multus',
#   'malitia',
#   'homo',
#   'sum',
#   'in',
#   'terra',
#   'et',
#   'cunctus',
#   'cogitatio',
#   'cor',
#   'intendo',
#   'sum',
#   'ad',
#   'malus#3',
#   'omnis',
#   'tempus'],
#  ['paenitet',
#   'is',
#   'quod',
#   'homo',
#   'facio',
#   'in',
#   'terra',
#   'et',
#   'tango',
#   'dolor',
#   'cor',
#   'intrinsecus'],
#  ['deleo',
#   'inquiam',
#   'homo',
#   'quis#2',
#   'creo',
#   'ab',
#   'facies',
#   'terra',
#   'ab',
#   'homo',
#   'usque',
#   'ad',
#   'animo',
#   'ab',
#   'reptilis',
#   'usque',
#   'ad',
#   'volucris',
#   'caelum',
#   'paeniteo',
#   'enim',
#   'ego',
#   'facio',
#   'is'],
#  ['Noe', 'verus', 'invenio', 'gratia', 'coram', 'dominus'],
#  ['hic',
#   'generatio',
#   'Noe',
#   'Noe',
#   'vir',
#   'iustus',
#   'atque',
#   'perficio',
#   'sum',
#   'in',
#   'generatio',
#   'suus',
#   'cum',
#   'deus',
#   'ambulo'],
#  ['et', 'gigno', 'tres', 'filius', 'Sem', 'Ham', 'et', 'Iafeth'],
#  ['corrumpo',
#   'sum',
#   'autem',
#   'terra',
#   'coram',
#   'deus',
#   'et',
#   'repleo',
#   'sum',
#   'iniquitas'],
#  ['cumque',
#   'video',
#   'deus',
#   'terra',
#   'sum',
#   'corruptus',
#   'omnis',
#   'quippe',
#   'caro',
#   'conrumpo',
#   'via',
#   'suus',
#   'super',
#   'terra'],
#  ['dico#2',
#   'ad',
#   'Noe',
#   'finis',
#   'universus',
#   'caro',
#   'venio',
#   'coram',
#   'ego',
#   'repleo',
#   'sum',
#   'terra',
#   'iniquitas',
#   'ab',
#   'facies',
#   'is',
#   'et',
#   'ego',
#   'disperdo',
#   'is',
#   'cum',
#   'terra'],
#  ['facio',
#   'tu',
#   'arca',
#   'de',
#   'lignum',
#   'levigo',
#   'mansiunculas',
#   'in',
#   'arca',
#   'facies',
#   'et',
#   'bitumen',
#   'linies',
#   'intrinsecus',
#   'et',
#   'extrinsecus'],
#  ['et',
#   'sic',
#   'facies',
#   'is',
#   'trecentorum',
#   'cubitum',
#   'sum',
#   'longitudo',
#   'arca',
#   'quinquaginta',
#   'cubitum',
#   'latitudo',
#   'et',
#   'triginta',
#   'cubitum',
#   'altitudo',
#   'ille'],
#  ['fenestra',
#   'in',
#   'arca',
#   'facies',
#   'et',
#   'in',
#   'cubitum',
#   'consummo',
#   'summitas',
#   'ostium',
#   'autem',
#   'arca',
#   'pono',
#   'ex',
#   'latus',
#   'deorsum',
#   'cenaculum',
#   'et',
#   'tristega',
#   'facies',
#   'in',
#   'is'],
#  ['ecce',
#   'ego',
#   'adduco',
#   'diluvium',
#   'aqua',
#   'super',
#   'terra',
#   'ut',
#   'interficio',
#   'omnis',
#   'caro',
#   'in',
#   'qui',
#   'spiritus',
#   'vita',
#   'sum',
#   'subter',
#   'caelum',
#   'universus',
#   'quis#2',
#   'in',
#   'terra',
#   'sum',
#   'consumo'],
#  ['ponamque',
#   'foedus#2',
#   'meus',
#   'tu',
#   'et',
#   'ingredieris',
#   'arca',
#   'tuuus',
#   'et',
#   'filius',
#   'tuus',
#   'uxor',
#   'tuus',
#   'et',
#   'uxor',
#   'filius',
#   'tuus',
#   'tu'],
#  ['et',
#   'ex',
#   'cunctus',
#   'animo',
#   'universus',
#   'caro',
#   'bini',
#   'induco',
#   'in',
#   'arca',
#   'ut',
#   'vivo',
#   'tu',
#   'masculinus',
#   'sexus',
#   'et',
#   'femininus'],
#  ['de',
#   'volucribus',
#   'iuxta',
#   'genus',
#   'suus',
#   'et',
#   'de',
#   'iumentum',
#   'in',
#   'genus',
#   'suus',
#   'et',
#   'ex',
#   'omnis',
#   'reptilis',
#   'terra',
#   'secundum',
#   'genus',
#   'suus',
#   'bini',
#   'de',
#   'omnis',
#   'ingredientur',
#   'tu',
#   'ut',
#   'possum',
#   'vivo'],
#  ['tollo',
#   'igitur',
#   'tu',
#   'ex',
#   'omnis',
#   'esca',
#   'quis#2',
#   'mando',
#   'possum',
#   'et',
#   'conporto',
#   'apud',
#   'tu',
#   'et',
#   'sum',
#   'tam',
#   'tu',
#   'quam#4',
#   'ille',
#   'in',
#   'cibus'],
#  ['facio', 'ergo', 'Noe', 'omnis', 'quis#2', 'praecipio', 'ille', 'deus'],
#  ['dico',
#   'dominus',
#   'ad',
#   'is',
#   'ingredior',
#   'tuuus',
#   'et',
#   'omnis',
#   'domus',
#   'tuus',
#   'arca',
#   'tu',
#   'enim',
#   'video',
#   'iustus',
#   'coram',
#   'ego',
#   'in',
#   'generatio',
#   'hic'],
#  ['ex',
#   'omnis',
#   'animo',
#   'mundum',
#   'tollo',
#   'septeni',
#   'septeni',
#   'masculus',
#   'et',
#   'femina',
#   'de',
#   'animo',
#   'verus',
#   'non',
#   'mundum',
#   'duo',
#   'duo',
#   'masculus',
#   'et',
#   'femina'],
#  ['sed',
#   'et',
#   'de',
#   'volatilis',
#   'caelum',
#   'septeni',
#   'septeni',
#   'masculus',
#   'et',
#   'femina',
#   'ut',
#   'salveo',
#   'semen',
#   'super',
#   'facies',
#   'universus',
#   'terra'],
#  ['adhuc',
#   'enim',
#   'et',
#   'post',
#   'dies',
#   'septem',
#   'ego',
#   'pluo',
#   'super',
#   'terra',
#   'quadraginta',
#   'dies',
#   'et',
#   'quadraginta',
#   'nox',
#   'et',
#   'deleo',
#   'omnis',
#   'substantia',
#   'quam#4',
#   'facio',
#   'de',
#   'superficies',
#   'terra'],
#  ['facio', 'ergo', 'Noe', 'omnis', 'quis#2', 'mando', 'is', 'dominus'],
#  ['eratque',
#   'sescentorum',
#   'annus',
#   'quando',
#   'diluvium',
#   'aqua',
#   'inundaverunt',
#   'super',
#   'terra'],
#  ['et',
#   'ingredior',
#   'sum',
#   'Noe',
#   'et',
#   'filius',
#   'is',
#   'uxor',
#   'is',
#   'et',
#   'uxor',
#   'filius',
#   'is',
#   'cum',
#   'is',
#   'in',
#   'arca',
#   'propter',
#   'aqua',
#   'diluvium'],
#  ['de',
#   'animo',
#   'quoque',
#   'mundum',
#   'et',
#   'immundus',
#   'et',
#   'de',
#   'volucribus',
#   'et',
#   'ex',
#   'omnis',
#   'quod',
#   'moveo',
#   'super',
#   'terra'],
#  ['duo',
#   'et',
#   'duo',
#   'ingredior',
#   'sum',
#   'ad',
#   'Noe',
#   'in',
#   'arca',
#   'masculus',
#   'et',
#   'femina',
#   'sicut',
#   'praecipio',
#   'deus',
#   'Noe'],
#  ['cumque',
#   'transeo',
#   'septem',
#   'dies',
#   'aqua',
#   'diluvium',
#   'inundaverunt',
#   'super',
#   'terra'],
#  ['annus',
#   'sescentesimo',
#   'vita',
#   'Noe',
#   'mensis',
#   'secundus',
#   'septimodecimo',
#   'dies',
#   'mensa',
#   'rumpo',
#   'sum',
#   'omnis',
#   'fons',
#   'abyssus',
#   'magnus',
#   'et',
#   'cataracta',
#   'caelum',
#   'aperio',
#   'sum'],
#  ['et',
#   'facio',
#   'sum',
#   'pluvius',
#   'super',
#   'terra',
#   'quadraginta',
#   'dies',
#   'et',
#   'quadraginta',
#   'nox'],
#  ['in',
#   'articulus',
#   'dies',
#   'ille',
#   'ingredior',
#   'sum',
#   'Noe',
#   'et',
#   'Sem',
#   'et',
#   'Ham',
#   'et',
#   'Iafeth',
#   'filius',
#   'is',
#   'uxor',
#   'ille',
#   'et',
#   'tres',
#   'uxor',
#   'filius',
#   'is',
#   'cum',
#   'is',
#   'in',
#   'arca'],
#  ['ipse',
#   'et',
#   'omnis',
#   'animal',
#   'secundum',
#   'genus',
#   'suus',
#   'universaque',
#   'iumentum',
#   'in',
#   'genus',
#   'suus',
#   'et',
#   'omnis',
#   'quod',
#   'moveo',
#   'super',
#   'terra',
#   'in',
#   'genus',
#   'suus',
#   'cunctumque',
#   'volatilis',
#   'secundum',
#   'genus',
#   'suus',
#   'universus',
#   'avis',
#   'omnesque',
#   'volucris'],
#  ['ingredior',
#   'sum',
#   'ad',
#   'Noe',
#   'in',
#   'arca',
#   'bini',
#   'et',
#   'bini',
#   'ex',
#   'omnis',
#   'caro',
#   'in',
#   'qui',
#   'sum',
#   'spiritus',
#   'vita'],
#  ['et',
#   'quis#2',
#   'ingredior',
#   'sum',
#   'masculus',
#   'et',
#   'femina',
#   'ex',
#   'omnis',
#   'caro',
#   'introeo',
#   'sicut',
#   'praecipio',
#   'is',
#   'deus',
#   'et',
#   'includo',
#   'is',
#   'dominus',
#   'de',
#   'foris#2'],
#  ['factumque',
#   'sum',
#   'diluvium',
#   'quadraginta',
#   'dies',
#   'super',
#   'terra',
#   'et',
#   'multiplico',
#   'sum',
#   'aqua',
#   'et',
#   'elevaverunt',
#   'arca',
#   'in',
#   'sublimus',
#   'ab',
#   'terra'],
#  ['vehementer',
#   'inundaverunt',
#   'et',
#   'omnis',
#   'repleo',
#   'in',
#   'superficies',
#   'terra',
#   'porro',
#   'arca',
#   'fero',
#   'super',
#   'aqua'],
#  ['et',
#   'aqua',
#   'praevaleo',
#   'nimis',
#   'super',
#   'terra',
#   'opertique',
#   'sum',
#   'omnis',
#   'mons',
#   'excello',
#   'sub',
#   'universus',
#   'caelum'],
#  ['quindecim',
#   'cubitum',
#   'alo',
#   'sum',
#   'aqua',
#   'super',
#   'mons',
#   'quos',
#   'operio'],
#  ['consumptaque',
#   'sum',
#   'omnis',
#   'caro',
#   'quis#2',
#   'moveo',
#   'super',
#   'terra',
#   'volucrum',
#   'animo',
#   'bestia',
#   'omniumque',
#   'reptilis',
#   'quis#2',
#   'repto',
#   'super',
#   'terra',
#   'universus',
#   'homo'],
#  ['et',
#   'cunctus',
#   'in',
#   'quis#2',
#   'spiraculum',
#   'vita',
#   'sum',
#   'in',
#   'terra',
#   'morior',
#   'sum'],
#  ['et',
#   'deleo',
#   'omnis',
#   'substantia',
#   'quis#2',
#   'sum',
#   'super',
#   'terra',
#   'ab',
#   'homo',
#   'usque',
#   'ad',
#   'pecus',
#   'tam',
#   'reptilis',
#   'quam#4',
#   'volucris',
#   'caelum',
#   'et',
#   'deleo',
#   'sum',
#   'de',
#   'terra',
#   'remaneo',
#   'autem',
#   'solus',
#   'Noe',
#   'et',
#   'quis#2',
#   'cum',
#   'is',
#   'sum',
#   'in',
#   'arca'],
#  ['obtinueruntque', 'aqua', 'terra', 'centum', 'quinquaginta', 'dies'],
#  ['recordor',
#   'autem',
#   'deus',
#   'Noe',
#   'cunctarumque',
#   'animo',
#   'et',
#   'omnis',
#   'iumentum',
#   'quis#2',
#   'sum',
#   'cum',
#   'is',
#   'in',
#   'arca',
#   'adduco',
#   'spiritus',
#   'super',
#   'terra',
#   'et',
#   'imminuo',
#   'sum',
#   'aqua'],
#  ['et',
#   'claudo',
#   'sum',
#   'fons',
#   'abyssus',
#   'et',
#   'cataracta',
#   'caelum',
#   'et',
#   'prohibeo',
#   'sum',
#   'pluvia',
#   'de',
#   'caelum'],
#  ['reversaeque',
#   'aqua',
#   'de',
#   'terra',
#   'eo',
#   'et',
#   'redeo',
#   'et',
#   'coepio',
#   'minuo',
#   'post',
#   'centum',
#   'quinquaginta',
#   'dies'],
#  ['requievitque',
#   'arca',
#   'mensis',
#   'septimus',
#   'vicesimus',
#   'septimus',
#   'dies',
#   'mensa',
#   'super',
#   'mons',
#   'Armenia'],
#  ['at',
#   'verus',
#   'aqua',
#   'eo',
#   'et',
#   'decresco',
#   'usque',
#   'ad',
#   'decimus',
#   'mensis',
#   'decimus',
#   'enim',
#   'mensis',
#   'primus',
#   'dies',
#   'mensa',
#   'appareo',
#   'cacumen',
#   'mons'],
#  ['cumque',
#   'transeo',
#   'quadraginta',
#   'dies',
#   'aperio',
#   'Noe',
#   'fenestra',
#   'arca',
#   'quam#4',
#   'facio',
#   'dimitto',
#   'corvus'],
#  ['quis#2',
#   'egredior',
#   'et',
#   'revorto',
#   'donec',
#   'sicco',
#   'aqua',
#   'super',
#   'terra'],
#  ['emitto',
#   'quoque',
#   'columba',
#   'post',
#   'is',
#   'ut',
#   'video',
#   'si',
#   'iam',
#   'cessassent',
#   'aqua',
#   'super',
#   'facies',
#   'terra'],
#  ['quis#2',
#   'cum',
#   'non',
#   'invenio',
#   'ubi',
#   'requiesco',
#   'pes',
#   'is',
#   'revertor',
#   'sum',
#   'ad',
#   'is',
#   'in',
#   'arca',
#   'aqua',
#   'enim',
#   'sum',
#   'super',
#   'universus',
#   'terra',
#   'extenditque',
#   'manus',
#   'et',
#   'adprehendo',
#   'infero',
#   'in',
#   'arca'],
#  ['exspecto',
#   'autem',
#   'ultra',
#   'septem',
#   'dies',
#   'alius',
#   'rursus',
#   'dimitto',
#   'columba',
#   'ex',
#   'arca'],
#  ['at',
#   'ille',
#   'venio',
#   'ad',
#   'is',
#   'ad',
#   'vespera',
#   'porto',
#   'ramus',
#   'oliva',
#   'vireo',
#   'folium',
#   'in',
#   'os#1',
#   'suus',
#   'intellego',
#   'ergo',
#   'Noe',
#   'quod',
#   'cessassent',
#   'aqua',
#   'super',
#   'terra'],
#  ['expectavitque',
#   'nihilominus',
#   'septem',
#   'alius',
#   'dies',
#   'et',
#   'emitto',
#   'columba',
#   'quis#2',
#   'non',
#   'sum',
#   'revertor',
#   'ultra',
#   'ad',
#   'is'],
#  ['igitur',
#   'sescentesimo',
#   'primus',
#   'annus',
#   'primus',
#   'mensis',
#   'primus',
#   'dies',
#   'mensa',
#   'imminuo',
#   'sum',
#   'aqua',
#   'super',
#   'terra',
#   'et',
#   'aperio',
#   'Noe',
#   'tego',
#   'arca',
#   'aspicio',
#   'video',
#   'quod',
#   'exsicco',
#   'sum',
#   'superficies',
#   'terra'],
#  ['mensis',
#   'secundus',
#   'septimus',
#   'et',
#   'vicesimus',
#   'dies',
#   'mensa',
#   'arefacio',
#   'sum',
#   'terra'],
#  ['loquor', 'sum', 'autem', 'deus', 'ad', 'Noe', 'dico#2'],
#  ['egredior',
#   'de',
#   'arca',
#   'tuuus',
#   'et',
#   'uxor',
#   'tuus',
#   'filius',
#   'tuus',
#   'et',
#   'uxor',
#   'filius',
#   'tuus',
#   'tu'],
#  ['cunctus',
#   'animo',
#   'quis#2',
#   'sum',
#   'apud',
#   'tu',
#   'ex',
#   'omnis',
#   'caro',
#   'tam',
#   'in',
#   'volatilis',
#   'quam#4',
#   'in',
#   'bestia',
#   'et',
#   'in',
#   'universus',
#   'reptilis',
#   'quis#2',
#   'repto',
#   'super',
#   'terra',
#   'educo',
#   'tu',
#   'et',
#   'ingredimini',
#   'super',
#   'terra',
#   'crescite',
#   'et',
#   'multiplico',
#   'super',
#   'is'],
#  ['egredior',
#   'sum',
#   'ergo',
#   'Noe',
#   'et',
#   'filius',
#   'is',
#   'uxor',
#   'ille',
#   'et',
#   'uxor',
#   'filius',
#   'is',
#   'cum',
#   'is'],
#  ['sed',
#   'et',
#   'omnis',
#   'animo',
#   'iumentum',
#   'et',
#   'reptilis',
#   'quis#2',
#   'repo',
#   'super',
#   'terra',
#   'secundum',
#   'genus',
#   'suus',
#   'arca',
#   'egredior',
#   'sum'],
#  ['aedifico',
#   'autem',
#   'Noe',
#   'altar',
#   'dominus',
#   'et',
#   'tollo',
#   'de',
#   'cunctus',
#   'pecus',
#   'et',
#   'volucribus',
#   'mundum',
#   'offertor',
#   'holocaustum',
#   'super',
#   'altar'],
#  ['odoratusque',
#   'sum',
#   'dominus',
#   'odor',
#   'suavitas',
#   'et',
#   'ajo',
#   'ad',
#   'is',
#   'nequaquam',
#   'ultra',
#   'maledicus',
#   'terra',
#   'propter',
#   'homo',
#   'sensus',
#   'enim',
#   'et',
#   'cogitatio',
#   'humanus',
#   'cor',
#   'in',
#   'malus#3',
#   'pronus',
#   'sum',
#   'ab',
#   'adulescentia',
#   'suus',
#   'non',
#   'igitur',
#   'ultra',
#   'percutio',
#   'omnis',
#   'animo',
#   'sicut',
#   'facio'],
#  ['cunctus',
#   'dies',
#   'terra',
#   'sementis',
#   'et',
#   'messis',
#   'frigus',
#   'et',
#   'aestus',
#   'aestas',
#   'et',
#   'hiem(p)s',
#   'nox',
#   'et',
#   'dies',
#   'non',
#   'requiesco'],
#  ['benedico',
#   'deus',
#   'Noe',
#   'et',
#   'filius',
#   'is',
#   'et',
#   'dico#2',
#   'ad',
#   'is',
#   'crescite',
#   'et',
#   'multiplico',
#   'et',
#   'impleo',
#   'terra'],
#  ['et',
#   'terror',
#   'vester',
#   'atque',
#   'tremor',
#   'sum',
#   'super',
#   'cunctus',
#   'animal',
#   'terra',
#   'et',
#   'super',
#   'omnis',
#   'volucris',
#   'caelum',
#   'cum',
#   'universus',
#   'quis#2',
#   'moveo',
#   'in',
#   'terra',
#   'omnis',
#   'piscis',
#   'mas',
#   'manus',
#   'vester',
#   'trado',
#   'sum'],
#  ['et',
#   'omnis',
#   'quod',
#   'moveo',
#   'et',
#   'vivo',
#   'sum',
#   'vos',
#   'in',
#   'cibus',
#   'quasi',
#   'holus',
#   'vireo',
#   'trado',
#   'vos',
#   'omnis'],
#  ['excipio', 'quod', 'caro', 'cum', 'sanguis', 'non', 'comedetis'],
#  ['sanguis',
#   'enim',
#   'anima',
#   'vestrarum',
#   'requiro',
#   'de',
#   'manus',
#   'cunctus',
#   'bestia',
#   'et',
#   'de',
#   'manus',
#   'homo',
#   'de',
#   'manus',
#   'vir',
#   'et',
#   'frater',
#   'is',
#   'requiro',
#   'anima',
#   'homo'],
#  ['quicumque',
#   'effundo',
#   'humanus',
#   'sanguis',
#   'fundo',
#   'sanguis',
#   'ille',
#   'ad',
#   'imago',
#   'quippe',
#   'deus',
#   'facio',
#   'sum',
#   'homo'],
#  ['vos',
#   'autem',
#   'crescite',
#   'et',
#   'multiplico',
#   'et',
#   'ingredimini',
#   'super',
#   'terra',
#   'et',
#   'impleo',
#   'is'],
#  ['hic',
#   'quoque',
#   'dico#2',
#   'deus',
#   'ad',
#   'Noe',
#   'et',
#   'ad',
#   'filius',
#   'is',
#   'cum',
#   'is'],
#  ['ecce',
#   'ego',
#   'statua',
#   'paciscor',
#   'meus',
#   'tu',
#   'et',
#   'cum',
#   'semen',
#   'vester',
#   'post',
#   'vos'],
#  ['et',
#   'ad',
#   'omnis',
#   'anima',
#   'vivo',
#   'quis#2',
#   'sum',
#   'tu',
#   'tam',
#   'in',
#   'volucribus',
#   'quam#4',
#   'in',
#   'iumentum',
#   'et',
#   'pecudibus',
#   'terra',
#   'cunctus',
#   'quis#2',
#   'egredior',
#   'sum',
#   'de',
#   'arca',
#   'et',
#   'universus',
#   'bestia',
#   'terra'],
#  ['statua',
#   'paciscor',
#   'meus',
#   'tu',
#   'et',
#   'nequaquam',
#   'ultra',
#   'interficio',
#   'omnis',
#   'caro',
#   'aqua',
#   'diluvium',
#   'neque',
#   'sum',
#   'deinceps',
#   'diluvium',
#   'dissipans',
#   'terra'],
#  ['dico',
#   'deus',
#   'hic',
#   'signum',
#   'foedus',
#   'quod',
#   'do',
#   'inter',
#   'ego',
#   'et',
#   'vos',
#   'et',
#   'ad',
#   'omnis',
#   'anima',
#   'vivo',
#   'quis#2',
#   'sum',
#   'tu',
#   'in',
#   'generatio',
#   'sempiternus'],
#  ['arcus',
#   'meus',
#   'pono',
#   'in',
#   'nubes',
#   'et',
#   'sum',
#   'signum',
#   'foedus',
#   'inter',
#   'ego',
#   'et',
#   'inter',
#   'terra'],
#  ['cumque',
#   'obduco',
#   'nubes',
#   'caelum',
#   'appareo',
#   'arcus',
#   'meus',
#   'in',
#   'nubes'],
#  ['et',
#   'recordabor',
#   'foedus',
#   'meus',
#   'tu',
#   'et',
#   'cum',
#   'omnis',
#   'anima',
#   'vivo',
#   'quis#2',
#   'caro',
#   'vegetat',
#   'et',
#   'non',
#   'sum',
#   'ultra',
#   'aqua',
#   'diluvium',
#   'ad',
#   'deleo',
#   'universus',
#   'caro'],
#  ['sum',
#   'arcus',
#   'in',
#   'nubes',
#   'et',
#   'video',
#   'ille',
#   'et',
#   'recordabor',
#   'foedus',
#   'sempiternus',
#   'quod',
#   'paciscor',
#   'sum',
#   'inter',
#   'deus',
#   'et',
#   'inter',
#   'omnis',
#   'anima',
#   'vivo',
#   'universus',
#   'caro',
#   'quis#2',
#   'sum',
#   'super',
#   'terra'],
#  ['dico',
#   'deus',
#   'Noe',
#   'hic',
#   'sum',
#   'signum',
#   'foedus',
#   'quod',
#   'constituo',
#   'inter',
#   'ego',
#   'et',
#   'inter',
#   'omnis',
#   'caro',
#   'super',
#   'terra'],
#  ['sum',
#   'igitur',
#   'filius',
#   'Noe',
#   'quis#2',
#   'egredior',
#   'sum',
#   'de',
#   'arca',
#   'Sem',
#   'Ham',
#   'et',
#   'Iafeth',
#   'porro',
#   'Ham',
#   'ipse',
#   'sum',
#   'pater',
#   'Chanaan'],
#  ['tres',
#   'iste',
#   'sum',
#   'filius',
#   'Noe',
#   'et',
#   'ab',
#   'hic',
#   'disseminatum',
#   'sum',
#   'omnis',
#   'homo',
#   'genus',
#   'super',
#   'universus',
#   'terra'],
#  ['coepitque',
#   'Noe',
#   'vir',
#   'agricola',
#   'exerceo',
#   'terra',
#   'et',
#   'planto',
#   'vinea'],
#  ['bibensque',
#   'vinum',
#   'inebrio',
#   'sum',
#   'et',
#   'nudo',
#   'in',
#   'tabernaculum',
#   'suus'],
#  ['quod',
#   'cum',
#   'video',
#   'Ham',
#   'pater',
#   'Chanaan',
#   'vereor',
#   'scilicet',
#   'pater',
#   'suus',
#   'sum',
#   'nudus',
#   'nuntio',
#   'duo',
#   'frater',
#   'suus',
#   'foras'],
#  ['at',
#   'verus',
#   'Sem',
#   'et',
#   'Iafeth',
#   'pallium',
#   'inpono',
#   'umerus',
#   'suus',
#   'et',
#   'incedo',
#   'retrorsus',
#   'operio',
#   'verecundus',
#   'pater',
#   'suus',
#   'faciesque',
#   'is',
#   'averto',
#   'sum',
#   'et',
#   'pater',
#   'virilis',
#   'non',
#   'video'],
#  ['evigilo',
#   'autem',
#   'Noe',
#   'ex',
#   'vinum',
#   'cum',
#   'disco',
#   'quis#2',
#   'facio',
#   'is',
#   'filius',
#   'suus',
#   'parvus'],
#  ['ajo', 'maledico', 'Chanaan', 'servus', 'servus', 'sum', 'frater', 'suus'],
#  ['dico',
#   'benedico',
#   'dominus',
#   'deus',
#   'Sem',
#   'sum',
#   'Chanaan',
#   'servus',
#   'is'],
#  ['dilato',
#   'deus',
#   'Iafeth',
#   'et',
#   'habito',
#   'in',
#   'tabernaculum',
#   'Sem',
#   'sitque',
#   'Chanaan',
#   'servus',
#   'is'],
#  ['vivo',
#   'autem',
#   'Noe',
#   'post',
#   'diluvium',
#   'trecenti',
#   'quinquaginta',
#   'annus'],
#  ['et',
#   'impleo',
#   'sum',
#   'omnis',
#   'dies',
#   'is',
#   'nongentorum',
#   'quinquaginta',
#   'annus',
#   'et',
#   'morior',
#   'sum'],
#  ['hic',
#   'generatio',
#   'filius',
#   'Noe',
#   'Sem',
#   'Ham',
#   'Iafeth',
#   'natique',
#   'sum',
#   'is',
#   'filius',
#   'post',
#   'diluvium'],
#  ['filius',
#   'Iafeth',
#   'Gomer',
#   'Magog',
#   'et',
#   'Madai',
#   'Iavan',
#   'et',
#   'Thubal',
#   'et',
#   'Mosoch',
#   'et',
#   'Thiras'],
#  ['porro', 'filius', 'Gomer', 'Aschenez', 'et', 'Rifath', 'et', 'Thogorma'],
#  ['filius',
#   'autem',
#   'Iavan',
#   'elido',
#   'et',
#   'Tharsis',
#   'Cetthim',
#   'et',
#   'Dodanim'],
#  ['ab',
#   'hic',
#   'divisor',
#   'sum',
#   'insula',
#   'gens',
#   'in',
#   'regio',
#   'suus',
#   'unusquisque',
#   'secundum',
#   'lingua',
#   'et',
#   'familia',
#   'in',
#   'natio',
#   'suus'],
#  ['filius',
#   'autem',
#   'Ham',
#   'Chus',
#   'et',
#   'Mesraim',
#   'et',
#   'Fut',
#   'et',
#   'Chanaan'],
#  ['filius',
#   'Chus',
#   'Saba',
#   'et',
#   'Hevila',
#   'et',
#   'Sabatha',
#   'et',
#   'Regma',
#   'et',
#   'Sabathaca',
#   'filius',
#   'Regma',
#   'Saba',
#   'et',
#   'Dadan'],
#  ['porro',
#   'Chus',
#   'gigno',
#   'Nemrod',
#   'ipse',
#   'coepio',
#   'sum',
#   'possum',
#   'in',
#   'terra'],
#  ['et',
#   'sum',
#   'robustus',
#   'venator',
#   'coram',
#   'dominus',
#   'ab',
#   'hic',
#   'exeo',
#   'proverbium',
#   'quasi',
#   'Nemrod',
#   'robustus',
#   'venator',
#   'coram',
#   'dominus'],
#  ['sum',
#   'autem',
#   'principium',
#   'regnum',
#   'is',
#   'Babylon',
#   'et',
#   'Arach',
#   'et',
#   'Archad',
#   'et',
#   'Chalanne',
#   'in',
#   'terra',
#   'Sennaar'],
#  ['de',
#   'terra',
#   'ille',
#   'egredior',
#   'sum',
#   'Assur',
#   'et',
#   'aedifico',
#   'Nineven',
#   'et',
#   'platea',
#   'civitas',
#   'et',
#   'Chale'],
#  ['Resen',
#   'quoque',
#   'inter',
#   'Nineven',
#   'et',
#   'Chale',
#   'hic',
#   'sum',
#   'civitas',
#   'magnus'],
#  ['at',
#   'verus',
#   'Mesraim',
#   'gigno',
#   'Ludim',
#   'et',
#   'Anamim',
#   'et',
#   'Laabim',
#   'Nepthuim'],
#  ['et',
#   'Phetrusim',
#   'et',
#   'Cesluim',
#   'de',
#   'quis#2',
#   'egredior',
#   'sum',
#   'Philisthim',
#   'et',
#   'Capthurim'],
#  ['Chanaan', 'autem', 'gigno', 'Sidon', 'primogenitus', 'suus', 'Ettheum'],
#  ['et', 'Iebuseum', 'et', 'Amorreum', 'Gergeseum'],
#  ['Eveum', 'et', 'Araceum', 'Sineum'],
#  ['et',
#   'Aradius',
#   'Samariten',
#   'et',
#   'Amatheum',
#   'et',
#   'post',
#   'hic',
#   'disseminati',
#   'sum',
#   'populus#2',
#   'Chananeorum'],
#  ['factique',
#   'sum',
#   'termen',
#   'Chanaan',
#   'venio',
#   'ab',
#   'Sidon',
#   'Geraram',
#   'usque',
#   'Gaza',
#   'donec',
#   'ingrediaris',
#   'Sodoma',
#   'et',
#   'Gomorra',
#   'et',
#   'Adama',
#   'et',
#   'Seboim',
#   'usque',
#   'Lesa'],
#  ['hic',
#   'filius',
#   'Ham',
#   'in',
#   'cognatio',
#   'et',
#   'lingua',
#   'et',
#   'generatio',
#   'terrisque',
#   'et',
#   'gens',
#   'suus'],
#  ['de',
#   'Sem',
#   'quoque',
#   'nascor',
#   'sum',
#   'pater',
#   'omnis',
#   'filius',
#   'Eber',
#   'frater',
#   'Iafeth',
#   'magnus'],
#  ['filius',
#   'Sem',
#   'Aelam',
#   'et',
#   'Assur',
#   'et',
#   'Arfaxad',
#   'et',
#   'Lud',
#   'et',
#   'Aram'],
#  ['filius', 'Aram', 'Us', 'et', 'Hul', 'et', 'Gether', 'et', 'Mes'],
#  ['at',
#   'verus',
#   'Arfaxad',
#   'gigno',
#   'salum',
#   'de',
#   'quo',
#   'ortus',
#   'sum',
#   'Eber'],
#  ['natique',
#   'sum',
#   'Eber',
#   'filius',
#   'duo',
#   'nomen',
#   'unus',
#   'Faleg',
#   'is',
#   'quod',
#   'in',
#   'dies',
#   'is',
#   'divido',
#   'sum',
#   'terra',
#   'et',
#   'nomen',
#   'frater',
#   'is',
#   'Iectan'],
#  ['quis#2',
#   'Iectan',
#   'gigno',
#   'Helmodad',
#   'et',
#   'Saleph',
#   'et',
#   'Asarmoth',
#   'Iare'],
#  ['et', 'Aduram', 'et', 'Uzal', 'Decla'],
#  ['et', 'Ebal', 'et', 'Abimahel', 'Saba'],
#  ['et',
#   'Ophir',
#   'et',
#   'Evila',
#   'et',
#   'Iobab',
#   'omnis',
#   'iste',
#   'filius',
#   'Iectan'],
#  ['et',
#   'facio',
#   'sum',
#   'habitatio',
#   'is',
#   'de',
#   'Messa',
#   'pergo',
#   'usque',
#   'Sephar',
#   'mons',
#   'orientalis'],
#  ['iste',
#   'filius',
#   'Sem',
#   'secundum',
#   'cognatio',
#   'et',
#   'lingua',
#   'et',
#   'regio',
#   'in',
#   'gens',
#   'suus'],
#  ['hic',
#   'familia',
#   'Noe',
#   'iuxta',
#   'populus',
#   'et',
#   'natio',
#   'suus',
#   'ab',
#   'hic',
#   'divisor',
#   'sum',
#   'gens',
#   'in',
#   'terra',
#   'post',
#   'diluvium'],
#  ['sum', 'autem', 'terra', 'labium', 'unus', 'et', 'sermo', 'idem'],
#  ['cumque',
#   'proficisco',
#   'de',
#   'oriens',
#   'invenio',
#   'campus',
#   'in',
#   'terra',
#   'Sennaar',
#   'et',
#   'habito',
#   'in',
#   'is'],
#  ['dico',
#   'alter',
#   'ad',
#   'proximum',
#   'suus',
#   'venio',
#   'facio',
#   'later',
#   'et',
#   'coquo',
#   'is',
#   'ignis',
#   'habueruntque',
#   'later',
#   'pro',
#   'saxum',
#   'et',
#   'bitumen',
#   'pro',
#   'cemento'],
#  ['et',
#   'dico#2',
#   'venio',
#   'facio',
#   'nos',
#   'civitas',
#   'et',
#   'turris',
#   'quis#2',
#   'culmen',
#   'pertingo',
#   'ad',
#   'caelum',
#   'et',
#   'celebro',
#   'nomen',
#   'noster',
#   'antequam',
#   'divido',
#   'in',
#   'universus',
#   'terra'],
#  ['descendo',
#   'autem',
#   'dominus',
#   'ut',
#   'video',
#   'civitas',
#   'et',
#   'turris',
#   'quam#4',
#   'aedifico',
#   'filius',
#   'Adam'],
#  ['et',
#   'dico#2',
#   'ecce',
#   'unus',
#   'sum',
#   'populus',
#   'et',
#   'unus',
#   'labium',
#   'omnis',
#   'coeperuntque',
#   'hic',
#   'facio',
#   'nec',
#   'desisto',
#   'ab',
#   'cogitatio',
#   'suus',
#   'donec',
#   'is',
#   'opus',
#   'conpleo'],
#  ['venio',
#   'igitur',
#   'descendo',
#   'et',
#   'confundo',
#   'ibi',
#   'lingua',
#   'is',
#   'ut',
#   'non',
#   'audio',
#   'unusquisque',
#   'vox',
#   'proximus',
#   'suus'],
#  ['atque',
#   'ita',
#   'divisor',
#   'is',
#   'dominus',
#   'ex',
#   'ille',
#   'locus',
#   'in',
#   'universus',
#   'terra',
#   'et',
#   'cesso',
#   'aedifico',
#   'civitas'],
#  ['et',
#   'idcirco',
#   'voco',
#   'sum',
#   'nomen',
#   'is',
#   'Babel',
#   'quia',
#   'ibi',
#   'confundo',
#   'sum',
#   'labium',
#   'universus',
#   'terra',
#   'et',
#   'inde',
#   'dispergo',
#   'is',
#   'dominus',
#   'super',
#   'facies',
#   'cunctus',
#   'regio'],
#  ['hic',
#   'generatio',
#   'Sem',
#   'Sem',
#   'centum',
#   'sum',
#   'annus',
#   'quando',
#   'gigno',
#   'Arfaxad',
#   'biennium',
#   'post',
#   'diluvium'],
#  ['vivo',
#   'Sem',
#   'postquam',
#   'gigno',
#   'Arfaxad',
#   'quingenti',
#   'annus',
#   'et',
#   'gigno',
#   'filius',
#   'et',
#   'filia'],
#  ['porro',
#   'Arfaxad',
#   'vivo',
#   'triginta',
#   'quinque',
#   'annus',
#   'et',
#   'gigno',
#   'Sale'],
#  ['vivo',
#   'Arfaxad',
#   'postquam',
#   'gigno',
#   'Sale',
#   'trecenti',
#   'tres',
#   'annus',
# ...
#   'aries',
#   'grex',
#   'tuus',
#   'non',
#   'comedo'],
#  ['nec',
#   'capio',
#   'ab',
#   'bestia',
#   'ostendo',
#   'tu',
#   'ego',
#   'damnum',
#   'omnis',
#   'reddo',
#   'quisquis',
#   'furto',
#   'pereo',
#   'ab',
#   'ego',
#   'exigo'],
#  ['dies',
#   'noctuque',
#   'aestus',
#   'uro',
#   'et',
#   'gelus',
#   'fugio',
#   'somnus',
#   'ab',
#   'oculus',
#   'meus'],
#  ['sic',
#   'per',
#   'viginti',
#   'annus',
#   'in',
#   'domus',
#   'tuus',
#   'servio',
#   'tu',
#   'quattuordecim',
#   'pro',
#   'filia',
#   'et',
#   'sex',
#   'pro',
#   'grex',
#   'tuus',
#   'inmutasti',
#   'quoque',
#   'merces',
#   'meus',
#   'decem',
#   'vicis'],
#  ['nisi',
#   'deus',
#   'pater',
#   'meus',
#   'Abraham',
#   'et',
#   'Timor',
#   'Isaac',
#   'adfuisset',
#   'ego',
#   'forsitan',
#   'modus',
#   'nudus',
#   'ego',
#   'dimitto',
#   'adflictionem',
#   'meus',
#   'et',
#   'labor',
#   'manus',
#   'meus',
#   'respicio',
#   'deus',
#   'et',
#   'arguo',
#   'tu',
#   'heri'],
#  ['respondeo',
#   'is',
#   'Laban',
#   'filia',
#   'et',
#   'filius',
#   'et',
#   'grex',
#   'tuus',
#   'et',
#   'omnis',
#   'quis#2',
#   'cerno',
#   'meus',
#   'sum',
#   'quis#2',
#   'possum',
#   'facio',
#   'filius',
#   'et',
#   'nepos',
#   'meus'],
#  ['venio',
#   'ergo',
#   'et',
#   'ineo',
#   'foedus#2',
#   'ut',
#   'sum',
#   'testimonium',
#   'inter',
#   'ego',
#   'et',
#   'tu'],
#  ['fero', 'itaque', 'Iacob', 'lapis', 'et', 'erigo', 'ille', 'in', 'titulus'],
#  ['dico',
#   'frater',
#   'suus',
#   'affero',
#   'lapis',
#   'quis#2',
#   'congrego',
#   'facio',
#   'tumulus',
#   'comederuntque',
#   'super',
#   'is'],
#  ['quis#2',
#   'voco',
#   'Laban',
#   'tumulus',
#   'Testa',
#   'et',
#   'Iacob',
#   'acervus',
#   'testimonium',
#   'uterque',
#   'iuxta',
#   'proprietas',
#   'lingua',
#   'suus'],
#  ['dico',
#   'Laban',
#   'tumulus',
#   'iste',
#   'testis',
#   'sum',
#   'inter',
#   'ego',
#   'et',
#   'tu',
#   'hodie',
#   'et',
#   'idcirco',
#   'appello',
#   'sum',
#   'nomen',
#   'is',
#   'Galaad',
#   'is',
#   'sum',
#   'tumulus',
#   'Testa'],
#  ['intueatur',
#   'dominus',
#   'et',
#   'iudico',
#   'inter',
#   'nos',
#   'quando',
#   'recedo',
#   'ab',
#   'nos'],
#  ['si',
#   'affligo',
#   'filia',
#   'meus',
#   'et',
#   'si',
#   'introduco',
#   'uxor',
#   'alius',
#   'super',
#   'is',
#   'nullus',
#   'sermo',
#   'noster',
#   'testis',
#   'sum',
#   'absque',
#   'deus',
#   'quis#2',
#   'praesens',
#   'respicio'],
#  ['dico',
#   'rursus',
#   'ad',
#   'Iacob',
#   'en',
#   'tumulus',
#   'hic',
#   'et',
#   'lapis',
#   'quis#2',
#   'erigo',
#   'inter',
#   'ego',
#   'et',
#   'tu'],
#  ['testis',
#   'sum',
#   'tumulus',
#   'inquam',
#   'iste',
#   'et',
#   'lapis',
#   'sum',
#   'in',
#   'testimonium',
#   'si',
#   'aut',
#   'ego',
#   'transeo',
#   'ille',
#   'pergo',
#   'ad',
#   'tu',
#   'aut',
#   'tuuus',
#   'praetereo',
#   'malus#3',
#   'ego',
#   'cogito'],
#  ['deus',
#   'Abraham',
#   'et',
#   'deus',
#   'Nahor',
#   'iudico',
#   'inter',
#   'nos',
#   'deus',
#   'pater',
#   'is',
#   'juro',
#   'Iacob',
#   'per',
#   'timor',
#   'pater',
#   'suus',
#   'Isaac'],
#  ['immolatisque',
#   'victima',
#   'in',
#   'mons',
#   'voco',
#   'frater',
#   'suus',
#   'ut',
#   'edo',
#   'panis',
#   'quis#2',
#   'cum',
#   'comedissent',
#   'maneo',
#   'ibi'],
#  ['Laban',
#   'verus',
#   'de',
#   'nox',
#   'consurgo',
#   'osculor',
#   'sum',
#   'filius',
#   'et',
#   'filia',
#   'suus',
#   'et',
#   'benedico',
#   'ille',
#   'revertor',
#   'in',
#   'locus',
#   'suus'],
#  ['Iacob',
#   'quoque',
#   'abeo',
#   'iter',
#   'quo',
#   'coepio',
#   'fueruntque',
#   'is',
#   'obviam',
#   'angelus',
#   'deus'],
#  ['quos',
#   'cum',
#   'video',
#   'ajo',
#   'castrum',
#   'deus',
#   'sum',
#   'hic',
#   'et',
#   'appello',
#   'nomen',
#   'locus',
#   'ille',
#   'Manaim',
#   'is',
#   'sum',
#   'castrum'],
#  ['mitto',
#   'autem',
#   'et',
#   'nuntius',
#   'ante',
#   'se',
#   'ad',
#   'Esau',
#   'frater',
#   'suus',
#   'in',
#   'terra',
#   'Seir',
#   'regio',
#   'Edom'],
#  ['praecipio',
#   'is',
#   'dico#2',
#   'sic',
#   'loquor',
#   'dominus',
#   'meus',
#   'Esau',
#   'hic',
#   'dico#2',
#   'frater',
#   'tuus',
#   'Iacob',
#   'apud',
#   'Laban',
#   'peregrinor',
#   'sum',
#   'et',
#   'sum',
#   'usque',
#   'in',
#   'praesens',
#   'dies'],
#  ['habeo',
#   'bos',
#   'et',
#   'asinus',
#   'ovis',
#   'et',
#   'servus',
#   'atque',
#   'ancilla',
#   'mittoque',
#   'nunc',
#   'legatio',
#   'ad',
#   'dominus',
#   'meus',
#   'ut',
#   'invenio',
#   'gratia',
#   'in',
#   'conspectus',
#   'tuus'],
#  ['revertor',
#   'sum',
#   'nuntium',
#   'ad',
#   'Iacob',
#   'dico#2',
#   'venio',
#   'ad',
#   'Esau',
#   'frater',
#   'tuus',
#   'et',
#   'ecce',
#   'propero',
#   'in',
#   'occursus',
#   'tu',
#   'cum',
#   'quadringentis',
#   'vir'],
#  ['timeo',
#   'Iacob',
#   'valde',
#   'et',
#   'perterreo',
#   'divisor',
#   'populus',
#   'quis#2',
#   'se',
#   'cum',
#   'sum',
#   'grex',
#   'quoque',
#   'et',
#   'ovis',
#   'et',
#   'bos',
#   'et',
#   'camelus',
#   'in',
#   'duo',
#   'turma'],
#  ['dico#2',
#   'si',
#   'venio',
#   'Esau',
#   'ad',
#   'unus',
#   'turma',
#   'et',
#   'percutio',
#   'is',
#   'alius',
#   'turma',
#   'quis#2',
#   'reliquus',
#   'sum',
#   'salvo'],
#  ['dico',
#   'Iacob',
#   'deus',
#   'pater',
#   'meus',
#   'Abraham',
#   'et',
#   'deus',
#   'pater',
#   'meus',
#   'Isaac',
#   'dominus',
#   'quis#2',
#   'dico#2',
#   'ego',
#   'revertere',
#   'in',
#   'terra',
#   'tuus',
#   'et',
#   'in',
#   'locus',
#   'nativitas',
#   'tuus',
#   'et',
#   'benefacio',
#   'tu'],
#  ['parvus',
#   'sum',
#   'cunctus',
#   'miseratio',
#   'et',
#   'veritas',
#   'quam#4',
#   'explesti',
#   'servus',
#   'tuus',
#   'in',
#   'baculum',
#   'meus',
#   'transeo',
#   'Iordanes',
#   'iste',
#   'et',
#   'nunc',
#   'cum',
#   'duo',
#   'turma',
#   'regredior'],
#  ['eruo',
#   'ego',
#   'de',
#   'manus',
#   'frater',
#   'meus',
#   'de',
#   'manus',
#   'Esau',
#   'quia',
#   'valde',
#   'is',
#   'timeo',
#   'ne#2',
#   'forte',
#   'venio',
#   'percutio',
#   'mater',
#   'cum',
#   'filius'],
#  ['tuuus',
#   'loquor',
#   'sum',
#   'quod',
#   'bene',
#   'ego',
#   'facio',
#   'et',
#   'dilato',
#   'semen',
#   'meus',
#   'sicut',
#   'harena',
#   'mas',
#   'quis#2',
#   'prae',
#   'multitudo',
#   'numerarius',
#   'non',
#   'possum'],
#  ['cumque',
#   'dormisset',
#   'ibi',
#   'nox',
#   'ille',
#   'separo',
#   'de',
#   'hic',
#   'quis#2',
#   'habeo',
#   'munus',
#   'Esau',
#   'frater',
#   'suus'],
#  ['capra',
#   'ducentas',
#   'hircos',
#   'viginti',
#   'ovis',
#   'ducentas',
#   'aries',
#   'viginti'],
#  ['camelus',
#   'fetus',
#   'cum',
#   'pullus',
#   'suus',
#   'triginta',
#   'vacca',
#   'quadraginta',
#   'et',
#   'taurus',
#   'viginti',
#   'asina',
#   'viginti',
#   'et',
#   'pullus',
#   'is',
#   'decem'],
#  ['et',
#   'mitto',
#   'per',
#   'manus',
#   'servus',
#   'suus',
#   'singulus',
#   'seorsum',
#   'grex',
#   'dico',
#   'puer',
#   'suus',
#   'antecedite',
#   'ego',
#   'et',
#   'sum',
#   'spatium',
#   'inter',
#   'grex',
#   'et',
#   'grex'],
#  ['et',
#   'praecipio',
#   'prior',
#   'dico#2',
#   'si',
#   'obvius',
#   'habeo',
#   'Esau',
#   'frater',
#   'meus',
#   'et',
#   'interrogo',
#   'tu',
#   'quis#2',
#   'sum',
#   'et',
#   'quo',
#   'vado',
#   'et',
#   'quis#2',
#   'sum',
#   'iste',
#   'quis#2',
#   'sequor'],
#  ['respondeo',
#   'servus',
#   'tuus',
#   'Iacob',
#   'munus',
#   'mitto',
#   'dominus',
#   'meus',
#   'Esau',
#   'ipse',
#   'quoque',
#   'post',
#   'nos',
#   'venio'],
#  ['similiter',
#   'mandatum',
#   'do',
#   'secundus',
#   'atque',
#   'tertius',
#   'et',
#   'cunctus',
#   'quis#2',
#   'sequor',
#   'grex',
#   'dico#2',
#   'idem',
#   'verbum',
#   'loquor',
#   'ad',
#   'Esau',
#   'cum',
#   'invenio',
#   'is'],
#  ['et',
#   'addo',
#   'ipse',
#   'quoque',
#   'servus',
#   'tuus',
#   'Iacob',
#   'iter',
#   'noster',
#   'insequor',
#   'dico#2',
#   'enim',
#   'placo',
#   'ille',
#   'munus',
#   'quis#2',
#   'praecedo',
#   'et',
#   'postea',
#   'video',
#   'forsitan',
#   'propitio',
#   'ego'],
#  ['praecedo',
#   'itaque',
#   'munus',
#   'ante',
#   'is',
#   'ipse',
#   'verus',
#   'maneo',
#   'nox',
#   'ille',
#   'in',
#   'castra'],
#  ['cumque',
#   'maturus',
#   'surgo',
#   'fero',
#   'duo',
#   'uxor',
#   'suus',
#   'et',
#   'totidem',
#   'famulus',
#   'cum',
#   'undecim',
#   'filius',
#   'et',
#   'transeo',
#   'vadum',
#   'Iaboc'],
#  ['transductisque', 'omnis', 'quis#2', 'ad', 'se', 'pertineo'],
#  ['remaneo',
#   'solus',
#   'et',
#   'ecce',
#   'vir',
#   'luctabatur',
#   'cum',
#   'is',
#   'usque',
#   'mane'],
#  ['quis#2',
#   'cum',
#   'video',
#   'quod',
#   'is',
#   'supero',
#   'non',
#   'possum',
#   'tango',
#   'nervus',
#   'femoris',
#   'is',
#   'et',
#   'statim',
#   'emarcuit'],
#  ['dico',
#   'ad',
#   'is',
#   'dimitto',
#   'ego',
#   'iam',
#   'enim',
#   'ascendo',
#   'aurora',
#   'respondeo',
#   'non',
#   'dimitto',
#   'tu',
#   'nisi',
#   'benedico',
#   'ego'],
#  ['ajo', 'ergo', 'quod', 'nomen', 'sum', 'tu', 'respondeo', 'Iacob'],
#  ['at',
#   'ille',
#   'nequaquam',
#   'inquiam',
#   'Iacob',
#   'appello',
#   'nomen',
#   'tuus',
#   'sed',
#   'Israel',
#   'quoniam',
#   'si',
#   'contra',
#   'deus',
#   'fortis',
#   'sum',
#   'quantus',
#   'magis',
#   'contra',
#   'homo',
#   'praevaleo'],
#  ['interrogo',
#   'is',
#   'Iacob',
#   'dico#2',
#   'ego',
#   'quo',
#   'appello',
#   'nomen',
#   'respondeo',
#   'cur',
#   'quaero',
#   'nomen',
#   'meus',
#   'et',
#   'benedico',
#   'is',
#   'in',
#   'idem',
#   'locus'],
#  ['voco',
#   'Iacob',
#   'nomen',
#   'locus',
#   'ille',
#   'Phanuhel',
#   'dico#2',
#   'video',
#   'deus',
#   'facies',
#   'ad',
#   'facies',
#   'et',
#   'salvus',
#   'facio',
#   'sum',
#   'anima',
#   'meus'],
#  ['ortusque',
#   'sum',
#   'is',
#   'statim',
#   'sol',
#   'postquam',
#   'transgressus',
#   'sum',
#   'Phanuhel',
#   'ipse',
#   'verus',
#   'claudico',
#   'pedis'],
#  ['quam#4',
#   'ob',
#   'causa',
#   'non',
#   'comedo',
#   'filius',
#   'Israel',
#   'nervus',
#   'quis#2',
#   'emarcuit',
#   'in',
#   'femore',
#   'Iacob',
#   'usque',
#   'in',
#   'praesens',
#   'dies',
#   'is',
#   'quod',
#   'tango',
#   'nervus',
#   'femoris',
#   'is',
#   'et',
#   'obstipesco'],
#  ['levo',
#   'autem',
#   'Iacob',
#   'oculus',
#   'suus',
#   'video',
#   'venio',
#   'Esau',
#   'et',
#   'cum',
#   'is',
#   'quadringenti',
#   'vir',
#   'divisitque',
#   'filius',
#   'Liae',
#   'et',
#   'Rahel',
#   'ambarumque',
#   'famula'],
#  ['et',
#   'pono',
#   'uterque',
#   'ancilla',
#   'et',
#   'liberi',
#   'is',
#   'in',
#   'principium',
#   'Liam',
#   'verus',
#   'et',
#   'filius',
#   'is',
#   'in',
#   'secundus',
#   'locus',
#   'Rahel',
#   'autem',
#   'et',
#   'Ioseph',
#   'novissimus'],
#  ['et',
#   'ipse',
#   'praegredior',
#   'adoro',
#   'pronus',
#   'in',
#   'terra',
#   'septiens',
#   'donec',
#   'appropinquo',
#   'frater',
#   'is'],
#  ['curro',
#   'itaque',
#   'Esau',
#   'obviam',
#   'frater',
#   'suus',
#   'amplexor',
#   'sum',
#   'is',
#   'stringensque',
#   'collum',
#   'et',
#   'osculo',
#   'fleo'],
#  ['levatisque',
#   'oculus',
#   'video',
#   'mulier',
#   'et',
#   'parvulus',
#   'is',
#   'et',
#   'ajo',
#   'quis#2',
#   'se',
#   'volo#1',
#   'iste',
#   'et',
#   'si',
#   'ad',
#   'tu',
#   'pertineo',
#   'respondeo',
#   'parvulus',
#   'sum',
#   'quos',
#   'dono',
#   'ego',
#   'deus',
#   'servus',
#   'tuus'],
#  ['et', 'appropinquo', 'ancilla', 'et', 'filius', 'is', 'incurvo', 'sum'],
#  ['accessitque',
#   'Lia',
#   'cum',
#   'liberi',
#   'suus',
#   'et',
#   'cum',
#   'similis',
#   'adoro',
#   'extremum',
#   'Ioseph',
#   'et',
#   'Rahel',
#   'adoro'],
#  ['quaenam',
#   'sum',
#   'inquiam',
#   'iste',
#   'turma',
#   'quis#2',
#   'obvius',
#   'habeo',
#   'respondeo',
#   'ut',
#   'invenio',
#   'gratia',
#   'coram',
#   'dominus',
#   'meus'],
#  ['et',
#   'ille',
#   'habeo',
#   'ajo',
#   'plurimus',
#   'frater',
#   'ego',
#   'sum',
#   'tuus',
#   'tu'],
#  ['dico#2',
#   'Iacob',
#   'nolo',
#   'ita',
#   'obsecro',
#   'sed',
#   'si',
#   'invenio',
#   'gratia',
#   'in',
#   'oculus',
#   'tuus',
#   'accipio',
#   'munusculum',
#   'de',
#   'manus',
#   'meus',
#   'sic',
#   'enim',
#   'video',
#   'facies',
#   'tuus',
#   'quasi',
#   'video',
#   'vultus',
#   'deus',
#   'sum',
#   'ego',
#   'propitius'],
#  ['et',
#   'suscipio',
#   'benedictio',
#   'quam#4',
#   'affero',
#   'tu',
#   'et',
#   'quam#4',
#   'dono',
#   'ego',
#   'deus',
#   'tribuo',
#   'omnis',
#   'vix',
#   'frater',
#   'conpellente',
#   'suscipio'],
#  ['ajo', 'gradiamur', 'simul', 'eroque', 'socius', 'iter', 'tuus'],
#  ['dico#2',
#   'Iacob',
#   'nosco',
#   'dominus',
#   'ego',
#   'quod',
#   'parvulus',
#   'habeo',
#   'teneros',
#   'et',
#   'ovis',
#   'atque',
#   'bos',
#   'fetus',
#   'ego',
#   'quis#2',
#   'si',
#   'plus',
#   'in',
#   'ambulo',
#   'facio',
#   'laboro',
#   'morientur',
#   'unus',
#   'dies',
#   'cunctus',
#   'grex'],
#  ['praecedo',
#   'dominus',
#   'meus',
#   'ante',
#   'servus',
#   'suus',
#   'et',
#   'ego',
#   'sequor',
#   'paulatim',
#   'vestigium',
#   'is',
#   'sicut',
#   'video',
#   'possum',
#   'parvulus',
#   'meus',
#   'donec',
#   'venio',
#   'ad',
#   'dominus',
#   'meus',
#   'in',
#   'Seir'],
#  ['respondeo',
#   'Esau',
#   'oro',
#   'tu',
#   'ut',
#   'de',
#   'populus',
#   'quis#2',
#   'ego',
#   'sum',
#   'saltem',
#   'socius',
#   'remaneo',
#   'via',
#   'tuus',
#   'non',
#   'sum',
#   'inquiam',
#   'necesse',
#   'hic',
#   'unus',
#   'indigeo',
#   'ut',
#   'invenio',
#   'gratia',
#   'in',
#   'conspectus',
#   'dominium',
#   'meus'],
#  ['revertor',
#   'sum',
#   'itaque',
#   'ille',
#   'dies',
#   'Esau',
#   'iter',
#   'quo',
#   'venio',
#   'in',
#   'Seir'],
#  ['et',
#   'Iacob',
#   'venio',
#   'in',
#   'Soccoth',
#   'ubi',
#   'aedifico',
#   'domus',
#   'et',
#   'figo',
#   'tentorium',
#   'appello',
#   'nomen',
#   'locus',
#   'ille',
#   'Soccoth',
#   'is',
#   'sum',
#   'tabernaculum'],
#  ['transivitque',
#   'in',
#   'Salem',
#   'urbs',
#   'Sycimorum',
#   'quis#2',
#   'sum',
#   'in',
#   'terra',
#   'Chanaan',
#   'postquam',
#   'regredior',
#   'sum',
#   'de',
#   'Mesopotamia',
#   'Syria',
#   'et',
#   'habito',
#   'iuxta',
#   'oppidum'],
#  ['emitque',
#   'pars',
#   'ager',
#   'in',
#   'qui',
#   'figo',
#   'tabernaculum',
#   'ab',
#   'filius',
#   'Emor',
#   'pater',
#   'Sychem',
#   'centum',
#   'agna'],
#  ['et',
#   'erigo',
#   'ibi',
#   'altar',
#   'invoco',
#   'super',
#   'ille',
#   'fortis',
#   'deus',
#   'Israel'],
#  ['egredior',
#   'sum',
#   'autem',
#   'Dina',
#   'filia',
#   'Liae',
#   'ut',
#   'video',
#   'mulier',
#   'regio',
#   'ille'],
#  ['quam#4',
#   'cum',
#   'video',
#   'Sychem',
#   'filius',
#   'Emor',
#   'Evei',
#   'princeps',
#   'terra',
#   'ille',
#   'adamo',
#   'et',
#   'rapio',
#   'et',
#   'dormio',
#   'cum',
#   'ille',
#   'vis',
#   'opprimo',
#   'virgo'],
#  ['et',
#   'conglutino',
#   'sum',
#   'anima',
#   'is',
#   'cum',
#   'is',
#   'tristemque',
#   'blanditia',
#   'delinivit'],
#  ['et',
#   'pergo',
#   'ad',
#   'Emor',
#   'pater',
#   'suus',
#   'accipio',
#   'ego',
#   'inquiam',
#   'puella',
#   'hic',
#   'coniunx'],
#  ['quod',
#   'cum',
#   'audio',
#   'Iacob',
#   'absum',
#   'filius',
#   'et',
#   'in',
#   'pastus',
#   'occupo',
#   'pecus',
#   'sileo',
#   'donec',
#   'redeo'],
#  ['egredior',
#   'autem',
#   'Emor',
#   'pater',
#   'Sychem',
#   'ut',
#   'loquor',
#   'ad',
#   'Iacob'],
#  ['ecce',
#   'filius',
#   'is',
#   'venio',
#   'de',
#   'ager',
#   'auditoque',
#   'quod',
#   'accido',
#   'irascor',
#   'sum',
#   'valde',
#   'is',
#   'quod',
#   'foedus',
#   'res',
#   'sum',
#   'operor',
#   'in',
#   'Israel',
#   'et',
#   'violatus',
#   'filia',
#   'Iacob',
#   'res',
#   'inlicitam',
#   'perpetrasset'],
#  ['loquor',
#   'sum',
#   'itaque',
#   'Emor',
#   'ad',
#   'is',
#   'Sychem',
#   'filius',
#   'meus',
#   'adhaereo',
#   'anima',
#   'filia',
#   'vester',
#   'do',
#   'is',
#   'ille',
#   'uxor'],
#  ['et',
#   'iungamus',
#   'vicissim',
#   'conubium',
#   'filia',
#   'vester',
#   'trado',
#   'nos',
#   'et',
#   'filia',
#   'noster',
#   'accipio'],
#  ['et',
#   'habito',
#   'nos',
#   'terra',
#   'in',
#   'potestas',
#   'vester',
#   'sum',
#   'exercete',
#   'negotior',
#   'et',
#   'possideo',
#   'is'],
#  ['sed',
#   'et',
#   'Sychem',
#   'ad',
#   'pater',
#   'et',
#   'ad',
#   'frater',
#   'is',
#   'ajo',
#   'invenio',
#   'gratia',
#   'coram',
#   'vos',
#   'et',
#   'quicumque',
#   'statuo',
#   'do'],
#  ['augete',
#   'dos',
#   'munus',
#   'postulo',
#   'libet',
#   'tribuo',
#   'quod',
#   'peto',
#   'tantus',
#   'do',
#   'ego',
#   'puella',
#   'hic',
#   'uxor'],
#  ['respondeo',
#   'filius',
#   'Iacob',
#   'Sychem',
#   'et',
#   'pater',
#   'is',
#   'in',
#   'dolo',
#   'saevio',
#   'ob',
#   'stuprum',
#   'soror'],
#  ['non',
#   'possum',
#   'facio',
#   'quod',
#   'peto',
#   'nec',
#   'do',
#   'soror',
#   'noster',
#   'homo',
#   'incircumcisus',
#   'quod',
#   'inlicitum',
#   'et',
#   'nefarius',
#   'sum',
#   'apud',
#   'nos'],
#  ['sed',
#   'in',
#   'hic',
#   'valeo',
#   'foederari',
#   'si',
#   'sum',
#   'volo',
#   'noster',
#   'similis',
#   'et',
#   'circumcido',
#   'in',
#   'vos',
#   'omnis',
#   'masculinus',
#   'sexus'],
#  ['tunc',
#   'do',
#   'et',
#   'accipio',
#   'mutuus',
#   'filia',
#   'noster',
#   'atque',
#   'vester',
#   'et',
#   'habito',
#   'tu',
#   'erimusque',
#   'unus',
#   'populus'],
#  ['sin',
#   'autem',
#   'circumcido',
#   'nolo',
#   'tollo',
#   'filia',
#   'noster',
#   'et',
#   'recedo'],
#  ['placeo', 'oblatio', 'is', 'Emor', 'et', 'Sychem', 'filius', 'is'],
#  ['nec',
#   'differo',
#   'adulescens',
#   'quin',
#   'statim',
#   'quod',
#   'peto',
#   'expleo',
#   'amo',
#   'enim',
#   'puella',
#   'valde',
#   'et',
#   'ipse',
#   'sum',
#   'inclitus',
#   'in',
#   'omnis',
#   'domus',
#   'pater',
#   'suus'],
#  ...]

# %%
len(corpus)
# Out:
# 512576

# %% [markdown]
# ## Test with "revolutio" on the whole corpus

# %% [markdown]
# Find the word "revolutio" in the corpus (twice in LAT0820 and once in LAT0970):

# %%
count_sentence = 0
for sentence in corpus:
    count_sentence = count_sentence + 1
    #if count_sentence % 1000 == 0:
    #    print(count_sentence)
    for w in sentence:
        #print(w)
        if w == "revolutio" or w == "reuolutio":
            print("revolutio!!!!!")
            print(sentence)
# Out:
# revolutio!!!!!
# ['de', 'cyclus', 'decennovennali', 'aureus', 'numerus', 'C', 'yclus', 'decennovennalis', 'aureus', 'numerus', 'sum', 'revolutio', 'numerus', 'annus', 'ab', 'usque', 'ad', 'qui', 'revolutione', 'perago', 'iterum', 'ad', 'unitas', 'reditur']
# revolutio!!!!!
# ['de', 'indictio', 'eo', 'ndictio', 'sum', 'revolutio', 'annus', 'ab', 'usque', 'ad', 'qui', 'revolutione', 'perago', 'iterum', 'reditur', 'ad', 'unitas', 'initiumque', 'sumo', 'quilibet', 'annus', 'hic', 'cyclus', 'ab', 'Januarius', 'in', 'bulla', 'pontifex']
# revolutio!!!!!
# ['quod', 'cum', 'parum', 'reperisset', 'iterum', 'ad', 'monumentum', 'orior', 'iam', 'sol', 'cum', 'alius', 'venio', 'et', 'tunc', 'reuolutio', 'lapis', 'facio', 'sum', 'quamvis', 'Ioannes', 'hic', 'reuolutionem', 'quasi', 'prius', 'facio', 'per', 'anticipationem', 'dico#2', 'ab', 'Maria', 'uisam', 'sum']

# %% [markdown]
# We correct and harmonize the lemmatisation for "revolutio":

# %%
corpus_corrected = list()
files_corpus = metadata_df
revolutio_texts = list()
for index, df_line in files_corpus.iterrows():
    #print("line:",df_line['id'], df_line['time_interval'])
    sign = "+"
    #print(df_line['date'])
    if df_line['date'] < 0:
        sign = "-"
    #print("date:", convert_dates(sign, abs(df_line['date'])))
    file_name = 'lat_'+str(convert_dates(sign, abs(df_line['date'])))+"_"+str(df_line['id'])+'.txt'
    print(file_name)
    file = open(os.path.join(dir_in, "preprocessed_"+lemmas_or_tokens, file_name), 'r')
    #sentences_this_file = list()
    while True:
        line = file.readline().strip()
        if line != "":
            #sentences_this_file.append(line.split(" "))
            #sentences_this_file.append([token for token in line.split(" ") if token not in punctuation])
            sentence = list()
            for w in line.split(" "):
                if w.startswith('revolutio') or w.startswith('reuolutio'):
                    w = 'revolutio'
            sentence.append(w)
            corpus_corrected.append([token for token in sentence if (token not in punctuation)])
            #corpus_corrected.append([token for token in line.split(" ") if ((token not in punctuation) and (token == "revolutio" or w == "reuolutio" or w == "revolutione" or w == "reuolutionem" or w.startswith('revolutio') or w.startswith('reuolutio')))])
            if ("revolutio" in line.split(" ") or  "reuolutio" in line.split(" ") or "revolutione" in line.split(" ") or "reuolutionem" in line.split(" ") or 'revolutio' in line.split(" ") or 'reuolutio' in line.split(" ")):  
                revolutio_texts.append(df_line['id']) 
        # if line is empty end of file is reached
        if not line:
            break
    file.close()
corpus_corrected.append(sentences_this_file)
# Out:
# lat_0382_IT-LAT0001.txt
# lat_-009_IT-LAT0537.txt
# lat_0524_IT-LAT0011.txt
# lat_1254_IT-LAT0012.txt
# lat_1254_IT-LAT0014.txt
# lat_0399_IT-LAT0015.txt
# lat_0391_IT-LAT0016.txt
# lat_1224_IT-LAT0017.txt
# lat_1150_IT-LAT0018.txt
# lat_2000_IT-LAT0021.txt
# lat_1517_IT-LAT0022.txt
# lat_1547_IT-LAT0023.txt
# lat_1530_IT-LAT0024.txt
# lat_1260_IT-LAT0025.txt
# lat_1250_IT-LAT0026.txt
# lat_1998_IT-LAT0027.txt
# lat_-0049_IT-LAT0029.txt
# lat_2001_IT-LAT0030.txt
# lat_1992_IT-LAT0031.txt
# lat_0158_IT-LAT0043.txt
# lat_0049_IT-LAT0045.txt
# lat_-0045_IT-LAT0047.txt
# lat_0050_IT-LAT0051.txt
# lat_0121_IT-LAT0054.txt
# lat_-0049_IT-LAT0056.txt
# lat_0199_IT-LAT0058.txt
# lat_0387_IT-LAT0061.txt
# lat_0197_IT-LAT0062.txt
# lat_0050_IT-LAT0563.txt
# lat_0062_IT-LAT0071.txt
# lat_0049_IT-LAT0072.txt
# lat_0063_IT-LAT0073.txt
# lat_0000_IT-LAT0075.txt
# lat_0062_IT-LAT0078.txt
# lat_0058_IT-LAT0079.txt
# lat_0385_IT-LAT0574.txt
# lat_0040_IT-LAT0083.txt
# lat_0385_IT-LAT0574_1.txt
# lat_0385_IT-LAT0574_2.txt
# lat_-0080_IT-LAT0093.txt
# lat_-0079_IT-LAT0094.txt
# lat_-0061_IT-LAT0095.txt
# lat_-0051_IT-LAT0096.txt
# lat_-0043_IT-LAT0097.txt
# lat_-0043_IT-LAT0098.txt
# lat_0385_IT-LAT0574_3.txt
# lat_-0043_IT-LAT0101.txt
# lat_0000_IT-LAT0102.txt
# lat_0385_IT-LAT0574_4.txt
# lat_-0049_IT-LAT0108.txt
# lat_0065_IT-LAT0109.txt
# lat_0100_IT-LAT0111.txt
# lat_0043_IT-LAT0112.txt
# lat_0050_IT-LAT0114.txt
# lat_0350_IT-LAT0115.txt
# lat_0041_IT-LAT0116.txt
# lat_0385_IT-LAT0574_5.txt
# lat_0250_IT-LAT0118.txt
# lat_-002_IT-LAT0119.txt
# lat_0113_IT-LAT0120.txt
# lat_0362_IT-LAT0121.txt
# lat_-0075_IT-LAT0122.txt
# lat_-0065_IT-LAT0124.txt
# lat_-0062_IT-LAT0125.txt
# lat_-0062_IT-LAT0126.txt
# lat_0000_IT-LAT0127.txt
# lat_-0058_IT-LAT0128.txt
# lat_0382_IT-LAT0001_1.txt
# lat_0385_IT-LAT0574_6.txt
# lat_0385_IT-LAT0574_7.txt
# lat_-0055_IT-LAT0133.txt
# lat_-0055_IT-LAT0134.txt
# lat_-0055_IT-LAT0135.txt
# lat_-0053_IT-LAT0136.txt
# lat_-0054_IT-LAT0137.txt
# lat_-0045_IT-LAT0138.txt
# lat_-0045_IT-LAT0139.txt
# lat_-0044_IT-LAT0140.txt
# lat_0385_IT-LAT0574_8.txt
# lat_-001_IT-LAT0142.txt
# lat_0029_IT-LAT0148.txt
# lat_0385_IT-LAT0574_9.txt
# lat_0050_IT-LAT0588.txt
# lat_0050_IT-LAT0588_1.txt
# lat_0800_IT-LAT0911.txt
# lat_-0043_IT-LAT0155.txt
# lat_0800_IT-LAT0911_1.txt
# lat_0800_IT-LAT0911_2.txt
# lat_0800_IT-LAT0911_3.txt
# lat_0800_IT-LAT0911_4.txt
# lat_0800_IT-LAT0911_5.txt
# lat_0800_IT-LAT0911_6.txt
# lat_-0045_IT-LAT0922.txt
# lat_-0045_IT-LAT0922_1.txt
# lat_-0045_IT-LAT0922_2.txt
# lat_-0045_IT-LAT0922_3.txt
# lat_0000_IT-LAT0181.txt
# lat_-0045_IT-LAT0922_4.txt
# lat_-0045_IT-LAT0922_5.txt
# lat_0390_IT-LAT0189.txt
# lat_0550_IT-LAT0196.txt
# lat_-0045_IT-LAT0922_6.txt
# lat_0250_IT-LAT0201.txt
# lat_-0045_IT-LAT0922_7.txt
# lat_0300_IT-LAT0203.txt
# lat_0250_IT-LAT0204.txt
# lat_-0045_IT-LAT0922_8.txt
# lat_-0045_IT-LAT0922_9.txt
# lat_-0045_IT-LAT0217.txt
# lat_-0059_IT-LAT0218.txt
# lat_-0045_IT-LAT0922_10.txt
# lat_-0055_IT-LAT0220.txt
# lat_-0084_IT-LAT0221.txt
# lat_-0045_IT-LAT0922_11.txt
# lat_0054_IT-LAT0228.txt
# lat_-0045_IT-LAT0922_12.txt
# lat_0062_IT-LAT0230.txt
# lat_-0045_IT-LAT0922_13.txt
# lat_0350_IT-LAT0233.txt
# lat_-0199_IT-LAT0236.txt
# lat_0065_IT-LAT0237.txt
# lat_0350_IT-LAT0238.txt
# lat_0050_IT-LAT0239.txt
# lat_-0089_IT-LAT0240.txt
# lat_-0049_IT-LAT0241.txt
# lat_-0049_IT-LAT0242.txt
# lat_0562_IT-LAT0243.txt
# lat_1428_IT-LAT0245.txt
# lat_0197_IT-LAT0246.txt
# lat_0198_IT-LAT0248.txt
# lat_0540_IT-LAT0250.txt
# lat_0535_IT-LAT0251.txt
# lat_0535_IT-LAT0252.txt
# lat_-0047_IT-LAT0254.txt
# lat_-0044_IT-LAT0255.txt
# lat_0198_IT-LAT0256.txt
# lat_-0051_IT-LAT0257.txt
# lat_0350_IT-LAT0261.txt
# lat_0350_IT-LAT0262.txt
# lat_0350_IT-LAT0263.txt
# lat_0300_IT-LAT0264.txt
# lat_0050_IT-LAT0265.txt
# lat_0050_IT-LAT0266.txt
# lat_0150_IT-LAT0267.txt
# lat_0318_IT-LAT0268.txt
# lat_0400_IT-LAT0270.txt
# lat_-0049_IT-LAT0272.txt
# lat_1350_IT-LAT0277.txt
# lat_0013_IT-LAT0278.txt
# lat_1254_IT-LAT0279.txt
# lat_-0049_IT-LAT0284.txt
# lat_-0450_IT-LAT0285.txt
# lat_0350_IT-LAT0286.txt
# lat_-0045_IT-LAT0922_14.txt
# lat_-0045_IT-LAT0922_15.txt
# lat_0550_IT-LAT0990.txt
# lat_1312_IT-LAT0291.txt
# lat_1278_IT-LAT0292.txt
# lat_0387_IT-LAT0315.txt
# lat_0394_IT-LAT0316.txt
# lat_0387_IT-LAT0317.txt
# lat_0387_IT-LAT0318.txt
# lat_0387_IT-LAT0319.txt
# lat_-0044_IT-LAT0320.txt
# lat_0050_IT-LAT0325.txt
# lat_0400_IT-LAT0329.txt
# lat_0091_IT-LAT0332.txt
# lat_0450_IT-LAT0333.txt
# lat_0450_IT-LAT0334.txt
# lat_0450_IT-LAT0336.txt
# lat_0420_IT-LAT0337.txt
# lat_0792_IT-LAT0338.txt
# lat_0100_IT-LAT0339.txt
# lat_0100_IT-LAT0340.txt
# lat_0100_IT-LAT0341.txt
# lat_0100_IT-LAT0342.txt
# lat_0100_IT-LAT0345.txt
# lat_0100_IT-LAT0346.txt
# lat_0100_IT-LAT0347.txt
# lat_0100_IT-LAT0348.txt
# lat_0100_IT-LAT0349.txt
# lat_0205_IT-LAT0350.txt
# lat_0300_IT-LAT0351.txt
# lat_0350_IT-LAT0353.txt
# lat_0050_IT-LAT0355.txt
# lat_0759_IT-LAT0357.txt
# lat_0759_IT-LAT0358.txt
# lat_0150_IT-LAT0360.txt
# lat_0350_IT-LAT0361.txt
# lat_0350_IT-LAT0362.txt
# lat_0350_IT-LAT0363.txt
# lat_0350_IT-LAT0364.txt
# lat_0350_IT-LAT0365.txt
# lat_0350_IT-LAT0366.txt
# lat_0350_IT-LAT0367.txt
# lat_-0091_IT-LAT0370.txt
# lat_1450_IT-LAT0371.txt
# lat_-0149_IT-LAT0372.txt
# lat_0398_IT-LAT0373.txt
# lat_-0049_IT-LAT0377.txt
# lat_001_IT-LAT0378.txt
# lat_-0199_IT-LAT0380.txt
# lat_1998_IT-LAT0381.txt
# lat_0030_IT-LAT0382.txt
# lat_0438_IT-LAT0383.txt
# lat_-0079_IT-LAT0384.txt
# lat_0818_IT-LAT0386.txt
# lat_-0049_IT-LAT0393.txt
# lat_0550_IT-LAT0990_1.txt
# lat_0393_IT-LAT0397.txt
# lat_0550_IT-LAT0990_2.txt
# lat_0550_IT-LAT0990_3.txt
# lat_0550_IT-LAT0990_4.txt
# lat_0399_IT-LAT0403.txt
# lat_-0199_IT-LAT0405.txt
# lat_0150_IT-LAT0406.txt
# lat_0150_IT-LAT0407.txt
# lat_0550_IT-LAT0990_5.txt
# lat_0403_IT-LAT0410.txt
# lat_0250_IT-LAT0413.txt
# lat_0450_IT-LAT0414.txt
# lat_0550_IT-LAT0990_6.txt
# lat_0704_IT-LAT0419.txt
# lat_0704_IT-LAT0420.txt
# lat_0704_IT-LAT0421.txt
# lat_0704_IT-LAT0422.txt
# lat_0721_IT-LAT0423.txt
# lat_0050_IT-LAT0425.txt
# lat_1110_IT-LAT0428.txt
# lat_0550_IT-LAT0429.txt
# lat_0550_IT-LAT0431.txt
# lat_0550_IT-LAT0433.txt
# lat_0550_IT-LAT0435.txt
# lat_2001_IT-LAT0437.txt
# lat_1435_IT-LAT0438.txt
# lat_1319_IT-LAT0441.txt
# lat_1293_IT-LAT0442.txt
# lat_1320_IT-LAT0443.txt
# lat_1310_IT-LAT0444.txt
# lat_1304_IT-LAT0445.txt
# lat_2002_IT-LAT0446.txt
# lat_2001_IT-LAT0447.txt
# lat_0197_IT-LAT0448.txt
# lat_1994_IT-LAT0449.txt
# lat_1438_IT-LAT0450.txt
# lat_1438_IT-LAT0451.txt
# lat_0550_IT-LAT0990_7.txt
# lat_1438_IT-LAT0453.txt
# lat_0550_IT-LAT0990_8.txt
# lat_1998_IT-LAT0456.txt
# lat_0950_IT-LAT0458.txt
# lat_0850_IT-LAT0459.txt
# lat_0800_IT-LAT0461.txt
# lat_1141_IT-LAT0463.txt
# lat_1550_IT-LAT0465.txt
# lat_1242_IT-LAT0466.txt
# lat_0200_IT-LAT0471.txt
# lat_0909_IT-LAT0472.txt
# lat_1098_IT-LAT0477.txt
# lat_1096_IT-LAT0478.txt
# lat_1150_IT-LAT0479.txt
# lat_1766_IT-LAT0480.txt
# lat_1050_IT-LAT0481.txt
# lat_0562_IT-LAT0482.txt
# lat_1492_IT-LAT0483.txt
# lat_0775_IT-LAT0486.txt
# lat_1526_IT-LAT0488.txt
# lat_1550_IT-LAT0489.txt
# lat_0382_IT-LAT0001_2.txt
# lat_0838_IT-LAT0494.txt
# lat_1410_IT-LAT0495.txt
# lat_1200_IT-LAT0496.txt
# lat_1098_IT-LAT0497.txt
# lat_1185_IT-LAT0498.txt
# lat_1300_IT-LAT0499.txt
# lat_0833_IT-LAT0500.txt
# lat_1200_IT-LAT0502.txt
# lat_1200_IT-LAT0503.txt
# lat_0382_IT-LAT0001_3.txt
# lat_0382_IT-LAT0001_4.txt
# lat_1125_IT-LAT0506.txt
# lat_1200_IT-LAT0507.txt
# lat_1200_IT-LAT0508.txt
# lat_1200_IT-LAT0509.txt
# lat_1200_IT-LAT0510.txt
# lat_1200_IT-LAT0511.txt
# lat_1200_IT-LAT0512.txt
# lat_1200_IT-LAT0513.txt
# lat_1200_IT-LAT0514.txt
# lat_1200_IT-LAT0515.txt
# lat_1200_IT-LAT0516.txt
# lat_1200_IT-LAT0517.txt
# lat_1200_IT-LAT0518.txt
# lat_1200_IT-LAT0519.txt
# lat_1200_IT-LAT0520.txt
# lat_1200_IT-LAT0521.txt
# lat_1200_IT-LAT0522.txt
# lat_1200_IT-LAT0523.txt
# lat_1118_IT-LAT0524.txt
# lat_1200_IT-LAT0525.txt
# lat_1200_IT-LAT0526.txt
# lat_1200_IT-LAT0527.txt
# lat_1200_IT-LAT0528.txt
# lat_0116_IT-LAT0534.txt
# lat_-0051_IT-LAT0535.txt
# lat_2002_IT-LAT0536.txt
# lat_0382_IT-LAT0001_5.txt
# lat_0382_IT-LAT0001_6.txt
# lat_1545_IT-LAT0546.txt
# lat_1524_IT-LAT0547.txt
# lat_1215_IT-LAT0548.txt
# lat_0382_IT-LAT0001_7.txt
# lat_0382_IT-LAT0001_8.txt
# lat_0382_IT-LAT0001_9.txt
# lat_0382_IT-LAT0001_10.txt
# lat_0382_IT-LAT0001_11.txt
# lat_0382_IT-LAT0001_12.txt
# lat_1546_IT-LAT0558.txt
# lat_1519_IT-LAT0559.txt
# lat_1516_IT-LAT0560.txt
# lat_1506_IT-LAT0561.txt
# lat_0050_IT-LAT0563_1.txt
# lat_0382_IT-LAT0001_13.txt
# lat_0382_IT-LAT0001_14.txt
# lat_0382_IT-LAT0001_15.txt
# lat_1820_IT-LAT0567.txt
# lat_1360_IT-LAT0568.txt
# lat_1530_IT-LAT0569.txt
# lat_1517_IT-LAT0570.txt
# lat_1998_IT-LAT0571.txt
# lat_1998_IT-LAT0572.txt
# lat_1815_IT-LAT0573.txt
# lat_1478_IT-LAT0575.txt
# lat_1486_IT-LAT0576.txt
# lat_1445_IT-LAT0577.txt
# lat_1750_IT-LAT0579.txt
# lat_1050_IT-LAT0580.txt
# lat_1868_IT-LAT0581.txt
# lat_1868_IT-LAT0582.txt
# lat_1869_IT-LAT0583.txt
# lat_1065_IT-LAT0584.txt
# lat_0382_IT-LAT0001_16.txt
# lat_1494_IT-LAT0586.txt
# lat_1550_IT-LAT0587.txt
# lat_0050_IT-LAT0588_2.txt
# lat_1632_IT-LAT0590.txt
# lat_1668_IT-LAT0591.txt
# lat_0382_IT-LAT0001_17.txt
# lat_0382_IT-LAT0001_18.txt
# lat_0382_IT-LAT0001_19.txt
# lat_1707_IT-LAT0595.txt
# lat_0382_IT-LAT0001_20.txt
# lat_1050_IT-LAT0597.txt
# lat_0382_IT-LAT0001_21.txt
# lat_0382_IT-LAT0001_22.txt
# lat_0382_IT-LAT0001_23.txt
# lat_1150_IT-LAT0604.txt
# lat_1050_IT-LAT0605.txt
# lat_0210_IT-LAT0606.txt
# lat_0250_IT-LAT0607.txt
# lat_0450_IT-LAT0608.txt
# lat_0350_IT-LAT0609.txt
# lat_0426_IT-LAT0610.txt
# lat_0450_IT-LAT0611.txt
# lat_0350_IT-LAT0612.txt
# lat_1150_IT-LAT0616.txt
# lat_0950_IT-LAT0617.txt
# lat_1250_IT-LAT0618.txt
# lat_1088_IT-LAT0619.txt
# lat_1492_IT-LAT0620.txt
# lat_0250_IT-LAT0621.txt
# lat_1150_IT-LAT0622.txt
# lat_1150_IT-LAT0623.txt
# lat_1667_IT-LAT0624.txt
# lat_1695_IT-LAT0625.txt
# lat_1695_IT-LAT0626.txt
# lat_1695_IT-LAT0627.txt
# lat_1695_IT-LAT0628.txt
# lat_1695_IT-LAT0629.txt
# lat_1695_IT-LAT0630.txt
# lat_1695_IT-LAT0631.txt
# lat_0050_IT-LAT0632.txt
# lat_1243_IT-LAT0633.txt
# lat_1650_IT-LAT0634.txt
# lat_1245_IT-LAT0635.txt
# lat_1650_IT-LAT0636.txt
# lat_1550_IT-LAT0637.txt
# lat_1483_IT-LAT0638.txt
# lat_1627_IT-LAT0639.txt
# lat_1550_IT-LAT0640.txt
# lat_1988_IT-LAT0641.txt
# lat_1999_IT-LAT0642.txt
# lat_1450_IT-LAT0643.txt
# lat_1450_IT-LAT0644.txt
# lat_1650_IT-LAT0645.txt
# lat_1494_IT-LAT0646.txt
# lat_1350_IT-LAT0649.txt
# lat_1350_IT-LAT0650.txt
# lat_1650_IT-LAT0652.txt
# lat_1593_IT-LAT0653.txt
# lat_1593_IT-LAT0654.txt
# lat_0382_IT-LAT0001_24.txt
# lat_0382_IT-LAT0001_25.txt
# lat_0382_IT-LAT0001_26.txt
# lat_0382_IT-LAT0001_27.txt
# lat_0382_IT-LAT0001_28.txt
# lat_1150_IT-LAT0663.txt
# lat_1112_IT-LAT0664.txt
# lat_0250_IT-LAT0665.txt
# lat_1504_IT-LAT0666.txt
# lat_1511_IT-LAT0667.txt
# lat_1979_IT-LAT0669.txt
# lat_1500_IT-LAT0674.txt
# lat_1595_IT-LAT0676.txt
# lat_1872_IT-LAT0686.txt
# lat_1073_IT-LAT0687.txt
# lat_1289_IT-LAT0689.txt
# lat_1323_IT-LAT0690.txt
# lat_1324_IT-LAT0691.txt
# lat_1482_IT-LAT0692.txt
# lat_1858_IT-LAT0695.txt
# lat_1226_IT-LAT0700.txt
# lat_1795_IT-LAT0701.txt
# lat_1810_IT-LAT0703.txt
# lat_1600_IT-LAT0705.txt
# lat_1767_IT-LAT0708.txt
# lat_1254_IT-LAT0718.txt
# lat_0350_IT-LAT0719.txt
# lat_0113_IT-LAT0720.txt
# lat_1150_IT-LAT0722.txt
# lat_1200_IT-LAT0723.txt
# lat_1000_IT-LAT0724.txt
# lat_0950_IT-LAT0725.txt
# lat_0390_IT-LAT0726.txt
# lat_0210_IT-LAT0733.txt
# lat_0213_IT-LAT0736.txt
# lat_0198_IT-LAT0737.txt
# lat_0550_IT-LAT0739.txt
# lat_1200_IT-LAT0743.txt
# lat_0205_IT-LAT0744.txt
# lat_0210_IT-LAT0746.txt
# lat_0213_IT-LAT0747.txt
# lat_0198_IT-LAT0749.txt
# lat_0198_IT-LAT0750.txt
# lat_1998_IT-LAT0753.txt
# lat_1999_IT-LAT0754.txt
# lat_0213_IT-LAT0755.txt
# lat_1100_IT-LAT0756.txt
# lat_1990_IT-LAT0758.txt
# lat_1978_IT-LAT0759.txt
# lat_1975_IT-LAT0760.txt
# lat_1975_IT-LAT0761.txt
# lat_2003_IT-LAT0762.txt
# lat_1978_IT-LAT0763.txt
# lat_0419_IT-LAT0768.txt
# lat_1781_IT-LAT0771.txt
# lat_1957_IT-LAT0772.txt
# lat_0850_IT-LAT0773.txt
# lat_1150_IT-LAT0774.txt
# lat_0350_IT-LAT0775.txt
# lat_0350_IT-LAT0776.txt
# lat_1165_IT-LAT0780.txt
# lat_1142_IT-LAT0781.txt
# lat_0871_IT-LAT0782.txt
# lat_0550_IT-LAT0783.txt
# lat_0100_IT-LAT0784.txt
# lat_0650_IT-LAT0785.txt
# lat_0950_IT-LAT0786.txt
# lat_1998_IT-LAT0787.txt
# lat_0213_IT-LAT0788.txt
# lat_1760_IT-LAT0789.txt
# lat_1779_IT-LAT0790.txt
# lat_0550_IT-LAT0791.txt
# lat_0850_IT-LAT0792.txt
# lat_0389_IT-LAT0793.txt
# lat_0382_IT-LAT0001_29.txt
# lat_0382_IT-LAT0001_30.txt
# lat_0382_IT-LAT0001_31.txt
# lat_0382_IT-LAT0001_32.txt
# lat_0382_IT-LAT0001_33.txt
# lat_0382_IT-LAT0001_34.txt
# lat_0382_IT-LAT0001_35.txt
# lat_1997_IT-LAT0806.txt
# lat_0382_IT-LAT0001_36.txt
# lat_0382_IT-LAT0001_37.txt
# lat_0382_IT-LAT0001_38.txt
# lat_0382_IT-LAT0001_39.txt
# lat_1917_IT-LAT0813.txt
# lat_1316_IT-LAT0814.txt
# lat_1148_IT-LAT0815.txt
# lat_1570_IT-LAT0820.txt
# lat_1350_IT-LAT0821.txt
# lat_1223_IT-LAT0823.txt
# lat_1968_IT-LAT0824.txt
# lat_1203_IT-LAT0825.txt
# lat_1204_IT-LAT0826.txt
# lat_1223_IT-LAT0827.txt
# lat_1588_IT-LAT0828.txt
# lat_1909_IT-LAT0829.txt
# lat_1250_IT-LAT0830.txt
# lat_1250_IT-LAT0831.txt
# lat_1242_IT-LAT0832.txt
# lat_1250_IT-LAT0834.txt
# lat_2001_IT-LAT0835.txt
# lat_1980_IT-LAT0836.txt
# lat_1250_IT-LAT0837.txt
# lat_1228_IT-LAT0838.txt
# lat_2004_IT-LAT0839.txt
# lat_2005_IT-LAT0840.txt
# lat_1150_IT-LAT0841.txt
# lat_1165_IT-LAT0842.txt
# lat_0400_IT-LAT0843.txt
# lat_1250_IT-LAT0844.txt
# lat_1150_IT-LAT0845.txt
# lat_0250_IT-LAT0846.txt
# lat_0391_IT-LAT0847.txt
# lat_0650_IT-LAT0848.txt
# lat_-0049_IT-LAT0849.txt
# lat_0350_IT-LAT0850.txt
# lat_0382_IT-LAT0001_40.txt
# lat_1650_IT-LAT0863.txt
# lat_1550_IT-LAT0864.txt
# lat_0250_IT-LAT0865.txt
# lat_0531_IT-LAT0867.txt
# lat_0050_IT-LAT0868.txt
# lat_1196_IT-LAT0869.txt
# lat_1150_IT-LAT0870.txt
# lat_1150_IT-LAT0871.txt
# lat_0300_IT-LAT0873.txt
# lat_1550_IT-LAT0874.txt
# lat_0550_IT-LAT0875.txt
# lat_1200_IT-LAT0876.txt
# lat_1150_IT-LAT0877.txt
# lat_0400_IT-LAT0878.txt
# lat_1486_IT-LAT0879.txt
# lat_0400_IT-LAT0880.txt
# lat_1792_IT-LAT0882.txt
# lat_0030_IT-LAT0883.txt
# lat_1235_IT-LAT0885.txt
# lat_0330_IT-LAT0886.txt
# lat_0841_IT-LAT0888.txt
# lat_0907_IT-LAT0891.txt
# lat_1610_IT-LAT0892.txt
# lat_0260_IT-LAT0893.txt
# lat_0260_IT-LAT0895.txt
# lat_0260_IT-LAT0896.txt
# lat_1699_IT-LAT0897.txt
# lat_1741_IT-LAT0899.txt
# lat_1078_IT-LAT0900.txt
# lat_1157_IT-LAT0901.txt
# lat_1254_IT-LAT0902.txt
# lat_1136_IT-LAT0903.txt
# lat_0450_IT-LAT0904.txt
# lat_1218_IT-LAT0905.txt
# lat_0550_IT-LAT0906.txt
# lat_0770_IT-LAT0907.txt
# lat_0598_IT-LAT0908.txt
# lat_0598_IT-LAT0909.txt
# lat_1112_IT-LAT0910.txt
# lat_0800_IT-LAT0911_7.txt
# lat_1073_IT-LAT0912.txt
# lat_0250_IT-LAT0913.txt
# lat_0250_IT-LAT0914.txt
# lat_0150_IT-LAT0916.txt
# lat_0502_IT-LAT0917.txt
# lat_1247_IT-LAT0918.txt
# lat_0350_IT-LAT0919.txt
# lat_0850_IT-LAT0920.txt
# lat_0731_IT-LAT0921.txt
# lat_-0045_IT-LAT0922_16.txt
# lat_1501_IT-LAT0923.txt
# lat_1501_IT-LAT0924.txt
# lat_1501_IT-LAT0925.txt
# lat_1603_IT-LAT0926.txt
# lat_1475_IT-LAT0927.txt
# lat_1501_IT-LAT0928.txt
# lat_1568_IT-LAT0929.txt
# lat_1434_IT-LAT0930.txt
# lat_1434_IT-LAT0931.txt
# lat_1434_IT-LAT0932.txt
# lat_1528_IT-LAT0933.txt
# lat_0067_IT-LAT0934.txt
# lat_1708_IT-LAT0935.txt
# lat_0833_IT-LAT0936.txt
# lat_1337_IT-LAT0937.txt
# lat_1339_IT-LAT0938.txt
# lat_1355_IT-LAT0939.txt
# lat_-0185_IT-LAT0952.txt
# lat_1397_IT-LAT0954.txt
# lat_-0044_IT-LAT0955.txt
# lat_-0044_IT-LAT0956.txt
# lat_0598_IT-LAT0957.txt
# lat_1250_IT-LAT0958.txt
# lat_0250_IT-LAT0959.txt
# lat_1110_IT-LAT0963.txt
# lat_1110_IT-LAT0964.txt
# lat_1110_IT-LAT0965.txt
# lat_1110_IT-LAT0966.txt
# lat_1110_IT-LAT0967.txt
# lat_1110_IT-LAT0968.txt
# lat_1110_IT-LAT0969.txt
# lat_1110_IT-LAT0970.txt
# lat_1110_IT-LAT0971.txt
# lat_1110_IT-LAT0972.txt
# lat_1110_IT-LAT0973.txt
# lat_1110_IT-LAT0974.txt
# lat_1067_IT-LAT0975.txt
# lat_1110_IT-LAT0976.txt
# lat_1110_IT-LAT0977.txt
# lat_0350_IT-LAT0978.txt
# lat_0950_IT-LAT0980.txt
# lat_1897_IT-LAT0982.txt
# lat_1902_IT-LAT0983.txt
# lat_1891_IT-LAT0984.txt
# lat_1892_IT-LAT0985.txt
# lat_1892_IT-LAT0986.txt
# lat_0550_IT-LAT0987.txt
# lat_-0149_IT-LAT0988.txt
# lat_0550_IT-LAT0990_9.txt
# lat_1550_IT-LAT0991.txt
# lat_-0107_IT-LAT0992.txt
# lat_1621_IT-LAT0993.txt
# lat_1614_IT-LAT0994.txt
# lat_1685_IT-LAT0995.txt
# lat_-0037_IT-LAT0996.txt
# lat_-0037_IT-LAT0997.txt
# lat_1501_IT-LAT1000.txt
# lat_0450_IT-LAT1001.txt
# lat_1483_IT-LAT1002.txt
# lat_1550_IT-LAT1003.txt
# lat_0395_IT-LAT1004.txt
# lat_-0229_IT-LAT1006.txt
# lat_1555_IT-LAT1007.txt
# lat_1684_IT-LAT1008.txt
# lat_1684_IT-LAT1009.txt
# lat_0382_IT-LAT0001_41.txt
# lat_0382_IT-LAT0001_42.txt
# lat_0382_IT-LAT0001_43.txt
# lat_0382_IT-LAT0001_44.txt
# lat_0382_IT-LAT0001_45.txt
# lat_0382_IT-LAT0001_46.txt
# lat_0382_IT-LAT0001_47.txt
# lat_0382_IT-LAT0001_48.txt
# lat_0382_IT-LAT0001_49.txt
# lat_0382_IT-LAT0001_50.txt
# lat_0382_IT-LAT0001_51.txt
# lat_0382_IT-LAT0001_52.txt
# lat_0382_IT-LAT0001_53.txt
# lat_0382_IT-LAT0001_54.txt
# lat_0382_IT-LAT0001_55.txt
# lat_0382_IT-LAT0001_56.txt
# lat_0382_IT-LAT0001_57.txt
# lat_0382_IT-LAT0001_58.txt
# lat_0382_IT-LAT0001_59.txt
# lat_0382_IT-LAT0001_60.txt
# lat_0382_IT-LAT0001_61.txt
# lat_0382_IT-LAT0001_62.txt
# lat_0382_IT-LAT0001_63.txt
# lat_0382_IT-LAT0001_64.txt
# lat_0382_IT-LAT0001_65.txt
# lat_0382_IT-LAT0001_66.txt
# lat_0382_IT-LAT0001_67.txt
# lat_0382_IT-LAT0001_68.txt
# lat_0382_IT-LAT0001_69.txt
# lat_0382_IT-LAT1039.txt
# lat_0116_IT-LAT0534_1.txt
# lat_0116_IT-LAT0534_2.txt
# lat_0116_IT-LAT0534_3.txt
# lat_0116_IT-LAT0534_4.txt
# lat_0533_IT-LAT0202.txt

# %%
#print(len(corpus))
#count_sentence = 0
#corpus_corrected = []
#for sentence in corpus:
#    count_sentence += 1
#    if count_sentence % 1000 == 0:
#        print(count_sentence)
#    sentence_new = []
#    for w in sentence:
#        #print(w)
#        if w == "revolutio" or w == "reuolutio" or w == "revolutione" or w == "reuolutionem" or w.startswith('revolutio') or w.startswith('reuolutio'):
#            w = "revolutio"
#        sentence_new.append(w)
#    corpus_corrected.append([w for w in sentence_new])
print(revolutio_texts)
print(len(corpus_corrected))
print(len(corpus))
# Out:
# ['IT-LAT0496', 'IT-LAT0512', 'IT-LAT0512', 'IT-LAT0820', 'IT-LAT0820', 'IT-LAT0970', 'IT-LAT0971', 'IT-LAT0971']
# 512576
# 512576

# %%
corpus_corrected[1]
# Out:
# ['aqua']

# %% [markdown]
# Check that the lemmatisations of "revolutio" are correct now:

# %%
count_sentence = 0
revolutio_sentences = []
count_revolutio_sentences = 0
for sentence in corpus_corrected:
    count_sentence = count_sentence + 1
    #if count_sentence % 1000 == 0:
    #    print(count_sentence)
    for w in sentence:
        #print(w)
        if w == "revolutio" or w == "reuolutio":
            print("revolutio!!!!!")
            print(sentence)
            count_revolutio_sentences += 1
            revolutio_sentences.append(sentence)
print(revolutio_sentences)
print(str(count_revolutio_sentences))
# Out:
# []
# 0

# %% [markdown]
# ### Check date texts for revolutio

# %%
revolutio_texts
for text in revolutio_texts:
    metadata_df_this_text = metadata_df[metadata_df['id'] == text]
    print((metadata_df_this_text.id, metadata_df_this_text.date))
# Out:
# (289    IT-LAT0496
# Name: id, dtype: object, 289    1200
# Name: date, dtype: int64)
# (304    IT-LAT0512
# Name: id, dtype: object, 304    1200
# Name: date, dtype: int64)
# (304    IT-LAT0512
# Name: id, dtype: object, 304    1200
# Name: date, dtype: int64)
# (508    IT-LAT0820
# Name: id, dtype: object, 508    1570
# Name: date, dtype: int64)
# (508    IT-LAT0820
# Name: id, dtype: object, 508    1570
# Name: date, dtype: int64)
# (619    IT-LAT0970
# Name: id, dtype: object, 619    1110
# Name: date, dtype: int64)
# (620    IT-LAT0971
# Name: id, dtype: object, 620    1110
# Name: date, dtype: int64)
# (620    IT-LAT0971
# Name: id, dtype: object, 620    1110
# Name: date, dtype: int64)

# %% [markdown]
# ## Split the corpus into subcorpora

# %% [markdown]
# Find the first and last year in the dataset:

# %%
first_date = min(metadata_df.date)
last_date = max(metadata_df.date)
print(first_date)
print(last_date)
# Out:
# -450
# 2005

# %% [markdown]
# Define size of the time intervals:

# %%
size_interval = 250

# %% [markdown]
# So there are x time intervals

# %%
n_intervals = round((last_date-first_date)/size_interval)
n_intervals
# Out:
# 10

# %% [markdown]
# Define the time periods and split the corpus:

# %%
intervals = [None]*(n_intervals+1)
for t in range(n_intervals+1):
    #print(t)
    if t == 0:
        intervals[t] = int(first_date)
    else:
        intervals[t] = int(intervals[t-1]+size_interval)
    #print(intervals[t])
    
print(intervals)
# Out:
# [-450, -200, 50, 300, 550, 800, 1050, 1300, 1550, 1800, 2050]

# %% [markdown]
# Add a column to the metadata_df for the time interval:

# %%
metadata_df['time_interval'] = ""
for t in range(len(intervals)-1):
    print(t)
    print(range(intervals[t],intervals[t+1]))
    metadata_df_t = metadata_df.loc[metadata_df['date'].isin(range(intervals[t],intervals[t+1]))]
    print(metadata_df_t.date)
    metadata_df.loc[metadata_df['date'].isin(range(intervals[t],intervals[t+1])),'time_interval'] = intervals[t]
metadata_df
# Out:
# 0
# range(-450, -200)
# 169   -450
# 649   -229
# Name: date, dtype: int64
# 1
# range(-200, 50)
# 19      -9
# 34     -49
# 38      49
# 39     -45
# 42     -49
#       ...
# 608    -44
# 635   -149
# 638   -107
# 642    -37
# 643    -37
# Name: date, Length: 89, dtype: int64
# 2
# range(50, 300)
# 37     158
# 40      50
# 41     121
# 43     199
# 45     197
#       ...
# 611    250
# 683    116
# 684    116
# 685    116
# 686    116
# Name: date, Length: 84, dtype: int64
# 3
# range(300, 550)
# 18      382
# 20      524
# 23      399
# 24      391
# 44      387
#        ...
# 679     382
# 680     382
# 681     382
# 682     382
# 1265    533
# Name: date, Length: 152, dtype: int64
# 4
# range(550, 800)
# 118    550
# 144    562
# 173    550
# 189    792
# 203    759
# 204    759
# 226    550
# 228    550
# 229    550
# 230    550
# 235    550
# 239    550
# 240    704
# 241    704
# 242    704
# 243    704
# 244    721
# 247    550
# 248    550
# 249    550
# 250    550
# 264    550
# 266    550
# 281    562
# 283    775
# 455    550
# 482    550
# 484    650
# 490    550
# 534    650
# 548    550
# 572    550
# 573    770
# 574    598
# 575    598
# 586    731
# 609    598
# 634    550
# 636    550
# Name: date, dtype: int64
# 5
# range(800, 1050)
# 102     800
# 104     800
# 105     800
# 106     800
# 107     800
# 108     800
# 109     800
# 224     818
# 268     950
# 269     850
# 270     800
# 275     909
# 287     838
# 293     833
# 384     950
# 449    1000
# 450     950
# 475     850
# 481     871
# 485     950
# 491     850
# 558     841
# 559     907
# 577     800
# 585     850
# 601     833
# 628     950
# Name: date, dtype: int64
# 6
# range(1050, 1300)
# 21     1254
# 22     1254
# 25     1224
# 26     1150
# 31     1260
#        ...
# 622    1110
# 623    1110
# 624    1067
# 625    1110
# 626    1110
# Name: date, Length: 115, dtype: int64
# 7
# range(1300, 1550)
# 28     1517
# 29     1547
# 30     1530
# 145    1428
# 165    1350
#        ...
# 603    1339
# 604    1355
# 606    1397
# 644    1501
# 646    1483
# Name: date, Length: 63, dtype: int64
# 8
# range(1550, 1800)
# 272    1550
# 279    1766
# 285    1550
# 353    1750
# 361    1550
# 363    1632
# 364    1668
# 368    1707
# 391    1667
# 392    1695
# 393    1695
# 394    1695
# 395    1695
# 396    1695
# 397    1695
# 398    1695
# 401    1650
# 403    1650
# 404    1550
# 406    1627
# 407    1550
# 412    1650
# 416    1650
# 417    1593
# 418    1593
# 431    1595
# 440    1795
# 442    1600
# 443    1767
# 473    1781
# 488    1760
# 489    1779
# 508    1570
# 515    1588
# 538    1650
# 539    1550
# 547    1550
# 554    1792
# 560    1610
# 564    1699
# 565    1741
# 591    1603
# 594    1568
# 600    1708
# 637    1550
# 639    1621
# 640    1614
# 641    1685
# 647    1550
# 650    1555
# 651    1684
# 652    1684
# Name: date, dtype: int64
# 9
# range(1800, 2050)
# 27     2000
# 33     1998
# 35     2001
# 36     1992
# 220    1998
# 251    2001
# 258    2002
# 259    2001
# 261    1994
# 267    1998
# 323    2002
# 343    1820
# 347    1998
# 348    1998
# 349    1815
# 355    1868
# 356    1868
# 357    1869
# 408    1988
# 409    1999
# 429    1979
# 432    1872
# 438    1858
# 441    1810
# 462    1998
# 463    1999
# 466    1990
# 467    1978
# 468    1975
# 469    1975
# 470    2003
# 471    1978
# 474    1957
# 486    1998
# 500    1997
# 505    1917
# 511    1968
# 516    1909
# 521    2001
# 522    1980
# 525    2004
# 526    2005
# 629    1897
# 630    1902
# 631    1891
# 632    1892
# 633    1892
# Name: date, dtype: int64
#                 id                          title  \
# 18      IT-LAT0001                        Vulgata
# 19      IT-LAT0537                   Ars amatoria
# 20      IT-LAT0011            S. Benedicti Regula
# 21      IT-LAT0012   In psalmis Davidis expositio
# 22      IT-LAT0014                Adoro te devote
# ...            ...                            ...
# 683   IT-LAT0534_1  De origine et situ Germanorum
# 684   IT-LAT0534_2        De vita Iulii Agricolae
# 685   IT-LAT0534_3         Dialogus de oratoribus
# 686   IT-LAT0534_4                      Historiae
# 1265    IT-LAT0202                  Institutiones
#
#                                                 creator  date    type  \
# 18                                           Hieronymus   382  poetry
# 19                                Ovidius Naso, Publius    -9  poetry
# 20                                 Benedictus Nursianus   524   prose
# 21                              Thomas Aquinas: Sanctus  1254   prose
# 22                              Thomas Aquinas: Sanctus  1254  poetry
# ...                                                 ...   ...     ...
# 683                  Tacitus, Publius (Gaius) Cornelius   116   prose
# 684                  Tacitus, Publius (Gaius) Cornelius   116   prose
# 685                  Tacitus, Publius (Gaius) Cornelius   116   prose
# 686                  Tacitus, Publius (Gaius) Cornelius   116   prose
# 1265  Iustinianus, Caesar Flavius (Imperator Iustini...   533   prose
#
#                            file time_interval
# 18      lat_0382_IT-LAT0001.txt           300
# 19      lat_-009_IT-LAT0537.txt          -200
# 20      lat_0524_IT-LAT0011.txt           300
# 21      lat_1254_IT-LAT0012.txt          1050
# 22      lat_1254_IT-LAT0014.txt          1050
# ...                         ...           ...
# 683   lat_0116_IT-LAT0534_1.txt            50
# 684   lat_0116_IT-LAT0534_2.txt            50
# 685   lat_0116_IT-LAT0534_3.txt            50
# 686   lat_0116_IT-LAT0534_4.txt            50
# 1265    lat_0533_IT-LAT0202.txt           300
#
# [670 rows x 7 columns]

# %% [markdown]
# Visualise distribution of time intervals:

# %%
metadata_df0 = metadata_df.groupby(['time_interval']).count()
metadata_df0 = metadata_df0['id']
metadata_df0
ax = metadata_df0.plot(kind='bar', figsize=(20,16), color="indigo", fontsize=10);
#ax.set_alpha(0.5)
ax.set_title("Number of works per time interval", fontsize=22)
plt.show()

# %% [markdown]
# ## Training embeddings for the whole corpus

# %% [markdown]
# Function for printing the vocabulary of a model

# %%
def print_vocab(model, top_n = None):
  if model == '':
    print("Empty model!")
  else:
    count = 0
    if top_n is not None:
      for index, word in enumerate(model.wv.index_to_key):
        count+= 1
        if count < top_n:
          print(f"word #{index}/{len(model.wv.index_to_key)} is {word}")
    else:
      for index, word in enumerate(model.wv.index_to_key):
        print(f"word #{index}/{len(model.wv.index_to_key)} is {word}")

# %% [markdown]
# Function for training FastText models (from Krzysztof Nowak):

# %%
def fasttext(self, opts=dict()):
        """
        Reads sentences from the corpus. Implements:
            https://radimrehurek.com/gensim/models/fasttext.html#gensim.models.fasttext.FastText
        Returns
        -------
        FastText model
        """
        default_opts = dict(vector_size=100, alpha=0.025,
                            window=5, min_count=5, epochs=5)
        opts_new = default_opts
        for opt in opts.keys():
            opts_new[opt] = opts[opt]
        model = FastText(
            vector_size=opts_new["vector_size"],
            alpha=opts_new["alpha"],
            window=opts_new["window"],
            min_count=opts_new["min_count"])
        model.build_vocab(corpus_iterable=[sentence for sentence in
                                           self.corpus.get_sents()])
        total_examples = model.corpus_count
        model.train(corpus_iterable=[sentence for sentence
                                     in self.corpus.get_sents()],
                    total_examples=total_examples,
                    epochs=opts_new["epochs"])
        return model

# %% [markdown]
# Parameters:
#
# `min_count`: the minimum frequency threshold allowed for a word to be included; set to 3 following Ribary & McGillivray (2020) or 5 following Sprugnoli et al. (2019).
#
# `vector_size`: the number of dimensions in which we wish to represent our word. This is the size of the word embedding; typically between 100 and 1,000. Set to 100 following Ribary & McGillivray (2020).
#
# `window`: The size of the context window determines how many words before and after a given word would be included as context words of the given word.  Typically between 5 and 10. Set to 10 following Sprugnoli et al. (2020).
#
# `sg`: – Training algorithm: 1 for skip-gram; otherwise CBOW. Set to 10 following Ribary & McGillivray (2020).

# %% [markdown]
# Train FastText embeddings and, for full reproducibility, limit the model to a single worker thread (workers=1), to eliminate ordering jitter from OS thread scheduling:

# %% [markdown]
# #### First test: Minimal frequency = 5 (check for lower frequency words) and vector size = 100

# %%
model = FastText(vector_size=100, alpha=0.025, window=1, min_count=5, workers=1, seed=1, hashfxn=hash)
model.build_vocab(corpus_iterable=corpus_corrected)
model.train(corpus_iterable=corpus_corrected, total_examples=model.corpus_count, epochs=5)
# Out:
# (35745470, 44714280)

# %% [markdown]
# Let's see what words are similar to "revolutio":

# %%
model.wv.similar_by_word('revolutio', 10)
# Out:
# [('resolutio', 0.9537547826766968),
#  ('revolutione', 0.9126618504524231),
#  ('deglutio', 0.9101446270942688),
#  ('remotio', 0.906026303768158),
#  ('redargutio', 0.9048041105270386),
#  ('ablutio', 0.9030078053474426),
#  ('dissolutio', 0.9014961123466492),
#  ('relaxatio', 0.899932861328125),
#  ('revocatio', 0.8973811864852905),
#  ('reductio', 0.8951544761657715)]

# %% [markdown]
# #### Test 2: Adding max_n=0 and min_n=0 to avoid selection at the string level (turn off subwords), keep the other parameters steady

# %%
start = time.time()
model = FastText(vector_size=100, window=5, min_count=5, workers=1, seed=1, hashfxn=hash, max_n = 0, min_n = 0)
model.build_vocab(corpus_iterable=corpus_corrected)
model.train(corpus_iterable=corpus_corrected, total_examples=model.corpus_count, epochs=5)
# Out:
# (35746259, 44714280)

# %%
end = time.time()
print("It has taken", round(end - start), "seconds")
model.wv.similar_by_word('revolutio', 10)
# Out:
# It has taken 118 seconds
# [('iurgantes', 0.0),
#  ('culturales', 0.0),
#  ('concreditum', 0.0),
#  ('capacibus', 0.0),
#  ('homiliam', 0.0),
#  ('Alemannia', 0.0),
#  ('definitivo', 0.0),
#  ('Phurim', 0.0),
#  ('IRENAEUSNon', 0.0),
#  ('spiritualitate', 0.0)]

# %% [markdown]
# ### test 3: experiment min_count = 1 and subwords turned off

# %%
start = time.time()
model = FastText(vector_size=100, window=5, min_count=1, workers=1, seed=1, hashfxn=hash, max_n = 0, min_n = 0)
model.build_vocab(corpus_iterable=corpus_corrected)
model.train(corpus_iterable=corpus_corrected, total_examples=model.corpus_count, epochs=5)

# %%
end = time.time()
print("It has taken", round(end - start), "seconds")
model.wv.similar_by_word('revolutio', 10)

# %% [markdown]
# The model has a vocabulary of

# %%
model.corpus_total_words

# %% [markdown]
# words and

# %%
model.corpus_count

# %% [markdown]
# sentences.

# %% [markdown]
# I evaluate different configurations of the parameters for the embeddings against the gold standard set by Sprugnoli et al. (2019) (https://github.com/CIRCSE/Lemma-Embeddings-for-Latin/blob/master/syn-selection-benchmark-Latin.tsv) to find the best configuration of parameters:

# %% [markdown]
# https://gitlab.surrey.ac.uk/mr0048/pydigest/-/blob/master/script/fasttext_003.py

# %% [markdown]
# WE MAY ALSO WANT TO EVALUATE THE TIME-INSENSITIVE EMBEDDINGS (i.e. trained of the full corpus) similarly to Ribary & McGillivray (2020)

# %% [markdown]
# For each time interval, I read the texts from files and create a list of lists, i.e. a list of sentences:

# %%
# dictionary that maps a time interval with the list of sentences of texts in that time interval"
time2corpus = dict()

# I loop over all time intervals:
for t in range(n_intervals+1):
    files_corpus_t = metadata_df.loc[metadata_df['time_interval'] == intervals[t]]
    #print("1:",files_corpus_t, type(files_corpus_t))
    corpus_t = list()
    for index, df_line in files_corpus_t.iterrows():
        #print("line:",df_line['id'], df_line['time_interval'])
        sign = "+"
        #print(df_line['date'])
        if df_line['date'] < 0:
            sign = "-"
        #print("date:", convert_dates(sign, abs(df_line['date'])))
        file_name = 'lat_'+str(convert_dates(sign, abs(df_line['date'])))+"_"+str(df_line['id'])+'.txt'
        #print("3:",file_name)
        file = open(os.path.join(dir_in, "preprocessed_"+lemmas_or_tokens, file_name), 'r')
        sentences_this_file = list()
        while True:
            line = file.readline().strip()
            if line != "":
                #sentences_this_file.append(line.split(" "))
                #sentences_this_file.append([token for token in line.split(" ") if token not in punctuation])
                corpus_corrected_t.append([token for token in line.split(" ") if ((token not in punctuation) and (token == "revolutio" or w == "reuolutio" or w == "revolutione" or w == "reuolutionem" or w.startswith('revolutio') or w.startswith('reuolutio')))])
                #corpus_t.append([token for token in line.split(" ") if token not in punctuation])
            # if line is empty end of file is reached
            if not line:
                break
        file.close()
        #corpus_t.append(sentences_this_file)
    #corpus_t1
    #print(len(corpus_t1[0]))
    time2corpus[t] = corpus_t

# %% [markdown]
# Let's inspect the corpus for the first time interval:

# %%
subcorpus2corpus[0]
# Out:
# [['frater', 'quis#2', 'sum', 'per', 'Aegyptus', 'Iudaei', 'salus', 'dico#2'],
#  ['frater',
#   'quis#2',
#   'sum',
#   'in',
#   'Hierosolyma',
#   'Iudaei',
#   'et',
#   'quis#2',
#   'in',
#   'regio'],
#  ['Iudaea', 'et', 'pax', 'bonus'],
#  ['benefacio',
#   'vos',
#   'deus',
#   'et',
#   'memini',
#   'testamentum',
#   'suus',
#   'quod',
#   'sum'],
#  ['ad', 'Abraham', 'et', 'Isaac', 'et', 'Iacob', 'servus', 'suus', 'fidelis'],
#  ['et', 'do', 'vos', 'cor', 'omnis', 'ut', 'colo', 'is', 'et', 'facio', 'is'],
#  ['voluntas', 'cor', 'magnus', 'et', 'animus', 'volente'],
#  ['adaperio',
#   'cor',
#   'vos',
#   'in',
#   'lex',
#   'suus',
#   'et',
#   'in',
#   'praeceptum',
#   'is',
#   'et'],
#  ['facio', 'pax'],
#  ['exaudio', 'oratio', 'vester', 'et', 'reconcilio', 'vos', 'nec', 'vos'],
#  ['desero', 'in', 'tempus', 'malus'],
#  ['et', 'nunc', 'hic', 'sum', 'oro', 'pro', 'vos'],
#  ['regno',
#   'Demetrium',
#   'annus',
#   'centesimus',
#   'sexagesimus',
#   'nonus',
#   'nos',
#   'Iudaei'],
#  ['scribo',
#   'vos',
#   'in',
#   'tribulatio',
#   'et',
#   'impetus',
#   'quis#2',
#   'supervenio',
#   'nos'],
#  ['in',
#   'iste',
#   'annus',
#   'ex',
#   'quo',
#   'recedo',
#   'Iason',
#   'ab',
#   'sanctus',
#   'terra',
#   'et',
#   'ab',
#   'regnum'],
#  ['porta', 'succendo', 'et', 'effundo', 'sanguis', 'innocens', 'et'],
#  ['oro',
#   'ad',
#   'dominus',
#   'et',
#   'exaudio',
#   'sum',
#   'et',
#   'offertor',
#   'sacrificium'],
#  ['et', 'similaginem', 'et', 'accendo', 'lucerna', 'et', 'propono', 'panis'],
#  ['et', 'nunc', 'frequento', 'dies', 'scenophegiae', 'mensa', 'casleu'],
#  ['annus', 'centesimus', 'octogesimo', 'octavus', 'populus', 'quis#2', 'sum'],
#  ['Hierosolyma',
#   'et',
#   'in',
#   'Iudaea',
#   'senatusque',
#   'et',
#   'Iudas',
#   'Aristobolo'],
#  ['magister',
#   'Ptolomei',
#   'rex',
#   'quis#2',
#   'sum',
#   'de',
#   'genus',
#   'christorum',
#   'sacerdos'],
#  ['et',
#   'hic',
#   'quis#2',
#   'in',
#   'Aegyptus',
#   'sum',
#   'Iudaei',
#   'salus',
#   'et',
#   'sanitas'],
#  ['de',
#   'magnus',
#   'periculum',
#   'ab',
#   'deus',
#   'libero',
#   'magnificus',
#   'gratia',
#   'ipse'],
#  ['utpote', 'quis#2', 'adversus#2', 'talis', 'rex', 'dimico'],
#  ['ipse',
#   'enim',
#   'ebullio',
#   'facio',
#   'de',
#   'Perside',
#   'is',
#   'quis#2',
#   'pugno'],
#  ['contra', 'nos'],
#  ['namque',
#   'cum',
#   'in',
#   'Perside',
#   'sum',
#   'dux',
#   'ipse',
#   'et',
#   'cum',
#   'ipse',
#   'inmensus'],
#  ['exercitus',
#   'cado',
#   'in',
#   'templum',
#   'Naneae',
#   'consilium',
#   'deceptus',
#   'sacerdos'],
#  ['Naneae'],
#  ['ut',
#   'enim',
#   'cum',
#   'is',
#   'habito',
#   'venio',
#   'ad',
#   'locus',
#   'Antiochus',
#   'et'],
#  ['amicus#2',
#   'is',
#   'et',
#   'ut',
#   'accipio',
#   'pecunia',
#   'multus',
#   'dos',
#   'nomen'],
#  ['cumque', 'propono', 'is', 'sacerdos', 'Naneae', 'et', 'ipse', 'cum'],
#  ['paucus',
#   'ingredior',
#   'sum',
#   'intro',
#   'ambitus',
#   'fanum',
#   'claudo',
#   'templum'],
#  ['cum', 'intro', 'Antiochus', 'apertoque', 'occultus', 'aditus', 'templum'],
#  ['mitto',
#   'lapis',
#   'percutio',
#   'dux',
#   'et',
#   'quis#2',
#   'cum',
#   'is',
#   'sum',
#   'et'],
#  ['divisor', 'membratim', 'et', 'caput', 'amputo', 'foras', 'projacio'],
#  ['per', 'omnis', 'benedico', 'deus', 'quis#2', 'trado', 'impius'],
#  ['facio', 'igitur', 'quintus', 'et', 'vicesimus', 'mensa', 'casleu'],
#  ['purificatio', 'templum', 'necessarius', 'duco', 'significo', 'vos', 'ut'],
#  ['vos',
#   'quoque',
#   'ago',
#   'dies',
#   'scenophegiae',
#   'et',
#   'dies',
#   'ignis',
#   'quis#2',
#   'do',
#   'sum'],
#  ['quando',
#   'Neemias',
#   'aedifico',
#   'templum',
#   'et',
#   'altar',
#   'offertor',
#   'sacrificium'],
#  ['namque',
#   'cum',
#   'in',
#   'Persidem',
#   'duco',
#   'pater',
#   'noster',
#   'sacerdos',
#   'quis#2'],
#  ['tunc',
#   'deus',
#   'cultor',
#   'sum',
#   'accipio',
#   'ignis',
#   'de',
#   'altarium',
#   'occulte'],
#  ['abscondo',
#   'in',
#   'vallus',
#   'ubi',
#   'sum',
#   'puteus',
#   'altus',
#   'siccus',
#   'et',
#   'in',
#   'is'],
#  ['contutati', 'sum', 'is', 'ita', 'ut', 'omnis', 'ignotus', 'sum', 'locus'],
#  ['cum',
#   'praetereo',
#   'autem',
#   'multus',
#   'annus',
#   'et',
#   'placeo',
#   'deus',
#   'ut'],
#  ['mitto', 'Neemias', 'ab', 'rex', 'Persidis', 'nepos', 'sacerdos', 'ille'],
#  ['quis#2', 'abscondo', 'mitto', 'ad', 'requiro', 'ignis', 'et', 'sicut'],
#  ['narro', 'nos', 'non', 'invenio', 'ignis', 'sed', 'aqua', 'crassus'],
#  ['et',
#   'jubeo',
#   'is',
#   'haurio',
#   'et',
#   'affero',
#   'se',
#   'et',
#   'sacrificium',
#   'quis#2'],
#  ['inpono',
#   'sum',
#   'jubeo',
#   'sacerdos',
#   'Neemias',
#   'aspargi',
#   'aqua',
#   'ipse',
#   'et'],
#  ['lignum', 'et', 'quis#2', 'sum', 'superpono'],
#  ['utque',
#   'hic',
#   'facio',
#   'sum',
#   'et',
#   'tempus',
#   'adsum',
#   'quo',
#   'sol',
#   'refulgeo',
#   'quis#2'],
#  ['prius',
#   'sum',
#   'in',
#   'nubilum',
#   'accensus',
#   'sum',
#   'ignis',
#   'magnus',
#   'ita',
#   'ut',
#   'omnis'],
#  ['miror'],
#  ['oratio', 'autem', 'facio', 'omnis', 'sacerdos', 'dum'],
#  ['consummo', 'sacrificium', 'Ionatha', 'inchoante', 'ceterus', 'autem'],
#  ['respondeo'],
#  ['et',
#   'Neemiae',
#   'sum',
#   'oratio',
#   'hic',
#   'habeo',
#   'modus',
#   'dominus',
#   'deus',
#   'omnis'],
#  ['creator',
#   'terribilis',
#   'et',
#   'fortis',
#   'iustus',
#   'et',
#   'misericors',
#   'quis#2',
#   'solus',
#   'sum'],
#  ['rex', 'bonus'],
#  ['solus',
#   'praesto',
#   'solus',
#   'iustus',
#   'et',
#   'omnipotens',
#   'et',
#   'aeternus',
#   'quis#2'],
#  ['libero',
#   'Israel',
#   'de',
#   'omnis',
#   'malus',
#   'quis#2',
#   'facio',
#   'pater',
#   'eligo',
#   'et'],
#  ['sanctificasti', 'is'],
#  ['accipio',
#   'sacrificium',
#   'pro',
#   'universus',
#   'populus',
#   'tuus',
#   'Israel',
#   'et'],
#  ['custos', 'pars', 'tuus', 'et', 'sanctifico'],
#  ['congregus', 'dispersio', 'noster', 'liber', 'is', 'quis#2', 'servio'],
#  ['gens',
#   'contemptus',
#   'et',
#   'abominor',
#   'respicio',
#   'ut',
#   'scio',
#   'gens',
#   'quod'],
#  ['tuuus', 'sum', 'deus', 'noster'],
#  ['adflige', 'opprimo', 'et', 'contumelia', 'facio', 'in', 'superbia'],
#  ['constitue',
#   'populus',
#   'tuus',
#   'in',
#   'locus',
#   'sanctus',
#   'tuus',
#   'sicut',
#   'dico#2',
#   'Moses'],
#  ['sacerdos', 'autem', 'psallebant', 'hymnus', 'usquequo', 'consumo'],
#  ['sum', 'sacrificium'],
#  ['cum', 'autem', 'consummo', 'sum', 'sacrificium', 'ex', 'residuus', 'aqua'],
#  ['Neemias', 'jubeo', 'lapis', 'magnus', 'perfundi'],
#  ['quod',
#   'ut',
#   'facio',
#   'sum',
#   'flamma',
#   'ex',
#   'is',
#   'accendo',
#   'sum',
#   'sed',
#   'ex',
#   'lumen'],
#  ['quod', 'refulgeo', 'ab', 'altar', 'consumo', 'sum'],
#  ['ut', 'verus', 'manifesto', 'sum', 'hic', 'renuntio', 'sum', 'rex'],
#  ['Persae',
#   'quod',
#   'in',
#   'locus',
#   'in',
#   'quo',
#   'ignis',
#   'abscondo',
#   'hic',
#   'quis#2'],
#  ['transfero',
#   'sum',
#   'sacerdos',
#   'aqua',
#   'appareo',
#   'de',
#   'qui',
#   'Neemias',
#   'et',
#   'quis#2'],
#  ['cum', 'is', 'sum', 'purificaverunt', 'sacrificium'],
#  ['considero',
#   'autem',
#   'rex',
#   'et',
#   'res',
#   'diligenter',
#   'examino',
#   'facio',
#   'is'],
#  ['templum'],
#  ['et',
#   'si',
#   'quis#2',
#   'dono',
#   'rex',
#   'multus',
#   'bonus',
#   'accipio',
#   'ex',
#   'hic',
#   'et'],
#  ['tribuo'],
#  ['appello', 'autem', 'Neemias', 'hic', 'Nepthar', 'quod', 'interpretor'],
#  ['purificatio', 'voco', 'autem', 'apud', 'multus', 'Nephi'],
#  ['invenio', 'autem', 'in', 'descriptio', 'Hieremiae', 'propheta', 'quod'],
#  ['jubeo',
#   'accipio',
#   'ignis',
#   'is',
#   'quis#2',
#   'transmigro',
#   'ut',
#   'significo'],
#  ['sum', 'et', 'ut', 'mando', 'transmigro'],
#  ['et',
#   'do',
#   'ille',
#   'lex',
#   'ne#2',
#   'obliviscerentur',
#   'praeceptum',
#   'dominus',
#   'et'],
#  ['ut',
#   'non',
#   'exerrarent',
#   'mens',
#   'video',
#   'simulacrum',
#   'aureus',
#   'et',
#   'argenteus'],
#  ['et', 'ornamentum', 'is'],
#  ['et',
#   'alius',
#   'huiuscemodi',
#   'dico#2',
#   'hortor',
#   'ne#2',
#   'lex',
#   'amoveo',
#   'ab'],
#  ['cor', 'suus'],
#  ['sum',
#   'autem',
#   'in',
#   'ipse',
#   'scriptura',
#   'quomodo',
#   'tabernaculum',
#   'et',
#   'arca'],
#  ['jubeo',
#   'propheta',
#   'divinus',
#   'responsum',
#   'ad',
#   'se',
#   'facio',
#   'comitari',
#   'se',
#   'cum'],
#  ['usquequo',
#   'exeo',
#   'in',
#   'mons',
#   'in',
#   'quo',
#   'Moses',
#   'ascendo',
#   'et',
#   'video',
#   'deus'],
#  ['hereditas'],
#  ['et', 'venio', 'ibi', 'Hieremias', 'invenio', 'locus', 'spelunca', 'et'],
#  ['tabernaculum',
#   'et',
#   'arca',
#   'et',
#   'altar',
#   'incensum',
#   'infero',
#   'illuc',
#   'et',
#   'ostium'],
#  ['obstruxit'],
#  ['et', 'accedo', 'quidam', 'simul', 'quis#2', 'sequor', 'ut', 'noto', 'se'],
#  ['locus', 'et', 'non', 'possum', 'invenio'],
#  ['ut',
#   'autem',
#   'cognosco',
#   'Hieremias',
#   'culpans',
#   'ille',
#   'dico#2',
#   'quod',
#   'ignotus'],
#  ['sum',
#   'locus',
#   'donec',
#   'congrego',
#   'deus',
#   'congregatio',
#   'populus#2',
#   'et'],
#  ['propitius', 'fio'],
#  ['et',
#   'tunc',
#   'dominus',
#   'ostendo',
#   'hic',
#   'et',
#   'appareo',
#   'maiestas',
#   'dominus'],
#  ['et',
#   'nubes',
#   'sum',
#   'sicut',
#   'et',
#   'Moses',
#   'manifesto',
#   'et',
#   'sicut',
#   'cum',
#   'Salomon'],
#  ['peto', 'ut', 'locus', 'sanctifico', 'magnus', 'deus', 'manifesto', 'hic'],
#  ['et',
#   'ut',
#   'sapientia',
#   'habeo',
#   'offertor',
#   'sacrificium',
#   'dedicatio',
#   'et'],
#  ['consummatio', 'templum'],
#  ['sicut',
#   'et',
#   'Moses',
#   'oro',
#   'ad',
#   'dominus',
#   'et',
#   'descendo',
#   'ignis',
#   'de'],
#  ['caelum', 'et', 'consumo', 'holocaustum'],
#  ['et',
#   'dico#2',
#   'Moses',
#   'is',
#   'quod',
#   'non',
#   'sum',
#   'mundo',
#   'quod',
#   'sum',
#   'pro'],
#  ['peccatum', 'et', 'consumo', 'sum'],
#  ['similiter', 'et', 'Salomon', 'octo', 'dies', 'celebro', 'dedicatio'],
#  ['inferebantur', 'autem', 'in', 'descriptio', 'et', 'commentarius'],
#  ['Neemiae',
#   'hic',
#   'idem',
#   'et',
#   'ut',
#   'construo',
#   'bibliotheca',
#   'congrego',
#   'de'],
#  ['rex',
#   'liber',
#   'et',
#   'propheta',
#   'et',
#   'David',
#   'et',
#   'epistula',
#   'rex',
#   'et',
#   'de'],
#  ['donarium'],
#  ['similiter',
#   'autem',
#   'et',
#   'Iudas',
#   'is',
#   'quis#2',
#   'disco',
#   'per',
#   'bellum',
#   'quod'],
#  ['nos', 'accido', 'congrego', 'omnis', 'et', 'sum', 'apud', 'nos'],
#  ['si', 'ergo', 'desiderastis', 'hic', 'mitto', 'quis#2', 'perfero', 'vos'],
#  ['ago', 'itaque', 'purificatio', 'scribo', 'vos', 'bene', 'igitur'],
#  ['facio', 'si', 'ago', 'hic', 'dies'],
#  ['deus', 'autem', 'quis#2', 'libero', 'populus', 'suus', 'et', 'reddo'],
#  ['hereditas', 'omnis', 'et', 'regnum', 'et', 'sacerdotium', 'et'],
#  ['sanctificatio'],
#  ['sicut', 'promitto', 'in', 'lex', 'spero', 'quod', 'cito', 'noster'],
#  ['misereo',
#   'et',
#   'congrego',
#   'de',
#   'sub',
#   'caelum',
#   'in',
#   'locus',
#   'sanctus'],
#  ['eripio',
#   'enim',
#   'nos',
#   'de',
#   'magnus',
#   'periculum',
#   'et',
#   'locus',
#   'purgavit'],
#  ['de',
#   'Iudas',
#   'verus',
#   'Macchabeo',
#   'et',
#   'frater',
#   'is',
#   'et',
#   'de',
#   'templum',
#   'magnus'],
#  ['purificatio', 'et', 'de', 'ara', 'dedicatio'],
#  ['sed',
#   'et',
#   'de',
#   'proelium',
#   'quis#2',
#   'pertineo',
#   'ad',
#   'Antiochus',
#   'nobilis',
#   'et'],
#  ['filius', 'is', 'Eupator'],
#  ['et',
#   'de',
#   'inluminationibus',
#   'quis#2',
#   'de',
#   'caelum',
#   'facio',
#   'sum',
#   'ad',
#   'is',
#   'quis#2'],
#  ['pro',
#   'Iudaei',
#   'fortiter',
#   'facio',
#   'ita',
#   'ut',
#   'universus',
#   'regio',
#   'cum'],
#  ['paucus', 'sum', 'vindico', 'et', 'barbara', 'multitudo', 'fugo'],
#  ['et', 'famosus', 'in', 'totus#2', 'orbis', 'templum', 'recuperarent', 'et'],
#  ['civitas', 'libero', 'ut', 'lex', 'quis#2', 'aboleo', 'sum'],
#  ['restituo',
#   'dominus',
#   'cum',
#   'omnis',
#   'tranquillitas',
#   'propitius',
#   'facio'],
#  ['ille'],
#  ['item', 'ab', 'Iason', 'Cyreneo', 'quinque', 'libra', 'comprehendo'],
#  ['tento', 'nos', 'unus', 'volumen', 'brevio'],
#  ['considero', 'enim', 'multitudo', 'librorum', 'et', 'difficultas'],
#  ['volo', 'adgredi', 'narratio', 'historia', 'propter', 'multitudo'],
#  ['res'],
#  ['curo', 'volo', 'quidem', 'lego#2', 'ut', 'sum', 'animus'],
#  ['oblectatio',
#   'studiosus',
#   'verus',
#   'ut',
#   'facilis',
#   'possum',
#   'memoria',
#   'commendo'],
#  ['omnis', 'autem', 'lego', 'utilitas', 'confero'],
#  ['et', 'nos', 'quidem', 'ipse', 'quis#2', 'opus', 'hic', 'brevio', 'causa'],
#  ['suscipio',
#   'non',
#   'facilis',
#   'labor',
#   'immo',
#   'verus',
#   'negotium',
#   'plenus'],
#  ['vigilia', 'et', 'sudor', 'adsumo'],
#  ['sicut', 'hic', 'quis#2', 'praeparo', 'convivium', 'et', 'quaero', 'alius'],
#  ['voluntas', 'pario', 'propter', 'multus', 'gratia', 'libet', 'labor'],
#  ['sustineo'],
#  ['veritas', 'quidem', 'de', 'singulus', 'auctor', 'concedo', 'ipse', 'autem'],
#  ['secundum', 'do', 'forma', 'brevitas', 'studeo'],
#  ['sicut',
#   'enim',
#   'novus',
#   'domus',
#   'architectus',
#   'de',
#   'universus',
#   'structura'],
#  ['curandus',
#   'sum',
#   'is',
#   'verus',
#   'quis#2',
#   'pingo',
#   'conor',
#   'quis#2',
#   'aptus',
#   'sum',
#   'ad'],
#  ['ornatus', 'exquiro', 'sum', 'ita', 'aestimo', 'sum', 'et', 'in', 'nos'],
#  ['etenim', 'intellego', 'colligo', 'et', 'ordino', 'sermo', 'et'],
#  ['curiosus', 'pars', 'singulus', 'quasque', 'disquaero', 'historia'],
#  ['congruo', 'auctor'],
#  ['brevitas', 'verus', 'dictio', 'sectarius', 'et', 'exsecutio', 'res'],
#  ['vito', 'brevitas', 'concedo', 'sum'],
#  ['hinc', 'igitur', 'narratio', 'incipio', 'de', 'praefatio', 'tantus'],
#  ['dico#2',
#   'sufficio',
#   'stultus',
#   'etenim',
#   'sum',
#   'ante',
#   'historia',
#   'effluo',
#   'in'],
#  ['ipse', 'autem', 'historia', 'succingi'],
#  ['igitur',
#   'cum',
#   'sanctus',
#   'civitas',
#   'habito',
#   'in',
#   'omnis',
#   'pax',
#   'lex'],
#  ['etiam', 'adhuc', 'optime', 'custodio', 'propter', 'Oniae', 'pontifex'],
#  ['pietas', 'et', 'animus', 'odium', 'habeo', 'malus'],
#  ['fio',
#   'ut',
#   'ipse',
#   'rex',
#   'et',
#   'princeps',
#   'locus',
#   'summus',
#   'honor',
#   'dignus'],
#  ['duco', 'et', 'templum', 'maximus', 'munus', 'inlustro'],
#  ['ita',
#   'ut',
#   'Seleucus',
#   'Asia',
#   'rex',
#   'de',
#   'reditus',
#   'suus',
#   'praesto',
#   'omnis'],
#  ['sumptus', 'ad', 'ministerium', 'sacrificium', 'pertineo'],
#  ['Simon',
#   'autem',
#   'de',
#   'tribus',
#   'Beniamin',
#   'praepositus',
#   'templum',
#   'constituo'],
#  ['contendo', 'obsisto', 'se', 'princeps', 'sacerdos', 'iniquus', 'aliquis'],
#  ['in', 'civitas', 'molior'],
#  ['sed',
#   'cum',
#   'vinco',
#   'Onian',
#   'non',
#   'possum',
#   'venio',
#   'ad',
#   'Apollonius'],
#  ['Tharseae',
#   'filius',
#   'quis#2',
#   'ille',
#   'tempus',
#   'sum',
#   'dux',
#   'Coelesyriae',
#   'et'],
#  ['Foenicis'],
#  ['et', 'nuntio', 'is', 'pecunia', 'innumerabilis', 'plenus', 'sum'],
#  ['aerarius',
#   'Hierosolyma',
#   'et',
#   'communis',
#   'copia',
#   'inmensas',
#   'sum',
#   'quis#2',
#   'non'],
#  ['pertineo',
#   'ad',
#   'ratio',
#   'sacrificium',
#   'sum',
#   'autem',
#   'possibilis',
#   'sub'],
#  ['potestas', 'rex', 'cado', 'universus'],
#  ['cumque', 'refero', 'Apollonius', 'ad', 'rex', 'de', 'pecunia', 'quis#2'],
#  ['defero',
#   'sum',
#   'ille',
#   'accio',
#   'Heliodorus',
#   'quis#2',
#   'sum',
#   'super',
#   'negotium'],
#  ['is', 'mitto', 'cum', 'mandatum', 'ut', 'praedico', 'pecunia', 'transporto'],
#  ['statimque',
#   'Heliodorus',
#   'iter',
#   'aggredior',
#   'species',
#   'quidem',
#   'quasi',
#   'per'],
#  ['Coelesyriam',
#   'et',
#   'Foenicen',
#   'civitas',
#   'sum',
#   'peragro',
#   'res',
#   'autem'],
#  ['verus', 'rex', 'propono', 'perficio'],
#  ['sed',
#   'cum',
#   'venio',
#   'Hierosolyma',
#   'et',
#   'benignus',
#   'ab',
#   'summus',
#   'sacerdos'],
#  ['in',
#   'civitas',
#   'sum',
#   'excipio',
#   'narro',
#   'de',
#   'do',
#   'indicium',
#   'pecunia'],
#  ['et',
#   'quis#2',
#   'reus',
#   'gratia',
#   'adsum',
#   'appareo',
#   'interrogo',
#   'autem',
#   'si',
#   'verus'],
#  ['hic', 'ita', 'sum'],
#  ['tunc', 'summus', 'sacerdos', 'ostendo', 'depositum', 'sum', 'hic', 'et'],
#  ['victualis', 'vidua', 'atque', 'pupillus'],
#  ['quidam',
#   'verus',
#   'sum',
#   'Hircani',
#   'Tobiae',
#   'vir',
#   'valde',
#   'emineo',
#   'in'],
#  ['hic',
#   'quis#2',
#   'defero',
#   'impius',
#   'Simon',
#   'universus',
#   'autem',
#   'argentum',
#   'talentum'],
#  ['quadringenti', 'sum', 'et', 'aurum', 'ducenti'],
#  ['decipi',
#   'verus',
#   'is',
#   'quis#2',
#   'credo',
#   'locus',
#   'et',
#   'templum',
#   'quod',
#   'per'],
#  ['universus',
#   'mundum',
#   'honoro',
#   'pro',
#   'suus',
#   'veneratio',
#   'et',
#   'sanctitas'],
#  ['impossibilis', 'omnino', 'sum'],
#  ['at',
#   'ille',
#   'pro',
#   'hic',
#   'quis#2',
#   'habeo',
#   'in',
#   'mandatum',
#   'ab',
#   'rex',
#   'dico#2'],
#  ['omnis', 'genus', 'regia', 'deferenda'],
#  ['constituo', 'autem', 'dies', 'intro', 'de', 'hic', 'Heliodorus', 'ordino'],
#  ['non',
#   'modicus',
#   'verus',
#   'per',
#   'universus',
#   'civitas',
#   'sum',
#   'trepidatio'],
#  ['sacerdos', 'autem', 'ante', 'altar', 'cum', 'sacerdotalis', 'stola'],
#  ['iactaverunt',
#   'se',
#   'et',
#   'invoco',
#   'de',
#   'caelum',
#   'is',
#   'quis#2',
#   'de',
#   'depono'],
#  ['lex', 'pono', 'ut', 'hic', 'quis#2', 'depono', 'is', 'salvus', 'custodio'],
#  ['iam', 'verus', 'quis#2', 'video', 'summus', 'sacerdos', 'vultus', 'mens'],
#  ['vulnero',
#   'facies',
#   'enim',
#   'et',
#   'color',
#   'inmutatus',
#   'declaro',
#   'internus'],
#  ['animus', 'dolor'],
#  ['circumfundo', 'enim', 'sum', 'vir', 'maestitia', 'quidam', 'et', 'horror'],
#  ['corpus', 'per', 'quis#2', 'manifestus', 'aspicio', 'dolor', 'cor', 'is'],
#  ['efficio'],
#  ['alius', 'etiam', 'congrego', 'de', 'domus', 'confluo', 'publicus'],
#  ['supplicatio',
#   'obsecro',
#   'pro',
#   'is',
#   'quod',
#   'in',
#   'contemptus',
#   'locus',
#   'sum'],
#  ['venio'],
#  ['accinctaeque', 'mulier', 'cilicium', 'pectus', 'per', 'platea'],
#  ['confluo', 'sed', 'et', 'virgo', 'quis#2', 'conclusus', 'sum', 'procurro'],
#  ['ad',
#   'Onian',
#   'alius',
#   'autem',
#   'ad',
#   'murus',
#   'quidam',
#   'verus',
#   'per',
#   'fenestra'],
#  ['aspicio'],
#  ['universus', 'autem', 'protendo', 'manus', 'in', 'caelum', 'deprecor'],
#  ['sum',
#   'enim',
#   'miserum',
#   'commisceo',
#   'multitudo',
#   'et',
#   'magnus',
#   'sacerdos'],
#  ['in', 'agon', 'constituo', 'expectatio'],
#  ['et', 'hic', 'quidem', 'invoco', 'omnipotens', 'deus', 'ut', 'credo', 'se'],
#  ['hic', 'quis#2', 'credo', 'cum', 'omnis', 'integritas', 'conservo'],
#  ['Heliodorus', 'autem', 'quod', 'decerno', 'perficio', 'idem', 'locus'],
#  ['ipse', 'cum', 'satellitibus', 'circa', 'aerarius', 'praesens'],
#  ['sed', 'spiritus', 'Omnipotentis', 'magnus', 'facio', 'suus', 'ostensio'],
#  ['evidentia',
#   'ita',
#   'ut',
#   'omnis',
#   'quis#2',
#   'audeo',
#   'sum',
#   'pario',
#   'is',
#   'ruo',
#   'deus'],
#  ['virtus', 'in', 'dissolutio', 'et', 'formidinem', 'converto'],
#  ['appareo',
#   'enim',
#   'ille',
#   'quidam',
#   'equus',
#   'terribilis',
#   'habeo',
#   'sessor'],
#  ['optimum', 'operimentum', 'adorno', 'isque', 'cum', 'impetus', 'Heliodorus'],
#  ['prior',
#   'calco',
#   'elido',
#   'quis#2',
#   'autem',
#   'is',
#   'sedeo',
#   'video',
#   'arma'],
#  ['habeo', 'aureus'],
#  ['alius', 'etiam', 'appareo', 'duo', 'iuvenis', 'virtus', 'decorum', 'bonus'],
#  ['gloria',
#   'speciosique',
#   'amictus',
#   'quis#2',
#   'circumsto',
#   'is',
#   'et',
#   'ex',
#   'uterque'],
#  ['pars', 'flagello', 'sine', 'intermissio', 'multus', 'plaga', 'Verantes'],
#  ['subito', 'autem', 'Heliodorus', 'concedo', 'in', 'terra', 'is', 'multus'],
#  ['caligo', 'circumfundo', 'rapio', 'atque', 'in', 'sella', 'gestatorius'],
#  ['pono', 'eicio'],
#  ['et',
#   'is',
#   'quis#2',
#   'cum',
#   'multus',
#   'cursor',
#   'et',
#   'satellitibus',
#   'praedico'],
#  ['ingredior',
#   'sum',
#   'aerarius',
#   'porto',
#   'nullus',
#   'se',
#   'auxilium',
#   'ferente'],
#  ['manifestus', 'cognosco', 'deus', 'virtus'],
#  ['et', 'ille', 'quidem', 'per', 'divinus', 'virtus', 'iaceo', 'mutus'],
#  ['hic', 'autem', 'dominus', 'benedico', 'quia', 'magnifico', 'locus', 'suus'],
#  ['et',
#   'templum',
#   'quod',
#   'paulum',
#   'ante',
#   'timor',
#   'atque',
#   'tumultus',
#   'sum',
#   'plenus'],
#  ['appareo',
#   'omnipotente',
#   'dominus',
#   'gaudium',
#   'et',
#   'laetitia',
#   'impleo',
#   'sum'],
#  ['tunc',
#   'verus',
#   'ex',
#   'amicus#2',
#   'Heliodorus',
#   'quidam',
#   'rogo',
#   'confestim'],
#  ['Onian', 'ut', 'invoco', 'alo', 'et', 'vita', 'dono', 'is', 'quis#2', 'in'],
#  ['superus', 'spiritus', 'sum', 'constituo'],
#  ['considero',
#   'autem',
#   'summus',
#   'sacerdos',
#   'ne#2',
#   'forte',
#   'rex',
#   'suspicor'],
#  ['malitia', 'aliquis', 'ex', 'Iudaei', 'circa', 'Heliodorus', 'consummatus'],
#  ['offertor', 'pro', 'salus', 'vir', 'hostia', 'salutaris'],
#  ['cum', 'summus', 'sacerdos', 'exoro', 'idem', 'iuvenis', 'idem'],
#  ['vestis',
#   'amicio',
#   'adstantes',
#   'Heliodorus',
#   'dico#2',
#   'Oniae',
#   'sacerdotium'],
#  ['gratia', 'ago', 'namque', 'propter', 'is', 'tu', 'dominus', 'vita', 'dono'],
#  ['tuuus',
#   'autem',
#   'ab',
#   'is',
#   'flagello',
#   'nuntius',
#   'omnis',
#   'magnalia',
#   'deus',
#   'et'],
#  ['potestas', 'et', 'hic', 'dico#2', 'non', 'conparuerunt'],
#  ['Heliodorus',
#   'autem',
#   'ostium',
#   'deus',
#   'offertor',
#   'et',
#   'votum',
#   'magnus',
#   'promitto'],
#  ['is',
#   'quis#2',
#   'vivo',
#   'ille',
#   'concedo',
#   'et',
#   'Oniae',
#   'gratia',
#   'agens',
#   'receptum'],
#  ['exercitus', 'repedabat', 'ad', 'rex'],
#  ['testo', 'autem', 'omnis', 'is', 'quis#2', 'sub', 'oculus', 'suus', 'video'],
#  ['opus', 'magnus', 'deus'],
#  ['cum',
#   'autem',
#   'rex',
#   'interrogasset',
#   'Heliodorus',
#   'quis#2',
#   'sum',
#   'aptus',
#   'adhuc'],
#  ['semel', 'Hierosolyma', 'mitto', 'ajo'],
#  ['si',
#   'quis#2',
#   'habeo',
#   'hostis',
#   'aut',
#   'regnum',
#   'tuus',
#   'insidiator',
#   'mitto',
#   'illuc'],
#  ['et',
#   'flagello',
#   'is',
#   'recipio',
#   'si',
#   'tamen',
#   'evado',
#   'is',
#   'quod',
#   'in',
#   'locus'],
#  ['verus', 'sum', 'deus', 'quidam', 'virtus'],
#  ['namque',
#   'ipse',
#   'quis#2',
#   'habeo',
#   'in',
#   'caelum',
#   'habitatio',
#   'visitator',
#   'et'],
#  ['adjuto',
#   'sum',
#   'locus',
#   'ille',
#   'et',
#   'venio',
#   'ad',
#   'malefacio',
#   'percutio'],
#  ['atque', 'perdo'],
#  ['igitur',
#   'de',
#   'Heliodorus',
#   'et',
#   'aerarius',
#   'custodia',
#   'ita',
#   'se',
#   'res',
#   'habeo'],
#  ['Simon', 'autem', 'praedico', 'pecunia', 'et', 'patria', 'delator', 'male'],
#  ['loquor',
#   'de',
#   'Onia',
#   'tamquam',
#   'ipse',
#   'Heliodorus',
#   'instigasset',
#   'ad',
#   'hic'],
#  ['et', 'ipse', 'sum', 'incentor', 'malus#3'],
#  ['provisoremque', 'civitas', 'atque', 'defensor', 'gens', 'suus', 'et'],
#  ['aemulatorem', 'lex', 'deus', 'audeo', 'insidiator', 'regnum', 'dico#2'],
#  ['sed', 'cum', 'inimicitia', 'in', 'tantus', 'procedo', 'ut', 'etiam', 'per'],
#  ['quidam', 'Simo', 'necessarius', 'homicidium', 'fio'],
#  ['considero', 'Onias', 'periculum', 'contentio', 'et', 'Apollonius'],
#  ['insanio', 'utpote', 'dux', 'Coelesyriae', 'et', 'Foenicis', 'ad', 'augeo'],
#  ['malitia', 'Simo', 'ad', 'rex', 'se', 'confero'],
#  ['non',
#   'ut',
#   'civis',
#   'accusator',
#   'sed',
#   'communis',
#   'utilitas',
#   'apud',
#   'sui'],
#  ['ipse', 'universus', 'multitudo', 'considero'],
#  ['video',
#   'enim',
#   'sine',
#   'regali',
#   'providentia',
#   'impossibilis',
#   'sum',
#   'pax'],
#  ['res', 'do', 'nec', 'Simo', 'possum', 'cesso', 'ab', 'stultitia', 'suus'],
#  ['sed', 'post', 'Seleucus', 'vita', 'excessus', 'cum', 'suscipio', 'regnum'],
#  ['Antiochus',
#   'quis#2',
#   'nobilis',
#   'appello',
#   'ambiebat',
#   'Iason',
#   'frater',
#   'Oniae'],
#  ['summus', 'sacerdotium'],
#  ['adito', 'rex', 'promitto', 'is', 'argentum', 'talentum', 'sexaginta', 'et'],
#  ['trecenta', 'et', 'ex', 'reditus', 'alius', 'talentum', 'octoginta'],
#  ['super', 'hic', 'promitto', 'et', 'alius', 'centum', 'quinquaginta', 'si'],
#  ['potestas', 'is', 'concedo', 'gymnasium', 'et', 'ephoebian', 'se'],
#  ['constituo',
#   'et',
#   'is',
#   'quis#2',
#   'in',
#   'Hierosolyma',
#   'sum',
#   'Antiochenos'],
#  ['scribo'],
#  ['quod', 'cum', 'rex', 'anosco', 'et', 'obtineo', 'principatus', 'statim'],
#  ['ad', 'gentilis', 'ritus', 'contribules', 'suus', 'transfero', 'coepio'],
#  ['et',
#   'amoveo',
#   'hic',
#   'quis#2',
#   'humanitas',
#   'causa',
#   'Iudaei',
#   'ab',
#   'rex'],
#  ['sum',
#   'constituo',
#   'per',
#   'Iohannes',
#   'pater',
#   'Eupolemus',
#   'quis#2',
#   'apud'],
#  ['Romanus', 'de', 'amicitia', 'et', 'societas', 'fungor', 'sum', 'legatio'],
#  ['legitimus', 'civis', 'jus', 'destituo', 'pravus', 'instituo', 'sancibat'],
#  ['etenim',
#   'audeo',
#   'sum',
#   'sub',
#   'ipse',
#   'arx',
#   'gymnasium',
#   'constituo',
#   'et'],
#  ['optimos', 'quosque', 'ephoeborum', 'in', 'lupanar', 'pono'],
#  ['sum',
#   'autem',
#   'hic',
#   'non',
#   'initium',
#   'sed',
#   'incrementum',
#   'quidam',
#   'et'],
#  ['proficiscor',
#   'gentilis',
#   'et',
#   'alienigena',
#   'conversatio',
#   'propter',
#   'impius'],
#  ['et', 'non', 'sacerdos', 'Iason', 'nefarius', 'et', 'inaudio', 'scelus'],
#  ['ita', 'ut', 'sacerdos', 'iam', 'non', 'circa', 'altar', 'officium', 'dedo'],
#  ['sum', 'sed', 'contemno', 'templum', 'et', 'sacrificium', 'neglego'],
#  ['festino', 'particeps', 'fio', 'palestrae', 'et', 'praebitio', 'is'],
#  ['iniustae', 'et', 'in', 'exercitium', 'discus'],
#  ['et', 'patrius#2', 'quidem', 'honor', 'nihil', 'habeo', 'Graecus', 'gloria'],
#  ['optimas', 'arbitror'],
#  ['quis#2', 'gratia', 'periculosus', 'is', 'contentio', 'habeo', 'et', 'is'],
#  ['instituo', 'aemulo', 'atque', 'per', 'omnis', 'hic', 'consimilis', 'sum'],
#  ['cupio', 'quos', 'hostis', 'et', 'peremptores', 'habeo'],
#  ['in',
#   'lex',
#   'enim',
#   'divinus',
#   'impie',
#   'ago',
#   'inpune',
#   'non',
#   'cedo',
#   'sed',
#   'hic'],
#  ['sequor', 'tempus', 'declaro'],
#  ['cum', 'autem', 'quinquennalis', 'agon', 'Tyros', 'celebro', 'et', 'rex'],
#  ['praesens', 'sum'],
#  ['mitto', 'Iason', 'facinorosus', 'ab', 'Hierosolyma', 'vir', 'peccator'],
#  ['porto',
#   'argentum',
#   'didragmas',
#   'trecentas',
#   'in',
#   'sacrificium',
#   'Hercules'],
#  ['quis#2',
#   'postulo',
#   'hic',
#   'quis#2',
#   'apporto',
#   'ne#2',
#   'in',
#   'sacrificium'],
#  ['erogo', 'quia', 'non', 'oportet', 'sed', 'in', 'alius', 'sumptus', 'is'],
#  ['deputari'],
#  ['sed',
#   'hic',
#   'offertor',
#   'sum',
#   'quidem',
#   'ab',
#   'is',
#   'quis#2',
#   'mitto',
#   'in'],
#  ['sacrificium',
#   'Hercules',
#   'propter',
#   'praesens',
#   'autem',
#   'do',
#   'sum',
#   'in'],
#  ['fabrica', 'navis', 'triremis'],
#  ['mitto',
#   'autem',
#   'in',
#   'Aegyptus',
#   'Apollonius',
#   'Mnestheus',
#   'filius',
#   'propter'],
#  ['primatus',
#   'Filometoris',
#   'rex',
#   'cum',
#   'cognosco',
#   'Antiochus',
#   'alienus',
#   'se'],
#  ['ab', 'negotium', 'regnum', 'efficio', 'proprius', 'utilitas', 'consulo'],
#  ['proficiscor', 'inde', 'venio', 'Ioppe', 'et', 'inde', 'Hierosolyma'],
#  ['et',
#   'magnificus',
#   'ab',
#   'Iason',
#   'et',
#   'civitas',
#   'suscipio',
#   'cum',
#   'facularum'],
#  ['lumen',
#   'et',
#   'laus',
#   'ingredior',
#   'sum',
#   'et',
#   'inde',
#   'Foenicen',
#   'exercitus'],
#  ['converto'],
#  ['et',
#   'post',
#   'triennium',
#   'tempus',
#   'mitto',
#   'Iason',
#   'Menelaus',
#   'supradicti'],
#  ['Simo', 'frater', 'porto', 'pecunia', 'rex', 'et', 'de', 'negotium'],
#  ['necessarius', 'responsum', 'perfero'],
#  ['at', 'ille', 'commendo', 'rex', 'cum', 'magnificasset', 'facies'],
#  ['potestas', 'is', 'in', 'sui', 'ipse', 'retorsit', 'summus', 'sacerdotium'],
#  ['superpono', 'Iason', 'talentum', 'argentum', 'trecenta'],
#  ['acceptisque',
#   'ab',
#   'rex',
#   'mandatum',
#   'venio',
#   'nihil',
#   'quidem',
#   'dignus'],
#  ['habeo',
#   'sacerdotium',
#   'animus',
#   'verus',
#   'crudelis',
#   'tyrannus',
#   'et',
#   'ferus',
#   'belua'],
#  ['ira', 'gero'],
#  ['et',
#   'Iason',
#   'quidem',
#   'quis#2',
#   'proprius',
#   'frater',
#   'captivaverat',
#   'ipse'],
#  ['deceptus', 'profugus', 'in', 'ammaniten', 'expello', 'sum', 'regio'],
#  ['Menelaus',
#   'autem',
#   'principatus',
#   'quidem',
#   'obtineo',
#   'de',
#   'pecunia',
#   'verus'],
#  ['rex', 'promissus', 'nihil', 'ago', 'cum', 'exactio', 'facio', 'Sostratus'],
#  ['quis#2', 'arx', 'sum', 'praepositus'],
#  ['namque',
#   'ad',
#   'hic',
#   'exactio',
#   'vectigalis',
#   'pertineo',
#   'quam#4',
#   'ob',
#   'causa'],
#  ['uterque', 'ad', 'rex', 'voco'],
#  ['Menelaus',
#   'motus',
#   'sum',
#   'sacerdotium',
#   'succedo',
#   'Lysimachus',
#   'frater'],
#  ['suus', 'Sostratus', 'autem', 'praefero', 'sum', 'Cypris'],
#  ['et', 'cum', 'hic', 'ago', 'contingo', 'Tarsensis', 'et', 'Mallotas'],
#  ['seditio', 'moveo', 'is', 'quod', 'Antiochidi', 'concubina', 'rex', 'donum'],
#  ['sum', 'do'],
#  ['festinanter',
#   'itaque',
#   'rex',
#   'venio',
#   'sedo',
#   'ille',
#   'relinquo',
#   'sufficio'],
#  ['unus', 'ex', 'comitibus', 'suus', 'Andronico'],
#  ['reor',
#   'autem',
#   'Menelaus',
#   'accipio',
#   'se',
#   'tempus',
#   'opportunus',
#   'aureus'],
#  ['quidam', 'vasum', 'templum', 'furor', 'dono', 'Andronico', 'et', 'alius'],
#  ['vendo', 'Tyros', 'et', 'per', 'vicina', 'civitas'],
#  ['quod', 'cum', 'certe', 'cognosco', 'Onias', 'arguo', 'is', 'ipse', 'in'],
#  ['locus', 'tuto', 'se', 'contineo', 'Antiochea', 'secus', 'Dafnen'],
#  ['unde', 'Menelaus', 'accedo', 'ad', 'Andronicum', 'rogo', 'ut', 'Onian'],
#  ['interficio',
#   'quis#2',
#   'cum',
#   'venio',
#   'ad',
#   'Onian',
#   'et',
#   'do',
#   'dexter',
#   'cum'],
#  ['iureiurando', 'quamvis', 'sum', 'is', 'suspicio', 'suadeo', 'asylum'],
#  ['procedo', 'statim', 'is', 'peremo', 'non', 'vereor', 'iustitia'],
#  ['ob',
#   'quis',
#   'causa',
#   'non',
#   'solus',
#   'Iudaei',
#   'sed',
#   'et',
#   'alius',
#   'quoque'],
#  ['natio',
#   'indignabantur',
#   'et',
#   'molestus',
#   'fero',
#   'de',
#   'nece',
#   'tantus',
#   'vir'],
#  ['iniustus'],
#  ['sed',
#   'regredior',
#   'rex',
#   'de',
#   'Cilicia',
#   'locus',
#   'adeo',
#   'Iudaei',
#   'apud'],
#  ['Antiochea',
#   'simul',
#   'et',
#   'Graecus',
#   'conquerentes',
#   'de',
#   'iniquus',
#   'nece',
#   'Oniae'],
#  ['contristo', 'itaque', 'ad', 'anima', 'Antiochus', 'et', 'flexus', 'ad'],
#  ['misericordia',
#   'lacrima',
#   'fundo',
#   'recordor',
#   'defungor',
#   'sobrietas',
#   'et'],
#  ['modestia'],
#  ['accensusque',
#   'anima',
#   'Andronicum',
#   'purpura',
#   'exuo',
#   'circumduci',
#   'per'],
#  ['totus#2',
#   'civitas',
#   'iubeo',
#   'et',
#   'idem',
#   'locus',
#   'quo',
#   'in',
#   'Onian',
#   'impietas'],
#  ['committo',
#   'sacrilegus',
#   'vita',
#   'privo',
#   'dominus',
#   'ille',
#   'dignus',
#   'poena'],
#  ['tribuo'],
#  ['multus',
#   'autem',
#   'sacrilegium',
#   'in',
#   'templum',
#   'ab',
#   'Lysimachus',
#   'commissum'],
#  ['Menelaus',
#   'consilium',
#   'et',
#   'divulgata',
#   'fama',
#   'congrego',
#   'sum',
#   'multitudo'],
#  ['adversus#2', 'Lysimachus', 'multus', 'iam', 'aurum', 'exporto'],
#  ['turba', 'autem', 'insurgo', 'et', 'anima', 'ira', 'repleo'],
#  ['Lysimachus', 'armo', 'ferus', 'tres', 'mille', 'iniquus', 'manus', 'uti'],
#  ['coepio',
#   'dux',
#   'quidam',
#   'tyrannus',
#   'aetas',
#   'pariter',
#   'et',
#   'dementia',
#   'proveho'],
#  ['sed', 'ut', 'intellego', 'conor', 'Lysimachus', 'alius', 'lapis', 'alius'],
#  ['fustes',
#   'validus',
#   'arripio',
#   'quidam',
#   'verus',
#   'cinis',
#   'in',
#   'Lysimachus'],
#  ['iacio'],
#  ['et',
#   'multus',
#   'quidem',
#   'vulnero',
#   'quidam',
#   'autem',
#   'et',
#   'prosterno',
#   'omnis'],
#  ['verus',
#   'in',
#   'fuga',
#   'verro',
#   'sum',
#   'ipse',
#   'etiam',
#   'sacrilegus',
#   'secus',
#   'aerarius'],
#  ['interfacio'],
#  ['de',
#   'hic',
#   'ergo',
#   'coepio',
#   'iudicium',
#   'adversus#2',
#   'Menelaus',
#   'agitor'],
#  ['et', 'cum', 'venio', 'rex', 'Tyros', 'ad', 'ipse', 'negotium', 'defero'],
#  ['mitto', 'vir', 'tres', 'ab', 'seni'],
#  ['et', 'cum', 'supero', 'Menelaus', 'promitto', 'Ptolomeo', 'multus'],
#  ['pecunia', 'ad', 'suadeo', 'rex'],
#  ['itaque',
#   'Ptolomeus',
#   'in',
#   'quidam',
#   'atrium',
#   'pono',
#   'quasi',
#   'refrigero'],
#  ['gratia', 'rex', 'adeo', 'et', 'ab', 'sententia', 'deduco'],
#  ['et', 'Menelaus', 'quidem', 'universus', 'malitia', 'reus', 'crimen'],
#  ['absolvo',
#   'miser',
#   'autem',
#   'quis#2',
#   'etiam',
#   'si',
#   'apud',
#   'Scytas',
#   'causa'],
#  ['dico#2', 'innocens', 'iudicarentur', 'mors', 'damno'],
#  ['cito', 'ergo', 'iniustam', 'poena', 'do', 'quis#2', 'pro', 'civitas', 'et'],
#  ['populus', 'et', 'sacer', 'vasum', 'causa', 'prosequor', 'sum'],
#  ['quam#4',
#   'ob',
#   'res',
#   'Tyros',
#   'quoque',
#   'indignor',
#   'erga',
#   'sepultura',
#   'is'],
#  ['liberalis', 'extiterunt'],
#  ['Menelaus', 'autem', 'propter', 'is', 'quis#2', 'in', 'potentia', 'sum'],
#  ['avaritia',
#   'permaneo',
#   'in',
#   'potestas',
#   'cresco',
#   'in',
#   'malitia',
#   'et',
#   'ad'],
#  ['insidiae', 'civis'],
#  ['idem', 'tempus', 'Antiochus', 'secundus', 'profectio', 'paro#2', 'in'],
#  ['Aegyptus'],
#  ['contingo',
#   'autem',
#   'per',
#   'universus',
#   'Hierosolymorum',
#   'civitas',
#   'video'],
#  ['dies', 'quadraginta', 'per', 'aes', 'eques', 'discurro', 'aurata', 'stola'],
#  ['habeo', 'et', 'hasta', 'quasi', 'cohors', 'armatus'],
#  ['et', 'cursus', 'equus', 'per', 'ordo', 'digero', 'et', 'congressio'],
#  ['fio', 'comminus', 'et', 'scutum', 'motus', 'et', 'galeatus', 'multitudo'],
#  ['gladius', 'destringo', 'et', 'telum', 'iacio', 'et', 'aureus', 'armus'],
#  ['splendor', 'omnisque', 'genus', 'lorica'],
#  ['quapropter', 'omnis', 'rogo', 'in', 'bonum', 'monstrum', 'converto'],
#  ['sed', 'cum', 'falsus', 'rumor', 'exeo', 'tamquam', 'vita', 'excedo'],
#  ['Antiochus', 'assumo', 'Iason', 'non', 'parvus', 'mille', 'vir', 'repente'],
#  ['aggredior',
#   'sum',
#   'civitas',
#   'et',
#   'civis',
#   'ad',
#   'murus',
#   'convolo',
#   'ad'],
#  ['ultimus', 'apprehendo', 'civitas', 'Menelaus', 'fugio', 'in', 'arx'],
#  ['Iason',
#   'verus',
#   'non',
#   'parco',
#   'in',
#   'caedes',
#   'civis',
#   'suus',
#   'nec',
#   'cogito'],
#  ['prosperitas',
#   'adversus#2',
#   'cognatus',
#   'malus#3',
#   'sum',
#   'maximus',
#   'arbitror'],
#  ['hostis', 'et', 'non', 'civis', 'se', 'tropea', 'capio'],
#  ['et',
#   'principatus',
#   'quidem',
#   'non',
#   'obtineo',
#   'finis',
#   'verus',
#   'insidiarum'],
#  ['suus',
#   'confusio',
#   'capio',
#   'et',
#   'profugus',
#   'iterum',
#   'abeo',
#   'in',
#   'Ammaniten'],
#  ['ad',
#   'ultimus',
#   'in',
#   'exitus',
#   'suus',
#   'conclusus',
#   'ab',
#   'Areta',
#   'Arabus',
#   'tyrannus'],
#  ['fugio',
#   'de',
#   'civitas',
#   'in',
#   'civitas',
#   'omnis',
#   'odiosus',
#   'ut',
#   'refuga'],
#  ['lex',
#   'et',
#   'execrabilis',
#   'ut',
#   'patria',
#   'et',
#   'civis',
#   'hostis',
#   'in',
#   'Aegyptus'],
#  ['extrudo', 'sum'],
#  ['et',
#   'quis#2',
#   'multus',
#   'de',
#   'patria',
#   'expello',
#   'peregre',
#   'pereo',
#   'Lacedemonas'],
#  ['proficiscor', 'quasi', 'pro', 'cognatio', 'ibi', 'refugium', 'habeo'],
#  ['et',
#   'quis#2',
#   'insepultus',
#   'abicio',
#   'multus',
#   'ipse',
#   'et',
#   'inlamentatus',
#   'et'],
#  ['insepultus',
#   'abicio',
#   'sepultura',
#   'neque',
#   'peregrinus',
#   'usus',
#   'neque',
#   'patrius'],
#  ['sepulcrum', 'participo'],
#  ['hic', 'ita', 'gestio', 'suspicor', 'sum', 'rex', 'societas', 'desero'],
#  ['Iudaei',
#   'et',
#   'ob',
#   'hic',
#   'proficiscor',
#   'ex',
#   'Aegyptus',
#   'effero',
#   'anima'],
#  ['civitas', 'quidem', 'arma', 'capio'],
#  ['jubeo', 'autem', 'miles', 'interficio', 'nec', 'parco'],
#  ['occurso', 'et', 'per', 'domus', 'ascendo', 'trucido'],
#  ['fio',
#   'ergo',
#   'caedes',
#   'iuvenis',
#   'atque',
#   'seni',
#   'mulier',
#   'et',
#   'nascor'],
#  ['exterminium', 'virginumque', 'et', 'parvulus', 'nex'],
#  ['sum', 'autem', 'totus#2', 'triduus', 'octoginta', 'mille', 'interficio'],
#  ['quadraginta', 'mille', 'vincio'],
#  ['sed',
#   'nec',
#   'iste',
#   'sufficio',
#   'audeo',
#   'sum',
#   'intro',
#   'templum',
#   'universus'],
#  ['terra',
#   'sancio',
#   'Menelaus',
#   'ductor',
#   'quis#2',
#   'lex',
#   'et',
#   'patria',
#   'sum'],
#  ['proditor'],
#  ['et',
#   'scelestus',
#   'manus',
#   'sumo',
#   'sanctus',
#   'vasum',
#   'quis#2',
#   'ab',
#   'alius'],
#  ['rex',
#   'et',
#   'civitas',
#   'sum',
#   'pono',
#   'ad',
#   'ornatus',
#   'locus',
#   'et',
#   'gloria'],
#  ['contrecto', 'indigne', 'et', 'contamino'],
#  ['ita', 'alieno', 'mens', 'Antiochus', 'non', 'considero', 'quod', 'propter'],
#  ['peccatum', 'habito', 'civitas', 'modicus', 'dominus', 'sum', 'irascor'],
#  ['propter', 'quod', 'et', 'accido#2', 'circa', 'locus', 'despectio'],
#  ['alioquin', 'nisi', 'contigo', 'is', 'multus', 'peccatum', 'sum'],
#  ['involvo',
#   'sicut',
#   'Heliodorus',
#   'quis#2',
#   'mitto',
#   'sum',
#   'ab',
#   'Seleucus',
#   'rex',
#   'ad'],
#  ['expoliandum',
#   'aerarius',
#   'etiam',
#   'hic',
#   'statim',
#   'advenio',
#   'flagello',
#   'et'],
#  ['repello', 'utique#2', 'sum', 'ab', 'audacia'],
#  ['verus',
#   'non',
#   'propter',
#   'locus',
#   'gens',
#   'sed',
#   'propter',
#   'gens',
#   'locus'],
#  ['dominus', 'eligo'],
#  ['ideoque',
#   'et',
#   'ipse',
#   'locus',
#   'particeps',
#   'facio',
#   'sum',
#   'populus#2',
#   'malus#3'],
#  ['postea',
#   'autem',
#   'fio',
#   'socius',
#   'et',
#   'bonus',
#   'et',
#   'quis#2',
#   'derelinquo',
#   'in',
#   'ira'],
#  ['deus',
#   'omnipotens',
#   'iterum',
#   'in',
#   'magnus',
#   'dominus',
#   'reconciliatio',
#   'cum'],
#  ['summa', 'gloria', 'exalto'],
#  ['igitur',
#   'Antiochus',
#   'mille',
#   'et',
#   'octingenti',
#   'aufero',
#   'de',
#   'templum'],
#  ['talentum',
#   'velociter',
#   'Antiochea',
#   'regredior',
#   'sum',
#   'existimo',
#   'se',
#   'prae'],
#  ['superbia',
#   'terra',
#   'ad',
#   'navigo',
#   'pelagus',
#   'verus',
#   'ad',
#   'iter',
#   'ago'],
#  ['deduco', 'propter', 'mens', 'elatio'],
#  ['relinquo', 'autem', 'et', 'praepositus', 'ad', 'adfligendam', 'gens'],
#  ['Hierosolyma', 'quidem', 'Philippus', 'genus', 'Frigem', 'mos', 'crudelis'],
#  ['is', 'ipse', 'ab', 'quo', 'constituo', 'sum'],
#  ['in',
#   'Garizin',
#   'autem',
#   'Andronicum',
#   'et',
#   'Menelaus',
#   'quis#2',
#   'graviter',
#   'quam#4'],
#  ['ceterus', 'inminebant', 'civis'],
#  ['cumque', 'appono', 'sum', 'contra', 'Iudaei', 'mitto', 'odiosus'],
#  ['princeps',
#   'Apollonius',
#   'cum',
#   'exercitus',
#   'viginti',
#   'et',
#   'duo',
#   'mille'],
#  ['praecipio',
#   'is',
#   'omnis',
#   'perfectus',
#   'aetas',
#   'interficio',
#   'mulier',
#   'atque'],
#  ['iuvenis', 'vendo'],
#  ['quis#2',
#   'cum',
#   'venio',
#   'Hierosolyma',
#   'pax',
#   'simulo',
#   'quiesco',
#   'usque'],
#  ['ad',
#   'sanctus',
#   'dies',
#   'sabbatum',
#   'et',
#   'tunc',
#   'ferior',
#   'Iudaei',
#   'arma',
#   'capio'],
#  ['suus', 'praecipio'],
#  ['omnesque', 'quis#2', 'ad', 'spectaculum', 'procedo', 'trucidavit', 'et'],
#  ['civitas', 'cum', 'armatus', 'discurro', 'ingens', 'multitudo', 'peremo'],
#  ['Iudas', 'autem', 'Macchabeus', 'quis#2', 'decimus', 'sum', 'secedo', 'in'],
#  ['desertum',
#   'locus',
#   'ibique',
#   'inter',
#   'fera',
#   'vita',
#   'in',
#   'mons',
#   'cum',
#   'suus'],
#  ['ago',
#   'et',
#   'faenum',
#   'cibus',
#   'vesco',
#   'demorabantur',
#   'ne#2',
#   'particeps'],
#  ['sum', 'coinquinatio'],
#  ['sed', 'non', 'post', 'multus', 'tempus', 'mitto', 'rex', 'senex', 'quidam'],
#  ['antiochenum',
#   'quis#2',
#   'conpelleret',
#   'Iudaei',
#   'ut',
#   'se',
#   'transferrent',
#   'ab'],
#  ['patrius#2', 'et', 'deus', 'lex'],
#  ['contamino', 'etiam', 'quod', 'in', 'Hierosolyma', 'sum', 'templum', 'et'],
#  ['cognomino',
#   'Iuppiter',
#   'Olympium',
#   'et',
#   'in',
#   'Garizin',
#   'prout',
#   'sum',
#   'hic',
#   'quis#2'],
#  ['locus', 'inhabito', 'Iuppiter', 'hospitalis'],
#  ['pessima',
#   'autem',
#   'universus',
#   'et',
#   'gravis',
#   'malus#3',
#   'sum',
#   'incursio'],
#  ['namque',
#   'templum',
#   'luxuria',
#   'et',
#   'comesationibus',
#   'sum',
#   'plenus',
#   'et'],
#  ['scortor', 'cum', 'meretrix', 'sacratisque', 'aedes', 'mulier', 'se'],
#  ['ultro', 'ingero', 'intro', 'fero', 'is', 'quis#2', 'non', 'licet'],
#  ['altar', 'etiam', 'plenus', 'sum', 'inlicitis', 'quis#2', 'lex'],
#  ['prohibeo'],
#  ['neque', 'autem', 'sabbatum', 'custodio', 'neque', 'dies', 'sollemnes'],
#  ['patrium', 'servo', 'nec', 'simplex', 'se', 'quisquam', 'Iudaeus', 'sum'],
#  ['confiteor'],
#  ['duco',
#   'autem',
#   'cum',
#   'amarus',
#   'necessitas',
#   'in',
#   'dies',
#   'natalis',
#   'rex'],
#  ['ad', 'sacrificium', 'et', 'cum', 'liberi', 'sacer', 'celebro', 'cogo'],
#  ['hedera', 'corono', 'liber', 'circumeo'],
#  ['decretum', 'autem', 'exeo', 'in', 'proximus', 'gentilis', 'civitas'],
#  ['suggero',
#   'Ptolomeis',
#   'ut',
#   'par',
#   'modus',
#   'et',
#   'ipse',
#   'adversus#2',
#   'Iudaei'],
#  ['ago', 'ut', 'sacrifico'],
#  ['is', 'autem', 'quis#2', 'nolo', 'transeo', 'ad', 'instituo', 'gentilis'],
#  ['interficio', 'sum', 'ergo', 'video', 'miseria'],
#  ['duo', 'enim', 'mulier', 'defero', 'sum', 'nascor', 'suus', 'circumcido'],
#  ['quis#2',
#   'infans',
#   'ad',
#   'uber',
#   'suspendo',
#   'cum',
#   'publicus',
#   'per',
#   'civitas'],
#  ['circumduxissent', 'per', 'murus', 'praecipito'],
#  ['alius',
#   'verus',
#   'ad',
#   'proximus',
#   'coeuntes',
#   'spelunca',
#   'et',
#   'latenter'],
#  ['sabbatum',
#   'dies',
#   'celebro',
#   'cum',
#   'indico',
#   'sum',
#   'Philippus',
#   'flamma'],
#  ['succenseo', 'sum', 'is', 'quod', 'verebantur', 'propter', 'religio', 'et'],
#  ['observantia', 'manus', 'egomet', 'auxilium', 'fero'],
#  ['obsecro', 'autem', 'is', 'quis#2', 'hic', 'liber#4', 'lego', 'sum', 'ne#2'],
#  ['abhorrescant',
#   'propter',
#   'adversus',
#   'casus',
#   'sed',
#   'reputo',
#   'is',
#   'quis#2'],
#  ['acciderunt',
#   'non',
#   'ad',
#   'interitus',
#   'sed',
#   'ad',
#   'correptio',
#   'genus',
#   'sum'],
#  ['noster'],
#  ['etenim', 'multus', 'tempus', 'non', 'sino', 'peccator', 'ex', 'sententia'],
#  ['ago',
#   'sed',
#   'statim',
#   'ultio',
#   'adhibeo',
#   'magnus',
#   'beneficium',
#   'sum',
#   'indicium'],
#  ['non', 'enim', 'sicut', 'in', 'alius', 'natio', 'dominus', 'patienter'],
#  ['exspecto',
#   'ut',
#   'is',
#   'cum',
#   'iudicium',
#   'dies',
#   'venio',
#   'in',
#   'plenitudo'],
#  ['peccator', 'puniat'],
#  ['ita',
#   'et',
#   'in',
#   'nos',
#   'statuo',
#   'ut',
#   'peccatum',
#   'noster',
#   'in',
#   'finis'],
#  ['devolvo', 'ita', 'demum', 'in', 'nos', 'vindico'],
#  ['propter', 'quod', 'numquam', 'quidem', 'ab', 'nos', 'misericordia', 'suus'],
#  ['amoveo',
#   'corripio',
#   'verus',
#   'in',
#   'adversa',
#   'populus',
#   'suus',
#   'non',
#   'derelinquo'],
#  ['sed', 'hic', 'nos', 'ad', 'commonitio', 'lego', 'dico#2', 'sum', 'paucus'],
#  ['iam', 'autem', 'venio', 'sum', 'ad', 'narratio'],
#  ['igitur', 'Eleazarus', 'de', 'primoris', 'scriba', 'vir', 'aetas'],
#  ['proveho',
#   'et',
#   'vultus',
#   'decorus',
#   'apertus',
#   'os#1',
#   'hio',
#   'conpellebatur'],
#  ['caro', 'porcina', 'manduco'],
#  ['at', 'ille', 'gloriosus', 'mors', 'magis', 'quam#4', 'odibilis', 'vita'],
#  ['amplector', 'voluntarius', 'praeibat', 'ad', 'supplicium'],
#  ['intueor', 'autem', 'quemadmodum', 'oportet', 'accedo', 'patienter'],
#  ['sustineo', 'destino', 'non', 'admitto', 'inlicita', 'propter', 'vita'],
#  ['amor'],
#  ['hic',
#   'autem',
#   'quis#2',
#   'asto',
#   'iniquus',
#   'miseratio',
#   'commoveo',
#   'propter'],
#  ['antiquus', 'vir', 'amicitia', 'tollo', 'is', 'secretum', 'rogo', 'affero'],
#  ['caro',
#   'quis#2',
#   'vescus',
#   'is',
#   'licet',
#   'et',
#   'simulo',
#   'manducasse',
#   'sicut'],
#  ['rex', 'impero', 'de', 'sacrificium', 'caro'],
#  ['ut', 'hic', 'facio', 'ab', 'mors', 'libero', 'et', 'propter', 'vetus'],
#  ['amicitia', 'hic', 'in', 'is', 'facio', 'humanitas'],
#  ['at', 'ille', 'cogitatio', 'capio', 'aetas', 'atque', 'senectus', 'suus'],
#  ['eminentia',
#   'dignus',
#   'et',
#   'ingenuitas',
#   'nobilitas',
#   'canities',
#   'atque',
#   'ab'],
#  ['puer',
#   'bonus',
#   'conversatio',
#   'et',
#   'secundum',
#   'sanctus',
#   'et',
#   'ab',
#   'deus'],
#  ['conditus',
#   'lex',
#   'constituo',
#   'respondeo',
#   'cito',
#   'dico#2',
#   'praemitti',
#   'se'],
#  ['volo#1', 'in', 'infernum'],
#  ['non',
#   'enim',
#   'aetas',
#   'noster',
#   'dignus',
#   'sum',
#   'inquiam',
#   'fingo',
#   'ut',
#   'multus'],
#  ['adulescens', 'arbitror', 'Eleazarum', 'nonaginta', 'annus', 'transeo'],
#  ['ad', 'vita', 'alienigena'],
#  ['et', 'ipse', 'propter', 'meus', 'simulatio', 'et', 'propter', 'modicus'],
#  ['corruptibilis',
#   'vita',
#   'tempus',
#   'decipio',
#   'et',
#   'per',
#   'hic',
#   'macula',
#   'atque'],
#  ['exsecratio', 'meus', 'senectus', 'conquiro'],
#  ['namque',
#   'et',
#   'si',
#   'in',
#   'praesens',
#   'tempus',
#   'supplicium',
#   'homo',
#   'eripio'],
#  ['sed',
#   'manus',
#   'Omnipotentis',
#   'neque',
#   'vivo',
#   'neque',
#   'defungor',
#   'effugius'],
#  ['quam#4', 'ob', 'res', 'fortiter', 'vita', 'excedo', 'senectus', 'quidem'],
#  ['dignus', 'appareo'],
#  ['adulescentibus',
#   'autem',
#   'exemplum',
#   'forte',
#   'relinquo',
#   'si',
#   'promptus'],
#  ['animus', 'atque', 'fortiter', 'pro', 'gravis', 'et', 'sanctus', 'lex'],
#  ['honestus',
#   'mors',
#   'perfungar',
#   'hic',
#   'dico#2',
#   'confestim',
#   'ad',
#   'supplicium'],
#  ['traho'],
#  ['hic',
#   'autem',
#   'quis#2',
#   'is',
#   'duco',
#   'et',
#   'paulum',
#   'ante',
#   'sum',
#   'mitis'],
#  ['in',
#   'ira',
#   'verro',
#   'sum',
#   'propter',
#   'sermo',
#   'ab',
#   'is',
#   'dico#2',
#   'quos',
#   'ille',
#   'per'],
#  ['arrogantia', 'profero', 'arbitror'],
#  ['sed',
#   'cum',
#   'plaga',
#   'perimo',
#   'ingemo',
#   'et',
#   'dico#2',
#   'dominus',
#   'quis#2'],
#  ['habeo',
#   'sanctus',
#   'scientia',
#   'manifeste',
#   'scio',
#   'tuuus',
#   'quia',
#   'cum',
#   'ab',
#   'mors'],
#  ['possum',
#   'libero',
#   'durus',
#   'corpus',
#   'sustineo',
#   'dolor',
#   'secundum',
#   'anima'],
#  ['verus', 'propter', 'timor', 'tuus', 'libet', 'hic', 'patior'],
#  ['et',
#   'iste',
#   'quidem',
#   'hic',
#   'modus',
#   'vita',
#   'decedo',
#   'non',
#   'solus',
#   'iuvenibus'],
#  ['sed',
#   'et',
#   'universus',
#   'gens',
#   'memoria',
#   'mors',
#   'suus',
#   'ad',
#   'exemplum'],
#  ['virtus', 'et', 'fortitudo', 'derelinquo'],
#  ['contingo', 'autem', 'et', 'septem', 'frater', 'cum', 'mater', 'adprehendo'],
#  ['conpelli',
#   'ab',
#   'rex',
#   'contra',
#   'fas',
#   'ad',
#   'caro',
#   'porcina',
#   'flagrum',
#   'et'],
#  ['taureus', 'crucio'],
#  ['unus',
#   'autem',
#   'ex',
#   'ille',
#   'quis#2',
#   'sum',
#   'primus',
#   'sic',
#   'ajo',
#   'quis#2',
#   'quaero',
#   'et'],
#  ['quis#2',
#   'volo#1',
#   'disco',
#   'ab',
#   'nos',
#   'paro',
#   'sum',
#   'morior',
#   'magis',
#   'quam#4',
#   'patria'],
#  ['deus', 'lex', 'praevaricari'],
#  ['irascor',
#   'itaque',
#   'rex',
#   'jubeo',
#   'sartagines',
#   'et',
#   'olla',
#   'aeneus',
#   'succendo'],
#  ['quis#2', 'statim', 'succendo'],
#  ['jubeo',
#   'is',
#   'quis#2',
#   'prior',
#   'sum',
#   'loquor',
#   'amputari',
#   'lingua',
#   'et',
#   'cute'],
#  ['capitum',
#   'abstraho',
#   'summus',
#   'quoque',
#   'manus',
#   'is',
#   'et',
#   'pes',
#   'praecido'],
#  ['ceterus', 'is', 'frater', 'et', 'mater', 'inspicio'],
#  ['et',
#   'cum',
#   'iam',
#   'per',
#   'omnis',
#   'inutilis',
#   'facio',
#   'sum',
#   'jubeo',
#   'ignis'],
#  ['admoveri',
#   'et',
#   'adhuc',
#   'spiro',
#   'torreri',
#   'in',
#   'sartaginem',
#   'in',
#   'qui',
#   'cum'],
#  ['diu',
#   'cruciaretur',
#   'ceterus',
#   'unus',
#   'cum',
#   'mater',
#   'invicem',
#   'se',
#   'hortor'],
#  ['morior', 'fortiter'],
#  ['dico#2', 'dominus', 'deus', 'aspicio', 'veritas', 'et', 'consolo', 'in'],
#  ['nos',
#   'quemadmodum',
#   'protestatio',
#   'canticus',
#   'declaro',
#   'Moses',
#   'et',
#   'in'],
#  ['serva', 'suus', 'consolo'],
#  ['mortuus',
#   'itaque',
#   'primus',
#   'ille',
#   'hic',
#   'modus',
#   'sequor',
#   'deduco',
#   'ad'],
#  ['inludendum', 'et', 'cute', 'capitum', 'is', 'cum', 'capillus', 'detraho'],
#  ['interrogo',
#   'si',
#   'manduco',
#   'priusquam',
#   'totus#2',
#   'corpus',
#   'per',
#   'membrum'],
#  ['singulus', 'puniretur'],
#  ['at',
#   'ille',
#   'respondeo',
#   'patria',
#   'vox',
#   'dico#2',
#   'non',
#   'facio',
#   'propter',
#   'quod'],
#  ['et', 'iste', 'sequens', 'locus', 'primus', 'tormentum', 'suscipio'],
#  ['et',
#   'in',
#   'ulterior',
#   'spiritus',
#   'constituo',
#   'ajo',
#   'tuuus',
#   'quidem',
#   'scelestus'],
#  ['in',
#   'praesens',
#   'vita',
#   'nos',
#   'perdo',
#   'sed',
#   'rex',
#   'mundum',
#   'defungor',
#   'nos',
#   'pro'],
#  ['suus', 'lex', 'in', 'aeternus', 'vita', 'resurrectio', 'suscito'],
#  ['post',
#   'hic',
#   'tertius',
#   'inludebatur',
#   'et',
#   'lingua',
#   'postulatus',
#   'cito'],
#  ['profero', 'et', 'manus', 'constanter', 'extendo'],
#  ['et',
#   'cum',
#   'fiducia',
#   'ajo',
#   'ex',
#   'caelum',
#   'iste',
#   'possideo',
#   'sed',
#   'propter',
#   'deus'],
#  ['lex',
#   'nunc',
#   'hic',
#   'ipse',
#   'despicio',
#   'quoniam',
#   'ab',
#   'ipse',
#   'ego',
#   'is',
#   'recipio'],
#  ['spero'],
#  ['ita',
#   'ut',
#   'rex',
#   'et',
#   'quis#2',
#   'cum',
#   'ipse',
#   'sum',
#   'miror',
#   'adulescentis'],
#  ['animus', 'quod', 'tamquam', 'nihilum', 'duco', 'cruciatus'],
#  ['et', 'hic', 'ita', 'defungor', 'quartus', 'similiter', 'vexo', 'torqueo'],
#  ['et',
#   'cum',
#   'iam',
#   'sum',
#   'ad',
#   'mors',
#   'sic',
#   'ajo',
#   'potius',
#   'sum',
#   'ab',
#   'homo'],
#  ['mors',
#   'do',
#   'spes',
#   'exspecto',
#   'ab',
#   'deus',
#   'iterum',
#   'ab',
#   'ipse',
#   'resuscitandos'],
#  ['tu', 'enim', 'resurrectio', 'ad', 'vita', 'non', 'sum'],
#  ['et', 'cum', 'admoveo', 'quintus', 'vexo', 'is', 'at', 'ille', 'respicio'],
#  ['in', 'is'],
#  ['dico#2',
#   'potestas',
#   'inter',
#   'homo',
#   'habeo',
#   'cum',
#   'sum',
#   'corruptibilis'],
#  ['facio',
#   'quod',
#   'volo#1',
#   'nolo',
#   'autem',
#   'puto',
#   'genus',
#   'noster',
#   'ab',
#   'deus',
#   'sum'],
#  ['derelinquo'],
#  ['patienter',
#   'sustine',
#   'et',
#   'video',
#   'magnus',
#   'potestas',
#   'ipse',
#   'qualiter'],
#  ['tu', 'et', 'semen', 'tuus', 'torqueo'],
#  ['post',
#   'hic',
#   'duco',
#   'et',
#   'sextus',
#   'et',
#   'is',
#   'morior',
#   'incipio',
#   'sic',
#   'ajo'],
#  ['nolo',
#   'frustra',
#   'erro',
#   'nos',
#   'enim',
#   'propter',
#   'nos',
#   'ipse',
#   'hic',
#   'patior'],
#  ['pecco',
#   'in',
#   'deus',
#   'noster',
#   'et',
#   'dignus',
#   'admiratio',
#   'facio',
#   'sum',
#   'in'],
#  ['nos'],
#  ['tuuus',
#   'autem',
#   'ne#2',
#   'existimo',
#   'tu',
#   'inpune',
#   'sum',
#   'quod',
#   'contra',
#   'deus'],
#  ['pugno', 'tento'],
#  ['supra',
#   'modus',
#   'autem',
#   'mater',
#   'mirabilis',
#   'et',
#   'bonus',
#   'memoria',
#   'dignus'],
#  ['quis#2',
#   'pereuntes',
#   'septem',
#   'filius',
#   'sub',
#   'unus',
# ...
#  ['depositum',
#   'vestis',
#   'gloria',
#   'per',
#   'mediterraneum',
#   'fugio',
#   'solus',
#   'venio'],
#  ['Antiochea', 'summa', 'infelicitas', 'de', 'interitus', 'suus', 'exercitus'],
#  ['consequor'],
#  ['et', 'quis#2', 'promitto', 'Romanus', 'se', 'tributum', 'restituo', 'de'],
#  ['captivitas', 'Hierosolymorum', 'praedico#1', 'nunc', 'protector', 'deus'],
#  ['habeo',
#   'Iudaei',
#   'et',
#   'ob',
#   'ipse',
#   'invulnerabilis',
#   'sum',
#   'is',
#   'quod'],
#  ['sequerentur', 'lex', 'ab', 'ipse', 'constituo'],
#  ['idem', 'tempus', 'Antiochus', 'inhonestus', 'revorto', 'de', 'Perside'],
#  ['intro', 'enim', 'is', 'quis#2', 'dico#2', 'Persipolis', 'et', 'tento'],
#  ['expoliare',
#   'templum',
#   'et',
#   'civitas',
#   'opprimo',
#   'sed',
#   'multitudo',
#   'ad',
#   'arma'],
#  ['concurro',
#   'in',
#   'fuga',
#   'verro',
#   'sum',
#   'et',
#   'ita',
#   'contingo',
#   'ut',
#   'Antiochus'],
#  ['post', 'fuga', 'turpiter', 'redeo'],
#  ['et', 'cum', 'venio', 'circa', 'Ecbatana', 'recognosco', 'quis#2', 'erga'],
#  ['Nicanor', 'et', 'Timotheus', 'gesto', 'sum'],
#  ['effero',
#   'autem',
#   'ira',
#   'arbitror',
#   'se',
#   'iniuria',
#   'ille',
#   'quis#2',
#   'se'],
#  ['fugo', 'possum', 'in', 'Iudaei', 'retorqueo', 'ideoque', 'jubeo', 'agitor'],
#  ['currus',
#   'sine',
#   'intermissio',
#   'agens',
#   'iter',
#   'caelestis',
#   'is',
#   'iudicium'],
#  ['perurguente', 'quod', 'ita', 'superbe', 'loquor', 'sum', 'venio', 'se'],
#  ['Hierosolyma', 'et', 'congeriem', 'sepulcrum', 'Iudaei', 'is', 'facio'],
#  ['sed',
#   'quis#2',
#   'universus',
#   'conspicio',
#   'dominus',
#   'Israel',
#   'percutio',
#   'is'],
#  ['insanabilis',
#   'et',
#   'invisibilis',
#   'plaga',
#   'ut',
#   'enim',
#   'finivit',
#   'hic',
#   'ipse'],
#  ['sermo', 'apprehendo', 'is', 'dolor', 'dirus', 'viscerum', 'et', 'amarus'],
#  ['internus', 'tormentum'],
#  ['et',
#   'quidem',
#   'satis',
#   'iuste',
#   'quippe',
#   'quis#2',
#   'multus',
#   'et',
#   'novus',
#   'cruciatus'],
#  ['alius',
#   'torqueo',
#   'viscera',
#   'licet',
#   'ille',
#   'nullus',
#   'modus',
#   'ab',
#   'suus',
#   'malitia'],
#  ['cesso'],
#  ['super',
#   'hic',
#   'autem',
#   'superbia',
#   'repleo',
#   'ignis',
#   'spiro',
#   'animus',
#   'in'],
#  ['Iudaei', 'et', 'praecipio', 'adcelero', 'negotium', 'contingo', 'ille'],
#  ['impetus',
#   'eo',
#   'de',
#   'currus',
#   'cado',
#   'et',
#   'gravis',
#   'corpus',
#   'conlisione'],
#  ['membrum', 'vexo'],
#  ['isque', 'quis#2', 'se', 'video', 'etiam', 'fluctus', 'mas', 'impero'],
#  ['supra',
#   'humanus',
#   'modus',
#   'superbia',
#   'repleo',
#   'et',
#   'mons',
#   'altitudo',
#   'in'],
#  ['statera',
#   'adpendere',
#   'nunc',
#   'humilio',
#   'ad',
#   'terra',
#   'in',
#   'gestatorius'],
#  ['porto', 'manifestus', 'deus', 'virtus', 'in', 'sui', 'ipse', 'contestor'],
#  ['ita',
#   'ut',
#   'de',
#   'corpus',
#   'impius',
#   'vermis',
#   'scaturrirent',
#   'atque',
#   'vivo',
#   'in'],
#  ['dolor', 'caro', 'is', 'effluo', 'odor', 'etiam', 'ille', 'et', 'fetor'],
#  ['exercitus', 'gravo'],
#  ['et',
#   'quis#2',
#   'paulum',
#   'ante',
#   'sidus',
#   'caelum',
#   'contingo',
#   'se',
#   'arbitror'],
#  ['is', 'nemo', 'possum', 'propter', 'intolerantiam', 'fetor', 'porto'],
#  ['hinc',
#   'igitur',
#   'coepio',
#   'ex',
#   'gravis',
#   'superbia',
#   'deduco',
#   'ad',
#   'agnitio'],
#  ['suus',
#   'venio',
#   'divinus',
#   'admoneo',
#   'plaga',
#   'per',
#   'momentum',
#   'singulus',
#   'dolor'],
#  ['suus', 'augmento', 'capio'],
#  ['et',
#   'cum',
#   'nec',
#   'ipse',
#   'iam',
#   'fetor',
#   'suus',
#   'fero',
#   'possum',
#   'ita',
#   'ajo'],
#  ['iustus',
#   'sum',
#   'subdo',
#   'sum',
#   'deus',
#   'et',
#   'mortalis',
#   'non',
#   'paria',
#   'deus',
#   'sentio'],
#  ['oro', 'autem', 'hic', 'scelestus', 'dominus', 'ab', 'quo', 'non', 'sum'],
#  ['misericordia', 'consequor'],
#  ['et',
#   'civitas',
#   'ad',
#   'quis',
#   'festino',
#   'venio',
#   'ut',
#   'is',
#   'ad',
#   'solus'],
#  ['deduco', 'et', 'sepulcrum', 'congero', 'facio', 'nunc', 'opto', 'liber'],
#  ['reddo'],
#  ['et',
#   'Iudaei',
#   'quos',
#   'nec',
#   'sepultura',
#   'quidem',
#   'se',
#   'dignus',
#   'habeo'],
#  ['sed',
#   'avis',
#   'atque',
#   'ferus',
#   'diripio',
#   'trado',
#   'et',
#   'cum',
#   'parvulus'],
#  ['extermino', 'dico#2', 'aequalis', 'nunc', 'Athenienses', 'facio'],
#  ['polliceor'],
#  ['templum',
#   'etiam',
#   'sanctus',
#   'quod',
#   'prius',
#   'expoliaverat',
#   'optimum',
#   'donum'],
#  ['orno', 'et', 'sanctus', 'vasum', 'multiplico', 'et', 'pertineo', 'ad'],
#  ['sacrificium', 'sumptus', 'de', 'reditus', 'suus', 'praestaturum'],
#  ['super', 'hic', 'et', 'Iudaeus', 'sum', 'et', 'omnis', 'locus', 'terra'],
#  ['perambulaturum', 'et', 'praedico', 'deus', 'potestas'],
#  ['sed', 'non', 'cesso', 'dolor', 'supervenerat', 'enim', 'in', 'is'],
#  ['iustus',
#   'deus',
#   'iudicium',
#   'despero',
#   'scribo',
#   'ad',
#   'Iudaei',
#   'in',
#   'modus'],
#  ['deprecatio', 'epistula', 'hic', 'continens'],
#  ['optimum',
#   'civis',
#   'Iudaei',
#   'plurimus',
#   'salus',
#   'et',
#   'bene',
#   'valeo',
#   'et'],
#  ['sum', 'felix', 'rex', 'et', 'princeps', 'Antiochus'],
#  ['si',
#   'bene',
#   'valeo',
#   'et',
#   'filius',
#   'vos',
#   'et',
#   'ex',
#   'sententia',
#   'vos'],
#  ['cunctus', 'sum', 'maximus', 'ago', 'gratia'],
#  ['et', 'ego', 'in', 'infirmitas', 'constituo', 'vos', 'autem', 'benignus'],
#  ['memor',
#   'regredior',
#   'de',
#   'Persidis',
#   'locus',
#   'et',
#   'infirmitas',
#   'gravis'],
#  ['adprehendo',
#   'necessarius',
#   'duco',
#   'pro',
#   'communis',
#   'utilitas',
#   'cura',
#   'habeo'],
#  ['non',
#   'despero',
#   'memet',
#   'ipse',
#   'sed',
#   'spes',
#   'multus',
#   'habeo',
#   'effugio'],
#  ['infirmitas'],
#  ['respicio',
#   'autem',
#   'quod',
#   'et',
#   'pater',
#   'quis#2',
#   'tempus',
#   'in',
#   'locus'],
#  ['superus',
#   'duco',
#   'exercitus',
#   'ostendo',
#   'quis#2',
#   'post',
#   'se',
#   'suscipio'],
#  ['principatus'],
#  ['ut',
#   'si',
#   'quis#2',
#   'contrarius',
#   'accido#2',
#   'aut',
#   'difficilis',
#   'nuntio'],
#  ['scio',
#   'hic',
#   'quis#2',
#   'in',
#   'regio',
#   'sum',
#   'quis#2',
#   'sum',
#   'res',
#   'summa'],
#  ['derelinquo', 'non', 'turbo'],
#  ['ad',
#   'hic',
#   'considero',
#   'de',
#   'proximus',
#   'potens',
#   'quosque',
#   'et',
#   'vicinus'],
#  ['tempus', 'insidior', 'et', 'eventum', 'exspecto', 'designo', 'filius'],
#  ['meus',
#   'Antiochus',
#   'rex',
#   'quis#2',
#   'saepe',
#   'recurro',
#   'in',
#   'superus',
#   'regnum'],
#  ['multus',
#   'vos',
#   'commendo',
#   'et',
#   'scribo',
#   'ad',
#   'is',
#   'quis#2',
#   'subiicio',
#   'sum'],
#  ['oro',
#   'itaque',
#   'vos',
#   'et',
#   'peto',
#   'memor',
#   'beneficium',
#   'publicus',
#   'et'],
#  ['privatim',
#   'ut',
#   'unusquisque',
#   'conservo',
#   'fides',
#   'ad',
#   'ego',
#   'et',
#   'ad',
#   'filius',
#   'meus'],
#  ['confido', 'enim', 'is', 'modestus', 'et', 'humane', 'ago', 'et', 'sequor'],
#  ['propono', 'meus', 'communis', 'vos', 'sum'],
#  ['igitur',
#   'homicida',
#   'et',
#   'blasphemus',
#   'pessime',
#   'percutio',
#   'et',
#   'ut',
#   'ipse'],
#  ['alius', 'tracto', 'peregre', 'in', 'mons', 'miserabilis', 'obitus', 'vita'],
#  ['fungor', 'sum'],
#  ['transferebat',
#   'autem',
#   'corpus',
#   'Philippus',
#   'collactaneus',
#   'is',
#   'quis#2'],
#  ['metuo',
#   'filius',
#   'Antiochius',
#   'ad',
#   'Ptolomeum',
#   'Filometora',
#   'in',
#   'Aegyptus'],
#  ['abeo'],
#  ['Macchabeus',
#   'autem',
#   'et',
#   'quis#2',
#   'cum',
#   'ille',
#   'sum',
#   'dominus',
#   'se',
#   'protego'],
#  ['templum', 'quidem', 'et', 'civitas', 'recipio'],
#  ['ara',
#   'autem',
#   'quis#2',
#   'alienigena',
#   'per',
#   'platea',
#   'extruxerant',
#   'item'],
#  ['delubrum', 'demolior', 'sum'],
#  ['et', 'purgo', 'templum', 'alius', 'altar', 'facio', 'et', 'de', 'ignio'],
#  ['lapis',
#   'ignis',
#   'conceptus',
#   'offertor',
#   'sacrificium',
#   'post',
#   'biennium',
#   'et'],
#  ['incensum', 'et', 'lucerna', 'et', 'panis', 'propositio', 'pono'],
#  ['quis#2', 'gestio', 'rogo', 'dominus', 'prosterno', 'in', 'terra', 'ne#2'],
#  ['amplus',
#   'malus',
#   'talis',
#   'incido',
#   'sed',
#   'et',
#   'si',
#   'quando',
#   'peccassent',
#   'ut'],
#  ['ab',
#   'ipse',
#   'mitis',
#   'corripio',
#   'et',
#   'non',
#   'blasphemus',
#   'atque',
#   'barbarus'],
#  ['homo', 'trado'],
#  ['qui', 'dies', 'autem', 'templum', 'ab', 'alienigena', 'polluo', 'sum'],
#  ['contingo',
#   'idem',
#   'dies',
#   'purgatio',
#   'fio',
#   'vicesimus',
#   'et',
#   'quintus',
#   'mensa'],
#  ['quis#2', 'sum', 'casleu'],
#  ['et',
#   'cum',
#   'laetitia',
#   'dies',
#   'octo',
#   'ago',
#   'in',
#   'modus',
#   'tabernaculum'],
#  ['recordor', 'quod', 'ante', 'modicus', 'tempus', 'dies', 'sollemnis'],
#  ['tabernaculum', 'in', 'mons', 'mos', 'bestia', 'ago'],
#  ['propter',
#   'quod',
#   'tyrsos',
#   'et',
#   'ramus',
#   'viridis',
#   'et',
#   'palma',
#   'praeferebant'],
#  ['is', 'quis#2', 'prosperavit', 'mundari', 'locus', 'suus'],
#  ['et',
#   'decerno',
#   'communis',
#   'praeceptum',
#   'et',
#   'decretum',
#   'universus',
#   'gens'],
#  ['Iudaei', 'omnis', 'annus', 'ago', 'dies', 'iste'],
#  ['et', 'Antiochius', 'quidem', 'quis#2', 'appello', 'sum', 'nobilis', 'vita'],
#  ['excessus', 'ita', 'se', 'habeo'],
#  ['nunc',
#   'autem',
#   'de',
#   'Eupator',
#   'Antiochius',
#   'filius',
#   'impius',
#   'quis#2',
#   'gesto'],
#  ['sum', 'narro', 'brevio', 'malus', 'quis#2', 'in', 'bellum', 'gesto', 'sum'],
#  ['hic',
#   'suscepto',
#   'regnum',
#   'constituo',
#   'super',
#   'negotium',
#   'regnum',
#   'Lysiam'],
#  ['quidam', 'Foenicis', 'et', 'Syria', 'militia', 'princeps'],
#  ['namque',
#   'Ptolomeus',
#   'quis#2',
#   'dico#2',
#   'Macer',
#   'iustus',
#   'tenax',
#   'erga',
#   'Iudaei'],
#  ['sum',
#   'instituo',
#   'et',
#   'praecipuus',
#   'propter',
#   'iniquitas',
#   'quis#2',
#   'facio',
#   'sum'],
#  ['in', 'is', 'et', 'pacificus', 'ago', 'cum', 'is'],
#  ['sed', 'ob', 'hic', 'accuso', 'ab', 'amicus#2', 'apud', 'Eupator', 'cum'],
#  ['frequenter', 'proditor', 'audio', 'is', 'quod', 'Cyprus', 'credo', 'ab'],
#  ['Filometore',
#   'nobilis',
#   'translatus',
#   'etiam',
#   'ab',
#   'is',
#   'recedo',
#   'venenum'],
#  ['vita', 'finivit'],
#  ['Gorgias', 'autem', 'cum', 'sum', 'dux', 'locus', 'assumo', 'advena'],
#  ['frequenter', 'Iudaei', 'debello'],
#  ['Iudaei', 'verus', 'quis#2', 'teneo', 'oportunas', 'munitio', 'fugo', 'ab'],
#  ['Hierosolyma', 'suscipio', 'et', 'bellare', 'temptabant'],
#  ['hic',
#   'verus',
#   'quis#2',
#   'sum',
#   'cum',
#   'Macchabeo',
#   'per',
#   'oratio',
#   'dominus'],
#  ['rogo', 'ut', 'sum', 'se', 'adjuto', 'impetus', 'facio', 'in', 'munitio'],
#  ['Idumeorum'],
#  ['multus', 'vis', 'insisto', 'locus', 'obtineo', 'occurro'],
#  ['interimo',
#   'et',
#   'omnis',
#   'simul',
#   'non',
#   'parvus',
#   'ab',
#   'viginti',
#   'mille'],
#  ['trucidaverunt'],
#  ['quidam',
#   'autem',
#   'cum',
#   'confugio',
#   'in',
#   'duo',
#   'turris',
#   'valde',
#   'munio'],
#  ['omnis', 'adparatum', 'ad', 'repugno', 'habeo'],
#  ['Macchabeus', 'ad', 'is', 'expugnatio', 'relinquo', 'Simo', 'et'],
#  ['Ioseppho',
#   'item',
#   'Macchabeo',
#   'eisque',
#   'quis#2',
#   'cum',
#   'ipse',
#   'sum',
#   'satis',
#   'multus'],
#  ['ipse',
#   'ad',
#   'is',
#   'quis#2',
#   'amplus',
#   'perurguebant',
#   'pugna',
#   'converto',
#   'sum'],
#  ['hic',
#   'verus',
#   'quis#2',
#   'cum',
#   'Simo',
#   'sum',
#   'cupiditas',
#   'duco',
#   'ab',
#   'quidam'],
#  ['quis#2',
#   'in',
#   'turris',
#   'sum',
#   'suadeo',
#   'sum',
#   'pecunia',
#   'et',
#   'septuaginta',
#   'mille'],
#  ['didragmis', 'accipio', 'dimitto', 'quidam', 'effugio'],
#  ['cum', 'autem', 'Macchabeo', 'nuntio', 'sum', 'quod', 'facio', 'sum'],
#  ['congrego', 'princeps', 'populus#2', 'accuso', 'quod', 'pecunia', 'frater'],
#  ['vendo', 'adversarius', 'is', 'dimitto'],
#  ['hic',
#   'igitur',
#   'proditor',
#   'facio',
#   'interfacio',
#   'et',
#   'confestim',
#   'duo'],
#  ['turris', 'occupo'],
#  ['arma', 'autem', 'atque', 'manus', 'omnis', 'prosperus', 'ago', 'in', 'duo'],
#  ['munitio', 'plus', 'quam#4', 'viginti', 'mille', 'peremo'],
#  ['Timotheus', 'quis#2', 'prius', 'ab', 'Iudaei', 'sum', 'supero', 'convoco'],
#  ['exercitus',
#   'peregrina',
#   'multitudo',
#   'et',
#   'congrego',
#   'exercitus',
#   'Asianus'],
#  ['advenio', 'quasi', 'arma', 'Iudaea', 'capio'],
#  ['Macchabeus',
#   'autem',
#   'et',
#   'quis#2',
#   'cum',
#   'ipse',
#   'sum',
#   'adpropio',
#   'ille'],
#  ['deprecor',
#   'deus',
#   'caput',
#   'terra',
#   'aspergentes',
#   'lumbosque',
#   'cilicium'],
#  ['praecingo'],
#  ['ad',
#   'altar',
#   'crepidinem',
#   'provolvo',
#   'ut',
#   'se',
#   'propitius',
#   'inimicus'],
#  ['autem',
#   'is',
#   'sum',
#   'inimicus',
#   'et',
#   'adversaretur',
#   'sicut',
#   'lex',
#   'dico#2'],
#  ['et', 'ita', 'post', 'oratio', 'sumo', 'arma', 'longus', 'de', 'civitas'],
#  ['procedo', 'et', 'proximus', 'hostis', 'effectum', 'resederunt'],
#  ['primus', 'autem', 'sol', 'ortus', 'uterque', 'committo', 'iste', 'quidem'],
#  ['victoria', 'et', 'prosperitas', 'sponsorem', 'cum', 'virtus', 'dominus'],
#  ['habeo', 'ille', 'autem', 'dux', 'bellum', 'animus', 'habeo'],
#  ['sed', 'cum', 'vehemens', 'pugna', 'sum', 'appareo', 'adversarius', 'de'],
#  ['caelum',
#   'vir',
#   'quinque',
#   'in',
#   'equus',
#   'frenum',
#   'aureus',
#   'decorum',
#   'ducatus'],
#  ['Iudaei', 'praesto'],
#  ['ex', 'quis#2', 'duo', 'Macchabeum', 'medius', 'habeo', 'arma', 'suus'],
#  ['circumsaepio',
#   'incolomem',
#   'conservo',
#   'in',
#   'adversarius',
#   'autem',
#   'tela'],
#  ['et',
#   'fulmen',
#   'iaciebant',
#   'ex',
#   'quo',
#   'et',
#   'caecitas',
#   'confundo',
#   'et',
#   'repleo'],
#  ['perturbatio', 'cado'],
#  ['interficio',
#   'sum',
#   'autem',
#   'viginti',
#   'mille',
#   'quingenti',
#   'et',
#   'eques'],
#  ['sescenti'],
#  ['Timotheus',
#   'autem',
#   'confugio',
#   'in',
#   'Gazara',
#   'praesidium',
#   'munio',
#   'quis#2'],
#  ['praesum', 'Caereas'],
#  ['Macchabeus',
#   'autem',
#   'et',
#   'quis#2',
#   'cum',
#   'is',
#   'sum',
#   'laetor',
#   'obsederunt'],
#  ['praesidium', 'dies', 'quattuor'],
#  ['at',
#   'hic',
#   'quis#2',
#   'in',
#   'turris',
#   'sum',
#   'locus',
#   'firmitas',
#   'confido',
#   'super'],
#  ['modus', 'maledico', 'et', 'sermo', 'nefandus', 'iacto'],
#  ['sed',
#   'cum',
#   'dies',
#   'quintus',
#   'inlucesceret',
#   'viginti',
#   'iuvenis',
#   'ex',
#   'hic'],
#  ['quis#2',
#   'cum',
#   'Macchabeo',
#   'sum',
#   'accensus',
#   'anima',
#   'propter',
#   'blasphemia'],
#  ['viriliter', 'accedo', 'ad', 'murus', 'et', 'feroci', 'animus', 'incedo'],
#  ['ascendo'],
#  ['sed', 'et', 'alius', 'similiter', 'ascendo', 'turris', 'portasque'],
#  ['succendo', 'aggredior', 'atque', 'ipse', 'maledicus', 'vivus', 'concremo'],
#  ['per', 'continuus', 'autem', 'biduum', 'praesidium', 'vasto', 'Timotheus'],
#  ['occulto',
#   'se',
#   'in',
#   'quidam',
#   'reppertum',
#   'locus',
#   'peremo',
#   'et',
#   'frater'],
#  ['ille', 'Caerean', 'et', 'Apollofanem', 'occido#1'],
#  ['quis#2', 'gestio', 'in', 'hymnus', 'et', 'confessio', 'benedico'],
#  ['dominus',
#   'quis#2',
#   'magnus',
#   'facio',
#   'cum',
#   'Israel',
#   'et',
#   'victoria',
#   'ille',
#   'do'],
#  ['sed', 'parvus', 'post', 'tempus', 'Lysias', 'procurator', 'rex', 'et'],
#  ['propinquus',
#   'atque',
#   'negotium',
#   'praepositus',
#   'graviter',
#   'fero',
#   'de',
#   'hic'],
#  ['quis#2', 'accido'],
#  ['congrego', 'octoginta', 'mille', 'et', 'equitatus', 'universus', 'venio'],
#  ['adversus#2',
#   'Iudaei',
#   'existimo',
#   'se',
#   'civitas',
#   'quidem',
#   'capio',
#   'gens'],
#  ['habitaculum', 'facio'],
#  ['templum',
#   'verus',
#   'in',
#   'pecunia',
#   'quaestus',
#   'sicut',
#   'ceterus',
#   'delubrum'],
#  ['gens', 'habeo', 'et', 'per', 'singulus', 'annus', 'venalis', 'sacerdotium'],
#  ['nusquam', 'recogito', 'deus', 'potestas', 'sed', 'mens', 'effreno', 'in'],
#  ['multitudo', 'pedes', 'et', 'in', 'mille', 'eques', 'et', 'in', 'octoginta'],
#  ['elefantis', 'confido'],
#  ['ingredior',
#   'autem',
#   'Iudaea',
#   'et',
#   'appropio',
#   'Bethsurae',
#   'quod',
#   'sum'],
#  ['in',
#   'angustus',
#   'locus',
#   'ab',
#   'Hierosolyma',
#   'intervallum',
#   'quinque',
#   'stadium'],
#  ['ille', 'praesidium', 'expugno'],
#  ['ut', 'autem', 'Macchabeus', 'et', 'quis#2', 'cum', 'is', 'sum', 'cognosco'],
#  ['expugno',
#   'praesidium',
#   'cum',
#   'fletus',
#   'et',
#   'lacrima',
#   'rogo',
#   'dominus',
#   'et'],
#  ['omnis',
#   'turba',
#   'simul',
#   'ut',
#   'bonus',
#   'angelus',
#   'mitto',
#   'ad',
#   'salus',
#   'Israel'],
#  ['et',
#   'ipse',
#   'primus',
#   'Macchabeus',
#   'sumo',
#   'arma',
#   'ceterus',
#   'adhortatus'],
#  ['sum',
#   'simul',
#   'se',
#   'cum',
#   'periculum',
#   'subeo',
#   'et',
#   'fero',
#   'auxilium',
#   'frater'],
#  ['suus'],
#  ['cumque', 'pariter', 'promptus', 'animus', 'procedo', 'Hierosolyma'],
#  ['appareo',
#   'praecedo',
#   'is',
#   'eques',
#   'in',
#   'vestis',
#   'candidus',
#   'arma',
#   'aureus'],
#  ['hasta', 'vibro'],
#  ...]

# %% [markdown]
# And the second:

# %%
subcorpus2corpus[1]
# Out:
# [['ut',
#   'alimentum',
#   'sanus',
#   'corpus',
#   'agricultura',
#   'sic',
#   'sanitas',
#   'aegrum',
#   'medicinus',
#   'promitto'],
#  ['hic',
#   'nusquam',
#   'quidem',
#   'non',
#   'sum',
#   'siquidem',
#   'etiam',
#   'inperitissimae',
#   'gens',
#   'herba',
#   'aliaque',
#   'promta',
#   'in',
#   'auxilium',
#   'vulnus',
#   'morborumque',
#   'nosco'],
#  ['verus',
#   'tamen',
#   'apud',
#   'Graecus',
#   'aliquantus',
#   'magis',
#   'quam#4',
#   'in',
#   'ceterus',
#   'natio',
#   'excolo',
#   'sum',
#   'atque',
#   'ne#2',
#   'apud',
#   'hic',
#   'quidem',
#   'ab',
#   'primus',
#   'origo',
#   'sed',
#   'paucus',
#   'ante',
#   'nos',
#   'saeculum'],
#  ['ut',
#   'pote',
#   'cum',
#   'vetustus',
#   'auctor',
#   'Aesculapius',
#   'celebro',
#   'quis#2',
#   'quoniam',
#   'adhuc',
#   'rudis',
#   'et',
#   'vulgaris',
#   'hic',
#   'scientia',
#   'paulum',
#   'subtilis',
#   'excoluit',
#   'in',
#   'deus',
#   'numerus',
#   'recipio',
#   'sum'],
#  ['hic',
#   'deinde',
#   'duo',
#   'filius',
#   'Podalirius',
#   'et',
#   'Machaon',
#   'bellum',
#   'Troiano',
#   'dux',
#   'Agamemnon',
#   'sequor',
#   'non',
#   'mediocris',
#   'ops',
#   'commilitonibus',
#   'suus',
#   'affero',
#   'quos',
#   'tamen',
#   'Homerus',
#   'non',
#   'in',
#   'pestilentia',
#   'neque',
#   'in',
#   'varius',
#   'genus',
#   'morbus',
#   'aliquis',
#   'affero',
#   'auxilium',
#   'sed',
#   'vulnus',
#   'tantummodo',
#   'ferrum',
#   'et',
#   'medicamentum',
#   'mederi',
#   'soleo',
#   'sum',
#   'propono'],
#  ['ex',
#   'quo',
#   'appareo',
#   'hic',
#   'pars',
#   'medicina',
#   'solus',
#   'ab',
#   'is',
#   'sum',
#   'temtatas',
#   'easque',
#   'sum',
#   'vetustus'],
#  ['idem',
#   'verus',
#   'auctor',
#   'discus',
#   'possum',
#   'morbus',
#   'tum',
#   'ad',
#   'ira',
#   'deus',
#   'inmortalium',
#   'refero',
#   'sum',
#   'et',
#   'ab',
#   'idem',
#   'ops',
#   'posci',
#   'soleo',
#   'verique',
#   'similis',
#   'sum',
#   'inter',
#   'nullus',
#   'auxilium',
#   'adversus',
#   'valetudinis',
#   'plerumque',
#   'tamen',
#   'is',
#   'bonus',
#   'contingo',
#   'ob',
#   'bonus',
#   'mos',
#   'quos',
#   'neque',
#   'desidia',
#   'neque',
#   'luxuria',
#   'vitiarant',
#   'siquidem',
#   'hic',
#   'duo',
#   'corpus',
#   'prius',
#   'in',
#   'Graecia',
#   'deinde',
#   'apud',
#   'nos',
#   'affligo',
#   'ideoque',
#   'multiplex',
#   'iste',
#   'medicina',
#   'neque',
#   'olim',
#   'neque',
#   'apud',
#   'alius',
#   'gens',
#   'necessarius',
#   'vix',
#   'aliquos',
#   'ex',
#   'nos',
#   'ad',
#   'senectus',
#   'principium',
#   'perduco'],
#  ['ergo',
#   'etiam',
#   'post',
#   'is',
#   'de',
#   'quis#2',
#   'refero',
#   'nullus',
#   'clarus',
#   'vir',
#   'medicina',
#   'exerceo',
#   'donec',
#   'magnus',
#   'studium',
#   'litterae',
#   'disciplina',
#   'agitor',
#   'coepio',
#   'quis#2',
#   'ut',
#   'animus',
#   'praecipuus',
#   'omnis',
#   'necessarius',
#   'sic',
#   'corpus',
#   'inimicus',
#   'sum'],
#  ['Primoque',
#   'medeor',
#   'scientia',
#   'sapientia',
#   'pars',
#   'habeo',
#   'ut',
#   'et',
#   'morbus',
#   'curatio',
#   'et',
#   'res',
#   'natura',
#   'contemplatio',
#   'sub',
#   'idem',
#   'auctor',
#   'nascor',
#   'sum',
#   'scilicet',
#   'is',
#   'hic',
#   'multus',
#   'requiro',
#   'quis#2',
#   'corpus',
#   'suus',
#   'robur',
#   'quietus',
#   'cogitatio',
#   'nocturnaque',
#   'vigilia',
#   'minuo'],
#  ['Ideoque',
#   'multus',
#   'ex',
#   'sapientia',
#   'professor',
#   'peritus',
#   'is',
#   'sum',
#   'accipio',
#   'clarus',
#   'verus',
#   'ex',
#   'is',
#   'Pythagoran',
#   'et',
#   'Enpedoclen',
#   'et',
#   'Democritus'],
#  ['hic',
#   'autem',
#   'ut',
#   'quidam',
#   'credo',
#   'discipulus',
#   'Hippocrates',
#   'Cous',
#   'primus',
#   'ex',
#   'omnis',
#   'memoria',
#   'dignus',
#   'ab',
#   'studium',
#   'sapientia',
#   'disciplina',
#   'hic',
#   'separo',
#   'vir',
#   'et',
#   'ars',
#   'et',
#   'facundia',
#   'insignis'],
#  ['post',
#   'quis#2',
#   'Diocles',
#   'Carystius',
#   'deinde',
#   'Praxagoras',
#   'et',
#   'Chrysippus',
#   'tum',
#   'Herophilus',
#   'et',
#   'Erasistratus',
#   'sic',
#   'ars',
#   'hic',
#   'exerceo',
#   'ut',
#   'etiam',
#   'in',
#   'diversus',
#   'curo',
#   'via',
#   'procedo'],
#  ['Isdemque',
#   'tempus',
#   'in',
#   'tres',
#   'pars',
#   'medicina',
#   'diduco',
#   'sum',
#   'ut',
#   'unus',
#   'sum',
#   'quis#2',
#   'victus',
#   'alter',
#   'quis#2',
#   'medicamentum',
#   'tertius',
#   'quis#2',
#   'manus',
#   'mederetur'],
#  ['primus',
#   'diaithtikhn',
#   'secundus',
#   'farmakeutikhn',
#   'tertius',
#   'ceirourgikhn',
#   'Graecus',
#   'nomino'],
#  ['is',
#   'autem',
#   'quis#2',
#   'victus',
#   'morbus',
#   'curo',
#   'longus',
#   'clarus',
#   'auctor',
#   'etiam',
#   'altus',
#   'quidam',
#   'agito',
#   'conor',
#   'res',
#   'quoque',
#   'natura',
#   'se',
#   'cognitio',
#   'vindicarunt',
#   'tamquam',
#   'sine',
#   'is',
#   'truncus',
#   'et',
#   'debilis',
#   'medicina',
#   'sum'],
#  ['post',
#   'quos',
#   'Serapion',
#   'primus',
#   'omnis',
#   'nihil',
#   'hic',
#   'rationalis',
#   'disciplina',
#   'pertineo',
#   'ad',
#   'medicina',
#   'profiteor',
#   'in',
#   'usus',
#   'tantus',
#   'et',
#   'experimentum',
#   'is',
#   'pono'],
#  ['quis#2',
#   'Apollonius',
#   'et',
#   'Glaucias',
#   'et',
#   'aliquantus',
#   'post',
#   'Heraclides',
#   'Tarentinus',
#   'et',
#   'aliquis',
#   'non',
#   'mediocris',
#   'vir',
#   'sequor',
#   'ex',
#   'ipse',
#   'professio',
#   'se',
#   'empiricus',
#   'appello'],
#  ['sic',
#   'in',
#   'duo',
#   'pars',
#   'is',
#   'quoque',
#   'quis#2',
#   'victus',
#   'curo',
#   'medicina',
#   'divido',
#   'sum',
#   'alius',
#   'rationalis',
#   'ars',
#   'alius',
#   'usus',
#   'tantus',
#   'se',
#   'vindico',
#   'nullus',
#   'verus',
#   'quisquam',
#   'post',
#   'is',
#   'quis#2',
#   'supra',
#   'comprehendo',
#   'sum',
#   'agito',
#   'nisi',
#   'quod',
#   'accipio',
#   'donec',
#   'Asclepiades',
#   'medeor',
#   'ratio',
#   'ex',
#   'magnus',
#   'pars',
#   'muto'],
#  ['ex',
#   'quis#2',
#   'successor',
#   'Themison',
#   'nuper',
#   'ipse',
#   'quoque',
#   'quidam',
#   'in',
#   'senectus',
#   'deflecto'],
#  ['et',
#   'per',
#   'hic',
#   'quidem',
#   'multus',
#   'vir',
#   'salutaris',
#   'iste',
#   'nos',
#   'professio',
#   'increvit'],
#  ['quoniam',
#   'autem',
#   'ex',
#   '[',
#   'tres',
#   ']',
#   'medicina',
#   'partus#2',
#   'ut',
#   'difficilis',
#   'sic',
#   'etiam',
#   'clarus',
#   'sum',
#   'is',
#   'quis#2',
#   'morbus',
#   'medetur',
#   'ante',
#   'omnis',
#   'de',
#   'hic',
#   'dico',
#   'sum'],
#  ['et',
#   'quia',
#   'primus',
#   'in',
#   'is',
#   'dissensio',
#   'sum',
#   'quod',
#   'alius',
#   'se',
#   'experimentum',
#   'tantummodo',
#   'notitia',
#   'necessarius',
#   'sum',
#   'contendo',
#   'alius',
#   'nisi',
#   'corpus',
#   'rerumque',
#   'ratio',
#   'comperio',
#   'non',
#   'satis',
#   'possum',
#   'usus',
#   'sum',
#   'propono',
#   'indico',
#   'sum',
#   'quis#2',
#   'multus',
#   'ex',
#   'uterque',
#   'pars',
#   'dico#2',
#   'quo',
#   'facilis',
#   'noster',
#   'quoque',
#   'opinio',
#   'interpono',
#   'possum'],
#  ['igitur',
#   'is',
#   'quis#2',
#   'rationalis',
#   'medicina',
#   'profiteor',
#   'hic',
#   'necessarius',
#   'sum',
#   'propono',
#   'abditus',
#   'et',
#   'morbus',
#   'contineo',
#   'causa',
#   'notitia',
#   'deinde',
#   'evidentium',
#   'post',
#   'hic',
#   'etiam',
#   'naturalis',
#   'actio',
#   'novissime',
#   'pars',
#   'interior'],
#  ['abditus',
#   'causa',
#   'voco',
#   'in',
#   'quis#2',
#   'requiro',
#   'ex',
#   'quis#2',
#   'principium',
#   'noster',
#   'corpus',
#   'sum',
#   'quis#2',
#   'secundus',
#   'quis#2',
#   'adversa',
#   'valetudinem',
#   'facio'],
#  ['neque',
#   'enim',
#   'credo',
#   'possum',
#   'is',
#   'scio',
#   'quomodo',
#   'morbus',
#   'curo',
#   'convenio',
#   'quis#2',
#   'unde',
#   'sum',
#   'ignoro',
#   'neque',
#   'sum',
#   'dubius',
#   'quin',
#   'alius',
#   'curatio',
#   'opus',
#   'sum',
#   'si',
#   'ex',
#   'quattuor',
#   'principium',
#   'vel',
#   'supero',
#   'aliquot',
#   'vel',
#   'deficio',
#   'adversa',
#   'valetudinem',
#   'creo',
#   'ut',
#   'quidam',
#   'ex',
#   'sapientia',
#   'professor',
#   'dico#2',
#   'alius',
#   'si',
#   'in',
#   'umidum',
#   'omnis',
#   'vitium',
#   'sum',
#   'ut',
#   'Herophilo',
#   'visum',
#   'sum',
#   'alius',
#   'si',
#   'in',
#   'spiritus',
#   'ut',
#   'Hippocrati',
#   'alius',
#   'si',
#   'sanguis',
#   'in',
#   'is',
#   'vena',
#   'quis#2',
#   'spiritus',
#   'accommodo',
#   'sum',
#   'transfundo',
#   'et',
#   'inflammatio',
#   'quam#4',
#   'Graecus',
#   'flegmonhn',
#   'nomino',
#   'excito',
#   'eaque',
#   'inflammatio',
#   'talis',
#   'motus',
#   'efficio',
#   'qualis',
#   'in',
#   'febre',
#   'sum',
#   'ut',
#   'Erasistrato',
#   'placeo',
#   'alius',
#   'si',
#   'mano',
#   'corpuscula',
#   'per',
#   'invisibilis',
#   'foramen',
#   'subsisto',
#   'iter',
#   'claudo',
#   'ut',
#   'Asclepiades',
#   'contendo',
#   'is',
#   'verus',
#   'rectus',
#   'curo',
#   'quis#2',
#   'primus',
#   'origo',
#   'causa',
#   'non',
#   'fallo'],
#  ['neque',
#   'verus',
#   'infitiantur',
#   'experimentum',
#   'quoque',
#   'sum',
#   'necessarius',
#   'sed',
#   'ne#2',
#   'ad',
#   'hic',
#   'quidem',
#   'aditus',
#   'fio',
#   'possum',
#   'nisi',
#   'ab',
#   'aliquis',
#   'ratio',
#   'contendo',
#   'non',
#   'enim',
#   'quilibet',
#   'antiquus',
#   'vir',
#   'aegrum',
#   'inculcasse',
#   'sed',
#   'cogitasse',
#   'quis#2',
#   'multus',
#   'convenio',
#   'et',
#   'is',
#   'usus',
#   'explorasse',
#   'ad',
#   'quod',
#   'ante',
#   'coniectura',
#   'aliquis',
#   'duco'],
#  ['neque',
#   'intersum',
#   'an',
#   'nunc',
#   'iam',
#   'plerusque',
#   'exploro',
#   'sum',
#   'si',
#   'ab',
#   'consilium',
#   'tamen',
#   'coepio'],
#  ['et', 'is', 'quidem', 'in', 'multus', 'ita', 'se', 'habeo'],
#  ['saepe',
#   'verus',
#   'etiam',
#   'novus',
#   'incido#2',
#   'genus',
#   'morbus',
#   'in',
#   'quis#2',
#   'nihil',
#   'adhuc',
#   'usus',
#   'ostendo',
#   'et',
#   'ideo',
#   'necessarius',
#   'sum',
#   'animadverto',
#   'unde',
#   'is',
#   'coepio',
#   'sine',
#   'quo',
#   'nemo',
#   'reperio',
#   'mortalis',
#   'possum',
#   'cur',
#   'hic',
#   'quam#4',
#   'ille',
#   'potius',
#   'utor'],
#  ['et',
#   'ob',
#   'hic',
#   'quidem',
#   'in',
#   'obscurum',
#   'pono',
#   'causa',
#   'persecuntur'],
#  ['Evidentes',
#   'verus',
#   'hic',
#   'appello',
#   'in',
#   'quis#2',
#   'quaero',
#   'initium',
#   'morbus',
#   'calor',
#   'affero',
#   'an',
#   'frigus',
#   'fames',
#   'an',
#   'satietas',
#   'et',
#   'quis#2',
#   'similis',
#   'sum',
#   'occurro',
#   'enim',
#   'vitium',
#   'dico#2',
#   'is',
#   'quis#2',
#   'origo',
#   'non',
#   'ignorarit'],
#  ['naturalis',
#   'verus',
#   'corpus',
#   'actio',
#   'appello',
#   'per',
#   'quis#2',
#   'spiritus',
#   'traho',
#   'et',
#   'emitto',
#   'cibus',
#   'potionemque',
#   'et',
#   'adsumo',
#   'et',
#   'concoquo',
#   'item',
#   'per',
#   'quis#2',
#   'idem',
#   'hic',
#   'in',
#   'omnis',
#   'membrum',
#   'pars',
#   'digero'],
#  ['tum',
#   'requiro',
#   'etiam',
#   'quare',
#   'vena',
#   'noster',
#   'modus',
#   'summitto',
#   'se',
#   'modus',
#   'attollo',
#   'quis#2',
#   'ratio',
#   'somnus',
#   'quis#2',
#   'vigilia',
#   'sum',
#   'sine',
#   'quis#2',
#   'notitia',
#   'nemo',
#   'puto',
#   'vel',
#   'occurro',
#   'vel',
#   'mederi',
#   'morbus',
#   'inter',
#   'hic',
#   'nascor',
#   'possum'],
#  ['ex',
#   'quis#2',
#   'quia',
#   'multus',
#   'pertineo',
#   'ad',
#   'res',
#   'concoctio',
#   'video',
#   'hic',
#   'potissimus',
#   'insisto',
#   'et',
#   'dux',
#   'alius',
#   'Erasistrato',
#   'teri',
#   'cibus',
#   'in',
#   'venter',
#   'contendo',
#   'alius',
#   'Plistonico',
#   'Praxagorae',
#   'discipulus',
#   'putrescere',
#   'alius',
#   'credo',
#   'Hippocrati',
#   'per',
#   'calor',
#   'cibus',
#   'concoqui',
#   'acceduntque',
#   'Asclepiadis',
#   'aemulus',
#   'quis#2',
#   'omnis',
#   'iste',
#   'vanus',
#   'et',
#   'supervacuus',
#   'sum',
#   'propono',
#   'nihil',
#   'enim',
#   'concoqui',
#   'sed',
#   'crudus',
#   'materia',
#   'sicut',
#   'adsumo',
#   'sum',
#   'in',
#   'corpus',
#   'omnis',
#   'diduco'],
#  ['et',
#   'hic',
#   'quidem',
#   'inter',
#   'is',
#   'parus',
#   'consto',
#   'ille',
#   'verus',
#   'convenio',
#   'alius',
#   'do',
#   'cibus',
#   'laboro',
#   'si',
#   'hic',
#   'alius',
#   'si',
#   'ille',
#   'verus',
#   'sum',
#   'namque',
#   'si',
#   'tero',
#   'intus',
#   'is',
#   'quaero',
#   'sum',
#   'quis#2',
#   'facilis',
#   'teri',
#   'possum',
#   'si',
#   'putrescit',
#   'is',
#   'in',
#   'quo',
#   'hic',
#   'expedio',
#   'sum',
#   'si',
#   'calor',
#   'concoquo',
#   'is',
#   'quis#2',
#   'multus',
#   'calor',
#   'moveo',
#   'at',
#   'nihil',
#   'ex',
#   'hic',
#   'sum',
#   'quaero',
#   'si',
#   'nihil',
#   'concoquo',
#   'is',
#   'verus',
#   'sumo',
#   'quis#2',
#   'multus',
#   'mano',
#   'qualis',
#   'adsumo',
#   'sum'],
#  ['Eademque',
#   'ratio',
#   'cum',
#   'spiritus',
#   'gravis',
#   'sum',
#   'cum',
#   'somnus',
#   'aut',
#   'vigilia',
#   'urguet',
#   'is',
#   'mederi',
#   'possum',
#   'arbitror',
#   'quis#2',
#   'prius',
#   'ille',
#   'ipse',
#   'qualiter',
#   'evenio',
#   'percipio'],
#  ['praeter',
#   'hic',
#   'cum',
#   'in',
#   'interior',
#   'partus#2',
#   'et',
#   'dolor',
#   'et',
#   'morbus',
#   'varius',
#   'genus',
#   'nasco',
#   'nemo',
#   'puto',
#   'hic',
#   'adhibeo',
#   'possum',
#   'remedium',
#   'quis#2',
#   'ipse',
#   'ignoro'],
#  ['ergo',
#   'necessarius',
#   'sum',
#   'incido#2',
#   'corpus',
#   'mortuus',
#   'is',
#   'viscera',
#   'atque',
#   'intestinum',
#   'scrutor',
#   'longeque',
#   'optime',
#   'facio',
#   'Herophilum',
#   'et',
#   'Erasistratum',
#   'quis#2',
#   'noceo',
#   'homo',
#   'ab',
#   'rex',
#   'ex',
#   'carcer',
#   'accipio',
#   'vivus',
#   'incido#1',
#   'considerarintque',
#   'etiamnum',
#   'spiritus',
#   'remaneo',
#   'is',
#   'quis#2',
#   'natura',
#   'ante',
#   'claudo',
#   'is',
#   'pono',
#   'color',
#   'figura',
#   'magnitudo',
#   'ordo',
#   'durities',
#   'mollitiem',
#   'levorem',
#   'contingo',
#   'processus',
#   'deinde',
#   'singulus',
#   'et',
#   'recessus',
#   'et',
#   'sive',
#   'quis#2',
#   'insero',
#   'alter',
#   'sive',
#   'quis#2',
#   'pars',
#   'alter',
#   'in',
#   'se',
#   'recipio',
#   'neque',
#   'enim',
#   'cum',
#   'dolor',
#   'intus',
#   'incido#2',
#   'scio',
#   'quis#2',
#   'doleo',
#   'is',
#   'quis#2',
#   'qui',
#   'pars',
#   'quisque',
#   'viscus',
#   'intestinumve',
#   'sum',
#   'non',
#   'cognosco',
#   'neque',
#   'curo',
#   'is',
#   'quod',
#   'aegrum',
#   'sum',
#   'possum',
#   'ab',
#   'is',
#   'quis#2',
#   'quis#2',
#   'sum',
#   'ignoro',
#   'et',
#   'cum',
#   'per',
#   'volnus',
#   'aliquis',
#   'viscera',
#   'patefacio',
#   'sum',
#   'is',
#   'quis#2',
#   'sanus',
#   'quisque',
#   'color',
#   'pars',
#   'ignoro',
#   'nescio',
#   'quis#2',
#   'integer',
#   'quis#2',
#   'corrumpo',
#   'sum',
#   'ita',
#   'ne#2',
#   'succurro',
#   'quidem',
#   'possum',
#   'corrumpo'],
#  ['Aptiusque',
#   'extrinsecus',
#   'inponi',
#   'remedium',
#   'conpertis',
#   'interior',
#   'et',
#   'sedes',
#   'et',
#   'figura',
#   'cognitaque',
#   'is',
#   'magnitudo',
#   'similesque',
#   'omnis',
#   'quis#2',
#   'pono',
#   'supra',
#   'sum',
#   'ratio',
#   'habeo'],
#  ['neque',
#   'sum',
#   'crudelis',
#   'sicut',
#   'plerusque',
#   'propono',
#   'homo',
#   'noceo',
#   'et',
#   'hic',
#   'quoque',
#   'paucus',
#   'supplicium',
#   'remedium',
#   'populus',
#   'innocens',
#   'saeculum',
#   'omnis',
#   'quaero'],
#  ['contra',
#   'is',
#   'quis#2',
#   'se',
#   'ENPIRICOS',
#   'ab',
#   'experientia',
#   'nomino',
#   'evidentes',
#   'quidem',
#   'causa',
#   'ut',
#   'necessaria',
#   'amplectuntur',
#   'obscurus',
#   'verus',
#   'causa',
#   'et',
#   'naturalis',
#   'actio',
#   'quaestio',
#   'ideo',
#   'supervacuus',
#   'sum',
#   'contendo',
#   'quoniam',
#   'non',
#   'conprehensibilis',
#   'natura',
#   'sum'],
#  ['non',
#   'possum',
#   'verus',
#   'comprehendo',
#   'patior',
#   'ex',
#   'is',
#   'quis#2',
#   'de',
#   'hic',
#   'disputarunt',
#   'discordium',
#   'cum',
#   'de',
#   'iste',
#   'res',
#   'neque',
#   'inter',
#   'sapientia',
#   'professor',
#   'neque',
#   'inter',
#   'ipse',
#   'medicus',
#   'convenio'],
#  ['cur',
#   'enim',
#   'potius',
#   'aliquis',
#   'Hippocrati',
#   'credo',
#   'quam#4',
#   'Herophilo'],
#  ['cur', 'hic', 'potius', 'quam#4', 'Asclepiadi'],
#  ['si',
#   'ratio',
#   'sequor',
#   'volo#1',
#   'omnis',
#   'possum',
#   'video',
#   'non',
#   'inprobabiles',
#   'si',
#   'curatio',
#   'ab',
#   'omnis',
#   'hic',
#   'aeger',
#   'perduco',
#   'sum',
#   'ad',
#   'sanitas'],
#  ['ita',
#   'neque',
#   'disputatio',
#   'neque',
#   'auctoritas',
#   'quisquam',
#   'fides',
#   'derogari',
#   'oportuisse'],
#  ['etiam',
#   'sapientia',
#   'studiosus',
#   'maximus',
#   'medicus',
#   'sum',
#   'si',
#   'ratiocinatio',
#   'hic',
#   'facio',
#   'nunc',
#   'ille',
#   'verbum',
#   'supersum',
#   'desum',
#   'medeor',
#   'scientia'],
#  ['differo',
#   'quoque',
#   'pro',
#   'natura',
#   'locus',
#   'genus',
#   'medicina',
#   'et',
#   'alius',
#   'opus',
#   'sum',
#   'Roma',
#   'alius',
#   'in',
#   'Aegyptus',
#   'alius',
#   'in',
#   'Gallia'],
#  ['quod',
#   'si',
#   'morbus',
#   'hic',
#   '[',
#   'causa',
#   ']',
#   'facio',
#   'quis#2',
#   'ubique',
#   'idem',
#   'sum',
#   'idem',
#   'remedium',
#   'quoque',
#   'ubique',
#   'sum',
#   'debeo'],
#  ['saepe',
#   'etiam',
#   'causa',
#   'appareo',
#   'ut',
#   'puto',
#   'lippitudinis',
#   'vulnus',
#   'neque',
#   'ex',
#   'hic',
#   'patior',
#   'medicina'],
#  ['quod',
#   'si',
#   'scientia',
#   'hic',
#   'non',
#   'subicio',
#   'evidens',
#   'causa',
#   'multus',
#   'parvus',
#   'is',
#   'possum',
#   'subicio',
#   'quis#2',
#   'in',
#   'dubius',
#   'sum'],
#  ['cum',
#   'igitur',
#   'ille',
#   'incertus',
#   'inconprehensibilis',
#   'sum',
#   'ab',
#   'certus',
#   'potius',
#   'et',
#   'exploro',
#   'peto',
#   'sum',
#   'praesidium',
#   'is',
#   'sum',
#   'is',
#   'quis#2',
#   'experientia',
#   'in',
#   'ipse',
#   'curatio',
#   'doceo',
#   'sicut',
#   'in',
#   'ceterus',
#   'omnis',
#   'ars'],
#  ['nam',
#   'ne#2',
#   'agricola',
#   'quidem',
#   'aut',
#   'gubernator',
#   'disputatio',
#   'sed',
#   'usus',
#   'fio'],
#  ['atque',
#   'nihil',
#   'iste',
#   'cogitatio',
#   'ad',
#   'medicina',
#   'pertineo',
#   'is',
#   'quoque',
#   'discus',
#   'quod',
#   'quis#2',
#   'diversus',
#   'de',
#   'hic',
#   'sentio',
#   'ad',
#   'idem',
#   'tamen',
#   'sanitas',
#   'homo',
#   'perduco',
#   'is',
#   'enim',
#   'facio',
#   'quia',
#   'non',
#   'ab',
#   'obscurus',
#   'causa',
#   'neque',
#   'ab',
#   'naturalis',
#   'actio',
#   'quis#2',
#   'apud',
#   'is',
#   'diversus',
#   'sum',
#   'sed',
#   'ab',
#   'experimentum',
#   'prout',
#   'quisque',
#   'respondeo',
#   'medeor',
#   'via',
#   'traho'],
#  ['ne',
#   'inter',
#   'initium',
#   'quidem',
#   'ab',
#   'iste',
#   'quaestio',
#   'deduco',
#   'sum',
#   'medicina',
#   'sed',
#   'ab',
#   'experimentum',
#   'aegrum',
#   'enim',
#   'quis#2',
#   'sine',
#   'medica',
#   'sum',
#   'alius',
#   'propter',
#   'aviditas',
#   'primus',
#   'dies',
#   'protinus',
#   'cibus',
#   'adsumo',
#   'alius',
#   'propter',
#   'fastidium',
#   'quum',
#   'levatumque',
#   'magis',
#   'is',
#   'morbus',
#   'sum',
#   'quis#2',
#   'abstinuerant'],
#  ['Itemque',
#   'alius',
#   'in',
#   'ipse',
#   'febre',
#   'aliquis',
#   'edo',
#   'alius',
#   'paulum',
#   'ante',
#   'is',
#   'alius',
#   'post',
#   'remissio',
#   'is',
#   'optime',
#   'deinde',
#   'is',
#   'cedo',
#   'quis#2',
#   'post',
#   'finis',
#   'febris',
#   'is',
#   'facio',
#   'eademque',
#   'ratio',
#   'alius',
#   'inter',
#   'principium',
#   'protinus',
#   'utor',
#   'sum',
#   'cibus',
#   'plenus',
#   'alius',
#   'exiguus',
#   'gravioresque',
#   'is',
#   'facio',
#   'quis#2',
#   'se',
#   'implerant'],
#  ['hic',
#   'similiaque',
#   'cum',
#   'cottidie',
#   'incido',
#   'diligo',
#   'homo',
#   'notasse',
#   'quis#2',
#   'plerumque',
#   'melius',
#   'respondeo',
#   'deinde',
#   'aegroto',
#   'is',
#   'praecipio',
#   'coepio'],
#  ['sic',
#   'medicina',
#   'orior',
#   'subinde',
#   'alius',
#   'salus',
#   'alius',
#   'interitus',
#   'perniciosus',
#   'discerno',
#   'ab',
#   'salutaris'],
#  ['reperio',
#   'deinde',
#   'iam',
#   'remedium',
#   'homo',
#   'de',
#   'ratio',
#   'is',
#   'dissero',
#   'coepio',
#   'nec',
#   'post',
#   'ratio',
#   'medicina',
#   'sum',
#   'invenio',
#   'sed',
#   'post',
#   'invenio',
#   'medicina',
#   'ratio',
#   'sum',
#   'quaero'],
#  ['requiro',
#   'etiam',
#   'se',
#   'ratio',
#   'idem',
#   'doceo',
#   'quod',
#   'experientia',
#   'an',
#   'alius',
#   'si',
#   'idem',
#   'supervacuus',
#   'sum',
#   'si',
#   'alius',
#   'etiam',
#   'contrarius'],
#  ['primus',
#   'tamen',
#   'remedium',
#   'exploro',
#   'summa',
#   'cura',
#   'sum',
#   'nunc',
#   'verus',
#   'iam',
#   'exploro',
#   'sum',
#   'neque',
#   'aut',
#   'novus',
#   'genus',
#   'morbus',
#   'reperiri',
#   'aut',
#   'novus',
#   'desiderari',
#   'medicina'],
#  ['quod',
#   'si',
#   'iam',
#   'incido',
#   'malus',
#   'genus',
#   'aliquot',
#   'ignotus',
#   'non',
#   'ideo',
#   'tamen',
#   'sum',
#   'medicus',
#   'de',
#   'res',
#   'cogito',
#   'obscurus',
#   'sed',
#   'is',
#   'protinus',
#   'video',
#   'quis#2',
#   'morbus',
#   'is',
#   'proximus',
#   'sum',
#   'temptaturumque',
#   'remedium',
#   'similis',
#   'ille',
#   'quis#2',
#   'vicinum',
#   'malus',
#   'saepe',
#   'succurro',
#   'et',
#   'per',
#   'is',
#   'similitudo',
#   'ops',
#   'reperio'],
#  ['neque',
#   'enim',
#   'se',
#   'dico#2',
#   'medicus',
#   'consilium',
#   'non',
#   'egeo',
#   'et',
#   'inrationale',
#   'animal',
#   'hic',
#   'ars',
#   'possum',
#   'praesto',
#   'sed',
#   'hic',
#   'lateo',
#   'res',
#   'coniecturas',
#   'ad',
#   'res',
#   'non',
#   'pertineo',
#   'quia',
#   'non',
#   'intersum',
#   'quis#2',
#   'morbus',
#   'facio',
#   'sed',
#   'quis#2',
#   'tollo',
#   'neque',
#   'ad',
#   'res',
#   'pertineo',
#   'quomodo',
#   'sed',
#   'quis#2',
#   'optime',
#   'digero',
#   'sive',
#   'hic',
#   'de',
#   'causa',
#   'concoctio',
#   'incido',
#   'sive',
#   'ille',
#   'et',
#   'sive',
#   'concoctio',
#   'sum',
#   'ille',
#   'sive',
#   'tantus',
#   'digestio'],
#  ['neque',
#   'quaero',
#   'sum',
#   'quomodo',
#   'spiro',
#   'sed',
#   'quis#2',
#   'gravis',
#   'et',
#   'tardus',
#   'spiritus',
#   'expedio',
#   'neque',
#   'quis#2',
#   'vena',
#   'moveo',
#   'sed',
#   'quis#2',
#   'quisque',
#   'motus',
#   'genus',
#   'significo'],
#  ['hic', 'autem', 'cognosco', 'experimentum'],
#  ['et',
#   'in',
#   'omnis',
#   'eiusmodi',
#   'cogitatio',
#   'in',
#   'uterque',
#   'pars',
#   'disseri',
#   'possum',
#   'itaque',
#   'ingenium',
#   'et',
#   'facundia',
#   'vinco',
#   'morbus',
#   'autem',
#   'non',
#   'eloquentia',
#   'sed',
#   'remedium',
#   'curo'],
#  ['qui',
#   'si',
#   'quis#2',
#   'elinguis',
#   'usus',
#   'discerno',
#   'bene',
#   'nosco',
#   'hic',
#   'aliquantus',
#   'magnus',
#   'medicus',
#   'sum',
#   'quam#4',
#   'si',
#   'sine',
#   'usus',
#   'lingua',
#   'suus',
#   'excoluerit'],
#  ['atque',
#   'is',
#   'quidem',
#   'de',
#   'quis#2',
#   'sum',
#   'dico#2',
#   'supervacuus',
#   'sum',
#   'tantummodo',
#   'is',
#   'verus',
#   'quod',
#   'resto',
#   'etiam',
#   'crudelis',
#   'vivus',
#   'homo',
#   'alvus',
#   'atque',
#   'praecordia',
#   'incido',
#   'et',
#   'salus',
#   'humanus',
#   'praeses',
#   'ars',
#   'non',
#   'solus',
#   'pestis',
#   'aliquis',
#   'sed',
#   'hic',
#   'etiam',
#   'atrox',
#   'infero',
#   'cum',
#   'praesertim',
#   'ex',
#   'hic',
#   'quis#2',
#   'tantus',
#   'violentia',
#   'quaero',
#   'alius',
#   'non',
#   'possum',
#   'omnino',
#   'cognosco',
#   'alius',
#   'possum',
#   'etiam',
#   'sine',
#   'scelus'],
#  ['nam',
#   'color',
#   'levorem',
#   'mollitiem',
#   'durities',
#   'similiaque',
#   'omnis',
#   'non',
#   'sum',
#   'talis',
#   'incisum',
#   'corpus',
#   'qualis',
#   'integro',
#   'sum',
#   'quia',
#   'cum',
#   'corpus',
#   'inviolatus',
#   'sum',
#   'hic',
#   'tamen',
#   'metus',
#   'dolor',
#   'inedia',
#   'cruditate',
#   'lassitudo',
#   'mille',
#   'alius',
#   'mediocris',
#   'adfectibus',
#   'saepe',
#   'muto',
#   'multus',
#   'magis',
#   'verus',
#   'similis',
#   'sum',
#   'interior',
#   'quis#2',
#   'magnus',
#   'mollities',
#   'lux',
#   'ipse',
#   'novus',
#   'sum',
#   'sub',
#   'gravis',
#   'vulnus',
#   'et',
#   'ipse',
#   'trucidatione',
#   'muto'],
#  ['neque',
#   'quisquam',
#   'sum',
#   'stultus',
#   'quam#4',
#   'qualis',
#   'quidque',
#   'vivo',
#   'homo',
#   'sum',
#   'talis',
#   'existimo',
#   'sum',
#   'morior',
#   'immo',
#   'iam',
#   'mortuus'],
#  ['nam',
#   'uterus',
#   'quidem',
#   'quis#2',
#   'parvus',
#   'ad',
#   'res',
#   'pertineo',
#   'spiro',
#   'homo',
#   'possum',
#   'diduco',
#   'simul',
#   'atque',
#   'verus',
#   'ferrum',
#   'ad',
#   'praecordia',
#   'accedo',
#   'et',
#   'discindo',
#   'transverto',
#   'saepio',
#   'sum',
#   'quod',
#   'membrana',
#   'quidam',
#   'sum',
#   'quis#2',
#   'superus',
#   'pars',
#   'ab',
#   'inferus',
#   'diduco',
#   '(',
#   'diafragma',
#   'Graecus',
#   'voco',
#   ')',
#   'homo',
#   'anima',
#   'protinus',
#   'amitto',
#   'ita',
#   'mortuus',
#   'demum',
#   'praecordia',
#   'et',
#   'viscus',
#   'omnis',
#   'in',
#   'conspicio',
#   'latrocinor',
#   'medicus',
#   'do',
#   'utique#2',
#   'necesse',
#   'sum',
#   'talis',
#   'qualis',
#   'mortuus',
#   'sum',
#   'non',
#   'qualis',
#   'vivus',
#   'sum'],
#  ['itaque',
#   'consequor',
#   'medicus',
#   'ut',
#   'homo',
#   'crudeliter',
#   'iugulet',
#   'non',
#   'ut',
#   'scio',
#   'qualis',
#   'vivus',
#   'viscera',
#   'habeo'],
#  ['si',
#   'quis#2',
#   'tamen',
#   'sum',
#   'quod',
#   'adhuc',
#   'spiro',
#   'homo',
#   'conspectus',
#   'subicio',
#   'is',
#   'saepe',
#   'casus',
#   'offero',
#   'curo'],
#  ['interdum',
#   'enim',
#   'gladiator',
#   'in',
#   'harena',
#   'vel',
#   'milito',
#   'in',
#   'acies',
#   'vel',
#   'viator',
#   'ab',
#   'latro',
#   'excipio',
#   'sic',
#   'vulnerarius',
#   'ut',
#   'is',
#   'interior',
#   'aliquis',
#   'pars',
#   'aperio',
#   'et',
#   'in',
#   'alius',
#   'alius',
#   'ita',
#   'sedes',
#   'pono',
#   'ordo',
#   'figura',
#   'similiaque',
#   'alius',
#   'cognosco',
#   'prudens',
#   'medicus',
#   'non',
#   'caedes',
#   'sed',
#   'sanitas',
#   'molio',
#   'is',
#   'per',
#   'misericordia',
#   'disco',
#   'quod',
#   'alius',
#   'dirus',
#   'crudelitas',
#   'cognorint'],
#  ['ob',
#   'hic',
#   'ne#2',
#   'mortuus',
#   'quidem',
#   'lacerationem',
#   'necessarius',
#   'sum',
#   '(',
#   'quis#2',
#   'etsi',
#   'non',
#   'crudelis',
#   'tamen',
#   'foedus',
#   'sum',
#   ')',
#   'cum',
#   'alius',
#   'plerusque',
#   'in',
#   'mortuus',
#   'se',
#   'habeo',
#   'quantum',
#   'verus',
#   'in',
#   'vivus',
#   'cognosco',
#   'possum',
#   'ipse',
#   'curatio',
#   'ostendo'],
#  ['cum',
#   'hic',
#   'per',
#   'multus',
#   'volumen',
#   'per',
#   'magnus',
#   'contentio',
#   '[',
#   'disputatio',
#   ']',
#   'ab',
#   'medica',
#   'saepe',
#   'tracto',
#   'sum',
#   'atque',
#   'tracto',
#   'subicio',
#   'sum',
#   'quis#2',
#   'proximus',
#   'verus',
#   'video',
#   'possum'],
#  ['is',
#   'neque',
#   'addico',
#   'alterutri',
#   'opinio',
#   'sum',
#   'neque',
#   'ab',
#   'uterque',
#   'nimium',
#   'abhorreo',
#   'sed',
#   'medius',
#   'quodammodo',
#   'inter',
#   'diversus',
#   'sententia',
#   'quod',
#   'in',
#   'plurimus',
#   'contentio',
#   'deprehendo',
#   'licet',
#   'sine',
#   'ambitio',
#   'verus',
#   'scrutor',
#   'ut',
#   'in',
#   'hic',
#   'ipse',
#   'res'],
#  ['nam',
#   'quis#2',
#   'demum',
#   'causa',
#   'vel',
#   'secundus',
#   'valetudinem',
#   'praesto',
#   'vel',
#   'morbus',
#   'excito',
#   'quo',
#   'modus',
#   'spiritus',
#   'aut',
#   'cibus',
#   'vel',
#   'traho',
#   'vel',
#   'digero',
#   'ne#2',
#   'sapientia',
#   'quidem',
#   'professor',
#   'scientia',
#   'conprehendunt',
#   'sed',
#   'coniectura',
#   'persecuntur'],
#  ['quis',
#   'autem',
#   'reus',
#   'non',
#   'sum',
#   'certus',
#   'notitia',
#   'is',
#   'opinio',
#   'certus',
#   'reperio',
#   'remedium',
#   'non',
#   'possum'],
#  ['Verumque',
#   'sum',
#   'ad',
#   'ipse',
#   'curo',
#   'ratio',
#   'nihil',
#   'plus',
#   'confero',
#   'quam#4',
#   'experientia'],
#  ['quamquam',
#   'igitur',
#   'multus',
#   'sum',
#   'ad',
#   'ipse',
#   'ars',
#   'proprius',
#   'non',
#   'pertineo',
#   'tamen',
#   'is',
#   'adiuvant',
#   'excito',
#   'artifex',
#   'ingenium',
#   'itaque',
#   'iste',
#   'quoque',
#   'natura',
#   'res',
#   'contemplatio',
#   'quamvis',
#   'non',
#   'facio',
#   'medicus',
#   'aptus',
#   'tamen',
#   'medicina',
#   'reddo',
#   'perfectumque'],
#  ['Verique',
#   'similis',
#   'sum',
#   'et',
#   'Hippocraten',
#   'et',
#   'Erasistratum',
#   'et',
#   'quicumque',
#   'alius',
#   'non',
#   'contentus',
#   '[',
#   'sum',
#   ']',
#   'febres',
#   'et',
#   'ulcus',
#   'agito',
#   'res',
#   'quoque',
#   'natura',
#   'aliquis',
#   'pars',
#   'scrutor',
#   'sum',
#   'non',
#   'ideo',
#   'quidem',
#   'medicus',
#   'sum',
#   'verus',
#   'ideo',
#   'quoque',
#   'magnus',
#   'medicus',
#   'existo'],
#  ['ratio',
#   'verus',
#   'opus',
#   'sum',
#   'ipse',
#   'medicina',
#   'etsi',
#   'non',
#   'inter',
#   'obscurus',
#   'causa',
#   'neque',
#   'inter',
#   'naturalis',
#   'actio',
#   'tamen',
#   'saepe',
#   'sum',
#   'enim',
#   'hic',
#   'ars',
#   'coniecturalis'],
#  ['neque',
#   'respondeo',
#   'is',
#   'plerumque',
#   'non',
#   'solus',
#   'coniectura',
#   'sed',
#   'etiam',
#   'experientia',
#   'et',
#   'interdum',
#   'non',
#   'febris',
#   'non',
#   'cibus',
#   'non',
#   'somnus',
#   'subsequor',
#   'sicut',
#   'assuesco'],
#  ['rarus',
#   'sed',
#   'aliquando',
#   'morbus',
#   'quoque',
#   'ipse',
#   'novus',
#   'sum',
#   'quis#2',
#   'non',
#   'incido#2',
#   'manifeste',
#   'falsus',
#   'sum',
#   'cum',
#   'aetas',
#   'noster',
#   'quis#2',
#   'ex',
#   'naturalis',
#   'partus#2',
#   'caro',
#   'prolabor',
#   'et',
#   'areo',
#   'intro',
#   'paucus',
#   'hora',
#   'exspiraverit',
#   'sic',
#   'ut',
#   'nobilis',
#   'medicus',
#   'neque',
#   'genus',
#   'malus',
#   'neque',
#   'remedium',
#   'invenio'],
#  ['quis#2',
#   'ego',
#   'nihil',
#   'temptasse',
#   'iudico',
#   'quia',
#   'nemo',
#   'in',
#   'splendidus',
#   'persona',
#   'periclitari',
#   'coniectura',
#   'suus',
#   'volo',
#   'ne#2',
#   'occido',
#   'nisi',
#   'servo',
#   'video',
#   'verus',
#   'tamen',
#   'similis',
#   'sum',
#   'possum',
#   'aliquis',
#   'cogito',
#   'detraho',
#   'talis',
#   'verecundia',
#   'et',
#   'fortasse',
#   'respondeo',
#   'sum',
#   'is',
#   'quod',
#   'aliquis',
#   'sum',
#   'experior'],
#  ['ad',
#   'quod',
#   'medicina',
#   'genus',
#   'neque',
#   'semper',
#   'similitudo',
#   'aliquis',
#   'confero',
#   'et',
#   'si',
#   'quando',
#   'confero',
#   'tamen',
#   'is',
#   'ipse',
#   'rationalis',
#   'sum',
#   'inter',
#   'similis',
#   'genus',
#   'et',
#   'morbus',
#   'et',
#   'remedium',
#   'cogito',
#   'quo',
#   'potissimus',
#   'medicamentum',
#   'sum',
#   'utor'],
#  ['cum',
#   'igitur',
#   'talis',
#   'res',
#   'incido#2',
#   'medicus',
#   'aliquis',
#   'oportet',
#   'invenio',
#   'quod',
#   'non',
#   'utique#2',
#   'fortasse',
#   'sed',
#   'saepis',
#   'tamen',
#   'etiam',
#   'respondeo'],
#  ['peto',
#   'autem',
#   'novus',
#   'quisque',
#   'consilium',
#   'non',
#   'ab',
#   'res',
#   'lateo',
#   '(',
#   'iste',
#   'enim',
#   'dubius',
#   'et',
#   'incertus',
#   'sum',
#   ')',
#   'sed',
#   'ab',
#   'is',
#   'quis#2',
#   'explorari',
#   'possum',
#   'is',
#   'sum',
#   'evidentibus',
#   'causa'],
#  ['intersum',
#   'enim',
#   'fatigatio',
#   'morbus',
#   'an',
#   'sum',
#   'an',
#   'frigus',
#   'an',
#   'calor',
#   'an',
#   'vigilia',
#   'an',
#   'fames',
#   'facio',
#   'an',
#   'cibus',
#   'vinique',
#   'abundantia',
#   'an',
#   'intemperantia',
#   'libido'],
#  ['neque',
#   'ignoro',
#   'hic',
#   'oportet',
#   'quis#2',
#   'sum',
#   'aeger',
#   'natura',
#   'umidum',
#   'magis',
#   'an',
#   'magis',
#   'siccus',
#   'corpus',
#   'is',
#   'sum',
#   'validus',
#   'nervus',
#   'an',
#   'infirmis',
#   'frequens',
#   'adversus',
#   'valetudo',
#   'an',
#   'rarus',
#   'eaque',
#   'cum',
#   'sum',
#   'vehemens',
#   'sum',
#   'soleo',
#   'an',
#   'levis#2',
#   'brevis',
#   'an',
#   'longus',
#   'quod',
#   'is',
#   'vita',
#   'genus',
#   'sum',
#   'sequor',
#   'laboriosus',
#   'an',
#   'quiesco',
#   'cum',
#   'luxus#2',
#   'an',
#   'cum',
#   'frugalitate',
#   'ex',
#   'hic',
#   'enim',
#   'similibusque',
#   'saepe',
#   'curo',
#   'novus',
#   'ratio',
#   'duco',
#   'sum'],
#  ['quamvis',
#   'ne#2',
#   'hic',
#   'quidem',
#   'sic',
#   'praeteriri',
#   'debeo',
#   'quasi',
#   'nullus',
#   'controversia',
#   'recipio'],
#  ['nam',
#   'et',
#   'Erasistratus',
#   'non',
#   'ex',
#   'ille',
#   'causa',
#   'fio',
#   'morbus',
#   'dico#2',
#   'quoniam',
#   'et',
#   'alius',
#   'et',
#   'idem',
#   'alius',
#   'post',
#   'iste',
#   'non',
#   'febricito',
#   'et',
#   'quidam',
#   'medicus',
#   'saeculum',
#   'noster',
#   'sub',
#   'auctor',
#   'ut',
#   'ipse',
#   'video',
#   'volo#1',
#   'Themisone',
#   'contendo',
#   'nullus',
#   'causa',
#   'notitia',
#   'quisquam',
#   'ad',
#   'curatio',
#   'pertineo',
#   'satisque',
#   'sum',
#   'quidam',
#   'communis',
#   'morbus',
#   'intuor'],
#  ['siquidem',
#   'hic',
#   'tres',
#   'genus',
#   'sum',
#   'unus',
#   'adstringo',
#   'alter',
#   'fluo',
#   'tertius',
#   'misceo'],
#  ['nam',
#   'modus',
#   'parus',
#   'excerno',
#   'aeger',
#   'modus',
#   'nimium',
#   'modus',
#   'alius',
#   'pars',
#   'parus',
#   'alius',
#   'nimium',
#   'hic',
#   'autem',
#   'genus',
#   'morbus',
#   'modus',
#   'acutus',
#   'sum',
#   'modus',
#   'longus',
#   'et',
#   'modus',
#   'incresco',
#   'modus',
#   'consisto',
#   'modus',
#   'minuo'],
#  ['cognosco',
#   'igitur',
#   'is',
#   'quod',
#   'ex',
#   'hic',
#   'sum',
#   'si',
#   'corpus',
#   'adstringo',
#   'sum',
#   'digero',
#   'sum',
#   'si',
#   'profluvium',
#   'laboro',
#   'contineo',
#   'si',
#   'misceo',
#   'vitium',
#   'habeo',
#   'occurro',
#   'subinde',
#   'vehemens',
#   'malus'],
#  ['et',
#   'alius',
#   'acutus',
#   'morbus',
#   'medeor',
#   'alius',
#   'vetustus',
#   'alius',
#   'incresco',
#   'alius',
#   'subsistens',
#   'alius',
#   'iam',
#   'ad',
#   'sanitas',
#   'inclino'],
#  ['hic',
#   'observatio',
#   'medicina',
#   'sum',
#   'quam#4',
#   'ita',
#   'finio',
#   'ut',
#   'quasi',
#   'via',
#   'quidam',
#   'quam#4',
#   'meqodon',
#   'nomino',
#   'is',
#   'quis#2',
#   'in',
#   'morbus',
#   'communis',
#   'sum',
#   'contemplatricem',
#   'sum',
#   'contendo'],
#  ['atque',
#   'neque',
#   'rationalis',
#   'se',
#   'neque',
#   'experimentum',
#   'tantus',
#   'specto',
#   'adnumero',
#   'volo#1',
#   'cum',
#   'ab',
#   'ille',
#   'is',
#   'nomen',
#   'dissentio',
#   'quod',
#   'in',
#   'coniectura',
#   'res',
#   'lateo',
#   'nolo',
#   'sum',
#   'medicina',
#   'ab',
#   'hic',
#   'is',
#   'quod',
#   'parus',
#   'ars',
#   'sum',
#   'in',
#   'observatio',
#   'experimentum',
#   'credo'],
#  ['quod',
#   'ad',
#   'Erasistratum',
#   'pertineo',
#   'primus',
#   'ipse',
#   'evidentia',
#   'is',
#   'opinio',
#   'repugno',
#   'quia',
#   'rarus',
#   'nisi',
#   'post',
#   'hic',
#   'aliquis',
#   'morbus',
#   'venio',
#   'deinde',
#   'non',
#   'sequor',
#   'ut',
#   'quod',
#   'alius',
#   'non',
#   'adficit',
#   'aut',
#   'idem',
#   'alius',
#   'is',
#   'ne#2',
#   'alter',
#   'quidem',
#   'aut',
#   'idem',
#   'tempus',
#   'alius',
#   'noceo'],
#  ['possum',
#   'enim',
#   'quidam',
#   'subsum',
#   'corpus',
#   'vel',
#   'ex',
#   'infirmitas',
#   'is',
#   'vel',
#   'ex',
#   'aliquis',
#   'afficio',
#   'quis#2',
#   'vel',
#   'in',
#   'alius',
#   'non',
#   'sum',
#   'vel',
#   'in',
#   'hic',
#   'alius',
#   'non',
#   'sum',
#   'eaque',
#   'per',
#   'se',
#   'non',
#   'tantus',
#   'ut',
#   'concito',
#   'morbus',
#   'tamen',
#   'obnoxius',
#   'magis',
#   'alius',
#   'inuria',
#   'corpus',
#   'efficio'],
#  ['quod',
#   'si',
#   'contemplatio',
#   'res',
#   'natura',
#   'quam#4',
#   'temere',
#   'medicus',
#   'iste',
#   'se',
#   'vindico',
#   'satis',
#   'comprehendo',
#   'etiam',
#   'ille',
#   'scisset',
#   'nihil',
#   'omnino',
#   'ob',
#   'unus',
#   'causa',
#   'fio',
#   'sed',
#   'is',
#   'pro',
#   'causa',
#   'adprehendo',
#   'quod',
#   'confero',
#   'plurimus',
#   'video'],
#  ['possum',
#   'autem',
#   'is',
#   'dum',
#   'solus',
#   'sum',
#   'non',
#   'moveo',
#   'quod',
#   'jungo',
#   'alius',
#   'multus',
#   'moveo'],
#  ['accedo',
#   'ad',
#   'hic',
#   'quod',
#   'ne#2',
#   'ipse',
#   'quidem',
#   'Erasistratus',
#   'quis#2',
#   'transfundo',
#   'in',
#   'arteria',
#   'sanguis',
#   'febrem',
#   'fio',
#   'dico#2',
#   'is',
#   'nimis',
#   'repleto',
#   'corpus',
#   'incido#2',
#   'reperio',
#   'cur',
#   'ex',
#   'duo',
#   'aequus',
#   'repleo',
#   'alter',
#   'in',
#   'morbus',
#   'incido',
#   'alter',
#   'omnis',
#   'periculum',
#   'vaco',
#   'quod',
#   'cottidie',
#   'fio',
#   'appareo'],
#  ['ex',
#   'quo',
#   'discus',
#   'possum',
#   'ut',
#   'verus',
#   'sum',
#   'ille',
#   'transfusio',
#   'tamen',
#   'ille',
#   'non',
#   'per',
#   'se',
#   'cum',
#   'plenus',
#   'corpus',
#   'sum',
#   'fio',
#   'sed',
#   'cum',
#   'hic',
#   'aliquis',
#   'accedo'],
#  ['Themisonis',
#   'verus',
#   'aemulus',
#   'si',
#   'perpetuus',
#   'quis#2',
#   'promitto',
#   'habeo',
#   'magis',
#   'etiam',
#   'quam#4',
#   'ullus',
#   'rationalis',
#   'sum'],
#  ['neque',
#   'enim',
#   'si',
#   'quis#2',
#   'non',
#   'omnis',
#   'teneo',
#   'quis#2',
#   'rationalis',
#   'alius',
#   'probo',
#   'protinus',
#   'alius',
#   '[',
#   'novus',
#   ']',
#   'nomen',
#   'ars',
#   'indigeo',
#   'si',
#   'modus',
#   '(',
#   'quod',
#   'primus',
#   'sum',
#   ')',
#   'non',
#   'memoria',
#   'solus',
#   'sed',
#   'ratio',
#   'quoque',
#   'insisto'],
#  ['si',
#   'verus',
#   'quod',
#   'propius',
#   'sum',
#   'vix',
#   'ullus',
#   'perpetuus',
#   'praeceptum',
#   'medicinalis',
#   'ars',
#   'recipio',
#   'idem',
#   'sum',
#   'quod',
#   'is',
#   'quos',
#   'experimentum',
#   'solus',
#   'sustineo',
#   'is',
#   'magis',
#   'quoniam',
#   'conpremo',
#   'aliquis',
#   'morbus',
#   'an',
#   'fundo#2',
#   'quilibet',
#   'etiam',
#   'inperitissimus',
#   'video',
#   'quis#2',
#   'autem',
#   'conpremo',
#   'corpus',
#   'resolvo',
#   'quis#2',
#   'solvo',
#   'teneo',
#   'si',
#   'ab',
#   'ratio',
#   'traho',
#   'sum',
#   'rationalis',
#   'sum',
#   'medicus',
#   'si',
#   'ut',
#   'is',
#   'quis#2',
#   'se',
#   'rationalis',
#   'nego',
#   'confiteor',
#   'necesse',
#   'sum',
#   'ab',
#   'experientia',
#   'empericus'],
#  ['ita',
#   'apud',
#   'is',
#   'morbus',
#   'cognitio',
#   'extra',
#   'ars',
#   'medicina',
#   'intro',
#   'usus',
#   'sum',
#   'neque',
#   'adicio',
#   'quisquam',
#   'empericorum',
#   'professio',
#   'sed',
#   'demptum',
#   'sum',
#   'quoniam',
#   'ille',
#   'multus',
#   'circumspicio',
#   'hic',
#   'tantus',
#   'facilis',
#   'et',
#   'non',
#   'plus',
#   'quam#4',
#   'vulgarius'],
#  ['nam',
#   'et',
#   'is',
#   'quis#2',
#   'pecus',
#   'atque',
#   'iumentum',
#   'medentur',
#   'cum',
#   'proprius',
#   'quisque',
#   'ex',
#   'mutus',
#   'animal',
#   'nosco',
#   'non',
#   'possum',
#   'communis',
#   'tantummodo',
#   'insisto',
#   'et',
#   'exterae',
#   'gens',
#   'cum',
#   'suptilem',
#   'medicina',
#   'ratio',
#   'non',
#   'nosco',
#   'communis',
#   'tantus',
#   'video',
#   'et',
#   'quis#2',
#   'amplus',
#   'valetudinarius',
#   'nutrio',
#   'quia',
#   'singulus',
#   'summa',
#   'cura',
#   'consulo',
#   'non',
#   'sustineo',
#   'ad',
#   'communis',
#   'iste',
#   'confugio'],
#  ['neque',
#   'Hercules',
#   'iste',
#   'antiquus',
#   'medicus',
#   'nescio',
#   'sed',
#   'hic',
#   'contentus',
#   'non',
#   'sum'],
#  ['ergo',
#   'etiam',
#   'vetustus',
#   'auctor',
#   'Hippocrates',
#   'dico#2',
#   'mederi',
#   'oportet',
#   'et',
#   'communis',
#   'et',
#   'proprius',
#   'intuo'],
#  ['atque',
#   'ne#2',
#   'iste',
#   'quidem',
#   'ipse',
#   'intro',
#   'suus',
#   'professio',
#   'consisto',
#   'ullus',
#   'modus',
#   'possum',
#   'siquidem',
#   'et',
#   'conpremo',
#   'et',
#   'fluo',
#   'morbus',
#   'genus',
#   'diversus',
#   'sum',
#   'faciliusque',
#   'is',
#   'in',
#   'is',
#   'quis#2',
#   'fluo',
#   'inspicium',
#   'possum'],
#  ['alius',
#   'sum',
#   'enim',
#   'sanguis',
#   'alius',
#   'bilem',
#   'alius',
#   'cibus',
#   'vomo',
#   'alius',
#   'deiectionibus',
#   'alius',
#   'torminibus',
#   'laboro',
#   'alius',
#   'sudor',
#   'digeri',
#   'alius',
#   'tabe',
#   'consumi'],
#  ['atque',
#   'in',
#   'pars',
#   'quoque',
#   'umor',
#   'erumpo',
#   'ut',
#   'oculus',
#   'aurisque',
#   'quo',
#   'periculum',
#   'nullus',
#   'humanus',
#   'membrum',
#   'vaco'],
#  ['nihil', 'autem', 'hic', 'sic', 'ut', 'alius', 'curo'],
#  ['ita',
#   'protinus',
#   'in',
#   'hic',
#   'ab',
#   'communis',
#   'fluentum',
#   'morbus',
#   'contemplatio',
#   'ad',
#   'proprius',
#   'medicina',
#   'descendo'],
#  ['atque',
#   'in',
#   'hic',
#   'quoque',
#   'rursus',
#   'alius',
#   'proprietas',
#   'notitia',
#   'saepe',
#   'necessarius',
#   'sum',
#   'quia',
#   'non',
#   'idem',
#   'omnis',
#   'etiam',
#   'in',
#   'similis',
#   'casus',
#   'opitulo',
#   'siquidem',
#   'certus',
#   'quidam',
#   'res',
#   'sum',
#   'quis#2',
#   'in',
#   'multus',
#   'venter',
#   'aut',
#   'adstringo',
#   'aut',
#   'resolvo'],
#  ['invenio',
#   'tamen',
#   'in',
#   'quis#2',
#   'alius',
#   'atque',
#   'in',
#   'ceterus',
#   'idem',
#   'evenio',
#   'in',
#   'hic',
#   'ergo',
#   'communis',
#   'inspectio',
#   'contrarius',
#   'sum',
#   'proprius',
#   'tantus',
#   'salutaris'],
#  ['et', 'causa', 'quoque', 'aestimatio', 'saepe', 'morbus', 'solvo'],
#  ['ergo',
#   'etiam',
#   'ingeniosus',
#   'saeculum',
#   'noster',
#   'medicus',
#   'quis#2',
#   'nuper',
#   'video',
#   'Cassius',
#   'febricito',
#   'quidam',
#   'et',
#   'magnus',
#   'sitis',
#   'afficio',
#   'cum',
#   'post',
#   'ebrietas',
#   'is',
#   'premo',
#   'coepio',
#   'cognosset',
#   'aqua',
#   'frigida',
#   'ingessit',
#   'qui',
#   'ille',
#   'epotus',
#   'cum',
#   'vinum',
#   'vis',
#   'misceo',
#   'frango',
#   'protinus',
#   'febrem',
#   'somnus',
#   'et',
#   'sudor',
#   'discussit'],
#  ['quod',
#   'auxilium',
#   'medicus',
#   'opportunus',
#   'provideo',
#   'non',
#   'ex',
#   'is',
#   'quod',
#   'aut',
#   'adstringo',
#   'corpus',
#   'sum',
#   'aut',
#   'fluo',
#   'sed',
#   'ex',
#   'is',
#   'causa',
#   'quis#2',
#   'ante',
#   'praecedo'],
#  ['sum',
#   'etiam',
#   'proprius',
#   'aliquis',
#   'et',
#   'locus',
#   'et',
#   'tempus',
#   'iste',
#   'quoque',
#   'auctor',
#   'quis#2',
#   'cum',
#   'disputo',
#   'quemadmodum',
#   'sanus',
#   'homo',
#   'ago',
#   'sum',
#   'praecipio',
#   'ut',
#   'gravis',
#   'aut',
#   'locus',
#   'aut',
#   'tempus',
#   'magis',
#   'vito',
#   'frigus',
#   'aestus',
#   'satietas',
#   'labor',
#   'libido',
#   'magisque',
#   'ut',
#   'conquiesco',
#   'idem',
#   'locus',
#   'aut',
#   'tempus',
#   'si',
#   'quis#2',
#   'gravitas',
#   'corpus',
#   'sentio',
#   'atque',
#   'neque',
#   'vomitus',
#   'stomachus',
#   'neque',
#   'purgatio',
#   'alvus',
#   'sollicito'],
#  ['qui',
#   'verus',
#   'quidem',
#   'sum',
#   'ab',
#   'communis',
#   'tamen',
#   'ad',
#   'quidam',
#   'proprius',
#   'descendo',
#   'nisi',
#   'persuadeo',
#   'nos',
#   'volo#1',
#   'sanus',
#   'quidem',
#   'considero',
#   'sum',
#   'quod',
#   'caelum',
#   'quod',
#   'tempus',
#   'annus',
#   'sum',
#   'aegrum',
#   'verus',
#   'non',
#   'sum',
#   'quis#2',
#   'tanto',
#   'magis',
#   'omnis',
#   'observatio',
#   'necessarius',
#   'sum',
#   'quantus',
#   'magis',
#   'obnoxius',
#   'offensum',
#   'infirmitas',
#   'sum'],
#  ['quin',
#   'etiam',
#   'morbus',
#   'in',
#   'idem',
#   'homo',
#   'alius',
#   'atque',
#   'alius',
#   'proprietas',
#   'sum',
#   'et',
#   'quis#2',
#   'secundus',
#   'aliquando',
#   'frustra',
#   'curo',
#   'sum',
#   'contrarius',
#   'saepe',
#   'restituo'],
#  ['Plurimaque',
#   'in',
#   'do',
#   'cibus',
#   'discrimen',
#   'reperio',
#   'ex',
#   'quis#2',
#   'contendo',
#   'unus',
#   'sum'],
#  ['nam',
#   'fames',
#   'facilis',
#   'adulescens',
#   'quam#4',
#   'puer',
#   'facilis',
#   'in',
#   'densus',
#   'caelum',
#   'quam#4',
#   'in',
#   'tenuis',
#   'facilis',
#   'hiem(p)s',
#   'quam#4',
#   'aestas',
#   'facilis',
#   'unus',
#   'cibus',
#   'quam#4',
#   'prandium',
#   'quoque',
#   'assuesco',
#   'facilis',
#   'inexercitatus',
#   'quam#4',
#   'exercito',
#   'homo',
#   'sustineo',
#   'saepe',
#   'autem',
#   'in',
#   'is',
#   'magis',
#   'necessarius',
#   'cibus',
#   'festinatio',
#   'sum',
#   'quis#2',
#   'parvus',
#   'inedia',
#   'tolero'],
#  ['ob',
#   'quis#2',
#   'conicio',
#   'is',
#   'quis#2',
#   'proprius',
#   'non',
#   'nosco',
#   'communis',
#   'tantus',
#   'debeo',
#   'intuor',
#   'is',
#   'quis#2',
#   'nosco',
#   'proprietas',
#   'possum',
#   'non',
#   'ille',
#   'quidem',
#   'oportet',
#   'neglego',
#   'sed',
#   'hic',
#   'quoque',
#   'insisto',
#   'ideoque',
#   'cum',
#   'par',
#   'scientia',
#   'sum',
#   'utilis',
#   'tamen',
#   'medicus',
#   'sum',
#   'amicus',
#   'quam#4',
#   'extraneus'],
#  ['igitur',
#   'ut',
#   'ad',
#   'propono',
#   'meus',
#   'redeo',
#   'rationalis',
#   'quidem',
#   'puto',
#   'medicina',
#   'sum',
#   'debeo',
#   'instrui',
#   'verus',
#   'ab',
#   'evidentibus',
#   'causa',
#   'obscurus',
#   'omnis',
#   'non',
#   'ab',
#   'cogitatio',
#   'artifex',
#   'sed',
#   'ab',
#   'ipse',
#   'ars',
#   'reiectis'],
#  ['incido#2',
#   'autem',
#   'vivus',
#   'corpus',
#   'et',
#   'crudelis',
#   'et',
#   'supervacuus',
#   'sum',
#   'mortuus',
#   'disco',
#   'necessarius',
#   'namque',
#   'pono',
#   'et',
#   'ordo',
#   'nosco',
#   'debeo',
#   'quis#2',
#   'cadaver',
#   'melius',
#   'quam#4',
#   'vivus',
#   'et',
#   'vulnero',
#   'homo',
#   'repraesento',
#   '[',
#   'n',
#   ']',
#   't'],
#  ['sed',
#   'et',
#   'ceterus',
#   'quis#2',
#   'modus',
#   'in',
#   'vivus',
#   'cognosco',
#   'possum',
#   'in',
#   'ipse',
#   'curatio',
#   'vulnero',
#   'paulum',
#   'tardus',
#   'sed',
#   'aliquantus',
#   'mitis',
#   'usus',
#   'ipse',
#   'monstro'],
#  ['hic',
#   'propositum',
#   'primus',
#   'dico#2',
#   'quemadmodum',
#   'sanus',
#   'ago',
#   'convenio',
#   'tum',
#   'ad',
#   'is',
#   'transibo',
#   'quis#2',
#   'ad',
#   'morbus',
#   'curationesque',
#   'is',
#   'pertineo'],
#  ['sanus',
#   'homo',
#   'quis#2',
#   'et',
#   'bene',
#   'valeo',
#   'et',
#   'suus',
#   'spontis',
#   'sum',
#   'nullus',
#   'obligo',
#   'se',
#   'lex',
#   'debeo',
#   'atque',
#   'neque',
#   'medicus',
#   'neque',
#   'iatroalipta',
#   'egeo'],
#  ['hic',
#   'oportet',
#   'varius',
#   'habeo',
#   'vita',
#   'genus',
#   'modus',
#   'rus',
#   'sum',
#   'modus',
#   'in',
#   'urbs',
#   'saepiusque',
#   'in',
#   'ager',
#   'navigo',
#   'venari',
#   'quiesco',
#   'interdum',
#   'sed',
#   'frequens',
#   'se',
#   'exerceo',
#   'siquidem',
#   'ignavia',
#   'corpus',
#   'hebeto',
#   'labor',
#   'firmo',
#   'ille',
#   'maturus',
#   'senectus',
#   'hic',
#   'longus',
#   'adulescentia',
#   'reddo'],
#  ['prosum',
#   'etiam',
#   'interdum',
#   'balineo',
#   'interdum',
#   'aqua',
#   'frigidum',
#   'uti',
#   'modus',
#   'unguis',
#   'modus',
#   'is',
#   'ipse',
#   'neglego',
#   'nullus',
#   'genus',
#   'cibus',
#   'fugio',
#   'quo',
#   'populus',
#   'utor',
#   'interdum',
#   'in',
#   'convictus',
#   'sum',
#   'interdum',
#   'ab',
#   'is',
#   'se',
#   'retraho',
#   'modus',
#   'plus',
#   'iustus',
#   'modus',
#   'non',
#   'amplus',
#   'adsumo',
#   'bis',
#   'dies',
#   'potius',
#   'quam#4',
#   'semel',
#   'cibus',
#   'capio',
#   'et',
#   'semper',
#   'quam#4',
#   'plurimus',
#   'dummodo',
#   'hic',
#   'concoquo'],
#  ['sed',
#   'ut',
#   'hic',
#   'genus',
#   'exercitatio',
#   'cibique',
#   'necessaria',
#   'sum',
#   'sic',
#   'athleticus',
#   'supervacuus',
#   'namque',
#   'et',
#   'intermissus',
#   'propter',
#   'civilis',
#   'aliqui',
#   'necessitas',
#   'ordo',
#   'exercitatio',
#   'corpus',
#   'adfligit',
#   'et',
#   'is',
#   'corpus',
#   'quis#2',
#   'mos',
#   'is',
#   'repleo',
#   'sum',
#   'celeriter',
#   'et',
#   'senesco',
#   'et',
#   'aegroto'],
#  ['concubitus',
#   'verus',
#   'neque',
#   'nimis',
#   'concupisco',
#   'neque',
#   'nimis',
#   'pertimesco',
#   'sum'],
#  ['rarus', 'corpus', 'excito', 'frequens', 'solvo'],
#  ['cum',
#   'autem',
#   'frequens',
#   'non',
#   'numerus',
#   'sum',
#   'sed',
#   'natura',
#   'ratio',
#   'aetas',
#   'et',
#   'corpus',
#   'scio',
#   'licet',
#   'is',
#   'non',
#   'inutilis',
#   'sum',
#   'quis#2',
#   'corpus',
#   'neque',
#   'languor',
#   'neque',
#   'dolor',
#   'sequor'],
#  ['idem',
#   'interdiu',
#   'malus',
#   'sum',
#   'noctu',
#   'tueor',
#   'ita',
#   'tamen',
#   'si',
#   'neque',
#   'ille',
#   'cibus',
#   'neque',
#   'hic',
#   'cum',
#   'vigilia',
#   'labor',
#   'statim',
#   'sequor'],
#  ['hic',
#   'firmus',
#   'servo',
#   'sum',
#   'cavendumque',
#   'ne#2',
#   'in',
#   'secundus',
#   'valetudine',
#   'adversus',
#   'praesidium',
#   'consumo'],
#  ['at',
#   'INBECILLIS',
#   'quo',
#   'in',
#   'numerus',
#   'magnus',
#   'pars',
#   'urbanus',
#   'omnesque',
#   'paene',
#   'cupidus',
#   'litterae',
#   'sum',
#   'observatio',
#   'magnus',
#   'necessarius',
#   'sum',
#   'ut',
#   'quod',
#   'vel',
#   'corpus',
#   'vel',
#   'locus',
#   'vel',
#   'studium',
#   'ratio',
#   'detraho',
#   'cura',
#   'restituo'],
#  ['ex',
#   'hic',
#   'igitur',
#   'quis#2',
#   'bene',
#   'concoxit',
#   'mane',
#   'tuto',
#   'surgo',
#   'quis#2',
#   'parus',
#   'quiesco',
#   'debeo',
#   'et',
#   'si',
#   'mane',
#   'surgo',
#   'necessitas',
#   'sum',
#   'redormire',
#   'quis#2',
#   'non',
#   'concoxit',
#   'ex',
#   'totus#2',
#   'conquiesco',
#   'atque',
#   'neque',
#   'labor',
#   'se',
#   'neque',
#   'exercitatio',
#   'neque',
#   'negotium',
#   'credo'],
#  ['qui',
#   'crudus',
#   'sine',
#   'praecordiorum',
#   'dolor',
#   'ructo',
#   'is',
#   'ex',
#   'intervallum',
#   'aqua',
#   'frigida',
#   'bibo',
#   'et',
#   'se',
#   'nihilum',
#   'parvus',
#   'contineo'],
#  ['habito',
#   'verus',
#   'aedificium',
#   'lucidus',
#   'perflo',
#   'aestivus',
#   'hibernum',
#   'sol',
#   'habeo',
#   'caveo',
#   'meridianus',
#   'sol',
#   'matutinum',
#   'et',
#   'vespertinus',
#   'frigus',
#   'item',
#   'aura',
#   'flumen',
#   'atque',
#   'stagnum',
#   'minimeque',
#   'nubilum',
#   'caelum',
#   'solus',
#   'aperio',
#   'se',
#   'committo',
#   'ne#2',
#   'modus',
#   'frigus',
#   'modus',
#   'calor',
#   'moveo',
#   'quis#2',
#   'res',
#   'multus',
#   'gravedines',
#   'destillationesque',
#   'concito'],
#  ['magis',
#   'verus',
#   'gravis',
#   'locus',
#   'iste',
#   'servo',
#   'sum',
#   'in',
#   'quis#2',
#   'etiam',
#   'pestilentia',
#   'facio'],
#  ['scio',
#   'autem',
#   'licet',
#   'integer',
#   'corpus',
#   'sum',
#   'quo',
#   'dies',
#   'mane',
#   'urina',
#   'albus',
#   'deinde',
#   'rufus',
#   'sum',
#   'ille',
#   'concoquo',
#   'hic',
#   'concoxisse',
#   'significo'],
#  ['ubi',
#   'expergiscor',
#   'sum',
#   'aliquis',
#   'paul(l)um',
#   'intermitto',
#   'deinde',
#   'nisi',
#   'hiem(p)s',
#   'sum',
#   'foveo',
#   'os#2',
#   'multus',
#   'aqua',
#   'frigidus',
#   'debeo',
#   'longus',
#   'dies',
#   'meridiari',
#   'potius',
#   'ante',
#   'cibus',
#   'si',
#   'parvus',
#   'pos',
#   'is'],
#  ['per',
#   'hiems',
#   'potissimus',
#   'totus',
#   'nox',
#   'conquiesco',
#   'sin',
#   'lucubrandum',
#   'sum',
#   'non',
#   'post',
#   'cibus',
#   'is',
#   'facio',
#   'sed',
#   'post',
#   'concoctio'],
#  ['quis#2',
#   'interdiu',
#   'vel',
#   'domesticus',
#   'vel',
#   'civilis',
#   'officium',
#   'teneo',
#   'hic',
#   'tempus',
#   'aliquot',
#   'servo',
#   'curatio',
#   'corpus',
#   'suus',
#   'sum'],
#  ['primus',
#   'autem',
#   'is',
#   'curatio',
#   'exercitatio',
#   'sum',
#   'quis#2',
#   'semper',
#   'antecedo',
#   'cibus',
#   'debeo',
#   'in',
#   'is',
#   'quis#2',
#   'parvus',
#   'laboro',
#   'et',
#   'bene',
#   'concoxit',
#   'amplus',
#   'in',
#   'is',
#   'quis#2',
#   'fatigo',
#   'sum',
#   'et',
#   'parvus',
#   'concoxit',
#   'remitto'],
#  ['commode',
#   'verus',
#   'exerceo',
#   'clarus',
#   'lectio',
#   'arma',
#   'pila',
#   'cursus',
#   'ambulatio',
#   'atque',
#   'hic',
#   'non',
#   'utique#2',
#   'plana',
#   'commodus',
#   'sum',
#   'siquidem',
#   'melius',
#   'ascensus',
#   'quoque',
#   'et',
#   'descensus',
#   'cum',
#   'quidam',
#   'varietas',
#   'corpus',
#   'moveo',
#   'nisi',
#   'tamen',
#   'is',
#   'perquam',
#   'inbecillum',
#   'sum',
#   'bonus',
#   'autem',
#   'sum',
#   'sub',
#   'divus',
#   'quam#4',
#   'in',
#   'porticus',
#   'bonus',
#   'si',
#   'caput',
#   'patior',
#   'in',
#   'sol',
#   'quam#4',
#   'in',
#   'umbra',
#   'bonus',
#   'in',
#   'umbra',
#   'quam#4',
#   'pario',
#   'aut',
#   'viridis',
#   'efficio',
#   'quam#4',
#   'quis#2',
# ...
#   'accessio',
#   'continuo',
#   'protinus',
#   'inclino',
#   'prior',
#   'do',
#   'cibus',
#   'sum'],
#  ['etenim',
#   'perpetuus',
#   'sum',
#   'ad',
#   'quod',
#   'omnis',
#   'consilium',
#   'dirigo',
#   'possum',
#   'cibus',
#   'quam#4',
#   'multus',
#   'semper',
#   'ab',
#   'accessio',
#   'sum',
#   'reduco',
#   'et',
#   'hic',
#   'salvus',
#   'do',
#   'quam#4',
#   'integer',
#   'corpus'],
#  ['quod',
#   'non',
#   'inter',
#   'duo',
#   'tantus',
#   'sed',
#   'etiam',
#   'inter',
#   'multus',
#   'accessio',
#   'servo'],
#  ['sed',
#   'cum',
#   'sum',
#   'aptus',
#   'tertius',
#   'quoque',
#   'dies',
#   'cibus',
#   'do',
#   'tamen',
#   'si',
#   'corpus',
#   'infirmus',
#   'sum',
#   'cottidie',
#   'do',
#   'sum',
#   'multoque',
#   'magis',
#   'si',
#   'continens',
#   'febres',
#   'sine',
#   'remissio',
#   'sum',
#   'quantus',
#   'magis',
#   'corpus',
#   'affligo',
#   'aut',
#   'si',
#   'duo',
#   'pluresve',
#   'accessio',
#   'idem',
#   'dies',
#   'venio'],
#  ['qui',
#   'res',
#   'efficio',
#   'ut',
#   'et',
#   'ab',
#   'primus',
#   'dies',
#   'protinus',
#   'cibus',
#   'do',
#   'cottidie',
#   'debeo',
#   'si',
#   'protinus',
#   'vena',
#   'concido#2',
#   'et',
#   'saepis',
#   'idem',
#   'dies',
#   'si',
#   'inter',
#   'multus',
#   'accessio',
#   'subinde',
#   'volo#1',
#   'corpus',
#   'desum'],
#  ['ille',
#   'tamen',
#   'in',
#   'hic',
#   'servo',
#   'sum',
#   'ut',
#   'post',
#   'is',
#   'febres',
#   'parvus',
#   'cibus',
#   'do',
#   'post',
#   'quis#2',
#   'si',
#   'per',
#   'corpus',
#   'licet',
#   'omnino',
#   'non',
#   'do'],
#  ['cum',
#   'verus',
#   'febris',
#   'insto',
#   'incipio',
#   'augeo',
#   'consisto',
#   'decedo',
#   'deinde',
#   'in',
#   'decessio',
#   'consisto',
#   'aut',
#   'finio',
#   'scio',
#   'licet',
#   'bonus',
#   'cibus',
#   'tempus',
#   'sum',
#   'febre',
#   'finio',
#   'deinde',
#   'cum',
#   'decessio',
#   'is',
#   'consisto',
#   'tertius',
#   'si',
#   'necesse',
#   'sum',
#   'quandocumque',
#   'decedo',
#   'ceterus',
#   'omnis',
#   'periculosus',
#   'sum'],
#  ['si',
#   'tamen',
#   'propter',
#   'infirmitas',
#   'necessitas',
#   'urgeo',
#   'sero',
#   'sum',
#   'consisto',
#   'iam',
#   'incrementum',
#   'febris',
#   'aliquis',
#   'offero',
#   'quam#4',
#   'incresco',
#   'sero',
#   'sum',
#   'insto',
#   'quam#4',
#   'incipio',
#   'cum',
#   'is',
#   'tamen',
#   'ut',
#   'nullus',
#   'tempus',
#   'is',
#   'quis#2',
#   'deficio',
#   'non',
#   'sum',
#   'sustineo'],
#  ['neque',
#   'Hercules',
#   'satis',
#   'sum',
#   'ipse',
#   'tantus',
#   'febres',
#   'medicus',
#   'intuor',
#   'sed',
#   'etiam',
#   'totus',
#   'corpus',
#   'habitus',
#   'et',
#   'ad',
#   'is',
#   'derigeo',
#   'curatio',
#   'sive',
#   'supersunt',
#   'vis',
#   'sive',
#   'desum',
#   'sive',
#   'quidam',
#   'alius',
#   'afficio',
#   'intervenio'],
#  ['cum',
#   'verus',
#   'semper',
#   'aeger',
#   'securus',
#   'ago',
#   'convenio',
#   'ut',
#   'corpus',
#   'tantus',
#   'non',
#   'etiam',
#   'animus',
#   'laboro',
#   'tum',
#   'praecipuus',
#   'ubi',
#   'cibus',
#   'sumo'],
#  ['itaque',
#   'si',
#   'qui',
#   'sum',
#   'quis#2',
#   'exaspero',
#   'is',
#   'animus',
#   'sum',
#   'bonus',
#   'sum',
#   'is',
#   'dum',
#   'aegroto',
#   'is',
#   'notitia',
#   'subtraho',
#   'si',
#   'is',
#   'fio',
#   'non',
#   'possum',
#   'sustineo',
#   'tamen',
#   'post',
#   'cibus',
#   'usque',
#   'somnus',
#   'tempus',
#   'et',
#   'cum',
#   'expergiscor',
#   'sum',
#   'tum',
#   'expono'],
#  ['sed',
#   'de',
#   'cibus',
#   'quidem',
#   'facilis',
#   'cum',
#   'aegrum',
#   'ratio',
#   'sum',
#   'quis#2',
#   'saepe',
#   'stomachus',
#   'hic',
#   'respuo',
#   'etiamsi',
#   'mens',
#   'concupisco',
#   'de',
#   'potio',
#   'verus',
#   'ingens',
#   'pugna',
#   'sum',
#   'eoque',
#   'magis',
#   'quo',
#   'magnus',
#   'febris',
#   'sum'],
#  ['hic',
#   'enim',
#   'sitis',
#   'accendo',
#   'et',
#   'tum',
#   'multus',
#   'aqua',
#   'exigo',
#   'cum',
#   'ille',
#   'periculosus',
#   'sum'],
#  ['sed',
#   'doceo',
#   'aeger',
#   'sum',
#   'ubi',
#   'febris',
#   'quierit',
#   'protinus',
#   'sitis',
#   'quoque',
#   'quiesco',
#   'longioremque',
#   'accessio',
#   'sum',
#   'si',
#   'quod',
#   'is',
#   'do',
#   'sum',
#   'alimentum',
#   'ita',
#   'celeriter',
#   'is',
#   'desino',
#   'sitio',
#   'quis#2',
#   'non',
#   'bibo'],
#  ['necesse',
#   'sum',
#   'tamen',
#   'quantus',
#   'facilis',
#   'etiam',
#   'sanus',
#   'fames',
#   'quam#4',
#   'sitis',
#   'sustineo',
#   'tanto',
#   'magis',
#   'aegrum',
#   'in',
#   'potio',
#   'quam#4',
#   'in',
#   'cibus',
#   'indulgeo'],
#  ['sed',
#   'primus',
#   'quidem',
#   'dies',
#   'nullus',
#   'umor',
#   'do',
#   'debeo',
#   'nisi',
#   'subito',
#   'sic',
#   'vena',
#   'cado',
#   'ut',
#   'cibus',
#   'quoque',
#   'do',
#   'debeo',
#   'secundus',
#   'verus',
#   'ceterisque',
#   'etiam',
#   'quis#2',
#   'cibus',
#   'non',
#   'do',
#   'tamen',
#   'si',
#   'magnus',
#   'sum',
#   'urgeo',
#   'potio',
#   'do',
#   'debeo'],
#  ['atque',
#   'ne#2',
#   'ille',
#   'quidem',
#   'ab',
#   'Heraclida',
#   'Tarentinus',
#   'dico#2',
#   'ratio',
#   'careo',
#   'ubi',
#   'aut',
#   'bilis',
#   'aegrum',
#   'aut',
#   'cruditas',
#   'male',
#   'habeo',
#   'expedio',
#   'quoque',
#   'per',
#   'modicus',
#   'potio',
#   'misceo',
#   'novus',
#   'materia',
#   'corruptus'],
#  ['ille',
#   'video',
#   'sum',
#   'ut',
#   'qualis',
#   'tempus',
#   'cibus',
#   'lego#2',
#   'talis',
#   'potioni',
#   'quoque',
#   'ubi',
#   'sine',
#   'ille',
#   'do',
#   'deligo',
#   'aut',
#   'cum',
#   'aegrum',
#   'dormio',
#   'cupio',
#   'quod',
#   'ferus',
#   'sum',
#   'prohibeo'],
#  ['satis',
#   'autem',
#   'convenio',
#   'cum',
#   'omnis',
#   'febricito',
#   'nimius',
#   'umor',
#   'alienus',
#   'sum',
#   'tum',
#   'praecipuus',
#   'sum',
#   'femina',
#   'quis#2',
#   'ex',
#   'partus',
#   'in',
#   'febres',
#   'incido'],
#  ['sed',
#   'cum',
#   'tempus',
#   'cibus',
#   'potionique',
#   'febris',
#   'et',
#   'remissio',
#   'ratio',
#   'do',
#   'non',
#   'sum',
#   'expedio',
#   'scio',
#   'quando',
#   'aeger',
#   'febricito',
#   'quando',
#   'bonus',
#   'sum',
#   'quando',
#   'deficio',
#   'sine',
#   'quis#2',
#   'dispensari',
#   'ille',
#   'non',
#   'possum'],
#  ['venio',
#   'enim',
#   'multus',
#   'credo',
#   'fallax',
#   'reus',
#   'quia',
#   'saepe',
#   'iste',
#   'lenis',
#   'celerioresve',
#   'sum',
#   'et',
#   'aetas',
#   'et',
#   'sexu',
#   'et',
#   'corpus',
#   'natura'],
#  ['et',
#   'plerumque',
#   'satis',
#   'sanus',
#   'corpus',
#   'si',
#   'stomachus',
#   'infirmus',
#   'sum',
#   'nonnumquam',
#   'etiam',
#   'incipio',
#   'febre',
#   'subeo',
#   'et',
#   'quiesco',
#   'ut',
#   'inbecillus',
#   'is',
#   'video',
#   'possum',
#   'quis#2',
#   'facilis',
#   'fero',
#   'gravis',
#   'insto',
#   'accessio'],
#  ['contra',
#   'saepe',
#   'is',
#   'concito',
#   'solo',
#   'balneum',
#   'et',
#   'exercitatio',
#   'et',
#   'metus',
#   'et',
#   'ira',
#   'et',
#   'quilibet',
#   'alius',
#   'animus',
#   'adficio',
#   'adeo#2',
#   'ut',
#   'cum',
#   'primus',
#   'medicus',
#   'venio',
#   'sollicitudo',
#   'aeger',
#   'dubito',
#   'quomodo',
#   'ille',
#   'se',
#   'habeo',
#   'video',
#   'is',
#   'moveo'],
#  ['ob',
#   'quis',
#   'causa',
#   'peritus',
#   'medicus',
#   'sum',
#   'non',
#   'protinus',
#   'ut',
#   'venio',
#   'apprehendo',
#   'manus',
#   'bracchium',
#   'sed',
#   'primus',
#   'desideo',
#   'hilaris',
#   'vultus',
#   'percontarique',
#   'quemadmodum',
#   'se',
#   'habeo',
#   'et',
#   'si',
#   'quis#2',
#   'is',
#   'metus',
#   'sum',
#   'is',
#   'probabilis',
#   'sermo',
#   'lenio',
#   'tum',
#   'deinde',
#   'is',
#   'corpus',
#   'manus',
#   'admoveo'],
#  ['qui',
#   'vena',
#   'autem',
#   'conspicio',
#   'medicus',
#   'moveo',
#   'quam#4',
#   'facilis',
#   'mille',
#   'res',
#   'turbo'],
#  ['alter',
#   'res',
#   'sum',
#   'quis#2',
#   'credo',
#   'calor',
#   'aequus',
#   'fallax',
#   'namque',
#   'hic',
#   'quoque',
#   'excito',
#   'aestus',
#   'labor',
#   'somnus',
#   'metus',
#   'sollicitudine'],
#  ['intuor',
#   'quidem',
#   'etiam',
#   'iste',
#   'oportet',
#   'sed',
#   'is',
#   'non',
#   'omnis',
#   'credo'],
#  ['atque',
#   'protinus',
#   'quidem',
#   'scio',
#   'sum',
#   'non',
#   'febricito',
#   'is',
#   'quis#2',
#   'vena',
#   'naturalis',
#   'ordino',
#   'sum',
#   'teporque',
#   'talis',
#   'sum',
#   'qualis',
#   'sum',
#   'sanus',
#   'solo',
#   'non',
#   'protinus',
#   'autem',
#   'sub',
#   'calor',
#   'motuque',
#   'febrem',
#   'sum',
#   'concipio',
#   'sed',
#   'ita',
#   'si',
#   'summa',
#   'quoque',
#   'aridus',
#   'inaequalis',
#   'cutis',
#   'sum',
#   'si',
#   'calor',
#   'et',
#   'in',
#   'frons#2',
#   'sum',
#   'et',
#   'ex',
#   'imum',
#   'praecordiis',
#   'orior',
#   'si',
#   'spiritus',
#   'ex',
#   'naribus',
#   'cum',
#   'fervor',
#   'prorumpo',
#   'si',
#   'color',
#   'aut',
#   'rubor',
#   'aut',
#   'pallor',
#   'novus',
#   'mutatus',
#   'sum',
#   'si',
#   'oculus',
#   'gravis',
#   'et',
#   'aut',
#   'persicci',
#   'aut',
#   'subumidi',
#   'sum',
#   'si',
#   'sudor',
#   'cum',
#   'sum',
#   'inaequalis',
#   'sum',
#   'si',
#   'vena',
#   'non',
#   'aequalis',
#   'intervallum',
#   'moveo'],
#  ['ob',
#   'quis',
#   'causa',
#   'medicus',
#   'neque',
#   'in',
#   'tenebrae',
#   'neque',
#   'ab',
#   'caput',
#   'aeger',
#   'debeo',
#   'resideo',
#   'sed',
#   'inlustri',
#   'locus',
#   'adversus',
#   'ut',
#   'omnis',
#   'notus',
#   'ex',
#   'vultus',
#   'quoque',
#   'cubo',
#   'percipio'],
#  ['ubi',
#   'verus',
#   'febris',
#   'sum',
#   'atque',
#   'decerno',
#   'exspecto',
#   'oportet',
#   'num',
#   'tempus',
#   'partesve',
#   'corpus',
#   'alius',
#   'paul(l)um',
#   'madesco',
#   'quis#2',
#   'sudor',
#   'venio',
#   'sum',
#   'testo',
#   'atque',
#   'si',
#   'qui',
#   'notus',
#   'sum',
#   'tum',
#   'demum',
#   'do',
#   'possum',
#   'aqua',
#   'calida',
#   'quis#2',
#   'salubris',
#   'efficio',
#   'sum',
#   'si',
#   'sudor',
#   'per',
#   'omnis',
#   'membrum',
#   'diffundo'],
#  ['hic',
#   'autem',
#   'reus',
#   'causa',
#   'contineo',
#   'aeger',
#   'sub',
#   'vestis',
#   'satis',
#   'multus',
#   'manus',
#   'debeo',
#   'eademque',
#   'crus',
#   'pedesque',
#   'contego',
#   'qui',
#   'male',
#   'plerusque',
#   'aeger',
#   'in',
#   'ipse',
#   'febris',
#   'impetus',
#   'pessimeque',
#   'ubi',
#   'ardeo',
#   'is',
#   'sum',
#   'male',
#   'habeo'],
#  ['si',
#   'sudo',
#   'corpus',
#   'coepio',
#   'linteum',
#   'tepefacio',
#   'oportet',
#   'paulatimque',
#   'singulus',
#   'membrum',
#   'detergeo'],
#  ['at',
#   'ubi',
#   'sudor',
#   'omnis',
#   'finio',
#   'sum',
#   'aut',
#   'si',
#   'is',
#   'non',
#   'venio',
#   'ubi',
#   'quam#4',
#   'multus',
#   'possum',
#   'idoneus',
#   'sum',
#   'cibus',
#   'aeger',
#   'video',
#   'leviter',
#   'sub',
#   'vestis',
#   'ungo',
#   'sum',
#   'tum',
#   'detergeo',
#   'deinde',
#   'is',
#   'cibus',
#   'do'],
#  ['cibus',
#   'autem',
#   'febricito',
#   'umidus',
#   'sum',
#   'aptus',
#   'aut',
#   'umor',
#   'certus',
#   'quam#4',
#   'proximus',
#   'utique#2',
#   'ex',
#   'materia',
#   'quam#4',
#   'levis',
#   'maximeque',
#   'sorbitio',
#   'eaque',
#   'si',
#   'magnus',
#   'febres',
#   'sum',
#   'quam#4',
#   'tenuis',
#   'sum',
#   'debeo'],
#  ['mel',
#   'quoque',
#   'despumatum',
#   'hic',
#   'rectus',
#   'adicio',
#   'quo',
#   'corpus',
#   'magis',
#   'nutrio',
#   'sed',
#   'is',
#   'si',
#   'stomachus',
#   'offendo',
#   'supervacuus',
#   'sum',
#   'sicut',
#   'ipse',
#   'quoque',
#   'sorbitio'],
#  ['do',
#   'verus',
#   'in',
#   'vicis',
#   'is',
#   'possum',
#   'vel',
#   'intritus',
#   'ex',
#   'aqua',
#   'calida',
#   'vel',
#   'halica',
#   'elota',
#   'si',
#   'firmus',
#   'sum',
#   'stomachus',
#   'et',
#   'compressus',
#   'alvus',
#   'ex',
#   'aqua',
#   'mulsa',
#   'si',
#   'vel',
#   'ille',
#   'langueo',
#   'vel',
#   'hic',
#   'profluo',
#   'ex',
#   'posca'],
#  ['et',
#   'primus',
#   'quidem',
#   'cibus',
#   'is',
#   'satis',
#   'sum',
#   'secundus',
#   'verus',
#   'aliquis',
#   'adicio',
#   'possum',
#   'ex',
#   'idem',
#   'tamen',
#   'genus',
#   'materia',
#   'vel',
#   'holus',
#   'vel',
#   'conchylium',
#   'vel',
#   'pomum'],
#  ['et',
#   'dum',
#   'febres',
#   'quidem',
#   'incresco',
#   'hic',
#   'solus',
#   'cibus',
#   'idoneus',
#   'sum',
#   'ubi',
#   'verus',
#   'aut',
#   'desino',
#   'aut',
#   'levo',
#   'semper',
#   'quidem',
#   'incipio',
#   'sum',
#   'ab',
#   'aliquis',
#   'ex',
#   'materia',
#   'levis',
#   'adicio',
#   'verus',
#   'aliquis',
#   'ex',
#   'medius',
#   'ratio',
#   'habeo',
#   'subinde',
#   'et',
#   'vis',
#   'homo',
#   'et',
#   'morbus'],
#  ['pono',
#   'verus',
#   'aegrum',
#   'varius',
#   'cibus',
#   'sicut',
#   'Asclepiades',
#   'praecipio',
#   'tum',
#   'demum',
#   'sum',
#   'ubi',
#   'fastidium',
#   'urgeo',
#   'neque',
#   'satis',
#   'vis',
#   'sufficio',
#   'ut',
#   'paul(l)um',
#   'ex',
#   'singulus',
#   'degusto',
#   'fames',
#   'vito'],
#  ['at',
#   'si',
#   'neque',
#   'volo#1',
#   'neque',
#   'cupiditas',
#   'desum',
#   'nullus',
#   'varietas',
#   'sollicito',
#   'aeger',
#   'sum',
#   'ne#2',
#   'plus',
#   'adsumo',
#   'quam#4',
#   'concoquo'],
#  ['neque',
#   'verus',
#   'sum',
#   'quod',
#   'ab',
#   'is',
#   'dico#2',
#   'facilis',
#   'concoqui',
#   'cibus',
#   'varius',
#   'edo',
#   'enim',
#   'facilis',
#   'ad',
#   'concoctio',
#   'autem',
#   'materia',
#   'genus',
#   'et',
#   'modus',
#   'pertineo'],
#  ['neque',
#   'inter',
#   'magnus',
#   'dolor',
#   'neque',
#   'incresco',
#   'morbus',
#   'tutus',
#   'sum',
#   'aegrum',
#   'cibus',
#   'impleo',
#   'sed',
#   'ubi',
#   'inclino',
#   'iam',
#   'in',
#   'bonus',
#   'valetudo',
#   'sum'],
#  ['sum', 'alius', 'quoque', 'in', 'febris', 'observatio', 'necessaria'],
#  ['atque',
#   'is',
#   'quoque',
#   'video',
#   'sum',
#   'quod',
#   'quidam',
#   'solus',
#   'praecipio',
#   'adstringo',
#   'corpus',
#   'sum',
#   'an',
#   'profluo',
#   'quis#2',
#   'alter',
#   'strangulo',
#   'alter',
#   'digero'],
#  ['nam',
#   'si',
#   'adstringo',
#   'sum',
#   'duco',
#   'alvus',
#   'sum',
#   'moveo',
#   'urina',
#   'elicio',
#   'omnis',
#   'modus',
#   'sudor'],
#  ['in',
#   'hic',
#   'genus',
#   'morbus',
#   'emitto',
#   'sanguis',
#   'concutio',
#   'vehemens',
#   'gestatio',
#   'corpus',
#   'in',
#   'lumen',
#   'habeo',
#   'imperasse',
#   'fames',
#   'sitis',
#   'vigilia',
#   'prosum'],
#  ['utilis',
#   'sum',
#   'etiam',
#   'duco',
#   'in',
#   'balneum',
#   'prius',
#   'demitto',
#   'in',
#   'solium',
#   'tum',
#   'ungo',
#   'iterum',
#   'ad',
#   'solium',
#   'redeo',
#   'multus',
#   'aqua',
#   'foveo',
#   'inguina',
#   'interdum',
#   'etiam',
#   'oleum',
#   'in',
#   'solium',
#   'cum',
#   'aqua',
#   'calida',
#   'misceo',
#   'uti',
#   'cibus',
#   'serus',
#   'et',
#   'rarus',
#   'tenuis',
#   'simplex',
#   'mollis',
#   'calidus',
#   'exiguus',
#   'maximeque',
#   'holus',
#   'qualis',
#   'sum',
#   'lapatium',
#   'urtica',
#   'malva',
#   'vel',
#   'jus',
#   'etiam',
#   'concha',
#   'musculorumve',
#   'aut',
#   'locusta',
#   'neque',
#   'do',
#   'caro',
#   'nisi',
#   'elixus',
#   'sum'],
#  ['at',
#   'potio',
#   'sum',
#   'debeo',
#   'magis',
#   'liberalis',
#   'et',
#   'ante',
#   'cibus',
#   'et',
#   'post',
#   'hic',
#   'et',
#   'cum',
#   'hic',
#   'ultra',
#   'quam#4',
#   'sum',
#   'cogo'],
#  ['Poteritque',
#   'ab',
#   'balineo',
#   'etiam',
#   'pinguis',
#   'aut',
#   'dulcis',
#   'do',
#   'vinum',
#   'possum',
#   'semel',
#   'aut',
#   'bis',
#   'interpono',
#   'Graecus',
#   'salio'],
#  ['contra',
#   'verus',
#   'si',
#   'corpus',
#   'profluo',
#   'sudor',
#   'coerceo',
#   'requies',
#   'habeo',
#   'sum',
#   'tenebrae',
#   'somnoque',
#   'quandoque',
#   'volo',
#   'utor',
#   'non',
#   'nisi',
#   'lenis',
#   'gestatio',
#   'corpus',
#   'agito',
#   'et',
#   'pro',
#   'genus',
#   'malus',
#   'subvenio'],
#  ['nam',
#   'si',
#   'venter',
#   'fluo',
#   'aut',
#   'si',
#   'stomachus',
#   'non',
#   'contineo',
#   'ubi',
#   'febris',
#   'decerno',
#   'liberaliter',
#   'oportet',
#   'aqua',
#   'tepidus',
#   'possum',
#   'do',
#   'et',
#   'vomo',
#   'cogo',
#   'nisi',
#   'aut',
#   'fauces',
#   'aut',
#   'praecordia',
#   'aut',
#   'latus#2',
#   'doleo',
#   'aut',
#   'vetus',
#   'morbus',
#   'sum'],
#  ['si',
#   'verus',
#   'sudor',
#   'exerceo',
#   'duro',
#   'cutis',
#   'sum',
#   'nitrum',
#   'vel',
#   'sale',
#   'quis#2',
#   'cum',
#   'oleum',
#   'misceo',
#   'atque',
#   'si',
#   'levis',
#   'is',
#   'vitium',
#   'sum',
#   'oleum',
#   'corpus',
#   'ungo',
#   'si',
#   'vehemens',
#   'rosa',
#   'vel',
#   'melinus',
#   'vel',
#   'murteo',
#   'quis#2',
#   'vinum',
#   'austerus',
#   'sum',
#   'adicio'],
#  ['quisquis',
#   'autem',
#   'fluor',
#   'aeger',
#   'sum',
#   'cum',
#   'venio',
#   'in',
#   'balineum',
#   'prius',
#   'ungo',
#   'deinde',
#   'in',
#   'solium',
#   'demitto',
#   'sum'],
#  ['si',
#   'in',
#   'cute',
#   'vitium',
#   'sum',
#   'frigidus',
#   'quoque',
#   'quam#4',
#   'calida',
#   'aqua',
#   'melius',
#   'utor'],
#  ['ubi',
#   'ad',
#   'cibus',
#   'venio',
#   'sum',
#   'do',
#   'debeo',
#   'is',
#   'valeo',
#   'frigidus',
#   'siccus',
#   'simplex',
#   'quis#2',
#   'quam#4',
#   'parum',
#   'corrumpo',
#   'possum',
#   'panus',
#   'torreo',
#   'caro',
#   'assum',
#   'vinum',
#   'austerus',
#   'vel',
#   'certus',
#   'subausterum',
#   'si',
#   'venter',
#   'profluo',
#   'calidus',
#   'si',
#   'sudor',
#   'noceo',
#   'vomitusve',
#   'sum',
#   'frigidus'],
#  ['ab'],
#  ['desidero',
#   'quoque',
#   'proprius',
#   'animadvorsionem',
#   'in',
#   'febris',
#   'pestilentia',
#   'casus'],
#  ['in',
#   'hic',
#   'utilis',
#   'parum',
#   'sum',
#   'aut',
#   'fames',
#   'aut',
#   'medicamentum',
#   'uti',
#   'aut',
#   'duco',
#   'alvus'],
#  ...]

# %% [markdown]
# Following the findings of Sprugnoli et al. (2019) and Ribary & McGillivray (2020), for each subcorpus I train a fasttext model:

# %% [markdown]
# Start with the first subcorpus:
# Barbara: "The corpus is small and the fasttext seems to prefer orthographic similarity with smaller min_counts. We're not interested in dies being similar to rabies, but rather dies being similar to annus or mensis. So, we have two options: we may either turn off the subwords or apply high frequency threshold (but we're going to loose low-frequency terms)"
#
# Try excluding subwords and setting minimal frequency to 5 (see experiment on embeddings for the full corpus with "causa": ideal combination of parameters is max_n=0, min_n=0, min_count=5

# %%
start = time.time()
#model = gensim.models.Word2Vec(time2corpus[0], min_count=5, vector_size=100, window = 10, sg = 1)
start = time.time()
model = FastText(vector_size=100, window=5, min_count=5, workers=1, seed=1, hashfxn=hash, min_n=0, max_n=0)
model.build_vocab(corpus_iterable=subcorpus2corpus[0])
model.train(corpus_iterable=subcorpus2corpus[0], total_examples=model.corpus_count, epochs=5)
end = time.time()
print("It has taken", round(end - start), "seconds")
model.wv.similar_by_word('causa', 10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-c84169939220> in <module>
#       4 model = FastText(vector_size=100, window=5, min_count=5, workers=1, seed=1, hashfxn=hash, min_n=0, max_n=0)
#       5 model.build_vocab(corpus_iterable=subcorpus2corpus[0])
# ----> 6 model.train(corpus_iterable=subcorpus2corpus[0], total_examples=model.corpus_count, epochs=5)
#       7 end = time.time()
#       8 print("It has taken", round(end - start), "seconds")
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/models/word2vec.py in train(self, corpus_iterable, corpus_file, total_examples, total_words, epochs, start_alpha, end_alpha, word_count, queue_factor, report_delay, compute_loss, callbacks, **kwargs)
#    1063                     corpus_iterable, cur_epoch=cur_epoch, total_examples=total_examples,
#    1064                     total_words=total_words, queue_factor=queue_factor, report_delay=report_delay,
# -> 1065                     callbacks=callbacks, **kwargs)
#    1066             else:
#    1067                 trained_word_count_epoch, raw_word_count_epoch, job_tally_epoch = self._train_epoch_corpusfile(
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/models/word2vec.py in _train_epoch(self, data_iterable, cur_epoch, total_examples, total_words, queue_factor, report_delay, callbacks)
#    1423         trained_word_count, raw_word_count, job_tally = self._log_epoch_progress(
#    1424             progress_queue, job_queue, cur_epoch=cur_epoch, total_examples=total_examples,
# -> 1425             total_words=total_words, report_delay=report_delay, is_corpus_file_mode=False,
#    1426         )
#    1427
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/models/word2vec.py in _log_epoch_progress(self, progress_queue, job_queue, cur_epoch, total_examples, total_words, report_delay, is_corpus_file_mode)
#    1276
#    1277         while unfinished_worker_count > 0:
# -> 1278             report = progress_queue.get()  # blocks if workers too slow
#    1279             if report is None:  # a thread reporting that it finished
#    1280                 unfinished_worker_count -= 1
#
# ~/anaconda3/lib/python3.7/queue.py in get(self, block, timeout)
#     168             elif timeout is None:
#     169                 while not self._qsize():
# --> 170                     self.not_empty.wait()
#     171             elif timeout < 0:
#     172                 raise ValueError("'timeout' must be a non-negative number")
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
print_vocab(model, 10)
# Out:
# word #0/33583 is et
# word #1/33583 is sum
# word #2/33583 is in
# word #3/33583 is quis#2
# word #4/33583 is is
# word #5/33583 is non
# word #6/33583 is hic
# word #7/33583 is ad
# word #8/33583 is ut

# %% [markdown]
# Another test with "sum"

# %%
model.wv.similar_by_word('sum', 10)
# Out:
# [('appareo', 0.5292460918426514),
#  ('habeo', 0.517448902130127),
#  ('existo', 0.5027661919593811),
#  ('invenio', 0.48599913716316223),
#  ('permaneo', 0.4838952422142029),
#  ('iudico', 0.48345261812210083),
#  ('indigeo', 0.48066267371177673),
#  ('contingo', 0.4800867736339569),
#  ('praecedo', 0.467045396566391),
#  ('nasco', 0.46400588750839233)]

# %% [markdown]
# Additionally, we could set a higher frequency threshold, but that we would lose low-frequency terms: with minimal frequency = 50

# %%
start = time.time()
#model = gensim.models.Word2Vec(time2corpus[0], min_count=5, vector_size=100, window = 10, sg = 1)
start = time.time()
model = FastText(vector_size=100, window=5, min_count=50, workers=1, seed=1, hashfxn=hash, max_n=0) 
model.build_vocab(corpus_iterable=subcorpus2corpus[0])
model.train(corpus_iterable=subcorpus2corpus[0], total_examples=model.corpus_count, epochs=5)
end = time.time()
print("It has taken", round(end - start), "seconds")
model.wv.similar_by_word('causa', 10)
# Out:
# It has taken 66 seconds
# [('lite', 0.6106802225112915),
#  ('accusatio', 0.6002997159957886),
#  ('disceptatio', 0.5790320038795471),
#  ('ratio', 0.5747724771499634),
#  ('defensio', 0.5611129403114319),
#  ('deliberatio', 0.5604794025421143),
#  ('probatio', 0.5601478815078735),
#  ('quaestio', 0.5547122955322266),
#  ('culpa', 0.5457818508148193),
#  ('crimen', 0.5342454314231873)]

# %% [markdown]
# ### Train one model for each subcorpus
# I now train one model for each subcorpus (medical vs. non medical): set minimal frequency 5 and exclude subwords

# %%
len(subcorpus2corpus)
# Out:
# 2

# %%
models = list()
start = time.time()
for s in range(len(subcorpus2corpus)):
    if len(subcorpus2corpus[s])>0:
        print(s)
        #model = gensim.models.Word2Vec(time2corpus[0][0], min_count=1, vector_size=300, window = 5, sg = 0)
        model = FastText(vector_size=100, window=5, min_count=5, workers=1, seed=1, hashfxn=hash, max_n=0, min_n=0)  # instantiate
        model.build_vocab(corpus_iterable=subcorpus2corpus[s])
        model.train(corpus_iterable=subcorpus2corpus[s], total_examples=len(subcorpus2corpus[s]), epochs=10)  # train
        models.append(model)
        #model = fasttext.train_unsupervised(time2corpus[0][0], model='skipgram')
end = time.time()
print("It has taken", round(end - start), "seconds, or ", round((end - start)/60), "minutes")
# Out:
# 0
# 1
# It has taken 198 seconds, or  3 minutes

# %% [markdown]
# Check on the two models

# %%
print_vocab(models[0], 20)
# Out:
# word #0/33583 is et
# word #1/33583 is sum
# word #2/33583 is in
# word #3/33583 is quis#2
# word #4/33583 is is
# word #5/33583 is non
# word #6/33583 is hic
# word #7/33583 is ad
# word #8/33583 is ut
# word #9/33583 is ab
# word #10/33583 is cum
# word #11/33583 is ille
# word #12/33583 is omnis
# word #13/33583 is dico#2
# word #14/33583 is quod
# word #15/33583 is suus
# word #16/33583 is de
# word #17/33583 is si
# word #18/33583 is ego

# %% [markdown]
# ## Check malus

# %%
models[0].wv.similar_by_word('malus', 10)
# Out:
# [('malus#3', 0.7445393800735474),
#  ('deterior', 0.6224241256713867),
#  ('publicatio', 0.550349771976471),
#  ('conscientia', 0.5132147073745728),
#  ('fraudis', 0.503659725189209),
#  ('invidus', 0.5022456645965576),
#  ('malignitas', 0.48834073543548584),
#  ('nequitia', 0.48028719425201416),
#  ('malitia', 0.47844555974006653),
#  ('pessimi', 0.4778210520744324)]

# %%
print_vocab(models[1], 20)
# Out:
# word #0/2122 is sum
# word #1/2122 is et
# word #2/2122 is is
# word #3/2122 is in
# word #4/2122 is quis#2
# word #5/2122 is si
# word #6/2122 is ex
# word #7/2122 is hic
# word #8/2122 is vel
# word #9/2122 is non
# word #10/2122 is aut
# word #11/2122 is quod
# word #12/2122 is ut
# word #13/2122 is cum
# word #14/2122 is ad
# word #15/2122 is ab
# word #16/2122 is quoque
# word #17/2122 is sed
# word #18/2122 is etiam

# %%
models[1].wv.similar_by_word('malus', 10)
# Out:
# [('difficultas', 0.9630550742149353),
#  ('articulus', 0.9567130208015442),
#  ('consuesco', 0.9554041624069214),
#  ('male', 0.9552204012870789),
#  ('urina', 0.9537398219108582),
#  ('voluntas', 0.9534554481506348),
#  ('spes', 0.9531292915344238),
#  ('sensus', 0.9526328444480896),
#  ('insania', 0.9525879621505737),
#  ('vesica', 0.9525068998336792)]

# %% [markdown]
# ## Check potio

# %%
models[0].wv.similar_by_word('potio', 10)
# Out:
# [('potus', 0.596651554107666),
#  ('sopio', 0.5308095216751099),
#  ('quies', 0.5303115844726562),
#  ('medicamentum', 0.5270382165908813),
#  ('cibus', 0.5206639766693115),
#  ('satio', 0.515001654624939),
#  ('potionis', 0.5114859342575073),
#  ('somnoque', 0.5112212896347046),
#  ('haurio', 0.5046415328979492),
#  ('adlici', 0.4984215795993805)]

# %%
models[1].wv.similar_by_word('potio', 10)
# Out:
# [('utor', 0.9829772114753723),
#  ('abstineo', 0.9741743803024292),
#  ('pridie', 0.9734511971473694),
#  ('uti', 0.9712179899215698),
#  ('egelidus', 0.9695520401000977),
#  ('adsumo', 0.9688200354576111),
#  ('acer', 0.9610457420349121),
#  ('sumo', 0.9605630040168762),
#  ('modicus', 0.9598569869995117),
#  ('debeo', 0.9592777490615845)]

# %% [markdown]
# ## Check lenticula

# %%
models[0].wv.similar_by_word('lenticula', 10)
# Out:
# [('perunges', 0.8608763813972473),
#  ('asperso', 0.8605087995529175),
#  ('cyperum', 0.8578701019287109),
#  ('defritum', 0.8502394556999207),
#  ('porrus', 0.8457130789756775),
#  ('anethum', 0.8446499109268188),
#  ('puleium', 0.8427358269691467),
#  ('asperges', 0.841949999332428),
#  ('silfi', 0.8419413566589355),
#  ('pisum', 0.8400180339813232)]

# %%
models[1].wv.similar_by_word('lenticula', 10)
# Out:
# [('lac', 0.9950354695320129),
#  ('ruta', 0.9947835803031921),
#  ('olea', 0.99403315782547),
#  ('marrubium', 0.9940274357795715),
#  ('rubus', 0.9916974902153015),
#  ('adjicio', 0.9916856288909912),
#  ('sucidus', 0.9906005263328552),
#  ('malicorium', 0.9898480772972107),
#  ('farina', 0.9896025061607361),
#  ('furfur', 0.9895826578140259)]

# %% [markdown]
# ## Check Impetus

# %%
models[0].wv.similar_by_word('impetus', 10)
# Out:
# [('eruptio', 0.718285858631134),
#  ('incursus', 0.6353676319122314),
#  ('concursus', 0.6190795302391052),
#  ('acriter', 0.5763891339302063),
#  ('concito', 0.5652066469192505),
#  ('uiribus', 0.560851514339447),
#  ('pavor', 0.5604428648948669),
#  ('perrumpo', 0.559894323348999),
#  ('inpetu', 0.5539030432701111),
#  ('rabies', 0.5501555800437927)]

# %%
models[1].wv.similar_by_word('impetus', 10)
# Out:
# [('scroto', 0.997705340385437),
#  ('iacio', 0.9975391626358032),
#  ('inbecillitas', 0.9973631501197815),
#  ('mature', 0.9973325133323669),
#  ('mano', 0.9972262382507324),
#  ('numquam', 0.9970070719718933),
#  ('aliquando', 0.9968353509902954),
#  ('vaco', 0.996812105178833),
#  ('muto', 0.9967483878135681),
#  ('totus', 0.9967460632324219)]

# %% [markdown]
# ## Check Plaga

# %%
models[0].wv.similar_by_word('plaga', 10)
# Out:
# [('contritio', 0.49932730197906494),
#  ('septentrionalis', 0.47354528307914734),
#  ('aquilo', 0.4706868827342987),
#  ('pessima', 0.4643608033657074),
#  ('septentrionem', 0.4558558166027069),
#  ('meridies', 0.4414684474468231),
#  ('desolo', 0.43876615166664124),
#  ('serpens', 0.43028056621551514),
#  ('languor', 0.43025338649749756),
#  ('sibilo', 0.4296463131904602)]

# %%
models[1].wv.similar_by_word('plaga', 10)
# Out:
# [('crus', 0.9959562420845032),
#  ('ibi', 0.994205892086029),
#  ('scalpellum', 0.9938284158706665),
#  ('extendo', 0.9937617182731628),
#  ('descendo', 0.9934535622596741),
#  ('excidium', 0.993284285068512),
#  ('ergo', 0.9932499527931213),
#  ('proximus', 0.9931142330169678),
#  ('integer', 0.9930745363235474),
#  ('iacio', 0.9929271936416626)]

# %% [markdown]
# ## Check anus

# %%
models[0].wv.similar_by_word('anus', 10)
# Out:
# [('formosus', 0.7208097577095032),
#  ('nutrico', 0.7165568470954895),
#  ('delicatus', 0.6415420770645142),
#  ('mamma', 0.6402621269226074),
#  ('virguncula', 0.6257895827293396),
#  ('nutrix', 0.6114704012870789),
#  ('Sabina', 0.6049647331237793),
#  ('lacto', 0.5958934426307678),
#  ('puella', 0.5957138538360596),
#  ('thalamus', 0.5906150341033936)]

# %%
models[1].wv.similar_by_word('anus', 10)
# Out:
# [('maxilla', 0.9982499480247498),
#  ('inguen', 0.9979749917984009),
#  ('iuxta', 0.9974749088287354),
#  ('ferramentum', 0.9971880912780762),
#  ('scrotum', 0.9971383213996887),
#  ('antequam', 0.9969991445541382),
#  ('vinculum', 0.9969804883003235),
#  ('glutino', 0.9967426061630249),
#  ('sedeo', 0.9965815544128418),
#  ('vulnero', 0.9965251684188843)]

# %% [markdown]
# ## Check Aranea

# %%
models[0].wv.similar_by_word('aranea', 10)
# Out:
# [('pharetra', 0.6134344339370728),
#  ('vibro', 0.6050527095794678),
#  ('transfigo', 0.6030136346817017),
#  ('sulpur', 0.5997458696365356),
#  ('hastile', 0.5971342325210571),
#  ('texentium', 0.5743292570114136),
#  ('stipula', 0.5697602033615112),
#  ('ferrum', 0.5689342617988586),
#  ('liciatorium', 0.5648847818374634),
#  ('spiculus', 0.5626999139785767)]

# %%
models[1].wv.similar_by_word('aranea', 10)
# Out:
# [('emortuus', 0.0),
#  ('neve', 0.0),
#  ('contusum', 0.0),
#  ('hyoscyamus', 0.0),
#  ('linamentis', 0.0),
#  ('ater', 0.0),
#  ('masculus', 0.0),
#  ('caldus', 0.0),
#  ('desido', 0.0),
#  ('pilus#2', 0.0)]

# %% [markdown]
# ## Check Cancer

# %%
models[0].wv.similar_by_word('cancer', 10)
# Out:
# [('aequinoctialis', 0.7350070476531982),
#  ('Capricornus', 0.7211254239082336),
#  ('lune', 0.7174912691116333),
#  ('Chelis', 0.7116904854774475),
#  ('exortus', 0.7026336193084717),
#  ('Orion', 0.6997062563896179),
#  ('Hydrae', 0.696772038936615),
#  ('Cancri', 0.6959371566772461),
#  ('brumalis', 0.676031231880188),
#  ('exoriri', 0.6754188537597656)]

# %%
models[1].wv.similar_by_word('cancer', 10)
# Out:
# [('perniciosus', 0.9970979690551758),
#  ('muto', 0.9970343112945557),
#  ('abscido', 0.9969481825828552),
#  ('animal', 0.9968684315681458),
#  ('vetustas', 0.9966973066329956),
#  ('afficio', 0.9966148734092712),
#  ('occupo', 0.9965019226074219),
#  ('desum', 0.9964045882225037),
#  ('vinculum', 0.9962295889854431),
#  ('caelum', 0.9959255456924438)]

# %% [markdown]
# ## Check Caninus

# %%
models[0].wv.similar_by_word('caninus', 10)
# Out:
# [('palo', 0.7080064415931702),
#  ('palustrem', 0.7017350196838379),
#  ('unctus', 0.6942863464355469),
#  ('sucidus', 0.6911542415618896),
#  ('pampinus', 0.6911504864692688),
#  ('myrteum', 0.6873365044593811),
#  ('caedito', 0.686789333820343),
#  ('refoveo', 0.686775803565979),
#  ('Arsa', 0.6860144138336182),
#  ('balsamum', 0.6847855448722839)]

# %%
models[1].wv.similar_by_word('caninus', 10)
# Out:
# [('emortuus', 0.0),
#  ('neve', 0.0),
#  ('contusum', 0.0),
#  ('hyoscyamus', 0.0),
#  ('linamentis', 0.0),
#  ('ater', 0.0),
#  ('masculus', 0.0),
#  ('caldus', 0.0),
#  ('desido', 0.0),
#  ('pilus#2', 0.0)]

# %% [markdown]
# ## Colis

# %%
models[0].wv.similar_by_word('caulis', 10)
# Out:
# [('baiulum', 0.0),
#  ('vicissimque', 0.0),
#  ('auferendo', 0.0),
#  ('turbavere', 0.0),
#  ('deprecarentur', 0.0),
#  ('Parmenion', 0.0),
#  ('potentum', 0.0),
#  ('destructor', 0.0),
#  ('osteum', 0.0),
#  ('Clausus', 0.0)]

# %%
models[1].wv.similar_by_word('caulis', 10)
# Out:
# [('emortuus', 0.0),
#  ('neve', 0.0),
#  ('contusum', 0.0),
#  ('hyoscyamus', 0.0),
#  ('linamentis', 0.0),
#  ('ater', 0.0),
#  ('masculus', 0.0),
#  ('caldus', 0.0),
#  ('desido', 0.0),
#  ('pilus#2', 0.0)]

# %% [markdown]
# ## Fistula

# %%
models[0].wv.similar_by_word('fistula', 10)
# Out:
# [('vicenum', 0.7571058869361877),
#  ('centenum', 0.727862536907196),
#  ('modulus', 0.7275359630584717),
#  ('diametrum', 0.7077943682670593),
#  ('plumbea', 0.7031548023223877),
#  ('vicenarius', 0.6905785799026489),
#  ('semuncia', 0.6882086992263794),
#  ('pertundito', 0.6747350692749023),
#  ('crocus', 0.6727489829063416),
#  ('quadratus', 0.6727017164230347)]

# %%
models[1].wv.similar_by_word('fistula', 10)
# Out:
# [('abscido', 0.9949777722358704),
#  ('patefacio', 0.9944912195205688),
#  ('membrana', 0.994250476360321),
#  ('vinculum', 0.9940910935401917),
#  ('cancer', 0.9940453171730042),
#  ('rumpo', 0.9939383268356323),
#  ('naturalis', 0.9937660694122314),
#  ('quicumque', 0.9937065243721008),
#  ('talus', 0.9936233758926392),
#  ('ala', 0.9935315847396851)]

# %% [markdown]
# ## Folliculus

# %%
models[0].wv.similar_by_word('folliculus', 10)
# Out:
# [('pampinus', 0.8198416829109192),
#  ('pineum', 0.8055068850517273),
#  ('furfur', 0.8008548617362976),
#  ('citrum', 0.796357274055481),
#  ('callosus', 0.7912360429763794),
#  ('lupinus', 0.7903788089752197),
#  ('ficos', 0.787680983543396),
#  ('sucidus', 0.7866107821464539),
#  ('ulmeus', 0.7819167375564575),
#  ('damascena', 0.78098064661026)]

# %%
models[1].wv.similar_by_word('folliculus', 10)
# Out:
# [('emortuus', 0.0),
#  ('neve', 0.0),
#  ('contusum', 0.0),
#  ('hyoscyamus', 0.0),
#  ('linamentis', 0.0),
#  ('ater', 0.0),
#  ('masculus', 0.0),
#  ('caldus', 0.0),
#  ('desido', 0.0),
#  ('pilus#2', 0.0)]

# %% [markdown]
# ## Lumen

# %%
models[0].wv.similar_by_word('lumen', 10)
# Out:
# [('fulgor', 0.7066628932952881),
#  ('lux', 0.6773566603660583),
#  ('lucidus', 0.6475052237510681),
#  ('radius', 0.6295573115348816),
#  ('candor', 0.6255735754966736),
#  ('caligo', 0.6172627210617065),
#  ('luceo', 0.592840313911438),
#  ('inlumino', 0.5927273035049438),
#  ('splendor', 0.5899431109428406),
#  ('caliginem', 0.5879647135734558)]

# %%
models[1].wv.similar_by_word('lumen', 10)
# Out:
# [('expeditus', 0.9964432120323181),
#  ('plerumque', 0.9961612224578857),
#  ('paene', 0.9961373805999756),
#  ('restituo', 0.9958831667900085),
#  ('curiosus', 0.9958614706993103),
#  ('infans', 0.9958545565605164),
#  ('capillus', 0.9958263635635376),
#  ('adversus', 0.9957664012908936),
#  ('prolabor', 0.9956214427947998),
#  ('planta', 0.995497465133667)]

# %% [markdown]
# ## Menstrua

# %%
models[0].wv.similar_by_word('menstruus', 10)
# Out:
# [('quintadecima', 0.6784973740577698),
#  ('coagulo', 0.6650052070617676),
#  ('effluxerit', 0.6644333600997925),
#  ('caedito', 0.6587182283401489),
#  ('Octobrium', 0.6507802605628967),
#  ('seruentur', 0.6498989462852478),
#  ('putrescit', 0.6493684649467468),
#  ('decembri', 0.6474031805992126),
#  ('autumnalis', 0.6436105966567993),
#  ('uespera', 0.6390299797058105)]

# %%
models[1].wv.similar_by_word('menstruus', 10)
# Out:
# [('emortuus', 0.0),
#  ('neve', 0.0),
#  ('contusum', 0.0),
#  ('hyoscyamus', 0.0),
#  ('linamentis', 0.0),
#  ('ater', 0.0),
#  ('masculus', 0.0),
#  ('caldus', 0.0),
#  ('desido', 0.0),
#  ('pilus#2', 0.0)]

# %% [markdown]
# ## Mola

# %%
models[0].wv.similar_by_word('mola', 10)
# Out:
# [('plumbum', 0.746660053730011),
#  ('aggero', 0.7344804406166077),
#  ('cratis', 0.7252821922302246),
#  ('bitumen', 0.703269362449646),
#  ('crates', 0.7016198635101318),
#  ('asinarius', 0.7005409002304077),
#  ('funis', 0.6971569061279297),
#  ('lamminis', 0.6944992542266846),
#  ('condensus', 0.6931260228157043),
#  ('coagmento', 0.6929770112037659)]

# %%
models[1].wv.similar_by_word('mola', 10)
# Out:
# [('emortuus', 0.0),
#  ('neve', 0.0),
#  ('contusum', 0.0),
#  ('hyoscyamus', 0.0),
#  ('linamentis', 0.0),
#  ('ater', 0.0),
#  ('masculus', 0.0),
#  ('caldus', 0.0),
#  ('desido', 0.0),
#  ('pilus#2', 0.0)]

# %% [markdown]
# ## Musculus

# %%
models[0].wv.similar_by_word('musculus', 10)
# Out:
# [('cratis', 0.8192490935325623),
#  ('pluteum', 0.7833704352378845),
#  ('tabulatus', 0.7824996113777161),
#  ('ballista', 0.7676939368247986),
#  ('vimen', 0.7657342553138733),
#  ('trabes', 0.7561563849449158),
#  ('stipites', 0.7425310015678406),
#  ('sudibus', 0.7417828440666199),
#  ('tignum', 0.7387229800224304),
#  ('corium', 0.7376952171325684)]

# %%
models[1].wv.similar_by_word('musculus', 10)
# Out:
# [('rumpo', 0.9939658641815186),
#  ('incisum', 0.9939491152763367),
#  ('exeo', 0.9936187267303467),
#  ('subsum', 0.9931867122650146),
#  ('decido', 0.993084192276001),
#  ('mors', 0.992587685585022),
#  ('vitio', 0.9925201535224915),
#  ('cucurbitula', 0.9923760294914246),
#  ('appareo', 0.9922506809234619),
#  ('tumeo', 0.9920444488525391)]

# %% [markdown]
# ## Patella

# %%
models[0].wv.similar_by_word('patella', 10)
# Out:
# [('patina', 0.8819414973258972),
#  ('caccabus', 0.8786182999610901),
#  ('oenogaro', 0.8742801547050476),
#  ('mortarium', 0.8705757260322571),
#  ('frico', 0.8621558547019958),
#  ('cocta', 0.8574983477592468),
#  ('perunges', 0.8552541732788086),
#  ('liquamine', 0.8513573408126831),
#  ('surclas', 0.8509286642074585),
#  ('furnus', 0.8497797250747681)]

# %%
models[1].wv.similar_by_word('patella', 10)
# Out:
# [('emortuus', 0.0),
#  ('neve', 0.0),
#  ('contusum', 0.0),
#  ('hyoscyamus', 0.0),
#  ('linamentis', 0.0),
#  ('ater', 0.0),
#  ('masculus', 0.0),
#  ('caldus', 0.0),
#  ('desido', 0.0),
#  ('pilus#2', 0.0)]

# %% [markdown]
# ## Pecten

# %%
models[0].wv.similar_by_word('pecten', 10)
# Out:
# [('baiulum', 0.0),
#  ('vicissimque', 0.0),
#  ('auferendo', 0.0),
#  ('turbavere', 0.0),
#  ('deprecarentur', 0.0),
#  ('Parmenion', 0.0),
#  ('potentum', 0.0),
#  ('destructor', 0.0),
#  ('osteum', 0.0),
#  ('Clausus', 0.0)]

# %% [markdown]
# ## Pupilla

# %%
models[0].wv.similar_by_word('pupilla', 10)
# Out:
# [('pupillus', 0.6586187481880188),
#  ('tutor', 0.6093322038650513),
#  ('administrasse', 0.6037088632583618),
#  ('tutela', 0.5639089941978455),
#  ('obligatus', 0.5460118651390076),
#  ('curator', 0.5336513519287109),
#  ('patrona', 0.5176621675491333),
#  ('vidua', 0.5000547766685486),
#  ('pupillaris', 0.4934292137622833),
#  ('pignus', 0.48506319522857666)]

# %%
models[1].wv.similar_by_word('pupilla', 10)
# Out:
# [('commode', 0.9960851073265076),
#  ('protraho', 0.995667040348053),
#  ('exaspero', 0.995612621307373),
#  ('coicienda', 0.9955204129219055),
#  ('specillo', 0.9954385161399841),
#  ('inde', 0.995216429233551),
#  ('labrum', 0.9949774146080017),
#  ('mamma', 0.9946674108505249),
#  ('conpremo', 0.9946157932281494),
#  ('testa', 0.994404137134552)]

# %% [markdown]
# ## Scrotum

# %%
models[0].wv.similar_by_word('scrautum', 10)
# Out:
# [('baiulum', 0.0),
#  ('vicissimque', 0.0),
#  ('auferendo', 0.0),
#  ('turbavere', 0.0),
#  ('deprecarentur', 0.0),
#  ('Parmenion', 0.0),
#  ('potentum', 0.0),
#  ('destructor', 0.0),
#  ('osteum', 0.0),
#  ('Clausus', 0.0)]

# %% [markdown]
# ## Spina

# %%
models[0].wv.similar_by_word('spina', 10)
# Out:
# [('folium', 0.7782173752784729),
#  ('vepres', 0.7522402405738831),
#  ('stramentum', 0.738955020904541),
#  ('locusta', 0.7326549291610718),
#  ('oliva', 0.7314444184303284),
#  ('testa', 0.7297854423522949),
#  ('arista', 0.721219003200531),
#  ('spica', 0.7201421856880188),
#  ('granum', 0.719623863697052),
#  ('virgultum', 0.7191399931907654)]

# %%
models[1].wv.similar_by_word('spina', 10)
# Out:
# [('vertebra', 0.9980313777923584),
#  ('retundo', 0.9976984858512878),
#  ('uncus', 0.9976956248283386),
#  ('sinuo', 0.997674822807312),
#  ('apprehendo', 0.9971036911010742),
#  ('cerebrum', 0.9969908595085144),
#  ('inhaeresco', 0.9969809055328369),
#  ('costa', 0.9968867301940918),
#  ('rima', 0.9968589544296265),
#  ('transversum', 0.9968309998512268)]

# %% [markdown]
# ## Spiritus

# %%
models[0].wv.similar_by_word('spiritus', 10)
# Out:
# [('trinitas', 0.5778629779815674),
#  ('angelus', 0.5743215680122375),
#  ('Trinitatis', 0.5146111845970154),
#  ('diabolus', 0.5006036758422852),
#  ('invocatio', 0.4707029163837433),
#  ('inspiratio', 0.46047791838645935),
#  ('corruptio', 0.4583539068698883),
#  ('caro', 0.45777449011802673),
#  ('angelicus', 0.45664042234420776),
#  ('anima', 0.44951263070106506)]

# %%
models[1].wv.similar_by_word('spiritus', 10)
# Out:
# [('nam', 0.9927971959114075),
#  ('intus', 0.9913724064826965),
#  ('pus', 0.9886324405670166),
#  ('frango', 0.9884505271911621),
#  ('tumor', 0.9881983995437622),
#  ('relinquo', 0.988068163394928),
#  ('motus', 0.9880082011222839),
#  ('febre', 0.9873912930488586),
#  ('nonnumquam', 0.9869715571403503),
#  ('intendo', 0.9869352579116821)]

# %% [markdown]
# ## Tibia

# %%
models[0].wv.similar_by_word('tibia', 10)
# Out:
# [('fides#2', 0.7541792988777161),
#  ('cantus', 0.7499963641166687),
#  ('cymbalum', 0.7445164918899536),
#  ('lyra', 0.7413572072982788),
#  ('cithara', 0.7400211095809937),
#  ('tympanum', 0.7399448752403259),
#  ('tinnitus', 0.7395069003105164),
#  ('organum', 0.7257954478263855),
#  ('plectrum', 0.7043542861938477),
#  ('chorda', 0.6989166736602783)]

# %%
models[1].wv.similar_by_word('tibia', 10)
# Out:
# [('emortuus', 0.0),
#  ('neve', 0.0),
#  ('contusum', 0.0),
#  ('hyoscyamus', 0.0),
#  ('linamentis', 0.0),
#  ('ater', 0.0),
#  ('masculus', 0.0),
#  ('caldus', 0.0),
#  ('desido', 0.0),
#  ('pilus#2', 0.0)]

# %% [markdown]
# ## Vitium

# %%
models[0].wv.similar_by_word('vitium', 10)
# Out:
# [('avaritia', 0.6334289312362671),
#  ('uitiis', 0.62870192527771),
#  ('inertia', 0.6192713379859924),
#  ('vitiosus', 0.6179677248001099),
#  ('culpa', 0.6062299609184265),
#  ('stultitia', 0.6019758582115173),
#  ('malitia', 0.5940094590187073),
#  ('insolentia', 0.5920464992523193),
#  ('neglegentia', 0.5816465616226196),
#  ('nequitia', 0.5792486667633057)]

# %%
models[1].wv.similar_by_word('vitium', 10)
# Out:
# [('video', 0.9915851354598999),
#  ('ferus', 0.9847535490989685),
#  ('medicina', 0.9810498952865601),
#  ('casus', 0.9806272387504578),
#  ('sub', 0.9806148409843445),
#  ('autem', 0.9795443415641785),
#  ('incido#2', 0.978618860244751),
#  ('auxilium', 0.9781866073608398),
#  ('orior', 0.9775609374046326),
#  ('causa', 0.9765673875808716)]

# %% [markdown]
# ## Salus

# %%
models[0].wv.similar_by_word('salus', 10)
# Out:
# [('incolumitas', 0.7022579312324524),
#  ('conservo', 0.5443711280822754),
#  ('clementia', 0.4989524483680725),
#  ('periculum', 0.4911067485809326),
#  ('supplico', 0.48557671904563904),
#  ('innocentia', 0.4801259934902191),
#  ('redemptio', 0.47199010848999023),
#  ('beneficus', 0.47106367349624634),
#  ('obsecratio', 0.46735039353370667),
#  ('ultio', 0.4653434753417969)]

# %%
models[1].wv.similar_by_word('salus', 10)
# Out:
# [('tenebrae', 0.9944223761558533),
#  ('insanio', 0.994313657283783),
#  ('momentum', 0.9940486550331116),
#  ('num', 0.9936050772666931),
#  ('simplex', 0.9935969114303589),
#  ('ordo', 0.9935298562049866),
#  ('varietas', 0.9934267401695251),
#  ('sapientia', 0.9933403134346008),
#  ('expeditus', 0.9933046102523804),
#  ('penitus#3', 0.9931431412696838)]
